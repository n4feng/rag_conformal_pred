# %% [markdown]
# **HotpotQA**

# %%
import os
import sys

# Set the project root directory
project_root = os.path.abspath("..")  # Adjust this based on the notebook's location
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

file_path = "../index_store/magazine/title_text_map.txt"
wiki_embedding = WikitextsDocumentScorer()
gen = OpenAIAtomicFactGenerator()

wiki_embedding.create_embedding(file_path)
query = "Which magazine was started first Arthur\'s Magazine or First for Women?"
retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10)
print(retrieved_docs)
response = wiki_embedding.faiss_manager.generate_response_from_context(query, retrieved_docs)
print(response)
atomicFacts = gen.get_facts_from_text(response)
# Out:
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Associated texts saved to file: ../index_store/magazine/title_text_map_texts.json
# 1/11 embeddings done
# 2/11 embeddings done
# 3/11 embeddings done
# 4/11 embeddings done
# 5/11 embeddings done
# 6/11 embeddings done
# 7/11 embeddings done
# 8/11 embeddings done
# 9/11 embeddings done
# 10/11 embeddings done
# 11/11 embeddings done
# Embeddings from file '../index_store/magazine/title_text_map.txt' added to FAISS index between indice 50797 to 50808.
# ["File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5978", "page_content='First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.\n' metadata={'source': 'First for Women'} indice=1 score=0.5967", "File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5790", 'page_content=\'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=5 score=0.5790', 'page_content=\'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=6 score=0.5322', "File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5321"]
# Arthur's Magazine was started first. It was published from 1844 to 1846, whereas First for Women was started in 1989.

# %%
print(atomicFacts)
# Out:
# ["Arthur's Magazine was started first:supported", " Arthur's Magazine was published from 1844 to 1846:supported", ' First for Women was started in 1989:supported']

# %%
print(retrieved_docs)
# Out:
# ["page_content='First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.\n' metadata={'source': 'First for Women'} indice=1 score=0.5966", 'page_content=\'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=5 score=0.5791', 'page_content=\'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=6 score=0.5322']

# %%
for result in retrieved_docs:
    parsed_result = wiki_embedding.faiss_manager.parse_result(result)
    print(parsed_result)
# Out:
# {'page_content': "First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.", 'metadata': {'source': 'First for Women'}, 'indice': 1, 'score': 0.5966}
# {'page_content': 'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".', 'metadata': {'source': "Arthur's Magazine"}, 'indice': 5, 'score': 0.5791}
# {'page_content': 'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".', 'metadata': {'source': "Arthur's Magazine"}, 'indice': 6, 'score': 0.5322}

# %%
for fact in atomicFacts:
    score = wiki_embedding.score(fact.rpartition(':')[0], retrieved_docs)
    print(f'{fact} has a score of {score}')
# Out:
# Arthur's Magazine was started first:supported has a score of [[0.31389496]]
#  Arthur's Magazine was published from 1844 to 1846:supported has a score of [[0.29862073]]
#  First for Women was started in 1989:supported has a score of [[0.20763773]]

# %%
realscore = wiki_embedding.score('Arthur\'s Magazine', retrieved_docs)
print(realscore)
# Out:
# [[0.32663262]]

# %%
import json
import os
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

def scoreWikiAnswers(input_file_path, output_file_path, data_file_path="", skiplines = 0):
    wiki_embedding = WikitextsDocumentScorer()
    if data_file_path and os.path.exists(data_file_path):
        wiki_embedding.create_embedding(data_file_path)
    gen = OpenAIAtomicFactGenerator()

    qa_data = []
    scores = []
    with open(input_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            qa_data.append(json.loads(line))
    for i, qa in enumerate(qa_data):
        if i < skiplines:
            continue
        query = qa['input']
        subclaims_score = {}
        retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10, threshold=0.3)
        response = wiki_embedding.faiss_manager.generate_response_from_context(query, retrieved_docs)
        atomicFacts = gen.get_facts_from_text(response)
        for fact in atomicFacts:
            purefact = fact.rpartition(':')[0] if ':' in fact else fact
            score = wiki_embedding.score(purefact, retrieved_docs)
            subclaims_score[purefact] = float(score)
        #sort subclaims based on score
        subclaims_score = sorted(subclaims_score.items(), key=lambda x: x[1], reverse=True)
        answer = qa['output'][0]['answer']
        calibrate_score = float(wiki_embedding.score(query + ' ' + answer, retrieved_docs))
        with open(output_file_path, 'a', encoding='utf-8') as f:
            f.write(json.dumps({'query': query, 'answer': answer, 'calibrate_score': calibrate_score, 'response': response, 'subclaims_score': subclaims_score}) + '\n')
        print(f'calibrate data {i} / {len(qa_data)} done')

# %%
#calibrate data
file_path = "../index_store/conformalhotpot500/hotpotqa-train-kilt-500.jsonl"
scoreWikiAnswers(file_path, '../index_store/conformalhotpot500/hotpot_calibrate_score_500.jsonl', '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# File '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' already exists in the FAISS index.
# calibrate data 0 / 500 done
# calibrate data 1 / 500 done
# calibrate data 2 / 500 done
# calibrate data 3 / 500 done
# calibrate data 4 / 500 done
# calibrate data 5 / 500 done
# calibrate data 6 / 500 done
# calibrate data 7 / 500 done
# calibrate data 8 / 500 done
# calibrate data 9 / 500 done
# calibrate data 10 / 500 done
# calibrate data 11 / 500 done
# calibrate data 12 / 500 done
# calibrate data 13 / 500 done
# calibrate data 14 / 500 done
# calibrate data 15 / 500 done
# calibrate data 16 / 500 done
# calibrate data 17 / 500 done
# calibrate data 18 / 500 done
# calibrate data 19 / 500 done
# calibrate data 20 / 500 done
# calibrate data 21 / 500 done
# calibrate data 22 / 500 done
# calibrate data 23 / 500 done
# calibrate data 24 / 500 done
# calibrate data 25 / 500 done
# calibrate data 26 / 500 done
# calibrate data 27 / 500 done
# calibrate data 28 / 500 done
# calibrate data 29 / 500 done
# calibrate data 30 / 500 done
# calibrate data 31 / 500 done
# calibrate data 32 / 500 done
# calibrate data 33 / 500 done
# calibrate data 34 / 500 done
# calibrate data 35 / 500 done
# calibrate data 36 / 500 done
# calibrate data 37 / 500 done
# calibrate data 38 / 500 done
# calibrate data 39 / 500 done
# calibrate data 40 / 500 done
# calibrate data 41 / 500 done
# calibrate data 42 / 500 done
# calibrate data 43 / 500 done
# calibrate data 44 / 500 done
# calibrate data 45 / 500 done
# calibrate data 46 / 500 done
# calibrate data 47 / 500 done
# calibrate data 48 / 500 done
# calibrate data 49 / 500 done
# calibrate data 50 / 500 done
# calibrate data 51 / 500 done
# calibrate data 52 / 500 done
# calibrate data 53 / 500 done
# calibrate data 54 / 500 done
# calibrate data 55 / 500 done
# calibrate data 56 / 500 done
# calibrate data 57 / 500 done
# calibrate data 58 / 500 done
# calibrate data 59 / 500 done
# calibrate data 60 / 500 done
# calibrate data 61 / 500 done
# calibrate data 62 / 500 done
# calibrate data 63 / 500 done
# calibrate data 64 / 500 done
# calibrate data 65 / 500 done
# calibrate data 66 / 500 done
# calibrate data 67 / 500 done
# calibrate data 68 / 500 done
# calibrate data 69 / 500 done
# calibrate data 70 / 500 done
# calibrate data 71 / 500 done
# calibrate data 72 / 500 done
# calibrate data 73 / 500 done
# calibrate data 74 / 500 done
# calibrate data 75 / 500 done
# calibrate data 76 / 500 done
# calibrate data 77 / 500 done
# calibrate data 78 / 500 done
# calibrate data 79 / 500 done
# calibrate data 80 / 500 done
# calibrate data 81 / 500 done
# calibrate data 82 / 500 done
# calibrate data 83 / 500 done
# calibrate data 84 / 500 done
# calibrate data 85 / 500 done
# calibrate data 86 / 500 done
# calibrate data 87 / 500 done
# calibrate data 88 / 500 done
# calibrate data 89 / 500 done
# calibrate data 90 / 500 done
# calibrate data 91 / 500 done
# calibrate data 92 / 500 done
# calibrate data 93 / 500 done
# calibrate data 94 / 500 done
# calibrate data 95 / 500 done
# calibrate data 96 / 500 done
# calibrate data 97 / 500 done
# calibrate data 98 / 500 done
# calibrate data 99 / 500 done
# calibrate data 100 / 500 done
# calibrate data 101 / 500 done
# calibrate data 102 / 500 done
# calibrate data 103 / 500 done
# calibrate data 104 / 500 done
# calibrate data 105 / 500 done
# calibrate data 106 / 500 done
# calibrate data 107 / 500 done
# calibrate data 108 / 500 done
# calibrate data 109 / 500 done
# calibrate data 110 / 500 done
# calibrate data 111 / 500 done
# calibrate data 112 / 500 done
# calibrate data 113 / 500 done
# calibrate data 114 / 500 done
# calibrate data 115 / 500 done
# calibrate data 116 / 500 done
# calibrate data 117 / 500 done
# calibrate data 118 / 500 done
# calibrate data 119 / 500 done
# calibrate data 120 / 500 done
# calibrate data 121 / 500 done
# calibrate data 122 / 500 done
# calibrate data 123 / 500 done
# calibrate data 124 / 500 done
# calibrate data 125 / 500 done
# calibrate data 126 / 500 done
# calibrate data 127 / 500 done
# calibrate data 128 / 500 done
# calibrate data 129 / 500 done
# calibrate data 130 / 500 done
# calibrate data 131 / 500 done
# calibrate data 132 / 500 done
# calibrate data 133 / 500 done
# calibrate data 134 / 500 done
# calibrate data 135 / 500 done
# calibrate data 136 / 500 done
# calibrate data 137 / 500 done
# calibrate data 138 / 500 done
# calibrate data 139 / 500 done
# calibrate data 140 / 500 done
# calibrate data 141 / 500 done
# calibrate data 142 / 500 done
# calibrate data 143 / 500 done
# calibrate data 144 / 500 done
# calibrate data 145 / 500 done
# calibrate data 146 / 500 done
# calibrate data 147 / 500 done
# calibrate data 148 / 500 done
# calibrate data 149 / 500 done
# calibrate data 150 / 500 done
# calibrate data 151 / 500 done
# calibrate data 152 / 500 done
# calibrate data 153 / 500 done
# calibrate data 154 / 500 done
# calibrate data 155 / 500 done
# calibrate data 156 / 500 done
# calibrate data 157 / 500 done
# calibrate data 158 / 500 done
# calibrate data 159 / 500 done
# calibrate data 160 / 500 done
# calibrate data 161 / 500 done
# calibrate data 162 / 500 done
# calibrate data 163 / 500 done
# calibrate data 164 / 500 done
# calibrate data 165 / 500 done
# calibrate data 166 / 500 done
# calibrate data 167 / 500 done
# calibrate data 168 / 500 done
# calibrate data 169 / 500 done
# calibrate data 170 / 500 done
# calibrate data 171 / 500 done
# calibrate data 172 / 500 done
# calibrate data 173 / 500 done
# calibrate data 174 / 500 done
# calibrate data 175 / 500 done
# calibrate data 176 / 500 done
# calibrate data 177 / 500 done
# calibrate data 178 / 500 done
# calibrate data 179 / 500 done
# calibrate data 180 / 500 done
# calibrate data 181 / 500 done
# calibrate data 182 / 500 done
# calibrate data 183 / 500 done
# calibrate data 184 / 500 done
# calibrate data 185 / 500 done
# calibrate data 186 / 500 done
# calibrate data 187 / 500 done
# calibrate data 188 / 500 done
# calibrate data 189 / 500 done
# calibrate data 190 / 500 done
# calibrate data 191 / 500 done
# calibrate data 192 / 500 done
# calibrate data 193 / 500 done
# calibrate data 194 / 500 done
# calibrate data 195 / 500 done
# calibrate data 196 / 500 done
# calibrate data 197 / 500 done
# calibrate data 198 / 500 done
# calibrate data 199 / 500 done
# calibrate data 200 / 500 done
# calibrate data 201 / 500 done
# calibrate data 202 / 500 done
# calibrate data 203 / 500 done
# calibrate data 204 / 500 done
# calibrate data 205 / 500 done
# calibrate data 206 / 500 done
# calibrate data 207 / 500 done
# calibrate data 208 / 500 done
# calibrate data 209 / 500 done
# calibrate data 210 / 500 done
# calibrate data 211 / 500 done
# calibrate data 212 / 500 done
# calibrate data 213 / 500 done
# calibrate data 214 / 500 done
# calibrate data 215 / 500 done
# calibrate data 216 / 500 done
# calibrate data 217 / 500 done
# calibrate data 218 / 500 done
# calibrate data 219 / 500 done
# calibrate data 220 / 500 done
# calibrate data 221 / 500 done
# calibrate data 222 / 500 done
# calibrate data 223 / 500 done
# calibrate data 224 / 500 done
# calibrate data 225 / 500 done
# calibrate data 226 / 500 done
# calibrate data 227 / 500 done
# calibrate data 228 / 500 done
# calibrate data 229 / 500 done
# calibrate data 230 / 500 done
# calibrate data 231 / 500 done
# calibrate data 232 / 500 done
# calibrate data 233 / 500 done
# calibrate data 234 / 500 done
# calibrate data 235 / 500 done
# calibrate data 236 / 500 done
# calibrate data 237 / 500 done
# calibrate data 238 / 500 done
# calibrate data 239 / 500 done
# calibrate data 240 / 500 done
# calibrate data 241 / 500 done
# calibrate data 242 / 500 done
# calibrate data 243 / 500 done
# calibrate data 244 / 500 done
# calibrate data 245 / 500 done
# calibrate data 246 / 500 done
# calibrate data 247 / 500 done
# calibrate data 248 / 500 done
# calibrate data 249 / 500 done
# calibrate data 250 / 500 done
# calibrate data 251 / 500 done
# calibrate data 252 / 500 done
# calibrate data 253 / 500 done
# calibrate data 254 / 500 done
# calibrate data 255 / 500 done
# calibrate data 256 / 500 done
# calibrate data 257 / 500 done
# calibrate data 258 / 500 done
# calibrate data 259 / 500 done
# calibrate data 260 / 500 done
# calibrate data 261 / 500 done
# calibrate data 262 / 500 done
# calibrate data 263 / 500 done
# calibrate data 264 / 500 done
# calibrate data 265 / 500 done
# calibrate data 266 / 500 done
# calibrate data 267 / 500 done
# calibrate data 268 / 500 done
# calibrate data 269 / 500 done
# calibrate data 270 / 500 done
# calibrate data 271 / 500 done
# calibrate data 272 / 500 done
# calibrate data 273 / 500 done
# calibrate data 274 / 500 done
# calibrate data 275 / 500 done
# calibrate data 276 / 500 done
# calibrate data 277 / 500 done
# calibrate data 278 / 500 done
# calibrate data 279 / 500 done
# calibrate data 280 / 500 done
# calibrate data 281 / 500 done
# calibrate data 282 / 500 done
# calibrate data 283 / 500 done
# calibrate data 284 / 500 done
# calibrate data 285 / 500 done
# calibrate data 286 / 500 done
# calibrate data 287 / 500 done
# calibrate data 288 / 500 done
# calibrate data 289 / 500 done
# calibrate data 290 / 500 done
# calibrate data 291 / 500 done
# calibrate data 292 / 500 done
# calibrate data 293 / 500 done
# calibrate data 294 / 500 done
# calibrate data 295 / 500 done
# calibrate data 296 / 500 done
# calibrate data 297 / 500 done
# calibrate data 298 / 500 done
# calibrate data 299 / 500 done
# calibrate data 300 / 500 done
# calibrate data 301 / 500 done
# calibrate data 302 / 500 done
# calibrate data 303 / 500 done
# calibrate data 304 / 500 done
# calibrate data 305 / 500 done
# calibrate data 306 / 500 done
# calibrate data 307 / 500 done
# calibrate data 308 / 500 done
# calibrate data 309 / 500 done
# calibrate data 310 / 500 done
# calibrate data 311 / 500 done
# calibrate data 312 / 500 done
# calibrate data 313 / 500 done
# calibrate data 314 / 500 done
# calibrate data 315 / 500 done
# calibrate data 316 / 500 done
# calibrate data 317 / 500 done
# calibrate data 318 / 500 done
# calibrate data 319 / 500 done
# calibrate data 320 / 500 done
# calibrate data 321 / 500 done
# calibrate data 322 / 500 done
# calibrate data 323 / 500 done
# calibrate data 324 / 500 done
# calibrate data 325 / 500 done
# calibrate data 326 / 500 done
# calibrate data 327 / 500 done
# calibrate data 328 / 500 done
# calibrate data 329 / 500 done
# calibrate data 330 / 500 done
# calibrate data 331 / 500 done
# calibrate data 332 / 500 done
# calibrate data 333 / 500 done
# calibrate data 334 / 500 done
# calibrate data 335 / 500 done
# calibrate data 336 / 500 done
# calibrate data 337 / 500 done
# calibrate data 338 / 500 done
# calibrate data 339 / 500 done
# calibrate data 340 / 500 done
# calibrate data 341 / 500 done
# calibrate data 342 / 500 done
# calibrate data 343 / 500 done
# calibrate data 344 / 500 done
# calibrate data 345 / 500 done
# calibrate data 346 / 500 done
# calibrate data 347 / 500 done
# calibrate data 348 / 500 done
# calibrate data 349 / 500 done
# calibrate data 350 / 500 done
# calibrate data 351 / 500 done
# calibrate data 352 / 500 done
# calibrate data 353 / 500 done
# calibrate data 354 / 500 done
# calibrate data 355 / 500 done
# calibrate data 356 / 500 done
# calibrate data 357 / 500 done
# calibrate data 358 / 500 done
# calibrate data 359 / 500 done
# calibrate data 360 / 500 done
# calibrate data 361 / 500 done
# calibrate data 362 / 500 done
# calibrate data 363 / 500 done
# calibrate data 364 / 500 done
# calibrate data 365 / 500 done
# calibrate data 366 / 500 done
# calibrate data 367 / 500 done
# calibrate data 368 / 500 done
# calibrate data 369 / 500 done
# calibrate data 370 / 500 done
# calibrate data 371 / 500 done
# calibrate data 372 / 500 done
# calibrate data 373 / 500 done
# calibrate data 374 / 500 done
# calibrate data 375 / 500 done
# calibrate data 376 / 500 done
# calibrate data 377 / 500 done
# calibrate data 378 / 500 done
# calibrate data 379 / 500 done
# calibrate data 380 / 500 done
# calibrate data 381 / 500 done
# calibrate data 382 / 500 done
# calibrate data 383 / 500 done
# calibrate data 384 / 500 done
# calibrate data 385 / 500 done
# calibrate data 386 / 500 done
# calibrate data 387 / 500 done
# calibrate data 388 / 500 done
# calibrate data 389 / 500 done
# calibrate data 390 / 500 done
# calibrate data 391 / 500 done
# calibrate data 392 / 500 done
# calibrate data 393 / 500 done
# calibrate data 394 / 500 done
# calibrate data 395 / 500 done
# calibrate data 396 / 500 done
# calibrate data 397 / 500 done
# calibrate data 398 / 500 done
# calibrate data 399 / 500 done
# calibrate data 400 / 500 done
# calibrate data 401 / 500 done
# calibrate data 402 / 500 done
# calibrate data 403 / 500 done
# calibrate data 404 / 500 done
# calibrate data 405 / 500 done
# calibrate data 406 / 500 done
# calibrate data 407 / 500 done
# calibrate data 408 / 500 done
# calibrate data 409 / 500 done
# calibrate data 410 / 500 done
# calibrate data 411 / 500 done
# calibrate data 412 / 500 done
# calibrate data 413 / 500 done
# calibrate data 414 / 500 done
# calibrate data 415 / 500 done
# calibrate data 416 / 500 done
# calibrate data 417 / 500 done
# calibrate data 418 / 500 done
# calibrate data 419 / 500 done
# calibrate data 420 / 500 done
# calibrate data 421 / 500 done
# calibrate data 422 / 500 done
# calibrate data 423 / 500 done
# calibrate data 424 / 500 done
# calibrate data 425 / 500 done
# calibrate data 426 / 500 done
# calibrate data 427 / 500 done
# calibrate data 428 / 500 done
# calibrate data 429 / 500 done
# calibrate data 430 / 500 done
# calibrate data 431 / 500 done
# calibrate data 432 / 500 done
# calibrate data 433 / 500 done
# calibrate data 434 / 500 done
# calibrate data 435 / 500 done
# calibrate data 436 / 500 done
# calibrate data 437 / 500 done
# calibrate data 438 / 500 done
# calibrate data 439 / 500 done
# calibrate data 440 / 500 done
# calibrate data 441 / 500 done
# calibrate data 442 / 500 done
# calibrate data 443 / 500 done
# calibrate data 444 / 500 done
# calibrate data 445 / 500 done
# calibrate data 446 / 500 done
# calibrate data 447 / 500 done
# calibrate data 448 / 500 done
# calibrate data 449 / 500 done
# calibrate data 450 / 500 done
# calibrate data 451 / 500 done
# calibrate data 452 / 500 done
# calibrate data 453 / 500 done
# calibrate data 454 / 500 done
# calibrate data 455 / 500 done
# calibrate data 456 / 500 done
# calibrate data 457 / 500 done
# calibrate data 458 / 500 done
# calibrate data 459 / 500 done
# calibrate data 460 / 500 done
# calibrate data 461 / 500 done
# calibrate data 462 / 500 done
# calibrate data 463 / 500 done
# calibrate data 464 / 500 done
# calibrate data 465 / 500 done
# calibrate data 466 / 500 done
# calibrate data 467 / 500 done
# calibrate data 468 / 500 done
# calibrate data 469 / 500 done
# calibrate data 470 / 500 done
# calibrate data 471 / 500 done
# calibrate data 472 / 500 done
# calibrate data 473 / 500 done
# calibrate data 474 / 500 done
# calibrate data 475 / 500 done
# calibrate data 476 / 500 done
# calibrate data 477 / 500 done
# calibrate data 478 / 500 done
# calibrate data 479 / 500 done
# calibrate data 480 / 500 done
# calibrate data 481 / 500 done
# calibrate data 482 / 500 done
# calibrate data 483 / 500 done
# calibrate data 484 / 500 done
# calibrate data 485 / 500 done
# calibrate data 486 / 500 done
# calibrate data 487 / 500 done
# calibrate data 488 / 500 done
# calibrate data 489 / 500 done
# calibrate data 490 / 500 done
# calibrate data 491 / 500 done
# calibrate data 492 / 500 done
# calibrate data 493 / 500 done
# calibrate data 494 / 500 done
# calibrate data 495 / 500 done
# calibrate data 496 / 500 done
# calibrate data 497 / 500 done
# calibrate data 498 / 500 done
# calibrate data 499 / 500 done

# %%
import json
from llm.openai_claim_verification import OpenAIClaimVerification

verifier = OpenAIClaimVerification()
llm_responses_file_path = 'llm_responses_500.jsonl'
# Function to transform subclaims_score into the desired format
def annotate_subclaims(data):
    transformed_claims = []
    query = data['query']
    answer = data['answer']
    with open (llm_responses_file_path, "w") as llm_responses_file:
        for subclaim, score in data["subclaims_score"]:
            res = verifier.openAI_response(query, answer, subclaim)
            annotation = verifier.detect_label(res)
            transformed_claims.append({
                "subclaim": subclaim,
                "similarity-score": score,
                "annotation": annotation
                # Assuming annotation is optional and could be added later
            })
            llm_responses_file.write(json.dumps({'subclaim': subclaim, 'score' : score, 'annotation': annotation, 'llmResponse': res},
                                                ensure_ascii=False) + '\n')
    return {
        "prompt": data["query"],
        "original-output": data["response"],
        "claims": transformed_claims,
    }

# %%
conformal_format_file_path = 'conformal_format_500.jsonl'
input_file = '../index_store/conformalhotpot500/hotpot_calibrate_score_500.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
idx = 0
# Process the file
with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    outfile.write('{"data": [\n')
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data)
        outfile.write(json.dumps(transformed_data, ensure_ascii=False) + ",\n")
        idx += 1
    outfile.write(']}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Processing line 51
# Processing line 52
# Processing line 53
# Processing line 54
# Processing line 55
# Processing line 56
# Processing line 57
# Processing line 58
# Processing line 59
# Processing line 60
# Processing line 61
# Processing line 62
# Processing line 63
# Processing line 64
# Processing line 65
# Processing line 66
# Processing line 67
# Processing line 68
# Processing line 69
# Processing line 70
# Processing line 71
# Processing line 72
# Processing line 73
# Processing line 74
# Processing line 75
# Processing line 76
# Processing line 77
# Processing line 78
# Processing line 79
# Processing line 80
# Processing line 81
# Processing line 82
# Processing line 83
# Processing line 84
# Processing line 85
# Processing line 86
# Processing line 87
# Processing line 88
# Processing line 89
# Processing line 90
# Processing line 91
# Processing line 92
# Processing line 93
# Processing line 94
# Processing line 95
# Processing line 96
# Processing line 97
# Processing line 98
# Processing line 99
# Processing line 100
# Processing line 101
# Processing line 102
# Processing line 103
# Processing line 104
# Processing line 105
# Processing line 106
# Processing line 107
# Processing line 108
# Processing line 109
# Processing line 110
# Processing line 111
# Processing line 112
# Processing line 113
# Processing line 114
# Processing line 115
# Processing line 116
# Processing line 117
# Processing line 118
# Processing line 119
# Processing line 120
# Processing line 121
# Processing line 122
# Processing line 123
# Processing line 124
# Processing line 125
# Processing line 126
# Processing line 127
# Processing line 128
# Processing line 129
# Processing line 130
# Processing line 131
# Processing line 132
# Processing line 133
# Processing line 134
# Processing line 135
# Processing line 136
# Processing line 137
# Processing line 138
# Processing line 139
# Processing line 140
# Processing line 141
# Processing line 142
# Processing line 143
# Processing line 144
# Processing line 145
# Processing line 146
# Processing line 147
# Processing line 148
# Processing line 149
# Processing line 150
# Processing line 151
# Processing line 152
# Processing line 153
# Processing line 154
# Processing line 155
# Processing line 156
# Processing line 157
# Processing line 158
# Processing line 159
# Processing line 160
# Processing line 161
# Processing line 162
# Processing line 163
# Processing line 164
# Processing line 165
# Processing line 166
# Processing line 167
# Processing line 168
# Processing line 169
# Processing line 170
# Processing line 171
# Processing line 172
# Processing line 173
# Processing line 174
# Processing line 175
# Processing line 176
# Processing line 177
# Processing line 178
# Processing line 179
# Processing line 180
# Processing line 181
# Processing line 182
# Processing line 183
# Processing line 184
# Processing line 185
# Processing line 186
# Processing line 187
# Processing line 188
# Processing line 189
# Processing line 190
# Processing line 191
# Processing line 192
# Processing line 193
# Processing line 194
# Processing line 195
# Processing line 196
# Processing line 197
# Processing line 198
# Processing line 199
# Processing line 200
# Processing line 201
# Processing line 202
# Processing line 203
# Processing line 204
# Processing line 205
# Processing line 206
# Processing line 207
# Processing line 208
# Processing line 209
# Processing line 210
# Processing line 211
# Processing line 212
# Processing line 213
# Processing line 214
# Processing line 215
# Processing line 216
# Processing line 217
# Processing line 218
# Processing line 219
# Processing line 220
# Processing line 221
# Processing line 222
# Processing line 223
# Processing line 224
# Processing line 225
# Processing line 226
# Processing line 227
# Processing line 228
# Processing line 229
# Processing line 230
# Processing line 231
# Processing line 232
# Processing line 233
# Processing line 234
# Processing line 235
# Processing line 236
# Processing line 237
# Processing line 238
# Processing line 239
# Processing line 240
# Processing line 241
# Processing line 242
# Processing line 243
# Processing line 244
# Processing line 245
# Processing line 246
# Processing line 247
# Processing line 248
# Processing line 249
# Processing line 250
# Processing line 251

# %%
print(transformed_data)
# Out:
# {'prompt': 'Musician and satirist Allie Goertz wrote a song about the "The Simpsons" character Milhouse, who Matt Groening named after who?', 'original-output': 'The character Milhouse from "The Simpsons" was named by Matt Groening after U.S. President Richard Nixon, whose middle name was Milhous.', 'claims': [{'subclaim': 'The character Milhouse from "The Simpsons" was named by Matt Groening after U.S. President Richard Nixon', 'similarity-score': 0.29849618673324585, 'annotation': 'S'}, {'subclaim': " Richard Nixon's middle name was Milhous", 'similarity-score': 0.14918304979801178, 'annotation': 'F'}]}

# %% [markdown]
# **PopQA**

# %% [markdown]
# ## Create Embedding Only##

# %%
data_path = '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt'
wiki_embedding = WikitextsDocumentScorer()
wiki_embedding.create_embedding(data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Associated texts saved to file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# 1/15390 embeddings done
# 2/15390 embeddings done
# 3/15390 embeddings done
# 4/15390 embeddings done
# 5/15390 embeddings done
# 6/15390 embeddings done
# 7/15390 embeddings done
# 8/15390 embeddings done
# 9/15390 embeddings done
# 10/15390 embeddings done
# 11/15390 embeddings done
# 12/15390 embeddings done
# 13/15390 embeddings done
# 14/15390 embeddings done
# 15/15390 embeddings done
# 16/15390 embeddings done
# 17/15390 embeddings done
# 18/15390 embeddings done
# 19/15390 embeddings done
# 20/15390 embeddings done
# 21/15390 embeddings done
# 22/15390 embeddings done
# 23/15390 embeddings done
# 24/15390 embeddings done
# 25/15390 embeddings done
# 26/15390 embeddings done
# 27/15390 embeddings done
# 28/15390 embeddings done
# 29/15390 embeddings done
# 30/15390 embeddings done
# 31/15390 embeddings done
# 32/15390 embeddings done
# 33/15390 embeddings done
# 34/15390 embeddings done
# 35/15390 embeddings done
# 36/15390 embeddings done
# 37/15390 embeddings done
# 38/15390 embeddings done
# 39/15390 embeddings done
# 40/15390 embeddings done
# 41/15390 embeddings done
# 42/15390 embeddings done
# 43/15390 embeddings done
# 44/15390 embeddings done
# 45/15390 embeddings done
# 46/15390 embeddings done
# 47/15390 embeddings done
# 48/15390 embeddings done
# 49/15390 embeddings done
# 50/15390 embeddings done
# 51/15390 embeddings done
# 52/15390 embeddings done
# 53/15390 embeddings done
# 54/15390 embeddings done
# 55/15390 embeddings done
# 56/15390 embeddings done
# 57/15390 embeddings done
# 58/15390 embeddings done
# 59/15390 embeddings done
# 60/15390 embeddings done
# 61/15390 embeddings done
# 62/15390 embeddings done
# 63/15390 embeddings done
# 64/15390 embeddings done
# 65/15390 embeddings done
# 66/15390 embeddings done
# 67/15390 embeddings done
# 68/15390 embeddings done
# 69/15390 embeddings done
# 70/15390 embeddings done
# 71/15390 embeddings done
# 72/15390 embeddings done
# 73/15390 embeddings done
# 74/15390 embeddings done
# 75/15390 embeddings done
# 76/15390 embeddings done
# 77/15390 embeddings done
# 78/15390 embeddings done
# 79/15390 embeddings done
# 80/15390 embeddings done
# 81/15390 embeddings done
# 82/15390 embeddings done
# 83/15390 embeddings done
# 84/15390 embeddings done
# 85/15390 embeddings done
# 86/15390 embeddings done
# 87/15390 embeddings done
# 88/15390 embeddings done
# 89/15390 embeddings done
# 90/15390 embeddings done
# 91/15390 embeddings done
# 92/15390 embeddings done
# 93/15390 embeddings done
# 94/15390 embeddings done
# 95/15390 embeddings done
# 96/15390 embeddings done
# 97/15390 embeddings done
# 98/15390 embeddings done
# 99/15390 embeddings done
# 100/15390 embeddings done
# 101/15390 embeddings done
# 102/15390 embeddings done
# 103/15390 embeddings done
# 104/15390 embeddings done
# 105/15390 embeddings done
# 106/15390 embeddings done
# 107/15390 embeddings done
# 108/15390 embeddings done
# 109/15390 embeddings done
# 110/15390 embeddings done
# 111/15390 embeddings done
# 112/15390 embeddings done
# 113/15390 embeddings done
# 114/15390 embeddings done
# 115/15390 embeddings done
# 116/15390 embeddings done
# 117/15390 embeddings done
# 118/15390 embeddings done
# 119/15390 embeddings done
# 120/15390 embeddings done
# 121/15390 embeddings done
# 122/15390 embeddings done
# 123/15390 embeddings done
# 124/15390 embeddings done
# 125/15390 embeddings done
# 126/15390 embeddings done
# 127/15390 embeddings done
# 128/15390 embeddings done
# 129/15390 embeddings done
# 130/15390 embeddings done
# 131/15390 embeddings done
# 132/15390 embeddings done
# 133/15390 embeddings done
# 134/15390 embeddings done
# 135/15390 embeddings done
# 136/15390 embeddings done
# 137/15390 embeddings done
# 138/15390 embeddings done
# 139/15390 embeddings done
# 140/15390 embeddings done
# 141/15390 embeddings done
# 142/15390 embeddings done
# 143/15390 embeddings done
# 144/15390 embeddings done
# 145/15390 embeddings done
# 146/15390 embeddings done
# 147/15390 embeddings done
# 148/15390 embeddings done
# 149/15390 embeddings done
# 150/15390 embeddings done
# 151/15390 embeddings done
# 152/15390 embeddings done
# 153/15390 embeddings done
# 154/15390 embeddings done
# 155/15390 embeddings done
# 156/15390 embeddings done
# 157/15390 embeddings done
# 158/15390 embeddings done
# 159/15390 embeddings done
# 160/15390 embeddings done
# 161/15390 embeddings done
# 162/15390 embeddings done
# 163/15390 embeddings done
# 164/15390 embeddings done
# 165/15390 embeddings done
# 166/15390 embeddings done
# 167/15390 embeddings done
# 168/15390 embeddings done
# 169/15390 embeddings done
# 170/15390 embeddings done
# 171/15390 embeddings done
# 172/15390 embeddings done
# 173/15390 embeddings done
# 174/15390 embeddings done
# 175/15390 embeddings done
# 176/15390 embeddings done
# 177/15390 embeddings done
# 178/15390 embeddings done
# 179/15390 embeddings done
# 180/15390 embeddings done
# 181/15390 embeddings done
# 182/15390 embeddings done
# 183/15390 embeddings done
# 184/15390 embeddings done
# 185/15390 embeddings done
# 186/15390 embeddings done
# 187/15390 embeddings done
# 188/15390 embeddings done
# 189/15390 embeddings done
# 190/15390 embeddings done
# 191/15390 embeddings done
# 192/15390 embeddings done
# 193/15390 embeddings done
# 194/15390 embeddings done
# 195/15390 embeddings done
# 196/15390 embeddings done
# 197/15390 embeddings done
# 198/15390 embeddings done
# 199/15390 embeddings done
# 200/15390 embeddings done
# 201/15390 embeddings done
# 202/15390 embeddings done
# 203/15390 embeddings done
# 204/15390 embeddings done
# 205/15390 embeddings done
# 206/15390 embeddings done
# 207/15390 embeddings done
# 208/15390 embeddings done
# 209/15390 embeddings done
# 210/15390 embeddings done
# 211/15390 embeddings done
# 212/15390 embeddings done
# 213/15390 embeddings done
# 214/15390 embeddings done
# 215/15390 embeddings done
# 216/15390 embeddings done
# 217/15390 embeddings done
# 218/15390 embeddings done
# 219/15390 embeddings done
# 220/15390 embeddings done
# 221/15390 embeddings done
# 222/15390 embeddings done
# 223/15390 embeddings done
# 224/15390 embeddings done
# 225/15390 embeddings done
# 226/15390 embeddings done
# 227/15390 embeddings done
# 228/15390 embeddings done
# 229/15390 embeddings done
# 230/15390 embeddings done
# 231/15390 embeddings done
# 232/15390 embeddings done
# 233/15390 embeddings done
# 234/15390 embeddings done
# 235/15390 embeddings done
# 236/15390 embeddings done
# 237/15390 embeddings done
# 238/15390 embeddings done
# 239/15390 embeddings done
# 240/15390 embeddings done
# 241/15390 embeddings done
# 242/15390 embeddings done
# 243/15390 embeddings done
# 244/15390 embeddings done
# 245/15390 embeddings done
# 246/15390 embeddings done
# 247/15390 embeddings done
# 248/15390 embeddings done
# 249/15390 embeddings done
# 250/15390 embeddings done
# 251/15390 embeddings done
# 252/15390 embeddings done
# 253/15390 embeddings done
# 254/15390 embeddings done
# 255/15390 embeddings done
# 256/15390 embeddings done
# 257/15390 embeddings done
# 258/15390 embeddings done
# 259/15390 embeddings done
# 260/15390 embeddings done
# 261/15390 embeddings done
# 262/15390 embeddings done
# 263/15390 embeddings done
# 264/15390 embeddings done
# 265/15390 embeddings done
# 266/15390 embeddings done
# 267/15390 embeddings done
# 268/15390 embeddings done
# 269/15390 embeddings done
# 270/15390 embeddings done
# 271/15390 embeddings done
# 272/15390 embeddings done
# 273/15390 embeddings done
# 274/15390 embeddings done
# 275/15390 embeddings done
# 276/15390 embeddings done
# 277/15390 embeddings done
# 278/15390 embeddings done
# 279/15390 embeddings done
# 280/15390 embeddings done
# 281/15390 embeddings done
# 282/15390 embeddings done
# 283/15390 embeddings done
# 284/15390 embeddings done
# 285/15390 embeddings done
# 286/15390 embeddings done
# 287/15390 embeddings done
# 288/15390 embeddings done
# 289/15390 embeddings done
# 290/15390 embeddings done
# 291/15390 embeddings done
# 292/15390 embeddings done
# 293/15390 embeddings done
# 294/15390 embeddings done
# 295/15390 embeddings done
# 296/15390 embeddings done
# 297/15390 embeddings done
# 298/15390 embeddings done
# 299/15390 embeddings done
# 300/15390 embeddings done
# 301/15390 embeddings done
# 302/15390 embeddings done
# 303/15390 embeddings done
# 304/15390 embeddings done
# 305/15390 embeddings done
# 306/15390 embeddings done
# 307/15390 embeddings done
# 308/15390 embeddings done
# 309/15390 embeddings done
# 310/15390 embeddings done
# 311/15390 embeddings done
# 312/15390 embeddings done
# 313/15390 embeddings done
# 314/15390 embeddings done
# 315/15390 embeddings done
# 316/15390 embeddings done
# 317/15390 embeddings done
# 318/15390 embeddings done
# 319/15390 embeddings done
# 320/15390 embeddings done
# 321/15390 embeddings done
# 322/15390 embeddings done
# 323/15390 embeddings done
# 324/15390 embeddings done
# 325/15390 embeddings done
# 326/15390 embeddings done
# 327/15390 embeddings done
# 328/15390 embeddings done
# 329/15390 embeddings done
# 330/15390 embeddings done
# 331/15390 embeddings done
# 332/15390 embeddings done
# 333/15390 embeddings done
# 334/15390 embeddings done
# 335/15390 embeddings done
# 336/15390 embeddings done
# 337/15390 embeddings done
# 338/15390 embeddings done
# 339/15390 embeddings done
# 340/15390 embeddings done
# 341/15390 embeddings done
# 342/15390 embeddings done
# 343/15390 embeddings done
# 344/15390 embeddings done
# 345/15390 embeddings done
# 346/15390 embeddings done
# 347/15390 embeddings done
# 348/15390 embeddings done
# 349/15390 embeddings done
# 350/15390 embeddings done
# 351/15390 embeddings done
# 352/15390 embeddings done
# 353/15390 embeddings done
# 354/15390 embeddings done
# 355/15390 embeddings done
# 356/15390 embeddings done
# 357/15390 embeddings done
# 358/15390 embeddings done
# 359/15390 embeddings done
# 360/15390 embeddings done
# 361/15390 embeddings done
# 362/15390 embeddings done
# 363/15390 embeddings done
# 364/15390 embeddings done
# 365/15390 embeddings done
# 366/15390 embeddings done
# 367/15390 embeddings done
# 368/15390 embeddings done
# 369/15390 embeddings done
# 370/15390 embeddings done
# 371/15390 embeddings done
# 372/15390 embeddings done
# 373/15390 embeddings done
# 374/15390 embeddings done
# 375/15390 embeddings done
# 376/15390 embeddings done
# 377/15390 embeddings done
# 378/15390 embeddings done
# 379/15390 embeddings done
# 380/15390 embeddings done
# 381/15390 embeddings done
# 382/15390 embeddings done
# 383/15390 embeddings done
# 384/15390 embeddings done
# 385/15390 embeddings done
# 386/15390 embeddings done
# 387/15390 embeddings done
# 388/15390 embeddings done
# 389/15390 embeddings done
# 390/15390 embeddings done
# 391/15390 embeddings done
# 392/15390 embeddings done
# 393/15390 embeddings done
# 394/15390 embeddings done
# 395/15390 embeddings done
# 396/15390 embeddings done
# 397/15390 embeddings done
# 398/15390 embeddings done
# 399/15390 embeddings done
# 400/15390 embeddings done
# 401/15390 embeddings done
# 402/15390 embeddings done
# 403/15390 embeddings done
# 404/15390 embeddings done
# 405/15390 embeddings done
# 406/15390 embeddings done
# 407/15390 embeddings done
# 408/15390 embeddings done
# 409/15390 embeddings done
# 410/15390 embeddings done
# 411/15390 embeddings done
# 412/15390 embeddings done
# 413/15390 embeddings done
# 414/15390 embeddings done
# 415/15390 embeddings done
# 416/15390 embeddings done
# 417/15390 embeddings done
# 418/15390 embeddings done
# 419/15390 embeddings done
# 420/15390 embeddings done
# 421/15390 embeddings done
# 422/15390 embeddings done
# 423/15390 embeddings done
# 424/15390 embeddings done
# 425/15390 embeddings done
# 426/15390 embeddings done
# 427/15390 embeddings done
# 428/15390 embeddings done
# 429/15390 embeddings done
# 430/15390 embeddings done
# 431/15390 embeddings done
# 432/15390 embeddings done
# 433/15390 embeddings done
# 434/15390 embeddings done
# 435/15390 embeddings done
# 436/15390 embeddings done
# 437/15390 embeddings done
# 438/15390 embeddings done
# 439/15390 embeddings done
# 440/15390 embeddings done
# 441/15390 embeddings done
# 442/15390 embeddings done
# 443/15390 embeddings done
# 444/15390 embeddings done
# 445/15390 embeddings done
# 446/15390 embeddings done
# 447/15390 embeddings done
# 448/15390 embeddings done
# 449/15390 embeddings done
# 450/15390 embeddings done
# 451/15390 embeddings done
# 452/15390 embeddings done
# 453/15390 embeddings done
# 454/15390 embeddings done
# 455/15390 embeddings done
# 456/15390 embeddings done
# 457/15390 embeddings done
# 458/15390 embeddings done
# 459/15390 embeddings done
# 460/15390 embeddings done
# 461/15390 embeddings done
# 462/15390 embeddings done
# 463/15390 embeddings done
# 464/15390 embeddings done
# 465/15390 embeddings done
# 466/15390 embeddings done
# 467/15390 embeddings done
# 468/15390 embeddings done
# 469/15390 embeddings done
# 470/15390 embeddings done
# 471/15390 embeddings done
# 472/15390 embeddings done
# 473/15390 embeddings done
# 474/15390 embeddings done
# 475/15390 embeddings done
# 476/15390 embeddings done
# 477/15390 embeddings done
# 478/15390 embeddings done
# 479/15390 embeddings done
# 480/15390 embeddings done
# 481/15390 embeddings done
# 482/15390 embeddings done
# 483/15390 embeddings done
# 484/15390 embeddings done
# 485/15390 embeddings done
# 486/15390 embeddings done
# 487/15390 embeddings done
# 488/15390 embeddings done
# 489/15390 embeddings done
# 490/15390 embeddings done
# 491/15390 embeddings done
# 492/15390 embeddings done
# 493/15390 embeddings done
# 494/15390 embeddings done
# 495/15390 embeddings done
# 496/15390 embeddings done
# 497/15390 embeddings done
# 498/15390 embeddings done
# 499/15390 embeddings done
# 500/15390 embeddings done
# 501/15390 embeddings done
# 502/15390 embeddings done
# 503/15390 embeddings done
# 504/15390 embeddings done
# 505/15390 embeddings done
# 506/15390 embeddings done
# 507/15390 embeddings done
# 508/15390 embeddings done
# 509/15390 embeddings done
# 510/15390 embeddings done
# 511/15390 embeddings done
# 512/15390 embeddings done
# 513/15390 embeddings done
# 514/15390 embeddings done
# 515/15390 embeddings done
# 516/15390 embeddings done
# 517/15390 embeddings done
# 518/15390 embeddings done
# 519/15390 embeddings done
# 520/15390 embeddings done
# 521/15390 embeddings done
# 522/15390 embeddings done
# 523/15390 embeddings done
# 524/15390 embeddings done
# 525/15390 embeddings done
# 526/15390 embeddings done
# 527/15390 embeddings done
# 528/15390 embeddings done
# 529/15390 embeddings done
# 530/15390 embeddings done
# 531/15390 embeddings done
# 532/15390 embeddings done
# 533/15390 embeddings done
# 534/15390 embeddings done
# 535/15390 embeddings done
# 536/15390 embeddings done
# 537/15390 embeddings done
# 538/15390 embeddings done
# 539/15390 embeddings done
# 540/15390 embeddings done
# 541/15390 embeddings done
# 542/15390 embeddings done
# 543/15390 embeddings done
# 544/15390 embeddings done
# 545/15390 embeddings done
# 546/15390 embeddings done
# 547/15390 embeddings done
# 548/15390 embeddings done
# 549/15390 embeddings done
# 550/15390 embeddings done
# 551/15390 embeddings done
# 552/15390 embeddings done
# 553/15390 embeddings done
# 554/15390 embeddings done
# 555/15390 embeddings done
# 556/15390 embeddings done
# 557/15390 embeddings done
# 558/15390 embeddings done
# 559/15390 embeddings done
# 560/15390 embeddings done
# 561/15390 embeddings done
# 562/15390 embeddings done
# 563/15390 embeddings done
# 564/15390 embeddings done
# 565/15390 embeddings done
# 566/15390 embeddings done
# 567/15390 embeddings done
# 568/15390 embeddings done
# 569/15390 embeddings done
# 570/15390 embeddings done
# 571/15390 embeddings done
# 572/15390 embeddings done
# 573/15390 embeddings done
# 574/15390 embeddings done
# 575/15390 embeddings done
# 576/15390 embeddings done
# 577/15390 embeddings done
# 578/15390 embeddings done
# 579/15390 embeddings done
# 580/15390 embeddings done
# 581/15390 embeddings done
# 582/15390 embeddings done
# 583/15390 embeddings done
# 584/15390 embeddings done
# 585/15390 embeddings done
# 586/15390 embeddings done
# 587/15390 embeddings done
# 588/15390 embeddings done
# 589/15390 embeddings done
# 590/15390 embeddings done
# 591/15390 embeddings done
# 592/15390 embeddings done
# 593/15390 embeddings done
# 594/15390 embeddings done
# 595/15390 embeddings done
# 596/15390 embeddings done
# 597/15390 embeddings done
# 598/15390 embeddings done
# 599/15390 embeddings done
# 600/15390 embeddings done
# 601/15390 embeddings done
# 602/15390 embeddings done
# 603/15390 embeddings done
# 604/15390 embeddings done
# 605/15390 embeddings done
# 606/15390 embeddings done
# 607/15390 embeddings done
# 608/15390 embeddings done
# 609/15390 embeddings done
# 610/15390 embeddings done
# 611/15390 embeddings done
# 612/15390 embeddings done
# 613/15390 embeddings done
# 614/15390 embeddings done
# 615/15390 embeddings done
# 616/15390 embeddings done
# 617/15390 embeddings done
# 618/15390 embeddings done
# 619/15390 embeddings done
# 620/15390 embeddings done
# 621/15390 embeddings done
# 622/15390 embeddings done
# 623/15390 embeddings done
# 624/15390 embeddings done
# 625/15390 embeddings done
# 626/15390 embeddings done
# 627/15390 embeddings done
# 628/15390 embeddings done
# 629/15390 embeddings done
# 630/15390 embeddings done
# 631/15390 embeddings done
# 632/15390 embeddings done
# 633/15390 embeddings done
# 634/15390 embeddings done
# 635/15390 embeddings done
# 636/15390 embeddings done
# 637/15390 embeddings done
# 638/15390 embeddings done
# 639/15390 embeddings done
# 640/15390 embeddings done
# 641/15390 embeddings done
# 642/15390 embeddings done
# 643/15390 embeddings done
# 644/15390 embeddings done
# 645/15390 embeddings done
# 646/15390 embeddings done
# 647/15390 embeddings done
# 648/15390 embeddings done
# 649/15390 embeddings done
# 650/15390 embeddings done
# 651/15390 embeddings done
# 652/15390 embeddings done
# 653/15390 embeddings done
# 654/15390 embeddings done
# 655/15390 embeddings done
# 656/15390 embeddings done
# 657/15390 embeddings done
# 658/15390 embeddings done
# 659/15390 embeddings done
# 660/15390 embeddings done
# 661/15390 embeddings done
# 662/15390 embeddings done
# 663/15390 embeddings done
# 664/15390 embeddings done
# 665/15390 embeddings done
# 666/15390 embeddings done
# 667/15390 embeddings done
# 668/15390 embeddings done
# 669/15390 embeddings done
# 670/15390 embeddings done
# 671/15390 embeddings done
# 672/15390 embeddings done
# 673/15390 embeddings done
# 674/15390 embeddings done
# 675/15390 embeddings done
# 676/15390 embeddings done
# 677/15390 embeddings done
# 678/15390 embeddings done
# 679/15390 embeddings done
# 680/15390 embeddings done
# 681/15390 embeddings done
# 682/15390 embeddings done
# 683/15390 embeddings done
# 684/15390 embeddings done
# 685/15390 embeddings done
# 686/15390 embeddings done
# 687/15390 embeddings done
# 688/15390 embeddings done
# 689/15390 embeddings done
# 690/15390 embeddings done
# 691/15390 embeddings done
# 692/15390 embeddings done
# 693/15390 embeddings done
# 694/15390 embeddings done
# 695/15390 embeddings done
# 696/15390 embeddings done
# 697/15390 embeddings done
# 698/15390 embeddings done
# 699/15390 embeddings done
# 700/15390 embeddings done
# 701/15390 embeddings done
# 702/15390 embeddings done
# 703/15390 embeddings done
# 704/15390 embeddings done
# 705/15390 embeddings done
# 706/15390 embeddings done
# 707/15390 embeddings done
# 708/15390 embeddings done
# 709/15390 embeddings done
# 710/15390 embeddings done
# 711/15390 embeddings done
# 712/15390 embeddings done
# 713/15390 embeddings done
# 714/15390 embeddings done
# 715/15390 embeddings done
# 716/15390 embeddings done
# 717/15390 embeddings done
# 718/15390 embeddings done
# 719/15390 embeddings done
# 720/15390 embeddings done
# 721/15390 embeddings done
# 722/15390 embeddings done
# 723/15390 embeddings done
# 724/15390 embeddings done
# 725/15390 embeddings done
# 726/15390 embeddings done
# 727/15390 embeddings done
# 728/15390 embeddings done
# 729/15390 embeddings done
# 730/15390 embeddings done
# 731/15390 embeddings done
# 732/15390 embeddings done
# 733/15390 embeddings done
# 734/15390 embeddings done
# 735/15390 embeddings done
# 736/15390 embeddings done
# 737/15390 embeddings done
# 738/15390 embeddings done
# 739/15390 embeddings done
# 740/15390 embeddings done
# 741/15390 embeddings done
# 742/15390 embeddings done
# 743/15390 embeddings done
# 744/15390 embeddings done
# 745/15390 embeddings done
# 746/15390 embeddings done
# 747/15390 embeddings done
# 748/15390 embeddings done
# 749/15390 embeddings done
# 750/15390 embeddings done
# 751/15390 embeddings done
# 752/15390 embeddings done
# 753/15390 embeddings done
# 754/15390 embeddings done
# 755/15390 embeddings done
# 756/15390 embeddings done
# 757/15390 embeddings done
# 758/15390 embeddings done
# 759/15390 embeddings done
# 760/15390 embeddings done
# 761/15390 embeddings done
# 762/15390 embeddings done
# 763/15390 embeddings done
# 764/15390 embeddings done
# 765/15390 embeddings done
# 766/15390 embeddings done
# 767/15390 embeddings done
# 768/15390 embeddings done
# 769/15390 embeddings done
# 770/15390 embeddings done
# 771/15390 embeddings done
# 772/15390 embeddings done
# 773/15390 embeddings done
# 774/15390 embeddings done
# 775/15390 embeddings done
# 776/15390 embeddings done
# 777/15390 embeddings done
# 778/15390 embeddings done
# 779/15390 embeddings done
# 780/15390 embeddings done
# 781/15390 embeddings done
# 782/15390 embeddings done
# 783/15390 embeddings done
# 784/15390 embeddings done
# 785/15390 embeddings done
# 786/15390 embeddings done
# 787/15390 embeddings done
# 788/15390 embeddings done
# 789/15390 embeddings done
# 790/15390 embeddings done
# 791/15390 embeddings done
# 792/15390 embeddings done
# 793/15390 embeddings done
# 794/15390 embeddings done
# 795/15390 embeddings done
# 796/15390 embeddings done
# 797/15390 embeddings done
# 798/15390 embeddings done
# 799/15390 embeddings done
# 800/15390 embeddings done
# 801/15390 embeddings done
# 802/15390 embeddings done
# 803/15390 embeddings done
# 804/15390 embeddings done
# 805/15390 embeddings done
# 806/15390 embeddings done
# 807/15390 embeddings done
# 808/15390 embeddings done
# 809/15390 embeddings done
# 810/15390 embeddings done
# 811/15390 embeddings done
# 812/15390 embeddings done
# 813/15390 embeddings done
# 814/15390 embeddings done
# 815/15390 embeddings done
# 816/15390 embeddings done
# 817/15390 embeddings done
# 818/15390 embeddings done
# 819/15390 embeddings done
# 820/15390 embeddings done
# 821/15390 embeddings done
# 822/15390 embeddings done
# 823/15390 embeddings done
# 824/15390 embeddings done
# 825/15390 embeddings done
# 826/15390 embeddings done
# 827/15390 embeddings done
# 828/15390 embeddings done
# 829/15390 embeddings done
# 830/15390 embeddings done
# 831/15390 embeddings done
# 832/15390 embeddings done
# 833/15390 embeddings done
# 834/15390 embeddings done
# 835/15390 embeddings done
# 836/15390 embeddings done
# 837/15390 embeddings done
# 838/15390 embeddings done
# 839/15390 embeddings done
# 840/15390 embeddings done
# 841/15390 embeddings done
# 842/15390 embeddings done
# 843/15390 embeddings done
# 844/15390 embeddings done
# 845/15390 embeddings done
# 846/15390 embeddings done
# 847/15390 embeddings done
# 848/15390 embeddings done
# 849/15390 embeddings done
# 850/15390 embeddings done
# 851/15390 embeddings done
# 852/15390 embeddings done
# 853/15390 embeddings done
# 854/15390 embeddings done
# 855/15390 embeddings done
# 856/15390 embeddings done
# 857/15390 embeddings done
# 858/15390 embeddings done
# 859/15390 embeddings done
# 860/15390 embeddings done
# 861/15390 embeddings done
# 862/15390 embeddings done
# 863/15390 embeddings done
# 864/15390 embeddings done
# 865/15390 embeddings done
# 866/15390 embeddings done
# 867/15390 embeddings done
# 868/15390 embeddings done
# 869/15390 embeddings done
# 870/15390 embeddings done
# 871/15390 embeddings done
# 872/15390 embeddings done
# 873/15390 embeddings done
# 874/15390 embeddings done
# 875/15390 embeddings done
# 876/15390 embeddings done
# 877/15390 embeddings done
# 878/15390 embeddings done
# 879/15390 embeddings done
# 880/15390 embeddings done
# 881/15390 embeddings done
# 882/15390 embeddings done
# 883/15390 embeddings done
# 884/15390 embeddings done
# 885/15390 embeddings done
# 886/15390 embeddings done
# 887/15390 embeddings done
# 888/15390 embeddings done
# 889/15390 embeddings done
# 890/15390 embeddings done
# 891/15390 embeddings done
# 892/15390 embeddings done
# 893/15390 embeddings done
# 894/15390 embeddings done
# 895/15390 embeddings done
# 896/15390 embeddings done
# 897/15390 embeddings done
# 898/15390 embeddings done
# 899/15390 embeddings done
# 900/15390 embeddings done
# 901/15390 embeddings done
# 902/15390 embeddings done
# 903/15390 embeddings done
# 904/15390 embeddings done
# 905/15390 embeddings done
# 906/15390 embeddings done
# 907/15390 embeddings done
# 908/15390 embeddings done
# 909/15390 embeddings done
# 910/15390 embeddings done
# 911/15390 embeddings done
# 912/15390 embeddings done
# 913/15390 embeddings done
# 914/15390 embeddings done
# 915/15390 embeddings done
# 916/15390 embeddings done
# 917/15390 embeddings done
# 918/15390 embeddings done
# 919/15390 embeddings done
# 920/15390 embeddings done
# 921/15390 embeddings done
# 922/15390 embeddings done
# 923/15390 embeddings done
# 924/15390 embeddings done
# 925/15390 embeddings done
# 926/15390 embeddings done
# 927/15390 embeddings done
# 928/15390 embeddings done
# 929/15390 embeddings done
# 930/15390 embeddings done
# 931/15390 embeddings done
# 932/15390 embeddings done
# 933/15390 embeddings done
# 934/15390 embeddings done
# 935/15390 embeddings done
# 936/15390 embeddings done
# 937/15390 embeddings done
# 938/15390 embeddings done
# 939/15390 embeddings done
# 940/15390 embeddings done
# 941/15390 embeddings done
# 942/15390 embeddings done
# 943/15390 embeddings done
# 944/15390 embeddings done
# 945/15390 embeddings done
# 946/15390 embeddings done
# 947/15390 embeddings done
# 948/15390 embeddings done
# 949/15390 embeddings done
# 950/15390 embeddings done
# 951/15390 embeddings done
# 952/15390 embeddings done
# 953/15390 embeddings done
# 954/15390 embeddings done
# 955/15390 embeddings done
# 956/15390 embeddings done
# 957/15390 embeddings done
# 958/15390 embeddings done
# 959/15390 embeddings done
# 960/15390 embeddings done
# 961/15390 embeddings done
# 962/15390 embeddings done
# 963/15390 embeddings done
# 964/15390 embeddings done
# 965/15390 embeddings done
# 966/15390 embeddings done
# 967/15390 embeddings done
# 968/15390 embeddings done
# 969/15390 embeddings done
# 970/15390 embeddings done
# 971/15390 embeddings done
# 972/15390 embeddings done
# 973/15390 embeddings done
# 974/15390 embeddings done
# 975/15390 embeddings done
# 976/15390 embeddings done
# 977/15390 embeddings done
# 978/15390 embeddings done
# 979/15390 embeddings done
# 980/15390 embeddings done
# 981/15390 embeddings done
# 982/15390 embeddings done
# 983/15390 embeddings done
# 984/15390 embeddings done
# 985/15390 embeddings done
# 986/15390 embeddings done
# 987/15390 embeddings done
# 988/15390 embeddings done
# 989/15390 embeddings done
# 990/15390 embeddings done
# 991/15390 embeddings done
# 992/15390 embeddings done
# 993/15390 embeddings done
# 994/15390 embeddings done
# 995/15390 embeddings done
# 996/15390 embeddings done
# 997/15390 embeddings done
# 998/15390 embeddings done
# 999/15390 embeddings done
# 1000/15390 embeddings done
# 1001/15390 embeddings done
# 1002/15390 embeddings done
# 1003/15390 embeddings done
# 1004/15390 embeddings done
# 1005/15390 embeddings done
# 1006/15390 embeddings done
# 1007/15390 embeddings done
# 1008/15390 embeddings done
# 1009/15390 embeddings done
# 1010/15390 embeddings done
# 1011/15390 embeddings done
# 1012/15390 embeddings done
# 1013/15390 embeddings done
# 1014/15390 embeddings done
# 1015/15390 embeddings done
# 1016/15390 embeddings done
# 1017/15390 embeddings done
# 1018/15390 embeddings done
# 1019/15390 embeddings done
# 1020/15390 embeddings done
# 1021/15390 embeddings done
# 1022/15390 embeddings done
# 1023/15390 embeddings done
# 1024/15390 embeddings done
# 1025/15390 embeddings done
# 1026/15390 embeddings done
# 1027/15390 embeddings done
# 1028/15390 embeddings done
# 1029/15390 embeddings done
# 1030/15390 embeddings done
# 1031/15390 embeddings done
# 1032/15390 embeddings done
# 1033/15390 embeddings done
# 1034/15390 embeddings done
# 1035/15390 embeddings done
# 1036/15390 embeddings done
# 1037/15390 embeddings done
# 1038/15390 embeddings done
# 1039/15390 embeddings done
# 1040/15390 embeddings done
# 1041/15390 embeddings done
# 1042/15390 embeddings done
# 1043/15390 embeddings done
# 1044/15390 embeddings done
# 1045/15390 embeddings done
# 1046/15390 embeddings done
# 1047/15390 embeddings done
# 1048/15390 embeddings done
# 1049/15390 embeddings done
# 1050/15390 embeddings done
# 1051/15390 embeddings done
# 1052/15390 embeddings done
# 1053/15390 embeddings done
# 1054/15390 embeddings done
# 1055/15390 embeddings done
# 1056/15390 embeddings done
# 1057/15390 embeddings done
# 1058/15390 embeddings done
# 1059/15390 embeddings done
# 1060/15390 embeddings done
# 1061/15390 embeddings done
# 1062/15390 embeddings done
# 1063/15390 embeddings done
# 1064/15390 embeddings done
# 1065/15390 embeddings done
# 1066/15390 embeddings done
# 1067/15390 embeddings done
# 1068/15390 embeddings done
# 1069/15390 embeddings done
# 1070/15390 embeddings done
# 1071/15390 embeddings done
# 1072/15390 embeddings done
# 1073/15390 embeddings done
# 1074/15390 embeddings done
# 1075/15390 embeddings done
# 1076/15390 embeddings done
# 1077/15390 embeddings done
# 1078/15390 embeddings done
# 1079/15390 embeddings done
# 1080/15390 embeddings done
# 1081/15390 embeddings done
# 1082/15390 embeddings done
# 1083/15390 embeddings done
# 1084/15390 embeddings done
# 1085/15390 embeddings done
# 1086/15390 embeddings done
# 1087/15390 embeddings done
# 1088/15390 embeddings done
# 1089/15390 embeddings done
# 1090/15390 embeddings done
# 1091/15390 embeddings done
# 1092/15390 embeddings done
# 1093/15390 embeddings done
# 1094/15390 embeddings done
# 1095/15390 embeddings done
# 1096/15390 embeddings done
# 1097/15390 embeddings done
# 1098/15390 embeddings done
# 1099/15390 embeddings done
# 1100/15390 embeddings done
# 1101/15390 embeddings done
# 1102/15390 embeddings done
# 1103/15390 embeddings done
# 1104/15390 embeddings done
# 1105/15390 embeddings done
# 1106/15390 embeddings done
# 1107/15390 embeddings done
# 1108/15390 embeddings done
# 1109/15390 embeddings done
# 1110/15390 embeddings done
# 1111/15390 embeddings done
# 1112/15390 embeddings done
# 1113/15390 embeddings done
# 1114/15390 embeddings done
# 1115/15390 embeddings done
# 1116/15390 embeddings done
# 1117/15390 embeddings done
# 1118/15390 embeddings done
# 1119/15390 embeddings done
# 1120/15390 embeddings done
# 1121/15390 embeddings done
# 1122/15390 embeddings done
# 1123/15390 embeddings done
# 1124/15390 embeddings done
# 1125/15390 embeddings done
# 1126/15390 embeddings done
# 1127/15390 embeddings done
# 1128/15390 embeddings done
# 1129/15390 embeddings done
# 1130/15390 embeddings done
# 1131/15390 embeddings done
# 1132/15390 embeddings done
# 1133/15390 embeddings done
# 1134/15390 embeddings done
# 1135/15390 embeddings done
# 1136/15390 embeddings done
# 1137/15390 embeddings done
# 1138/15390 embeddings done
# 1139/15390 embeddings done
# 1140/15390 embeddings done
# 1141/15390 embeddings done
# 1142/15390 embeddings done
# 1143/15390 embeddings done
# 1144/15390 embeddings done
# 1145/15390 embeddings done
# 1146/15390 embeddings done
# 1147/15390 embeddings done
# 1148/15390 embeddings done
# 1149/15390 embeddings done
# 1150/15390 embeddings done
# 1151/15390 embeddings done
# 1152/15390 embeddings done
# 1153/15390 embeddings done
# 1154/15390 embeddings done
# 1155/15390 embeddings done
# 1156/15390 embeddings done
# 1157/15390 embeddings done
# 1158/15390 embeddings done
# 1159/15390 embeddings done
# 1160/15390 embeddings done
# 1161/15390 embeddings done
# 1162/15390 embeddings done
# 1163/15390 embeddings done
# 1164/15390 embeddings done
# 1165/15390 embeddings done
# 1166/15390 embeddings done
# 1167/15390 embeddings done
# 1168/15390 embeddings done
# 1169/15390 embeddings done
# 1170/15390 embeddings done
# 1171/15390 embeddings done
# 1172/15390 embeddings done
# 1173/15390 embeddings done
# 1174/15390 embeddings done
# 1175/15390 embeddings done
# 1176/15390 embeddings done
# 1177/15390 embeddings done
# 1178/15390 embeddings done
# 1179/15390 embeddings done
# 1180/15390 embeddings done
# 1181/15390 embeddings done
# 1182/15390 embeddings done
# 1183/15390 embeddings done
# 1184/15390 embeddings done
# 1185/15390 embeddings done
# 1186/15390 embeddings done
# 1187/15390 embeddings done
# 1188/15390 embeddings done
# 1189/15390 embeddings done
# 1190/15390 embeddings done
# 1191/15390 embeddings done
# 1192/15390 embeddings done
# 1193/15390 embeddings done
# 1194/15390 embeddings done
# 1195/15390 embeddings done
# 1196/15390 embeddings done
# 1197/15390 embeddings done
# 1198/15390 embeddings done
# 1199/15390 embeddings done
# 1200/15390 embeddings done
# 1201/15390 embeddings done
# 1202/15390 embeddings done
# 1203/15390 embeddings done
# 1204/15390 embeddings done
# 1205/15390 embeddings done
# 1206/15390 embeddings done
# 1207/15390 embeddings done
# 1208/15390 embeddings done
# 1209/15390 embeddings done
# 1210/15390 embeddings done
# 1211/15390 embeddings done
# 1212/15390 embeddings done
# 1213/15390 embeddings done
# 1214/15390 embeddings done
# 1215/15390 embeddings done
# 1216/15390 embeddings done
# 1217/15390 embeddings done
# 1218/15390 embeddings done
# 1219/15390 embeddings done
# 1220/15390 embeddings done
# 1221/15390 embeddings done
# 1222/15390 embeddings done
# 1223/15390 embeddings done
# 1224/15390 embeddings done
# 1225/15390 embeddings done
# 1226/15390 embeddings done
# 1227/15390 embeddings done
# 1228/15390 embeddings done
# 1229/15390 embeddings done
# 1230/15390 embeddings done
# 1231/15390 embeddings done
# 1232/15390 embeddings done
# 1233/15390 embeddings done
# 1234/15390 embeddings done
# 1235/15390 embeddings done
# 1236/15390 embeddings done
# 1237/15390 embeddings done
# 1238/15390 embeddings done
# 1239/15390 embeddings done
# 1240/15390 embeddings done
# 1241/15390 embeddings done
# 1242/15390 embeddings done
# 1243/15390 embeddings done
# 1244/15390 embeddings done
# 1245/15390 embeddings done
# 1246/15390 embeddings done
# 1247/15390 embeddings done
# 1248/15390 embeddings done
# 1249/15390 embeddings done
# 1250/15390 embeddings done
# 1251/15390 embeddings done
# 1252/15390 embeddings done
# 1253/15390 embeddings done
# 1254/15390 embeddings done
# 1255/15390 embeddings done
# 1256/15390 embeddings done
# 1257/15390 embeddings done
# 1258/15390 embeddings done
# 1259/15390 embeddings done
# 1260/15390 embeddings done
# 1261/15390 embeddings done
# 1262/15390 embeddings done
# 1263/15390 embeddings done
# 1264/15390 embeddings done
# 1265/15390 embeddings done
# 1266/15390 embeddings done
# 1267/15390 embeddings done
# 1268/15390 embeddings done
# 1269/15390 embeddings done
# 1270/15390 embeddings done
# 1271/15390 embeddings done
# 1272/15390 embeddings done
# 1273/15390 embeddings done
# 1274/15390 embeddings done
# 1275/15390 embeddings done
# 1276/15390 embeddings done
# 1277/15390 embeddings done
# 1278/15390 embeddings done
# 1279/15390 embeddings done
# 1280/15390 embeddings done
# 1281/15390 embeddings done
# 1282/15390 embeddings done
# 1283/15390 embeddings done
# 1284/15390 embeddings done
# 1285/15390 embeddings done
# 1286/15390 embeddings done
# 1287/15390 embeddings done
# 1288/15390 embeddings done
# 1289/15390 embeddings done
# 1290/15390 embeddings done
# 1291/15390 embeddings done
# 1292/15390 embeddings done
# 1293/15390 embeddings done
# 1294/15390 embeddings done
# 1295/15390 embeddings done
# 1296/15390 embeddings done
# 1297/15390 embeddings done
# 1298/15390 embeddings done
# 1299/15390 embeddings done
# 1300/15390 embeddings done
# 1301/15390 embeddings done
# 1302/15390 embeddings done
# 1303/15390 embeddings done
# 1304/15390 embeddings done
# 1305/15390 embeddings done
# 1306/15390 embeddings done
# 1307/15390 embeddings done
# 1308/15390 embeddings done
# 1309/15390 embeddings done
# 1310/15390 embeddings done
# 1311/15390 embeddings done
# 1312/15390 embeddings done
# 1313/15390 embeddings done
# 1314/15390 embeddings done
# 1315/15390 embeddings done
# 1316/15390 embeddings done
# 1317/15390 embeddings done
# 1318/15390 embeddings done
# 1319/15390 embeddings done
# 1320/15390 embeddings done
# 1321/15390 embeddings done
# 1322/15390 embeddings done
# 1323/15390 embeddings done
# 1324/15390 embeddings done
# 1325/15390 embeddings done
# 1326/15390 embeddings done
# 1327/15390 embeddings done
# 1328/15390 embeddings done
# 1329/15390 embeddings done
# 1330/15390 embeddings done
# 1331/15390 embeddings done
# 1332/15390 embeddings done
# 1333/15390 embeddings done
# 1334/15390 embeddings done
# 1335/15390 embeddings done
# 1336/15390 embeddings done
# 1337/15390 embeddings done
# 1338/15390 embeddings done
# 1339/15390 embeddings done
# 1340/15390 embeddings done
# 1341/15390 embeddings done
# 1342/15390 embeddings done
# 1343/15390 embeddings done
# 1344/15390 embeddings done
# 1345/15390 embeddings done
# 1346/15390 embeddings done
# 1347/15390 embeddings done
# 1348/15390 embeddings done
# 1349/15390 embeddings done
# 1350/15390 embeddings done
# 1351/15390 embeddings done
# 1352/15390 embeddings done
# 1353/15390 embeddings done
# 1354/15390 embeddings done
# 1355/15390 embeddings done
# 1356/15390 embeddings done
# 1357/15390 embeddings done
# 1358/15390 embeddings done
# 1359/15390 embeddings done
# 1360/15390 embeddings done
# 1361/15390 embeddings done
# 1362/15390 embeddings done
# 1363/15390 embeddings done
# 1364/15390 embeddings done
# 1365/15390 embeddings done
# 1366/15390 embeddings done
# 1367/15390 embeddings done
# 1368/15390 embeddings done
# 1369/15390 embeddings done
# 1370/15390 embeddings done
# 1371/15390 embeddings done
# 1372/15390 embeddings done
# 1373/15390 embeddings done
# 1374/15390 embeddings done
# 1375/15390 embeddings done
# 1376/15390 embeddings done
# 1377/15390 embeddings done
# 1378/15390 embeddings done
# 1379/15390 embeddings done
# 1380/15390 embeddings done
# 1381/15390 embeddings done
# 1382/15390 embeddings done
# 1383/15390 embeddings done
# 1384/15390 embeddings done
# 1385/15390 embeddings done
# 1386/15390 embeddings done
# 1387/15390 embeddings done
# 1388/15390 embeddings done
# 1389/15390 embeddings done
# 1390/15390 embeddings done
# 1391/15390 embeddings done
# 1392/15390 embeddings done
# 1393/15390 embeddings done
# 1394/15390 embeddings done
# 1395/15390 embeddings done
# 1396/15390 embeddings done
# 1397/15390 embeddings done
# 1398/15390 embeddings done
# 1399/15390 embeddings done
# 1400/15390 embeddings done
# 1401/15390 embeddings done
# 1402/15390 embeddings done
# 1403/15390 embeddings done
# 1404/15390 embeddings done
# 1405/15390 embeddings done
# 1406/15390 embeddings done
# 1407/15390 embeddings done
# 1408/15390 embeddings done
# 1409/15390 embeddings done
# 1410/15390 embeddings done
# 1411/15390 embeddings done
# 1412/15390 embeddings done
# 1413/15390 embeddings done
# 1414/15390 embeddings done
# 1415/15390 embeddings done
# 1416/15390 embeddings done
# 1417/15390 embeddings done
# 1418/15390 embeddings done
# 1419/15390 embeddings done
# 1420/15390 embeddings done
# 1421/15390 embeddings done
# 1422/15390 embeddings done
# 1423/15390 embeddings done
# 1424/15390 embeddings done
# 1425/15390 embeddings done
# 1426/15390 embeddings done
# 1427/15390 embeddings done
# 1428/15390 embeddings done
# 1429/15390 embeddings done
# 1430/15390 embeddings done
# 1431/15390 embeddings done
# 1432/15390 embeddings done
# 1433/15390 embeddings done
# 1434/15390 embeddings done
# 1435/15390 embeddings done
# 1436/15390 embeddings done
# 1437/15390 embeddings done
# 1438/15390 embeddings done
# 1439/15390 embeddings done
# 1440/15390 embeddings done
# 1441/15390 embeddings done
# 1442/15390 embeddings done
# 1443/15390 embeddings done
# 1444/15390 embeddings done
# 1445/15390 embeddings done
# 1446/15390 embeddings done
# 1447/15390 embeddings done
# 1448/15390 embeddings done
# 1449/15390 embeddings done
# 1450/15390 embeddings done
# 1451/15390 embeddings done
# 1452/15390 embeddings done
# 1453/15390 embeddings done
# 1454/15390 embeddings done
# 1455/15390 embeddings done
# 1456/15390 embeddings done
# 1457/15390 embeddings done
# 1458/15390 embeddings done
# 1459/15390 embeddings done
# 1460/15390 embeddings done
# 1461/15390 embeddings done
# 1462/15390 embeddings done
# 1463/15390 embeddings done
# 1464/15390 embeddings done
# 1465/15390 embeddings done
# 1466/15390 embeddings done
# 1467/15390 embeddings done
# 1468/15390 embeddings done
# 1469/15390 embeddings done
# 1470/15390 embeddings done
# 1471/15390 embeddings done
# 1472/15390 embeddings done
# 1473/15390 embeddings done
# 1474/15390 embeddings done
# 1475/15390 embeddings done
# 1476/15390 embeddings done
# 1477/15390 embeddings done
# 1478/15390 embeddings done
# 1479/15390 embeddings done
# 1480/15390 embeddings done
# 1481/15390 embeddings done
# 1482/15390 embeddings done
# 1483/15390 embeddings done
# 1484/15390 embeddings done
# 1485/15390 embeddings done
# 1486/15390 embeddings done
# 1487/15390 embeddings done
# 1488/15390 embeddings done
# 1489/15390 embeddings done
# 1490/15390 embeddings done
# 1491/15390 embeddings done
# 1492/15390 embeddings done
# 1493/15390 embeddings done
# 1494/15390 embeddings done
# 1495/15390 embeddings done
# 1496/15390 embeddings done
# 1497/15390 embeddings done
# 1498/15390 embeddings done
# 1499/15390 embeddings done
# 1500/15390 embeddings done
# 1501/15390 embeddings done
# 1502/15390 embeddings done
# 1503/15390 embeddings done
# 1504/15390 embeddings done
# 1505/15390 embeddings done
# 1506/15390 embeddings done
# 1507/15390 embeddings done
# 1508/15390 embeddings done
# 1509/15390 embeddings done
# 1510/15390 embeddings done
# 1511/15390 embeddings done
# 1512/15390 embeddings done
# 1513/15390 embeddings done
# 1514/15390 embeddings done
# 1515/15390 embeddings done
# 1516/15390 embeddings done
# 1517/15390 embeddings done
# 1518/15390 embeddings done
# 1519/15390 embeddings done
# 1520/15390 embeddings done
# 1521/15390 embeddings done
# 1522/15390 embeddings done
# 1523/15390 embeddings done
# 1524/15390 embeddings done
# 1525/15390 embeddings done
# 1526/15390 embeddings done
# 1527/15390 embeddings done
# 1528/15390 embeddings done
# 1529/15390 embeddings done
# 1530/15390 embeddings done
# 1531/15390 embeddings done
# 1532/15390 embeddings done
# 1533/15390 embeddings done
# 1534/15390 embeddings done
# 1535/15390 embeddings done
# 1536/15390 embeddings done
# 1537/15390 embeddings done
# 1538/15390 embeddings done
# 1539/15390 embeddings done
# 1540/15390 embeddings done
# 1541/15390 embeddings done
# 1542/15390 embeddings done
# 1543/15390 embeddings done
# 1544/15390 embeddings done
# 1545/15390 embeddings done
# 1546/15390 embeddings done
# 1547/15390 embeddings done
# 1548/15390 embeddings done
# 1549/15390 embeddings done
# 1550/15390 embeddings done
# 1551/15390 embeddings done
# 1552/15390 embeddings done
# 1553/15390 embeddings done
# 1554/15390 embeddings done
# 1555/15390 embeddings done
# 1556/15390 embeddings done
# 1557/15390 embeddings done
# 1558/15390 embeddings done
# 1559/15390 embeddings done
# 1560/15390 embeddings done
# 1561/15390 embeddings done
# 1562/15390 embeddings done
# 1563/15390 embeddings done
# 1564/15390 embeddings done
# 1565/15390 embeddings done
# 1566/15390 embeddings done
# 1567/15390 embeddings done
# 1568/15390 embeddings done
# 1569/15390 embeddings done
# 1570/15390 embeddings done
# 1571/15390 embeddings done
# 1572/15390 embeddings done
# 1573/15390 embeddings done
# 1574/15390 embeddings done
# 1575/15390 embeddings done
# 1576/15390 embeddings done
# 1577/15390 embeddings done
# 1578/15390 embeddings done
# 1579/15390 embeddings done
# 1580/15390 embeddings done
# 1581/15390 embeddings done
# 1582/15390 embeddings done
# 1583/15390 embeddings done
# 1584/15390 embeddings done
# 1585/15390 embeddings done
# 1586/15390 embeddings done
# 1587/15390 embeddings done
# 1588/15390 embeddings done
# 1589/15390 embeddings done
# 1590/15390 embeddings done
# 1591/15390 embeddings done
# 1592/15390 embeddings done
# 1593/15390 embeddings done
# 1594/15390 embeddings done
# 1595/15390 embeddings done
# 1596/15390 embeddings done
# 1597/15390 embeddings done
# 1598/15390 embeddings done
# 1599/15390 embeddings done
# 1600/15390 embeddings done
# 1601/15390 embeddings done
# 1602/15390 embeddings done
# 1603/15390 embeddings done
# 1604/15390 embeddings done
# 1605/15390 embeddings done
# 1606/15390 embeddings done
# 1607/15390 embeddings done
# 1608/15390 embeddings done
# 1609/15390 embeddings done
# 1610/15390 embeddings done
# 1611/15390 embeddings done
# 1612/15390 embeddings done
# 1613/15390 embeddings done
# 1614/15390 embeddings done
# 1615/15390 embeddings done
# 1616/15390 embeddings done
# 1617/15390 embeddings done
# 1618/15390 embeddings done
# 1619/15390 embeddings done
# 1620/15390 embeddings done
# 1621/15390 embeddings done
# 1622/15390 embeddings done
# 1623/15390 embeddings done
# 1624/15390 embeddings done
# 1625/15390 embeddings done
# 1626/15390 embeddings done
# 1627/15390 embeddings done
# 1628/15390 embeddings done
# 1629/15390 embeddings done
# 1630/15390 embeddings done
# 1631/15390 embeddings done
# 1632/15390 embeddings done
# 1633/15390 embeddings done
# 1634/15390 embeddings done
# 1635/15390 embeddings done
# 1636/15390 embeddings done
# 1637/15390 embeddings done
# 1638/15390 embeddings done
# 1639/15390 embeddings done
# 1640/15390 embeddings done
# 1641/15390 embeddings done
# 1642/15390 embeddings done
# 1643/15390 embeddings done
# 1644/15390 embeddings done
# 1645/15390 embeddings done
# 1646/15390 embeddings done
# 1647/15390 embeddings done
# 1648/15390 embeddings done
# 1649/15390 embeddings done
# 1650/15390 embeddings done
# 1651/15390 embeddings done
# 1652/15390 embeddings done
# 1653/15390 embeddings done
# 1654/15390 embeddings done
# 1655/15390 embeddings done
# 1656/15390 embeddings done
# 1657/15390 embeddings done
# 1658/15390 embeddings done
# 1659/15390 embeddings done
# 1660/15390 embeddings done
# 1661/15390 embeddings done
# 1662/15390 embeddings done
# 1663/15390 embeddings done
# 1664/15390 embeddings done
# 1665/15390 embeddings done
# 1666/15390 embeddings done
# 1667/15390 embeddings done
# 1668/15390 embeddings done
# 1669/15390 embeddings done
# 1670/15390 embeddings done
# 1671/15390 embeddings done
# 1672/15390 embeddings done
# 1673/15390 embeddings done
# 1674/15390 embeddings done
# 1675/15390 embeddings done
# 1676/15390 embeddings done
# 1677/15390 embeddings done
# 1678/15390 embeddings done
# 1679/15390 embeddings done
# 1680/15390 embeddings done
# 1681/15390 embeddings done
# 1682/15390 embeddings done
# 1683/15390 embeddings done
# 1684/15390 embeddings done
# 1685/15390 embeddings done
# 1686/15390 embeddings done
# 1687/15390 embeddings done
# 1688/15390 embeddings done
# 1689/15390 embeddings done
# 1690/15390 embeddings done
# 1691/15390 embeddings done
# 1692/15390 embeddings done
# 1693/15390 embeddings done
# 1694/15390 embeddings done
# 1695/15390 embeddings done
# 1696/15390 embeddings done
# 1697/15390 embeddings done
# 1698/15390 embeddings done
# 1699/15390 embeddings done
# 1700/15390 embeddings done
# 1701/15390 embeddings done
# 1702/15390 embeddings done
# 1703/15390 embeddings done
# 1704/15390 embeddings done
# 1705/15390 embeddings done
# 1706/15390 embeddings done
# 1707/15390 embeddings done
# 1708/15390 embeddings done
# 1709/15390 embeddings done
# 1710/15390 embeddings done
# 1711/15390 embeddings done
# 1712/15390 embeddings done
# 1713/15390 embeddings done
# 1714/15390 embeddings done
# 1715/15390 embeddings done
# 1716/15390 embeddings done
# 1717/15390 embeddings done
# 1718/15390 embeddings done
# 1719/15390 embeddings done
# 1720/15390 embeddings done
# 1721/15390 embeddings done
# 1722/15390 embeddings done
# 1723/15390 embeddings done
# 1724/15390 embeddings done
# 1725/15390 embeddings done
# 1726/15390 embeddings done
# 1727/15390 embeddings done
# 1728/15390 embeddings done
# 1729/15390 embeddings done
# 1730/15390 embeddings done
# 1731/15390 embeddings done
# 1732/15390 embeddings done
# 1733/15390 embeddings done
# 1734/15390 embeddings done
# 1735/15390 embeddings done
# 1736/15390 embeddings done
# 1737/15390 embeddings done
# 1738/15390 embeddings done
# 1739/15390 embeddings done
# 1740/15390 embeddings done
# 1741/15390 embeddings done
# 1742/15390 embeddings done
# 1743/15390 embeddings done
# 1744/15390 embeddings done
# 1745/15390 embeddings done
# 1746/15390 embeddings done
# 1747/15390 embeddings done
# 1748/15390 embeddings done
# 1749/15390 embeddings done
# 1750/15390 embeddings done
# 1751/15390 embeddings done
# 1752/15390 embeddings done
# 1753/15390 embeddings done
# 1754/15390 embeddings done
# 1755/15390 embeddings done
# 1756/15390 embeddings done
# 1757/15390 embeddings done
# 1758/15390 embeddings done
# 1759/15390 embeddings done
# 1760/15390 embeddings done
# 1761/15390 embeddings done
# 1762/15390 embeddings done
# 1763/15390 embeddings done
# 1764/15390 embeddings done
# 1765/15390 embeddings done
# 1766/15390 embeddings done
# 1767/15390 embeddings done
# 1768/15390 embeddings done
# 1769/15390 embeddings done
# 1770/15390 embeddings done
# 1771/15390 embeddings done
# 1772/15390 embeddings done
# 1773/15390 embeddings done
# 1774/15390 embeddings done
# 1775/15390 embeddings done
# 1776/15390 embeddings done
# 1777/15390 embeddings done
# 1778/15390 embeddings done
# 1779/15390 embeddings done
# 1780/15390 embeddings done
# 1781/15390 embeddings done
# 1782/15390 embeddings done
# 1783/15390 embeddings done
# 1784/15390 embeddings done
# 1785/15390 embeddings done
# 1786/15390 embeddings done
# 1787/15390 embeddings done
# 1788/15390 embeddings done
# 1789/15390 embeddings done
# 1790/15390 embeddings done
# 1791/15390 embeddings done
# 1792/15390 embeddings done
# 1793/15390 embeddings done
# 1794/15390 embeddings done
# 1795/15390 embeddings done
# 1796/15390 embeddings done
# 1797/15390 embeddings done
# 1798/15390 embeddings done
# 1799/15390 embeddings done
# 1800/15390 embeddings done
# 1801/15390 embeddings done
# 1802/15390 embeddings done
# ...
# 14827/15390 embeddings done
# 14828/15390 embeddings done
# 14829/15390 embeddings done
# 14830/15390 embeddings done
# 14831/15390 embeddings done
# 14832/15390 embeddings done
# 14833/15390 embeddings done
# 14834/15390 embeddings done
# 14835/15390 embeddings done
# 14836/15390 embeddings done
# 14837/15390 embeddings done
# 14838/15390 embeddings done
# 14839/15390 embeddings done
# 14840/15390 embeddings done
# 14841/15390 embeddings done
# 14842/15390 embeddings done
# 14843/15390 embeddings done
# 14844/15390 embeddings done
# 14845/15390 embeddings done
# 14846/15390 embeddings done
# 14847/15390 embeddings done
# 14848/15390 embeddings done
# 14849/15390 embeddings done
# 14850/15390 embeddings done
# 14851/15390 embeddings done
# 14852/15390 embeddings done
# 14853/15390 embeddings done
# 14854/15390 embeddings done
# 14855/15390 embeddings done
# 14856/15390 embeddings done
# 14857/15390 embeddings done
# 14858/15390 embeddings done
# 14859/15390 embeddings done
# 14860/15390 embeddings done
# 14861/15390 embeddings done
# 14862/15390 embeddings done
# 14863/15390 embeddings done
# 14864/15390 embeddings done
# 14865/15390 embeddings done
# 14866/15390 embeddings done
# 14867/15390 embeddings done
# 14868/15390 embeddings done
# 14869/15390 embeddings done
# 14870/15390 embeddings done
# 14871/15390 embeddings done
# 14872/15390 embeddings done
# 14873/15390 embeddings done
# 14874/15390 embeddings done
# 14875/15390 embeddings done
# 14876/15390 embeddings done
# 14877/15390 embeddings done
# 14878/15390 embeddings done
# 14879/15390 embeddings done
# 14880/15390 embeddings done
# 14881/15390 embeddings done
# 14882/15390 embeddings done
# 14883/15390 embeddings done
# 14884/15390 embeddings done
# 14885/15390 embeddings done
# 14886/15390 embeddings done
# 14887/15390 embeddings done
# 14888/15390 embeddings done
# 14889/15390 embeddings done
# 14890/15390 embeddings done
# 14891/15390 embeddings done
# 14892/15390 embeddings done
# 14893/15390 embeddings done
# 14894/15390 embeddings done
# 14895/15390 embeddings done
# 14896/15390 embeddings done
# 14897/15390 embeddings done
# 14898/15390 embeddings done
# 14899/15390 embeddings done
# 14900/15390 embeddings done
# 14901/15390 embeddings done
# 14902/15390 embeddings done
# 14903/15390 embeddings done
# 14904/15390 embeddings done
# 14905/15390 embeddings done
# 14906/15390 embeddings done
# 14907/15390 embeddings done
# 14908/15390 embeddings done
# 14909/15390 embeddings done
# 14910/15390 embeddings done
# 14911/15390 embeddings done
# 14912/15390 embeddings done
# 14913/15390 embeddings done
# 14914/15390 embeddings done
# 14915/15390 embeddings done
# 14916/15390 embeddings done
# 14917/15390 embeddings done
# 14918/15390 embeddings done
# 14919/15390 embeddings done
# 14920/15390 embeddings done
# 14921/15390 embeddings done
# 14922/15390 embeddings done
# 14923/15390 embeddings done
# 14924/15390 embeddings done
# 14925/15390 embeddings done
# 14926/15390 embeddings done
# 14927/15390 embeddings done
# 14928/15390 embeddings done
# 14929/15390 embeddings done
# 14930/15390 embeddings done
# 14931/15390 embeddings done
# 14932/15390 embeddings done
# 14933/15390 embeddings done
# 14934/15390 embeddings done
# 14935/15390 embeddings done
# 14936/15390 embeddings done
# 14937/15390 embeddings done
# 14938/15390 embeddings done
# 14939/15390 embeddings done
# 14940/15390 embeddings done
# 14941/15390 embeddings done
# 14942/15390 embeddings done
# 14943/15390 embeddings done
# 14944/15390 embeddings done
# 14945/15390 embeddings done
# 14946/15390 embeddings done
# 14947/15390 embeddings done
# 14948/15390 embeddings done
# 14949/15390 embeddings done
# 14950/15390 embeddings done
# 14951/15390 embeddings done
# 14952/15390 embeddings done
# 14953/15390 embeddings done
# 14954/15390 embeddings done
# 14955/15390 embeddings done
# 14956/15390 embeddings done
# 14957/15390 embeddings done
# 14958/15390 embeddings done
# 14959/15390 embeddings done
# 14960/15390 embeddings done
# 14961/15390 embeddings done
# 14962/15390 embeddings done
# 14963/15390 embeddings done
# 14964/15390 embeddings done
# 14965/15390 embeddings done
# 14966/15390 embeddings done
# 14967/15390 embeddings done
# 14968/15390 embeddings done
# 14969/15390 embeddings done
# 14970/15390 embeddings done
# 14971/15390 embeddings done
# 14972/15390 embeddings done
# 14973/15390 embeddings done
# 14974/15390 embeddings done
# 14975/15390 embeddings done
# 14976/15390 embeddings done
# 14977/15390 embeddings done
# 14978/15390 embeddings done
# 14979/15390 embeddings done
# 14980/15390 embeddings done
# 14981/15390 embeddings done
# 14982/15390 embeddings done
# 14983/15390 embeddings done
# 14984/15390 embeddings done
# 14985/15390 embeddings done
# 14986/15390 embeddings done
# 14987/15390 embeddings done
# 14988/15390 embeddings done
# 14989/15390 embeddings done
# 14990/15390 embeddings done
# 14991/15390 embeddings done
# 14992/15390 embeddings done
# 14993/15390 embeddings done
# 14994/15390 embeddings done
# 14995/15390 embeddings done
# 14996/15390 embeddings done
# 14997/15390 embeddings done
# 14998/15390 embeddings done
# 14999/15390 embeddings done
# 15000/15390 embeddings done
# 15001/15390 embeddings done
# 15002/15390 embeddings done
# 15003/15390 embeddings done
# 15004/15390 embeddings done
# 15005/15390 embeddings done
# 15006/15390 embeddings done
# 15007/15390 embeddings done
# 15008/15390 embeddings done
# 15009/15390 embeddings done
# 15010/15390 embeddings done
# 15011/15390 embeddings done
# 15012/15390 embeddings done
# 15013/15390 embeddings done
# 15014/15390 embeddings done
# 15015/15390 embeddings done
# 15016/15390 embeddings done
# 15017/15390 embeddings done
# 15018/15390 embeddings done
# 15019/15390 embeddings done
# 15020/15390 embeddings done
# 15021/15390 embeddings done
# 15022/15390 embeddings done
# 15023/15390 embeddings done
# 15024/15390 embeddings done
# 15025/15390 embeddings done
# 15026/15390 embeddings done
# 15027/15390 embeddings done
# 15028/15390 embeddings done
# 15029/15390 embeddings done
# 15030/15390 embeddings done
# 15031/15390 embeddings done
# 15032/15390 embeddings done
# 15033/15390 embeddings done
# 15034/15390 embeddings done
# 15035/15390 embeddings done
# 15036/15390 embeddings done
# 15037/15390 embeddings done
# 15038/15390 embeddings done
# 15039/15390 embeddings done
# 15040/15390 embeddings done
# 15041/15390 embeddings done
# 15042/15390 embeddings done
# 15043/15390 embeddings done
# 15044/15390 embeddings done
# 15045/15390 embeddings done
# 15046/15390 embeddings done
# 15047/15390 embeddings done
# 15048/15390 embeddings done
# 15049/15390 embeddings done
# 15050/15390 embeddings done
# 15051/15390 embeddings done
# 15052/15390 embeddings done
# 15053/15390 embeddings done
# 15054/15390 embeddings done
# 15055/15390 embeddings done
# 15056/15390 embeddings done
# 15057/15390 embeddings done
# 15058/15390 embeddings done
# 15059/15390 embeddings done
# 15060/15390 embeddings done
# 15061/15390 embeddings done
# 15062/15390 embeddings done
# 15063/15390 embeddings done
# 15064/15390 embeddings done
# 15065/15390 embeddings done
# 15066/15390 embeddings done
# 15067/15390 embeddings done
# 15068/15390 embeddings done
# 15069/15390 embeddings done
# 15070/15390 embeddings done
# 15071/15390 embeddings done
# 15072/15390 embeddings done
# 15073/15390 embeddings done
# 15074/15390 embeddings done
# 15075/15390 embeddings done
# 15076/15390 embeddings done
# 15077/15390 embeddings done
# 15078/15390 embeddings done
# 15079/15390 embeddings done
# 15080/15390 embeddings done
# 15081/15390 embeddings done
# 15082/15390 embeddings done
# 15083/15390 embeddings done
# 15084/15390 embeddings done
# 15085/15390 embeddings done
# 15086/15390 embeddings done
# 15087/15390 embeddings done
# 15088/15390 embeddings done
# 15089/15390 embeddings done
# 15090/15390 embeddings done
# 15091/15390 embeddings done
# 15092/15390 embeddings done
# 15093/15390 embeddings done
# 15094/15390 embeddings done
# 15095/15390 embeddings done
# 15096/15390 embeddings done
# 15097/15390 embeddings done
# 15098/15390 embeddings done
# 15099/15390 embeddings done
# 15100/15390 embeddings done
# 15101/15390 embeddings done
# 15102/15390 embeddings done
# 15103/15390 embeddings done
# 15104/15390 embeddings done
# 15105/15390 embeddings done
# 15106/15390 embeddings done
# 15107/15390 embeddings done
# 15108/15390 embeddings done
# 15109/15390 embeddings done
# 15110/15390 embeddings done
# 15111/15390 embeddings done
# 15112/15390 embeddings done
# 15113/15390 embeddings done
# 15114/15390 embeddings done
# 15115/15390 embeddings done
# 15116/15390 embeddings done
# 15117/15390 embeddings done
# 15118/15390 embeddings done
# 15119/15390 embeddings done
# 15120/15390 embeddings done
# 15121/15390 embeddings done
# 15122/15390 embeddings done
# 15123/15390 embeddings done
# 15124/15390 embeddings done
# 15125/15390 embeddings done
# 15126/15390 embeddings done
# 15127/15390 embeddings done
# 15128/15390 embeddings done
# 15129/15390 embeddings done
# 15130/15390 embeddings done
# 15131/15390 embeddings done
# 15132/15390 embeddings done
# 15133/15390 embeddings done
# 15134/15390 embeddings done
# 15135/15390 embeddings done
# 15136/15390 embeddings done
# 15137/15390 embeddings done
# 15138/15390 embeddings done
# 15139/15390 embeddings done
# 15140/15390 embeddings done
# 15141/15390 embeddings done
# 15142/15390 embeddings done
# 15143/15390 embeddings done
# 15144/15390 embeddings done
# 15145/15390 embeddings done
# 15146/15390 embeddings done
# 15147/15390 embeddings done
# 15148/15390 embeddings done
# 15149/15390 embeddings done
# 15150/15390 embeddings done
# 15151/15390 embeddings done
# 15152/15390 embeddings done
# 15153/15390 embeddings done
# 15154/15390 embeddings done
# 15155/15390 embeddings done
# 15156/15390 embeddings done
# 15157/15390 embeddings done
# 15158/15390 embeddings done
# 15159/15390 embeddings done
# 15160/15390 embeddings done
# 15161/15390 embeddings done
# 15162/15390 embeddings done
# 15163/15390 embeddings done
# 15164/15390 embeddings done
# 15165/15390 embeddings done
# 15166/15390 embeddings done
# 15167/15390 embeddings done
# 15168/15390 embeddings done
# 15169/15390 embeddings done
# 15170/15390 embeddings done
# 15171/15390 embeddings done
# 15172/15390 embeddings done
# 15173/15390 embeddings done
# 15174/15390 embeddings done
# 15175/15390 embeddings done
# 15176/15390 embeddings done
# 15177/15390 embeddings done
# 15178/15390 embeddings done
# 15179/15390 embeddings done
# 15180/15390 embeddings done
# 15181/15390 embeddings done
# 15182/15390 embeddings done
# 15183/15390 embeddings done
# 15184/15390 embeddings done
# 15185/15390 embeddings done
# 15186/15390 embeddings done
# 15187/15390 embeddings done
# 15188/15390 embeddings done
# 15189/15390 embeddings done
# 15190/15390 embeddings done
# 15191/15390 embeddings done
# 15192/15390 embeddings done
# 15193/15390 embeddings done
# 15194/15390 embeddings done
# 15195/15390 embeddings done
# 15196/15390 embeddings done
# 15197/15390 embeddings done
# 15198/15390 embeddings done
# 15199/15390 embeddings done
# 15200/15390 embeddings done
# 15201/15390 embeddings done
# 15202/15390 embeddings done
# 15203/15390 embeddings done
# 15204/15390 embeddings done
# 15205/15390 embeddings done
# 15206/15390 embeddings done
# 15207/15390 embeddings done
# 15208/15390 embeddings done
# 15209/15390 embeddings done
# 15210/15390 embeddings done
# 15211/15390 embeddings done
# 15212/15390 embeddings done
# 15213/15390 embeddings done
# 15214/15390 embeddings done
# 15215/15390 embeddings done
# 15216/15390 embeddings done
# 15217/15390 embeddings done
# 15218/15390 embeddings done
# 15219/15390 embeddings done
# 15220/15390 embeddings done
# 15221/15390 embeddings done
# 15222/15390 embeddings done
# 15223/15390 embeddings done
# 15224/15390 embeddings done
# 15225/15390 embeddings done
# 15226/15390 embeddings done
# 15227/15390 embeddings done
# 15228/15390 embeddings done
# 15229/15390 embeddings done
# 15230/15390 embeddings done
# 15231/15390 embeddings done
# 15232/15390 embeddings done
# 15233/15390 embeddings done
# 15234/15390 embeddings done
# 15235/15390 embeddings done
# 15236/15390 embeddings done
# 15237/15390 embeddings done
# 15238/15390 embeddings done
# 15239/15390 embeddings done
# 15240/15390 embeddings done
# 15241/15390 embeddings done
# 15242/15390 embeddings done
# 15243/15390 embeddings done
# 15244/15390 embeddings done
# 15245/15390 embeddings done
# 15246/15390 embeddings done
# 15247/15390 embeddings done
# 15248/15390 embeddings done
# 15249/15390 embeddings done
# 15250/15390 embeddings done
# 15251/15390 embeddings done
# 15252/15390 embeddings done
# 15253/15390 embeddings done
# 15254/15390 embeddings done
# 15255/15390 embeddings done
# 15256/15390 embeddings done
# 15257/15390 embeddings done
# 15258/15390 embeddings done
# 15259/15390 embeddings done
# 15260/15390 embeddings done
# 15261/15390 embeddings done
# 15262/15390 embeddings done
# 15263/15390 embeddings done
# 15264/15390 embeddings done
# 15265/15390 embeddings done
# 15266/15390 embeddings done
# 15267/15390 embeddings done
# 15268/15390 embeddings done
# 15269/15390 embeddings done
# 15270/15390 embeddings done
# 15271/15390 embeddings done
# 15272/15390 embeddings done
# 15273/15390 embeddings done
# 15274/15390 embeddings done
# 15275/15390 embeddings done
# 15276/15390 embeddings done
# 15277/15390 embeddings done
# 15278/15390 embeddings done
# 15279/15390 embeddings done
# 15280/15390 embeddings done
# 15281/15390 embeddings done
# 15282/15390 embeddings done
# 15283/15390 embeddings done
# 15284/15390 embeddings done
# 15285/15390 embeddings done
# 15286/15390 embeddings done
# 15287/15390 embeddings done
# 15288/15390 embeddings done
# 15289/15390 embeddings done
# 15290/15390 embeddings done
# 15291/15390 embeddings done
# 15292/15390 embeddings done
# 15293/15390 embeddings done
# 15294/15390 embeddings done
# 15295/15390 embeddings done
# 15296/15390 embeddings done
# 15297/15390 embeddings done
# 15298/15390 embeddings done
# 15299/15390 embeddings done
# 15300/15390 embeddings done
# 15301/15390 embeddings done
# 15302/15390 embeddings done
# 15303/15390 embeddings done
# 15304/15390 embeddings done
# 15305/15390 embeddings done
# 15306/15390 embeddings done
# 15307/15390 embeddings done
# 15308/15390 embeddings done
# 15309/15390 embeddings done
# 15310/15390 embeddings done
# 15311/15390 embeddings done
# 15312/15390 embeddings done
# 15313/15390 embeddings done
# 15314/15390 embeddings done
# 15315/15390 embeddings done
# 15316/15390 embeddings done
# 15317/15390 embeddings done
# 15318/15390 embeddings done
# 15319/15390 embeddings done
# 15320/15390 embeddings done
# 15321/15390 embeddings done
# 15322/15390 embeddings done
# 15323/15390 embeddings done
# 15324/15390 embeddings done
# 15325/15390 embeddings done
# 15326/15390 embeddings done
# 15327/15390 embeddings done
# 15328/15390 embeddings done
# 15329/15390 embeddings done
# 15330/15390 embeddings done
# 15331/15390 embeddings done
# 15332/15390 embeddings done
# 15333/15390 embeddings done
# 15334/15390 embeddings done
# 15335/15390 embeddings done
# 15336/15390 embeddings done
# 15337/15390 embeddings done
# 15338/15390 embeddings done
# 15339/15390 embeddings done
# 15340/15390 embeddings done
# 15341/15390 embeddings done
# 15342/15390 embeddings done
# 15343/15390 embeddings done
# 15344/15390 embeddings done
# 15345/15390 embeddings done
# 15346/15390 embeddings done
# 15347/15390 embeddings done
# 15348/15390 embeddings done
# 15349/15390 embeddings done
# 15350/15390 embeddings done
# 15351/15390 embeddings done
# 15352/15390 embeddings done
# 15353/15390 embeddings done
# 15354/15390 embeddings done
# 15355/15390 embeddings done
# 15356/15390 embeddings done
# 15357/15390 embeddings done
# 15358/15390 embeddings done
# 15359/15390 embeddings done
# 15360/15390 embeddings done
# 15361/15390 embeddings done
# 15362/15390 embeddings done
# 15363/15390 embeddings done
# 15364/15390 embeddings done
# 15365/15390 embeddings done
# 15366/15390 embeddings done
# 15367/15390 embeddings done
# 15368/15390 embeddings done
# 15369/15390 embeddings done
# 15370/15390 embeddings done
# 15371/15390 embeddings done
# 15372/15390 embeddings done
# 15373/15390 embeddings done
# 15374/15390 embeddings done
# 15375/15390 embeddings done
# 15376/15390 embeddings done
# 15377/15390 embeddings done
# 15378/15390 embeddings done
# 15379/15390 embeddings done
# 15380/15390 embeddings done
# 15381/15390 embeddings done
# 15382/15390 embeddings done
# 15383/15390 embeddings done
# 15384/15390 embeddings done
# 15385/15390 embeddings done
# 15386/15390 embeddings done
# 15387/15390 embeddings done
# 15388/15390 embeddings done
# 15389/15390 embeddings done
# 15390/15390 embeddings done
# Embeddings from file '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt' added to FAISS index between indice 64921 to 80311.

# %% [markdown]
# ## Create Embedding + Score ##

# %%
file_path = "../index_store/conformalpopqa500/popqa-train-kilt-500.jsonl"
scoreWikiAnswers(file_path, '../index_store/conformalpopqa500/popqa_calibrate_score_500.jsonl', '../index_store/conformalpopqa500/title_text_map_popqa_500.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# File '../index_store/conformalpopqa500/title_text_map_popqa_500.txt' already exists in the FAISS index.
# calibrate data 0 / 505 done
# calibrate data 1 / 505 done
# calibrate data 2 / 505 done
# calibrate data 3 / 505 done
# calibrate data 4 / 505 done
# calibrate data 5 / 505 done
# calibrate data 6 / 505 done
# calibrate data 7 / 505 done
# calibrate data 8 / 505 done
# calibrate data 9 / 505 done
# calibrate data 10 / 505 done
# calibrate data 11 / 505 done
# calibrate data 12 / 505 done
# calibrate data 13 / 505 done
# calibrate data 14 / 505 done
# calibrate data 15 / 505 done
# calibrate data 16 / 505 done
# calibrate data 17 / 505 done
# calibrate data 18 / 505 done
# calibrate data 19 / 505 done
# calibrate data 20 / 505 done
# calibrate data 21 / 505 done
# calibrate data 22 / 505 done
# calibrate data 23 / 505 done
# calibrate data 24 / 505 done
# calibrate data 25 / 505 done
# calibrate data 26 / 505 done
# calibrate data 27 / 505 done
# calibrate data 28 / 505 done
# calibrate data 29 / 505 done
# calibrate data 30 / 505 done
# calibrate data 31 / 505 done
# calibrate data 32 / 505 done
# calibrate data 33 / 505 done
# calibrate data 34 / 505 done
# calibrate data 35 / 505 done
# calibrate data 36 / 505 done
# calibrate data 37 / 505 done
# calibrate data 38 / 505 done
# calibrate data 39 / 505 done
# calibrate data 40 / 505 done
# calibrate data 41 / 505 done
# calibrate data 42 / 505 done
# calibrate data 43 / 505 done
# calibrate data 44 / 505 done
# calibrate data 45 / 505 done
# calibrate data 46 / 505 done
# calibrate data 47 / 505 done
# calibrate data 48 / 505 done
# calibrate data 49 / 505 done
# calibrate data 50 / 505 done
# calibrate data 51 / 505 done
# calibrate data 52 / 505 done
# calibrate data 53 / 505 done
# calibrate data 54 / 505 done
# calibrate data 55 / 505 done
# calibrate data 56 / 505 done
# calibrate data 57 / 505 done
# calibrate data 58 / 505 done
# calibrate data 59 / 505 done
# calibrate data 60 / 505 done
# calibrate data 61 / 505 done
# calibrate data 62 / 505 done
# calibrate data 63 / 505 done
# calibrate data 64 / 505 done
# calibrate data 65 / 505 done
# calibrate data 66 / 505 done
# calibrate data 67 / 505 done
# calibrate data 68 / 505 done
# calibrate data 69 / 505 done
# calibrate data 70 / 505 done
# calibrate data 71 / 505 done
# calibrate data 72 / 505 done
# calibrate data 73 / 505 done
# calibrate data 74 / 505 done
# calibrate data 75 / 505 done
# calibrate data 76 / 505 done
# calibrate data 77 / 505 done
# calibrate data 78 / 505 done
# calibrate data 79 / 505 done
# calibrate data 80 / 505 done
# calibrate data 81 / 505 done
# calibrate data 82 / 505 done
# calibrate data 83 / 505 done
# calibrate data 84 / 505 done
# calibrate data 85 / 505 done
# calibrate data 86 / 505 done
# calibrate data 87 / 505 done
# calibrate data 88 / 505 done
# calibrate data 89 / 505 done
# calibrate data 90 / 505 done
# calibrate data 91 / 505 done
# calibrate data 92 / 505 done
# calibrate data 93 / 505 done
# calibrate data 94 / 505 done
# calibrate data 95 / 505 done
# calibrate data 96 / 505 done
# calibrate data 97 / 505 done
# calibrate data 98 / 505 done
# calibrate data 99 / 505 done
# calibrate data 100 / 505 done
# calibrate data 101 / 505 done
# calibrate data 102 / 505 done
# calibrate data 103 / 505 done
# calibrate data 104 / 505 done
# calibrate data 105 / 505 done
# calibrate data 106 / 505 done
# calibrate data 107 / 505 done
# calibrate data 108 / 505 done
# calibrate data 109 / 505 done
# calibrate data 110 / 505 done
# calibrate data 111 / 505 done
# calibrate data 112 / 505 done
# calibrate data 113 / 505 done
# calibrate data 114 / 505 done
# calibrate data 115 / 505 done
# calibrate data 116 / 505 done
# calibrate data 117 / 505 done
# calibrate data 118 / 505 done
# calibrate data 119 / 505 done
# calibrate data 120 / 505 done
# calibrate data 121 / 505 done
# calibrate data 122 / 505 done
# calibrate data 123 / 505 done
# calibrate data 124 / 505 done
# calibrate data 125 / 505 done
# calibrate data 126 / 505 done
# calibrate data 127 / 505 done
# calibrate data 128 / 505 done
# calibrate data 129 / 505 done
# calibrate data 130 / 505 done
# calibrate data 131 / 505 done
# calibrate data 132 / 505 done
# calibrate data 133 / 505 done
# calibrate data 134 / 505 done
# calibrate data 135 / 505 done
# calibrate data 136 / 505 done
# calibrate data 137 / 505 done
# calibrate data 138 / 505 done
# calibrate data 139 / 505 done
# calibrate data 140 / 505 done
# calibrate data 141 / 505 done
# calibrate data 142 / 505 done
# calibrate data 143 / 505 done
# calibrate data 144 / 505 done
# calibrate data 145 / 505 done
# calibrate data 146 / 505 done
# calibrate data 147 / 505 done
# calibrate data 148 / 505 done
# calibrate data 149 / 505 done
# calibrate data 150 / 505 done
# calibrate data 151 / 505 done
# calibrate data 152 / 505 done
# calibrate data 153 / 505 done
# calibrate data 154 / 505 done
# calibrate data 155 / 505 done
# calibrate data 156 / 505 done
# calibrate data 157 / 505 done
# calibrate data 158 / 505 done
# calibrate data 159 / 505 done
# calibrate data 160 / 505 done
# calibrate data 161 / 505 done
# calibrate data 162 / 505 done
# calibrate data 163 / 505 done
# calibrate data 164 / 505 done
# calibrate data 165 / 505 done
# calibrate data 166 / 505 done
# calibrate data 167 / 505 done
# calibrate data 168 / 505 done
# calibrate data 169 / 505 done
# calibrate data 170 / 505 done
# calibrate data 171 / 505 done
# calibrate data 172 / 505 done
# calibrate data 173 / 505 done
# calibrate data 174 / 505 done
# calibrate data 175 / 505 done
# calibrate data 176 / 505 done
# calibrate data 177 / 505 done
# calibrate data 178 / 505 done
# calibrate data 179 / 505 done
# calibrate data 180 / 505 done
# calibrate data 181 / 505 done
# calibrate data 182 / 505 done
# calibrate data 183 / 505 done
# calibrate data 184 / 505 done
# calibrate data 185 / 505 done
# calibrate data 186 / 505 done
# calibrate data 187 / 505 done
# calibrate data 188 / 505 done
# calibrate data 189 / 505 done
# calibrate data 190 / 505 done
# calibrate data 191 / 505 done
# calibrate data 192 / 505 done
# calibrate data 193 / 505 done
# calibrate data 194 / 505 done
# calibrate data 195 / 505 done
# calibrate data 196 / 505 done
# calibrate data 197 / 505 done
# calibrate data 198 / 505 done
# calibrate data 199 / 505 done
# calibrate data 200 / 505 done
# calibrate data 201 / 505 done
# calibrate data 202 / 505 done
# calibrate data 203 / 505 done
# calibrate data 204 / 505 done
# calibrate data 205 / 505 done
# calibrate data 206 / 505 done
# calibrate data 207 / 505 done
# calibrate data 208 / 505 done
# calibrate data 209 / 505 done
# calibrate data 210 / 505 done
# calibrate data 211 / 505 done
# calibrate data 212 / 505 done
# calibrate data 213 / 505 done
# calibrate data 214 / 505 done
# calibrate data 215 / 505 done
# calibrate data 216 / 505 done
# calibrate data 217 / 505 done
# calibrate data 218 / 505 done
# calibrate data 219 / 505 done
# calibrate data 220 / 505 done
# calibrate data 221 / 505 done
# calibrate data 222 / 505 done
# calibrate data 223 / 505 done
# calibrate data 224 / 505 done
# calibrate data 225 / 505 done
# calibrate data 226 / 505 done
# calibrate data 227 / 505 done
# calibrate data 228 / 505 done
# calibrate data 229 / 505 done
# calibrate data 230 / 505 done
# calibrate data 231 / 505 done
# calibrate data 232 / 505 done
# calibrate data 233 / 505 done
# calibrate data 234 / 505 done
# calibrate data 235 / 505 done
# calibrate data 236 / 505 done
# calibrate data 237 / 505 done
# calibrate data 238 / 505 done
# calibrate data 239 / 505 done
# calibrate data 240 / 505 done
# calibrate data 241 / 505 done
# calibrate data 242 / 505 done
# calibrate data 243 / 505 done
# calibrate data 244 / 505 done
# calibrate data 245 / 505 done
# calibrate data 246 / 505 done
# calibrate data 247 / 505 done
# calibrate data 248 / 505 done
# calibrate data 249 / 505 done
# calibrate data 250 / 505 done
# calibrate data 251 / 505 done
# calibrate data 252 / 505 done
# calibrate data 253 / 505 done
# calibrate data 254 / 505 done
# calibrate data 255 / 505 done
# calibrate data 256 / 505 done
# calibrate data 257 / 505 done
# calibrate data 258 / 505 done
# calibrate data 259 / 505 done
# calibrate data 260 / 505 done
# calibrate data 261 / 505 done
# calibrate data 262 / 505 done
# calibrate data 263 / 505 done
# calibrate data 264 / 505 done
# calibrate data 265 / 505 done
# calibrate data 266 / 505 done
# calibrate data 267 / 505 done
# calibrate data 268 / 505 done
# calibrate data 269 / 505 done
# calibrate data 270 / 505 done
# calibrate data 271 / 505 done
# calibrate data 272 / 505 done
# calibrate data 273 / 505 done
# calibrate data 274 / 505 done
# calibrate data 275 / 505 done
# calibrate data 276 / 505 done
# calibrate data 277 / 505 done
# calibrate data 278 / 505 done
# calibrate data 279 / 505 done
# calibrate data 280 / 505 done
# calibrate data 281 / 505 done
# calibrate data 282 / 505 done
# calibrate data 283 / 505 done
# calibrate data 284 / 505 done
# calibrate data 285 / 505 done
# calibrate data 286 / 505 done
# calibrate data 287 / 505 done
# calibrate data 288 / 505 done
# calibrate data 289 / 505 done
# calibrate data 290 / 505 done
# calibrate data 291 / 505 done
# calibrate data 292 / 505 done
# calibrate data 293 / 505 done
# calibrate data 294 / 505 done
# calibrate data 295 / 505 done
# calibrate data 296 / 505 done
# calibrate data 297 / 505 done
# calibrate data 298 / 505 done
# calibrate data 299 / 505 done
# calibrate data 300 / 505 done
# calibrate data 301 / 505 done
# calibrate data 302 / 505 done
# calibrate data 303 / 505 done
# calibrate data 304 / 505 done
# calibrate data 305 / 505 done
# calibrate data 306 / 505 done
# calibrate data 307 / 505 done
# calibrate data 308 / 505 done
# calibrate data 309 / 505 done
# calibrate data 310 / 505 done
# calibrate data 311 / 505 done
# calibrate data 312 / 505 done
# calibrate data 313 / 505 done
# calibrate data 314 / 505 done
# calibrate data 315 / 505 done
# calibrate data 316 / 505 done
# calibrate data 317 / 505 done
# calibrate data 318 / 505 done
# calibrate data 319 / 505 done
# calibrate data 320 / 505 done
# calibrate data 321 / 505 done
# calibrate data 322 / 505 done
# calibrate data 323 / 505 done
# calibrate data 324 / 505 done
# calibrate data 325 / 505 done
# calibrate data 326 / 505 done
# calibrate data 327 / 505 done
# calibrate data 328 / 505 done
# calibrate data 329 / 505 done
# calibrate data 330 / 505 done
# calibrate data 331 / 505 done
# calibrate data 332 / 505 done
# calibrate data 333 / 505 done
# calibrate data 334 / 505 done
# calibrate data 335 / 505 done
# calibrate data 336 / 505 done
# calibrate data 337 / 505 done
# calibrate data 338 / 505 done
# calibrate data 339 / 505 done
# calibrate data 340 / 505 done
# calibrate data 341 / 505 done
# calibrate data 342 / 505 done
# calibrate data 343 / 505 done
# calibrate data 344 / 505 done
# calibrate data 345 / 505 done
# calibrate data 346 / 505 done
# calibrate data 347 / 505 done
# calibrate data 348 / 505 done
# calibrate data 349 / 505 done
# calibrate data 350 / 505 done
# calibrate data 351 / 505 done
# calibrate data 352 / 505 done
# calibrate data 353 / 505 done
# calibrate data 354 / 505 done
# calibrate data 355 / 505 done
# calibrate data 356 / 505 done
# calibrate data 357 / 505 done
# calibrate data 358 / 505 done
# calibrate data 359 / 505 done
# calibrate data 360 / 505 done
# calibrate data 361 / 505 done
# calibrate data 362 / 505 done
# calibrate data 363 / 505 done
# calibrate data 364 / 505 done
# calibrate data 365 / 505 done
# calibrate data 366 / 505 done
# calibrate data 367 / 505 done
# calibrate data 368 / 505 done
# calibrate data 369 / 505 done
# calibrate data 370 / 505 done
# calibrate data 371 / 505 done
# calibrate data 372 / 505 done
# calibrate data 373 / 505 done
# calibrate data 374 / 505 done
# calibrate data 375 / 505 done
# calibrate data 376 / 505 done
# calibrate data 377 / 505 done
# calibrate data 378 / 505 done
# calibrate data 379 / 505 done
# calibrate data 380 / 505 done
# calibrate data 381 / 505 done
# calibrate data 382 / 505 done
# calibrate data 383 / 505 done
# calibrate data 384 / 505 done
# calibrate data 385 / 505 done
# calibrate data 386 / 505 done
# calibrate data 387 / 505 done
# calibrate data 388 / 505 done
# calibrate data 389 / 505 done
# calibrate data 390 / 505 done
# calibrate data 391 / 505 done
# calibrate data 392 / 505 done
# calibrate data 393 / 505 done
# calibrate data 394 / 505 done
# calibrate data 395 / 505 done
# calibrate data 396 / 505 done
# calibrate data 397 / 505 done
# calibrate data 398 / 505 done
# calibrate data 399 / 505 done
# calibrate data 400 / 505 done
# calibrate data 401 / 505 done
# calibrate data 402 / 505 done
# calibrate data 403 / 505 done
# calibrate data 404 / 505 done
# calibrate data 405 / 505 done
# calibrate data 406 / 505 done
# calibrate data 407 / 505 done
# calibrate data 408 / 505 done
# calibrate data 409 / 505 done
# calibrate data 410 / 505 done
# calibrate data 411 / 505 done
# calibrate data 412 / 505 done
# calibrate data 413 / 505 done
# calibrate data 414 / 505 done
# calibrate data 415 / 505 done
# calibrate data 416 / 505 done
# calibrate data 417 / 505 done
# calibrate data 418 / 505 done
# calibrate data 419 / 505 done
# calibrate data 420 / 505 done
# calibrate data 421 / 505 done
# calibrate data 422 / 505 done
# calibrate data 423 / 505 done
# calibrate data 424 / 505 done
# calibrate data 425 / 505 done
# calibrate data 426 / 505 done
# calibrate data 427 / 505 done
# calibrate data 428 / 505 done
# calibrate data 429 / 505 done
# calibrate data 430 / 505 done
# calibrate data 431 / 505 done
# calibrate data 432 / 505 done
# calibrate data 433 / 505 done
# calibrate data 434 / 505 done
# calibrate data 435 / 505 done
# calibrate data 436 / 505 done
# calibrate data 437 / 505 done
# calibrate data 438 / 505 done
# calibrate data 439 / 505 done
# calibrate data 440 / 505 done
# calibrate data 441 / 505 done
# calibrate data 442 / 505 done
# calibrate data 443 / 505 done
# calibrate data 444 / 505 done
# calibrate data 445 / 505 done
# calibrate data 446 / 505 done
# calibrate data 447 / 505 done
# calibrate data 448 / 505 done
# calibrate data 449 / 505 done
# calibrate data 450 / 505 done
# calibrate data 451 / 505 done
# calibrate data 452 / 505 done
# calibrate data 453 / 505 done
# calibrate data 454 / 505 done
# calibrate data 455 / 505 done
# calibrate data 456 / 505 done
# calibrate data 457 / 505 done
# calibrate data 458 / 505 done
# calibrate data 459 / 505 done
# calibrate data 460 / 505 done
# calibrate data 461 / 505 done
# calibrate data 462 / 505 done
# calibrate data 463 / 505 done
# calibrate data 464 / 505 done
# calibrate data 465 / 505 done
# calibrate data 466 / 505 done
# calibrate data 467 / 505 done
# calibrate data 468 / 505 done
# calibrate data 469 / 505 done
# calibrate data 470 / 505 done
# calibrate data 471 / 505 done
# calibrate data 472 / 505 done
# calibrate data 473 / 505 done
# calibrate data 474 / 505 done
# calibrate data 475 / 505 done
# calibrate data 476 / 505 done
# calibrate data 477 / 505 done
# calibrate data 478 / 505 done
# calibrate data 479 / 505 done
# calibrate data 480 / 505 done
# calibrate data 481 / 505 done
# calibrate data 482 / 505 done
# calibrate data 483 / 505 done
# calibrate data 484 / 505 done
# calibrate data 485 / 505 done
# calibrate data 486 / 505 done
# calibrate data 487 / 505 done
# calibrate data 488 / 505 done
# calibrate data 489 / 505 done
# calibrate data 490 / 505 done
# calibrate data 491 / 505 done
# calibrate data 492 / 505 done
# calibrate data 493 / 505 done
# calibrate data 494 / 505 done
# calibrate data 495 / 505 done
# calibrate data 496 / 505 done
# calibrate data 497 / 505 done
# calibrate data 498 / 505 done
# calibrate data 499 / 505 done
# calibrate data 500 / 505 done
# calibrate data 501 / 505 done
# calibrate data 502 / 505 done
# calibrate data 503 / 505 done
# calibrate data 504 / 505 done

# %%
from rag.faiss_manager import FAISSIndexManager

fm = FAISSIndexManager()
fm.is_indice_align()
# Out:
# True

# %%
input_file = '../index_store/conformalpopqa500/popqa_calibrate_score_500.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
idx = 0
# Process the file
with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    outfile.write('{"data": [\n')
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data)
        outfile.write(json.dumps(transformed_data, ensure_ascii=False) + ",\n")
        idx += 1
    outfile.write(']}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Processing line 51
# Processing line 52
# Processing line 53
# Processing line 54
# Processing line 55
# Processing line 56
# Processing line 57
# Processing line 58
# Processing line 59
# Processing line 60
# Processing line 61
# Processing line 62
# Processing line 63
# Processing line 64
# Processing line 65
# Processing line 66
# Processing line 67
# Processing line 68
# Processing line 69
# Processing line 70
# Processing line 71
# Processing line 72
# Processing line 73
# Processing line 74
# Processing line 75
# Processing line 76
# Processing line 77
# Processing line 78
# Processing line 79
# Processing line 80
# Processing line 81
# Processing line 82
# Processing line 83
# Processing line 84
# Processing line 85
# Processing line 86
# Processing line 87
# Processing line 88
# Processing line 89
# Processing line 90
# Processing line 91
# Processing line 92
# Processing line 93
# Processing line 94
# Processing line 95
# Processing line 96
# Processing line 97
# Processing line 98
# Processing line 99
# Processing line 100
# Processing line 101
# Processing line 102
# Processing line 103
# Processing line 104
# Processing line 105
# Processing line 106
# Processing line 107
# Processing line 108
# Processing line 109
# Processing line 110
# Processing line 111
# Processing line 112
# Processing line 113
# Processing line 114
# Processing line 115
# Processing line 116
# Processing line 117
# Processing line 118
# Processing line 119
# Processing line 120
# Processing line 121
# Processing line 122
# Processing line 123
# Processing line 124
# Processing line 125
# Processing line 126
# Processing line 127
# Processing line 128
# Processing line 129
# Processing line 130
# Processing line 131
# Processing line 132
# Processing line 133
# Processing line 134
# Processing line 135
# Processing line 136
# Processing line 137
# Processing line 138
# Processing line 139
# Processing line 140
# Processing line 141
# Processing line 142
# Processing line 143
# Processing line 144
# Processing line 145
# Processing line 146
# Processing line 147
# Processing line 148
# Processing line 149
# Processing line 150
# Processing line 151
# Processing line 152
# Processing line 153
# Processing line 154
# Processing line 155
# Processing line 156
# Processing line 157
# Processing line 158
# Processing line 159
# Processing line 160
# Processing line 161
# Processing line 162
# Processing line 163
# Processing line 164
# Processing line 165
# Processing line 166
# Processing line 167
# Processing line 168
# Processing line 169
# Processing line 170
# Processing line 171
# Processing line 172
# Processing line 173
# Processing line 174
# Processing line 175
# Processing line 176
# Processing line 177
# Processing line 178
# Processing line 179
# Processing line 180
# Processing line 181
# Processing line 182
# Processing line 183
# Processing line 184
# Processing line 185
# Processing line 186
# Processing line 187
# Processing line 188
# Processing line 189
# Processing line 190
# Processing line 191
# Processing line 192
# Processing line 193
# Processing line 194
# Processing line 195
# Processing line 196
# Processing line 197
# Processing line 198
# Processing line 199
# Processing line 200
# Processing line 201
# Processing line 202
# Processing line 203
# Processing line 204
# Processing line 205
# Processing line 206
# Processing line 207
# Processing line 208
# Processing line 209
# Processing line 210
# Processing line 211
# Processing line 212
# Processing line 213
# Processing line 214
# Processing line 215
# Processing line 216
# Processing line 217
# Processing line 218
# Processing line 219
# Processing line 220
# Processing line 221
# Processing line 222
# Processing line 223
# Processing line 224
# Processing line 225
# Processing line 226
# Processing line 227
# Processing line 228
# Processing line 229
# Processing line 230
# Processing line 231
# Processing line 232
# Processing line 233
# Processing line 234
# Processing line 235
# Processing line 236
# Processing line 237
# Processing line 238
# Processing line 239
# Processing line 240
# Processing line 241
# Processing line 242
# Processing line 243
# Processing line 244
# Processing line 245
# Processing line 246
# Processing line 247
# Processing line 248
# Processing line 249
# Processing line 250
# Processing line 251
# Processing line 252
# Processing line 253
# Processing line 254
# Processing line 255
# Processing line 256
# Processing line 257
# Processing line 258
# Processing line 259
# Processing line 260
# Processing line 261
# Processing line 262
# Processing line 263
# Processing line 264
# Processing line 265
# Processing line 266
# Processing line 267
# Processing line 268
# Processing line 269
# Processing line 270
# Processing line 271
# Processing line 272
# Processing line 273
# Processing line 274
# Processing line 275
# Processing line 276
# Processing line 277
# Processing line 278
# Processing line 279
# Processing line 280
# Processing line 281
# Processing line 282
# Processing line 283
# Processing line 284
# Processing line 285
# Processing line 286
# Processing line 287
# Processing line 288
# Processing line 289
# Processing line 290
# Processing line 291
# Processing line 292
# Processing line 293
# Processing line 294
# Processing line 295
# Processing line 296
# Processing line 297
# Processing line 298
# Processing line 299
# Processing line 300
# Processing line 301
# Processing line 302
# Processing line 303
# Processing line 304
# Processing line 305
# Processing line 306
# Processing line 307
# Processing line 308
# Processing line 309
# Processing line 310
# Processing line 311
# Processing line 312
# Processing line 313
# Processing line 314
# Processing line 315
# Processing line 316
# Processing line 317
# Processing line 318
# Processing line 319
# Processing line 320
# Processing line 321
# Processing line 322
# Processing line 323
# Processing line 324
# Processing line 325
# Processing line 326
# Processing line 327
# Processing line 328
# Processing line 329
# Processing line 330
# Processing line 331
# Processing line 332
# Processing line 333
# Processing line 334
# Processing line 335
# Processing line 336
# Processing line 337
# Processing line 338
# Processing line 339
# Processing line 340
# Processing line 341
# Processing line 342
# Processing line 343
# Processing line 344
# Processing line 345
# Processing line 346
# Processing line 347
# Processing line 348
# Processing line 349
# Processing line 350
# Processing line 351
# Processing line 352
# Processing line 353
# Processing line 354
# Processing line 355
# Processing line 356
# Processing line 357
# Processing line 358
# Processing line 359
# Processing line 360
# Processing line 361
# Processing line 362
# Processing line 363
# Processing line 364
# Processing line 365
# Processing line 366
# Processing line 367
# Processing line 368
# Processing line 369
# Processing line 370
# Processing line 371
# Processing line 372
# Processing line 373
# Processing line 374
# Processing line 375
# Processing line 376
# Processing line 377
# Processing line 378
# Processing line 379
# Processing line 380
# Processing line 381
# Processing line 382
# Processing line 383
# Processing line 384
# Processing line 385
# Processing line 386
# Processing line 387
# Processing line 388
# Processing line 389
# Processing line 390
# Processing line 391
# Processing line 392
# Processing line 393
# Processing line 394
# Processing line 395
# Processing line 396
# Processing line 397
# Processing line 398
# Processing line 399
# Processing line 400
# Processing line 401
# Processing line 402
# Processing line 403
# Processing line 404
# Processing line 405
# Processing line 406
# Processing line 407
# Processing line 408
# Processing line 409
# Processing line 410
# Processing line 411
# Processing line 412
# Processing line 413
# Processing line 414
# Processing line 415
# Processing line 416
# Processing line 417
# Processing line 418
# Processing line 419
# Processing line 420
# Processing line 421
# Processing line 422
# Processing line 423
# Processing line 424
# Processing line 425
# Processing line 426
# Processing line 427
# Processing line 428
# Processing line 429
# Processing line 430
# Processing line 431
# Processing line 432
# Processing line 433
# Processing line 434
# Processing line 435
# Processing line 436
# Processing line 437
# Processing line 438
# Processing line 439
# Processing line 440
# Processing line 441
# Processing line 442
# Processing line 443
# Processing line 444
# Processing line 445
# Processing line 446
# Processing line 447
# Processing line 448
# Processing line 449
# Processing line 450
# Processing line 451
# Processing line 452
# Processing line 453
# Processing line 454
# Processing line 455
# Processing line 456
# Processing line 457
# Processing line 458
# Processing line 459
# Processing line 460
# Processing line 461
# Processing line 462
# Processing line 463
# Processing line 464
# Processing line 465
# Processing line 466
# Processing line 467
# Processing line 468
# Processing line 469
# Processing line 470
# Processing line 471
# Processing line 472
# Processing line 473
# Processing line 474
# Processing line 475
# Processing line 476
# Processing line 477
# Processing line 478
# Processing line 479
# Processing line 480
# Processing line 481
# Processing line 482
# Processing line 483
# Processing line 484
# Processing line 485
# Processing line 486
# Processing line 487
# Processing line 488
# Processing line 489
# Processing line 490
# Processing line 491
# Processing line 492
# Processing line 493
# Processing line 494
# Processing line 495
# Processing line 496
# Processing line 497
# Processing line 498
# Processing line 499
# Processing line 500
# Processing line 501
# Processing line 502
# Processing line 503
# Processing line 504
# Transformed data written to similarity_annotations.jsonl.

# %%
import os
os.getcwd()
# Out:
# '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/rag'

# %%
import os

from rag.scorer.document_scorer import DocumentScorer

def conformal_pred(prompt, scorer: DocumentScorer, model='gpt-4'):
    threshold = 0.40
    (output, merged_output, all_subclaims, accepted_subclaims)= scorer.say_less(prompt, threshold, model)
    print("Original output: ")
    print(output)
    print("\n\n\n\n\nModified output: ")
    print(merged_output)
    print("\n\n\n\nAccepted sub-claims: ")
    print(accepted_subclaims)
    print("\n\n\n\nAll sub-claims: ")
    print(all_subclaims)

# %%
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer
wiki_embedding = WikitextsDocumentScorer()
prompt = "What is George Rankin's occupation?"
conformal_pred(prompt, wiki_embedding)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Original output:
# George Rankin was both an Australian soldier and a politician. He served in the military, achieving the rank of major general, and was also a member of the House of Representatives and the Senate, representing the Country Party of Australia.
#
#
#
#
#
# Modified output:
# George Rankin's occupation was a soldier.
#
#
#
#
# Accepted sub-claims:
# [('George Rankin was an Australian soldier', 0.45235167679190635)]
#
#
#
#
# All sub-claims:
# [('George Rankin was an Australian soldier', 0.45235167679190635), (' George Rankin was a politician', 0.39989348105192185), (' George Rankin served in the military', 0.399246557366848), (' George Rankin achieved the rank of major general', 0.36969011533260343), (' George Rankin was a member of the House of Representatives', 0.3528019578754902), (' George Rankin was a member of the Senate', 0.3573167937278747), (' George Rankin represented the Country Party of Australia', 0.3946427712440491)]
