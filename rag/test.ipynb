# %% [markdown]
# **HotpotQA**

# %%
import os
import sys

# Set the project root directory
project_root = os.path.abspath("..")  # Adjust this based on the notebook's location
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

file_path = "../index_store/magazine/title_text_map.txt"
wiki_embedding = WikitextsDocumentScorer()
gen = OpenAIAtomicFactGenerator()

wiki_embedding.create_embedding(file_path)
query = "Which magazine was started first Arthur\'s Magazine or First for Women?"
retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10)
print(retrieved_docs)
response = wiki_embedding.faiss_manager.generate_response_ffrom_context(query, retrieved_docs)
print(response)
atomicFacts = gen.get_facts_from_text(response)
# Out:
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Associated texts saved to file: ../index_store/magazine/title_text_map_texts.json
# 1/11 embeddings done
# 2/11 embeddings done
# 3/11 embeddings done
# 4/11 embeddings done
# 5/11 embeddings done
# 6/11 embeddings done
# 7/11 embeddings done
# 8/11 embeddings done
# 9/11 embeddings done
# 10/11 embeddings done
# 11/11 embeddings done
# Embeddings from file '../index_store/magazine/title_text_map.txt' added to FAISS index between indice 50797 to 50808.
# ["File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5978", "page_content='First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.\n' metadata={'source': 'First for Women'} indice=1 score=0.5967", "File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5790", 'page_content=\'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=5 score=0.5790', 'page_content=\'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=6 score=0.5322', "File manager not found for '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' score=0.5321"]
# Arthur's Magazine was started first. It was published from 1844 to 1846, whereas First for Women was started in 1989.

# %%
print(atomicFacts)
# Out:
# ["Arthur's Magazine was started first:supported", " Arthur's Magazine was published from 1844 to 1846:supported", ' First for Women was started in 1989:supported']

# %%
print(retrieved_docs)
# Out:
# ["page_content='First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.\n' metadata={'source': 'First for Women'} indice=1 score=0.5966", 'page_content=\'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=5 score=0.5791', 'page_content=\'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".\n\' metadata={\'source\': "Arthur\'s Magazine"} indice=6 score=0.5322']

# %%
for result in retrieved_docs:
    parsed_result = wiki_embedding.faiss_manager.parse_result(result)
    print(parsed_result)
# Out:
# {'page_content': "First for Women is a woman's magazine published by Bauer Media Group in the USA. The magazine was started in 1989. It is based in Englewood Cliffs, New Jersey. In 2011 the circulation of the magazine was 1,310,696 copies.", 'metadata': {'source': 'First for Women'}, 'indice': 1, 'score': 0.5966}
# {'page_content': 'Arthur\'s Magazine (1844–1846) was an American literary periodical published in Philadelphia in the 19th century. Edited by Timothy Shay Arthur, it featured work by Edgar A. Poe, J.H. Ingraham, Sarah Josepha Hale, Thomas G. Spear, and others. In May 1846 it was merged into "Godey\'s Lady\'s Book".', 'metadata': {'source': "Arthur's Magazine"}, 'indice': 5, 'score': 0.5791}
# {'page_content': 'A few years later Arthur would launch a new publication entitled "Arthur\'s Home Magazine".', 'metadata': {'source': "Arthur's Magazine"}, 'indice': 6, 'score': 0.5322}

# %%
for fact in atomicFacts:
    score = wiki_embedding.score(fact.rpartition(':')[0], retrieved_docs)
    print(f'{fact} has a score of {score}')
# Out:
# Arthur's Magazine was started first:supported has a score of [[0.31389496]]
#  Arthur's Magazine was published from 1844 to 1846:supported has a score of [[0.29862073]]
#  First for Women was started in 1989:supported has a score of [[0.20763773]]

# %%
realscore = wiki_embedding.score('Arthur\'s Magazine', retrieved_docs)
print(realscore)
# Out:
# [[0.32663262]]

# %% [markdown]
# **Create Embedding Only**

# %%
data_path = '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500.txt'
wiki_embedding = WikitextsDocumentScorer()
wiki_embedding.create_embedding(data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# 1/52869 embeddings done
# 2/52869 embeddings done
# 3/52869 embeddings done
# 4/52869 embeddings done
# 5/52869 embeddings done
# 6/52869 embeddings done
# 7/52869 embeddings done
# 8/52869 embeddings done
# 9/52869 embeddings done
# 10/52869 embeddings done
# 11/52869 embeddings done
# 12/52869 embeddings done
# 13/52869 embeddings done
# 14/52869 embeddings done
# 15/52869 embeddings done
# 16/52869 embeddings done
# 17/52869 embeddings done
# 18/52869 embeddings done
# 19/52869 embeddings done
# 20/52869 embeddings done
# 21/52869 embeddings done
# 22/52869 embeddings done
# 23/52869 embeddings done
# 24/52869 embeddings done
# 25/52869 embeddings done
# 26/52869 embeddings done
# 27/52869 embeddings done
# 28/52869 embeddings done
# 29/52869 embeddings done
# 30/52869 embeddings done
# 31/52869 embeddings done
# 32/52869 embeddings done
# 33/52869 embeddings done
# 34/52869 embeddings done
# 35/52869 embeddings done
# 36/52869 embeddings done
# 37/52869 embeddings done
# 38/52869 embeddings done
# 39/52869 embeddings done
# 40/52869 embeddings done
# 41/52869 embeddings done
# 42/52869 embeddings done
# 43/52869 embeddings done
# 44/52869 embeddings done
# 45/52869 embeddings done
# 46/52869 embeddings done
# 47/52869 embeddings done
# 48/52869 embeddings done
# 49/52869 embeddings done
# 50/52869 embeddings done
# 51/52869 embeddings done
# 52/52869 embeddings done
# 53/52869 embeddings done
# 54/52869 embeddings done
# 55/52869 embeddings done
# 56/52869 embeddings done
# 57/52869 embeddings done
# 58/52869 embeddings done
# 59/52869 embeddings done
# 60/52869 embeddings done
# 61/52869 embeddings done
# 62/52869 embeddings done
# 63/52869 embeddings done
# 64/52869 embeddings done
# 65/52869 embeddings done
# 66/52869 embeddings done
# 67/52869 embeddings done
# 68/52869 embeddings done
# 69/52869 embeddings done
# 70/52869 embeddings done
# 71/52869 embeddings done
# 72/52869 embeddings done
# 73/52869 embeddings done
# 74/52869 embeddings done
# 75/52869 embeddings done
# 76/52869 embeddings done
# 77/52869 embeddings done
# 78/52869 embeddings done
# 79/52869 embeddings done
# 80/52869 embeddings done
# 81/52869 embeddings done
# 82/52869 embeddings done
# 83/52869 embeddings done
# 84/52869 embeddings done
# 85/52869 embeddings done
# 86/52869 embeddings done
# 87/52869 embeddings done
# 88/52869 embeddings done
# 89/52869 embeddings done
# 90/52869 embeddings done
# 91/52869 embeddings done
# 92/52869 embeddings done
# 93/52869 embeddings done
# 94/52869 embeddings done
# 95/52869 embeddings done
# 96/52869 embeddings done
# 97/52869 embeddings done
# 98/52869 embeddings done
# 99/52869 embeddings done
# 100/52869 embeddings done
# 101/52869 embeddings done
# 102/52869 embeddings done
# 103/52869 embeddings done
# 104/52869 embeddings done
# 105/52869 embeddings done
# 106/52869 embeddings done
# 107/52869 embeddings done
# 108/52869 embeddings done
# 109/52869 embeddings done
# 110/52869 embeddings done
# 111/52869 embeddings done
# 112/52869 embeddings done
# 113/52869 embeddings done
# 114/52869 embeddings done
# 115/52869 embeddings done
# 116/52869 embeddings done
# 117/52869 embeddings done
# 118/52869 embeddings done
# 119/52869 embeddings done
# 120/52869 embeddings done
# 121/52869 embeddings done
# 122/52869 embeddings done
# 123/52869 embeddings done
# 124/52869 embeddings done
# 125/52869 embeddings done
# 126/52869 embeddings done
# 127/52869 embeddings done
# 128/52869 embeddings done
# 129/52869 embeddings done
# 130/52869 embeddings done
# 131/52869 embeddings done
# 132/52869 embeddings done
# 133/52869 embeddings done
# 134/52869 embeddings done
# 135/52869 embeddings done
# 136/52869 embeddings done
# 137/52869 embeddings done
# 138/52869 embeddings done
# 139/52869 embeddings done
# 140/52869 embeddings done
# 141/52869 embeddings done
# 142/52869 embeddings done
# 143/52869 embeddings done
# 144/52869 embeddings done
# 145/52869 embeddings done
# 146/52869 embeddings done
# 147/52869 embeddings done
# 148/52869 embeddings done
# 149/52869 embeddings done
# 150/52869 embeddings done
# 151/52869 embeddings done
# 152/52869 embeddings done
# 153/52869 embeddings done
# 154/52869 embeddings done
# 155/52869 embeddings done
# 156/52869 embeddings done
# 157/52869 embeddings done
# 158/52869 embeddings done
# 159/52869 embeddings done
# 160/52869 embeddings done
# 161/52869 embeddings done
# 162/52869 embeddings done
# 163/52869 embeddings done
# 164/52869 embeddings done
# 165/52869 embeddings done
# 166/52869 embeddings done
# 167/52869 embeddings done
# 168/52869 embeddings done
# 169/52869 embeddings done
# 170/52869 embeddings done
# 171/52869 embeddings done
# 172/52869 embeddings done
# 173/52869 embeddings done
# 174/52869 embeddings done
# 175/52869 embeddings done
# 176/52869 embeddings done
# 177/52869 embeddings done
# 178/52869 embeddings done
# 179/52869 embeddings done
# 180/52869 embeddings done
# 181/52869 embeddings done
# 182/52869 embeddings done
# 183/52869 embeddings done
# 184/52869 embeddings done
# 185/52869 embeddings done
# 186/52869 embeddings done
# 187/52869 embeddings done
# 188/52869 embeddings done
# 189/52869 embeddings done
# 190/52869 embeddings done
# 191/52869 embeddings done
# 192/52869 embeddings done
# 193/52869 embeddings done
# 194/52869 embeddings done
# 195/52869 embeddings done
# 196/52869 embeddings done
# 197/52869 embeddings done
# 198/52869 embeddings done
# 199/52869 embeddings done
# 200/52869 embeddings done
# 201/52869 embeddings done
# 202/52869 embeddings done
# 203/52869 embeddings done
# 204/52869 embeddings done
# 205/52869 embeddings done
# 206/52869 embeddings done
# 207/52869 embeddings done
# 208/52869 embeddings done
# 209/52869 embeddings done
# 210/52869 embeddings done
# 211/52869 embeddings done
# 212/52869 embeddings done
# 213/52869 embeddings done
# 214/52869 embeddings done
# 215/52869 embeddings done
# 216/52869 embeddings done
# 217/52869 embeddings done
# 218/52869 embeddings done
# 219/52869 embeddings done
# 220/52869 embeddings done
# 221/52869 embeddings done
# 222/52869 embeddings done
# 223/52869 embeddings done
# 224/52869 embeddings done
# 225/52869 embeddings done
# 226/52869 embeddings done
# 227/52869 embeddings done
# 228/52869 embeddings done
# 229/52869 embeddings done
# 230/52869 embeddings done
# 231/52869 embeddings done
# 232/52869 embeddings done
# 233/52869 embeddings done
# 234/52869 embeddings done
# 235/52869 embeddings done
# 236/52869 embeddings done
# 237/52869 embeddings done
# 238/52869 embeddings done
# 239/52869 embeddings done
# 240/52869 embeddings done
# 241/52869 embeddings done
# 242/52869 embeddings done
# 243/52869 embeddings done
# 244/52869 embeddings done
# 245/52869 embeddings done
# 246/52869 embeddings done
# 247/52869 embeddings done
# 248/52869 embeddings done
# 249/52869 embeddings done
# 250/52869 embeddings done
# 251/52869 embeddings done
# 252/52869 embeddings done
# 253/52869 embeddings done
# 254/52869 embeddings done
# 255/52869 embeddings done
# 256/52869 embeddings done
# 257/52869 embeddings done
# 258/52869 embeddings done
# 259/52869 embeddings done
# 260/52869 embeddings done
# 261/52869 embeddings done
# 262/52869 embeddings done
# 263/52869 embeddings done
# 264/52869 embeddings done
# 265/52869 embeddings done
# 266/52869 embeddings done
# 267/52869 embeddings done
# 268/52869 embeddings done
# 269/52869 embeddings done
# 270/52869 embeddings done
# 271/52869 embeddings done
# 272/52869 embeddings done
# 273/52869 embeddings done
# 274/52869 embeddings done
# 275/52869 embeddings done
# 276/52869 embeddings done
# 277/52869 embeddings done
# 278/52869 embeddings done
# 279/52869 embeddings done
# 280/52869 embeddings done
# 281/52869 embeddings done
# 282/52869 embeddings done
# 283/52869 embeddings done
# 284/52869 embeddings done
# 285/52869 embeddings done
# 286/52869 embeddings done
# 287/52869 embeddings done
# 288/52869 embeddings done
# 289/52869 embeddings done
# 290/52869 embeddings done
# 291/52869 embeddings done
# 292/52869 embeddings done
# 293/52869 embeddings done
# 294/52869 embeddings done
# 295/52869 embeddings done
# 296/52869 embeddings done
# 297/52869 embeddings done
# 298/52869 embeddings done
# 299/52869 embeddings done
# 300/52869 embeddings done
# 301/52869 embeddings done
# 302/52869 embeddings done
# 303/52869 embeddings done
# 304/52869 embeddings done
# 305/52869 embeddings done
# 306/52869 embeddings done
# 307/52869 embeddings done
# 308/52869 embeddings done
# 309/52869 embeddings done
# 310/52869 embeddings done
# 311/52869 embeddings done
# 312/52869 embeddings done
# 313/52869 embeddings done
# 314/52869 embeddings done
# 315/52869 embeddings done
# 316/52869 embeddings done
# 317/52869 embeddings done
# 318/52869 embeddings done
# 319/52869 embeddings done
# 320/52869 embeddings done
# 321/52869 embeddings done
# 322/52869 embeddings done
# 323/52869 embeddings done
# 324/52869 embeddings done
# 325/52869 embeddings done
# 326/52869 embeddings done
# 327/52869 embeddings done
# 328/52869 embeddings done
# 329/52869 embeddings done
# 330/52869 embeddings done
# 331/52869 embeddings done
# 332/52869 embeddings done
# 333/52869 embeddings done
# 334/52869 embeddings done
# 335/52869 embeddings done
# 336/52869 embeddings done
# 337/52869 embeddings done
# 338/52869 embeddings done
# 339/52869 embeddings done
# 340/52869 embeddings done
# 341/52869 embeddings done
# 342/52869 embeddings done
# 343/52869 embeddings done
# 344/52869 embeddings done
# 345/52869 embeddings done
# 346/52869 embeddings done
# 347/52869 embeddings done
# 348/52869 embeddings done
# 349/52869 embeddings done
# 350/52869 embeddings done
# 351/52869 embeddings done
# 352/52869 embeddings done
# 353/52869 embeddings done
# 354/52869 embeddings done
# 355/52869 embeddings done
# 356/52869 embeddings done
# 357/52869 embeddings done
# 358/52869 embeddings done
# 359/52869 embeddings done
# 360/52869 embeddings done
# 361/52869 embeddings done
# 362/52869 embeddings done
# 363/52869 embeddings done
# 364/52869 embeddings done
# 365/52869 embeddings done
# 366/52869 embeddings done
# 367/52869 embeddings done
# 368/52869 embeddings done
# 369/52869 embeddings done
# 370/52869 embeddings done
# 371/52869 embeddings done
# 372/52869 embeddings done
# 373/52869 embeddings done
# 374/52869 embeddings done
# 375/52869 embeddings done
# 376/52869 embeddings done
# 377/52869 embeddings done
# 378/52869 embeddings done
# 379/52869 embeddings done
# 380/52869 embeddings done
# 381/52869 embeddings done
# 382/52869 embeddings done
# 383/52869 embeddings done
# 384/52869 embeddings done
# 385/52869 embeddings done
# 386/52869 embeddings done
# 387/52869 embeddings done
# 388/52869 embeddings done
# 389/52869 embeddings done
# 390/52869 embeddings done
# 391/52869 embeddings done
# 392/52869 embeddings done
# 393/52869 embeddings done
# 394/52869 embeddings done
# 395/52869 embeddings done
# 396/52869 embeddings done
# 397/52869 embeddings done
# 398/52869 embeddings done
# 399/52869 embeddings done
# 400/52869 embeddings done
# 401/52869 embeddings done
# 402/52869 embeddings done
# 403/52869 embeddings done
# 404/52869 embeddings done
# 405/52869 embeddings done
# 406/52869 embeddings done
# 407/52869 embeddings done
# 408/52869 embeddings done
# 409/52869 embeddings done
# 410/52869 embeddings done
# 411/52869 embeddings done
# 412/52869 embeddings done
# 413/52869 embeddings done
# 414/52869 embeddings done
# 415/52869 embeddings done
# 416/52869 embeddings done
# 417/52869 embeddings done
# 418/52869 embeddings done
# 419/52869 embeddings done
# 420/52869 embeddings done
# 421/52869 embeddings done
# 422/52869 embeddings done
# 423/52869 embeddings done
# 424/52869 embeddings done
# 425/52869 embeddings done
# 426/52869 embeddings done
# 427/52869 embeddings done
# 428/52869 embeddings done
# 429/52869 embeddings done
# 430/52869 embeddings done
# 431/52869 embeddings done
# 432/52869 embeddings done
# 433/52869 embeddings done
# 434/52869 embeddings done
# 435/52869 embeddings done
# 436/52869 embeddings done
# 437/52869 embeddings done
# 438/52869 embeddings done
# 439/52869 embeddings done
# 440/52869 embeddings done
# 441/52869 embeddings done
# 442/52869 embeddings done
# 443/52869 embeddings done
# 444/52869 embeddings done
# 445/52869 embeddings done
# 446/52869 embeddings done
# 447/52869 embeddings done
# 448/52869 embeddings done
# 449/52869 embeddings done
# 450/52869 embeddings done
# 451/52869 embeddings done
# 452/52869 embeddings done
# 453/52869 embeddings done
# 454/52869 embeddings done
# 455/52869 embeddings done
# 456/52869 embeddings done
# 457/52869 embeddings done
# 458/52869 embeddings done
# 459/52869 embeddings done
# 460/52869 embeddings done
# 461/52869 embeddings done
# 462/52869 embeddings done
# 463/52869 embeddings done
# 464/52869 embeddings done
# 465/52869 embeddings done
# 466/52869 embeddings done
# 467/52869 embeddings done
# 468/52869 embeddings done
# 469/52869 embeddings done
# 470/52869 embeddings done
# 471/52869 embeddings done
# 472/52869 embeddings done
# 473/52869 embeddings done
# 474/52869 embeddings done
# 475/52869 embeddings done
# 476/52869 embeddings done
# 477/52869 embeddings done
# 478/52869 embeddings done
# 479/52869 embeddings done
# 480/52869 embeddings done
# 481/52869 embeddings done
# 482/52869 embeddings done
# 483/52869 embeddings done
# 484/52869 embeddings done
# 485/52869 embeddings done
# 486/52869 embeddings done
# 487/52869 embeddings done
# 488/52869 embeddings done
# 489/52869 embeddings done
# 490/52869 embeddings done
# 491/52869 embeddings done
# 492/52869 embeddings done
# 493/52869 embeddings done
# 494/52869 embeddings done
# 495/52869 embeddings done
# 496/52869 embeddings done
# 497/52869 embeddings done
# 498/52869 embeddings done
# 499/52869 embeddings done
# 500/52869 embeddings done
# 501/52869 embeddings done
# 502/52869 embeddings done
# 503/52869 embeddings done
# 504/52869 embeddings done
# 505/52869 embeddings done
# 506/52869 embeddings done
# 507/52869 embeddings done
# 508/52869 embeddings done
# 509/52869 embeddings done
# 510/52869 embeddings done
# 511/52869 embeddings done
# 512/52869 embeddings done
# 513/52869 embeddings done
# 514/52869 embeddings done
# 515/52869 embeddings done
# 516/52869 embeddings done
# 517/52869 embeddings done
# 518/52869 embeddings done
# 519/52869 embeddings done
# 520/52869 embeddings done
# 521/52869 embeddings done
# 522/52869 embeddings done
# 523/52869 embeddings done
# 524/52869 embeddings done
# 525/52869 embeddings done
# 526/52869 embeddings done
# 527/52869 embeddings done
# 528/52869 embeddings done
# 529/52869 embeddings done
# 530/52869 embeddings done
# 531/52869 embeddings done
# 532/52869 embeddings done
# 533/52869 embeddings done
# 534/52869 embeddings done
# 535/52869 embeddings done
# 536/52869 embeddings done
# 537/52869 embeddings done
# 538/52869 embeddings done
# 539/52869 embeddings done
# 540/52869 embeddings done
# 541/52869 embeddings done
# 542/52869 embeddings done
# 543/52869 embeddings done
# 544/52869 embeddings done
# 545/52869 embeddings done
# 546/52869 embeddings done
# 547/52869 embeddings done
# 548/52869 embeddings done
# 549/52869 embeddings done
# 550/52869 embeddings done
# 551/52869 embeddings done
# 552/52869 embeddings done
# 553/52869 embeddings done
# 554/52869 embeddings done
# 555/52869 embeddings done
# 556/52869 embeddings done
# 557/52869 embeddings done
# 558/52869 embeddings done
# 559/52869 embeddings done
# 560/52869 embeddings done
# 561/52869 embeddings done
# 562/52869 embeddings done
# 563/52869 embeddings done
# 564/52869 embeddings done
# 565/52869 embeddings done
# 566/52869 embeddings done
# 567/52869 embeddings done
# 568/52869 embeddings done
# 569/52869 embeddings done
# 570/52869 embeddings done
# 571/52869 embeddings done
# 572/52869 embeddings done
# 573/52869 embeddings done
# 574/52869 embeddings done
# 575/52869 embeddings done
# 576/52869 embeddings done
# 577/52869 embeddings done
# 578/52869 embeddings done
# 579/52869 embeddings done
# 580/52869 embeddings done
# 581/52869 embeddings done
# 582/52869 embeddings done
# 583/52869 embeddings done
# 584/52869 embeddings done
# 585/52869 embeddings done
# 586/52869 embeddings done
# 587/52869 embeddings done
# 588/52869 embeddings done
# 589/52869 embeddings done
# 590/52869 embeddings done
# 591/52869 embeddings done
# 592/52869 embeddings done
# 593/52869 embeddings done
# 594/52869 embeddings done
# 595/52869 embeddings done
# 596/52869 embeddings done
# 597/52869 embeddings done
# 598/52869 embeddings done
# 599/52869 embeddings done
# 600/52869 embeddings done
# 601/52869 embeddings done
# 602/52869 embeddings done
# 603/52869 embeddings done
# 604/52869 embeddings done
# 605/52869 embeddings done
# 606/52869 embeddings done
# 607/52869 embeddings done
# 608/52869 embeddings done
# 609/52869 embeddings done
# 610/52869 embeddings done
# 611/52869 embeddings done
# 612/52869 embeddings done
# 613/52869 embeddings done
# 614/52869 embeddings done
# 615/52869 embeddings done
# 616/52869 embeddings done
# 617/52869 embeddings done
# 618/52869 embeddings done
# 619/52869 embeddings done
# 620/52869 embeddings done
# 621/52869 embeddings done
# 622/52869 embeddings done
# 623/52869 embeddings done
# 624/52869 embeddings done
# 625/52869 embeddings done
# 626/52869 embeddings done
# 627/52869 embeddings done
# 628/52869 embeddings done
# 629/52869 embeddings done
# 630/52869 embeddings done
# 631/52869 embeddings done
# 632/52869 embeddings done
# 633/52869 embeddings done
# 634/52869 embeddings done
# 635/52869 embeddings done
# 636/52869 embeddings done
# 637/52869 embeddings done
# 638/52869 embeddings done
# 639/52869 embeddings done
# 640/52869 embeddings done
# 641/52869 embeddings done
# 642/52869 embeddings done
# 643/52869 embeddings done
# 644/52869 embeddings done
# 645/52869 embeddings done
# 646/52869 embeddings done
# 647/52869 embeddings done
# 648/52869 embeddings done
# 649/52869 embeddings done
# 650/52869 embeddings done
# 651/52869 embeddings done
# 652/52869 embeddings done
# 653/52869 embeddings done
# 654/52869 embeddings done
# 655/52869 embeddings done
# 656/52869 embeddings done
# 657/52869 embeddings done
# 658/52869 embeddings done
# 659/52869 embeddings done
# 660/52869 embeddings done
# 661/52869 embeddings done
# 662/52869 embeddings done
# 663/52869 embeddings done
# 664/52869 embeddings done
# 665/52869 embeddings done
# 666/52869 embeddings done
# 667/52869 embeddings done
# 668/52869 embeddings done
# 669/52869 embeddings done
# 670/52869 embeddings done
# 671/52869 embeddings done
# 672/52869 embeddings done
# 673/52869 embeddings done
# 674/52869 embeddings done
# 675/52869 embeddings done
# 676/52869 embeddings done
# 677/52869 embeddings done
# 678/52869 embeddings done
# 679/52869 embeddings done
# 680/52869 embeddings done
# 681/52869 embeddings done
# 682/52869 embeddings done
# 683/52869 embeddings done
# 684/52869 embeddings done
# 685/52869 embeddings done
# 686/52869 embeddings done
# 687/52869 embeddings done
# 688/52869 embeddings done
# 689/52869 embeddings done
# 690/52869 embeddings done
# 691/52869 embeddings done
# 692/52869 embeddings done
# 693/52869 embeddings done
# 694/52869 embeddings done
# 695/52869 embeddings done
# 696/52869 embeddings done
# 697/52869 embeddings done
# 698/52869 embeddings done
# 699/52869 embeddings done
# 700/52869 embeddings done
# 701/52869 embeddings done
# 702/52869 embeddings done
# 703/52869 embeddings done
# 704/52869 embeddings done
# 705/52869 embeddings done
# 706/52869 embeddings done
# 707/52869 embeddings done
# 708/52869 embeddings done
# 709/52869 embeddings done
# 710/52869 embeddings done
# 711/52869 embeddings done
# 712/52869 embeddings done
# 713/52869 embeddings done
# 714/52869 embeddings done
# 715/52869 embeddings done
# 716/52869 embeddings done
# 717/52869 embeddings done
# 718/52869 embeddings done
# 719/52869 embeddings done
# 720/52869 embeddings done
# 721/52869 embeddings done
# 722/52869 embeddings done
# 723/52869 embeddings done
# 724/52869 embeddings done
# 725/52869 embeddings done
# 726/52869 embeddings done
# 727/52869 embeddings done
# 728/52869 embeddings done
# 729/52869 embeddings done
# 730/52869 embeddings done
# 731/52869 embeddings done
# 732/52869 embeddings done
# 733/52869 embeddings done
# 734/52869 embeddings done
# 735/52869 embeddings done
# 736/52869 embeddings done
# 737/52869 embeddings done
# 738/52869 embeddings done
# 739/52869 embeddings done
# 740/52869 embeddings done
# 741/52869 embeddings done
# 742/52869 embeddings done
# 743/52869 embeddings done
# 744/52869 embeddings done
# 745/52869 embeddings done
# 746/52869 embeddings done
# 747/52869 embeddings done
# 748/52869 embeddings done
# 749/52869 embeddings done
# 750/52869 embeddings done
# 751/52869 embeddings done
# 752/52869 embeddings done
# 753/52869 embeddings done
# 754/52869 embeddings done
# 755/52869 embeddings done
# 756/52869 embeddings done
# 757/52869 embeddings done
# 758/52869 embeddings done
# 759/52869 embeddings done
# 760/52869 embeddings done
# 761/52869 embeddings done
# 762/52869 embeddings done
# 763/52869 embeddings done
# 764/52869 embeddings done
# 765/52869 embeddings done
# 766/52869 embeddings done
# 767/52869 embeddings done
# 768/52869 embeddings done
# 769/52869 embeddings done
# 770/52869 embeddings done
# 771/52869 embeddings done
# 772/52869 embeddings done
# 773/52869 embeddings done
# 774/52869 embeddings done
# 775/52869 embeddings done
# 776/52869 embeddings done
# 777/52869 embeddings done
# 778/52869 embeddings done
# 779/52869 embeddings done
# 780/52869 embeddings done
# 781/52869 embeddings done
# 782/52869 embeddings done
# 783/52869 embeddings done
# 784/52869 embeddings done
# 785/52869 embeddings done
# 786/52869 embeddings done
# 787/52869 embeddings done
# 788/52869 embeddings done
# 789/52869 embeddings done
# 790/52869 embeddings done
# 791/52869 embeddings done
# 792/52869 embeddings done
# 793/52869 embeddings done
# 794/52869 embeddings done
# 795/52869 embeddings done
# 796/52869 embeddings done
# 797/52869 embeddings done
# 798/52869 embeddings done
# 799/52869 embeddings done
# 800/52869 embeddings done
# 801/52869 embeddings done
# 802/52869 embeddings done
# 803/52869 embeddings done
# 804/52869 embeddings done
# 805/52869 embeddings done
# 806/52869 embeddings done
# 807/52869 embeddings done
# 808/52869 embeddings done
# 809/52869 embeddings done
# 810/52869 embeddings done
# 811/52869 embeddings done
# 812/52869 embeddings done
# 813/52869 embeddings done
# 814/52869 embeddings done
# 815/52869 embeddings done
# 816/52869 embeddings done
# 817/52869 embeddings done
# 818/52869 embeddings done
# 819/52869 embeddings done
# 820/52869 embeddings done
# 821/52869 embeddings done
# 822/52869 embeddings done
# 823/52869 embeddings done
# 824/52869 embeddings done
# 825/52869 embeddings done
# 826/52869 embeddings done
# 827/52869 embeddings done
# 828/52869 embeddings done
# 829/52869 embeddings done
# 830/52869 embeddings done
# 831/52869 embeddings done
# 832/52869 embeddings done
# 833/52869 embeddings done
# 834/52869 embeddings done
# 835/52869 embeddings done
# 836/52869 embeddings done
# 837/52869 embeddings done
# 838/52869 embeddings done
# 839/52869 embeddings done
# 840/52869 embeddings done
# 841/52869 embeddings done
# 842/52869 embeddings done
# 843/52869 embeddings done
# 844/52869 embeddings done
# 845/52869 embeddings done
# 846/52869 embeddings done
# 847/52869 embeddings done
# 848/52869 embeddings done
# 849/52869 embeddings done
# 850/52869 embeddings done
# 851/52869 embeddings done
# 852/52869 embeddings done
# 853/52869 embeddings done
# 854/52869 embeddings done
# 855/52869 embeddings done
# 856/52869 embeddings done
# 857/52869 embeddings done
# 858/52869 embeddings done
# 859/52869 embeddings done
# 860/52869 embeddings done
# 861/52869 embeddings done
# 862/52869 embeddings done
# 863/52869 embeddings done
# 864/52869 embeddings done
# 865/52869 embeddings done
# 866/52869 embeddings done
# 867/52869 embeddings done
# 868/52869 embeddings done
# 869/52869 embeddings done
# 870/52869 embeddings done
# 871/52869 embeddings done
# 872/52869 embeddings done
# 873/52869 embeddings done
# 874/52869 embeddings done
# 875/52869 embeddings done
# 876/52869 embeddings done
# 877/52869 embeddings done
# 878/52869 embeddings done
# 879/52869 embeddings done
# 880/52869 embeddings done
# 881/52869 embeddings done
# 882/52869 embeddings done
# 883/52869 embeddings done
# 884/52869 embeddings done
# 885/52869 embeddings done
# 886/52869 embeddings done
# 887/52869 embeddings done
# 888/52869 embeddings done
# 889/52869 embeddings done
# 890/52869 embeddings done
# 891/52869 embeddings done
# 892/52869 embeddings done
# 893/52869 embeddings done
# 894/52869 embeddings done
# 895/52869 embeddings done
# 896/52869 embeddings done
# 897/52869 embeddings done
# 898/52869 embeddings done
# 899/52869 embeddings done
# 900/52869 embeddings done
# 901/52869 embeddings done
# 902/52869 embeddings done
# 903/52869 embeddings done
# 904/52869 embeddings done
# 905/52869 embeddings done
# 906/52869 embeddings done
# 907/52869 embeddings done
# 908/52869 embeddings done
# 909/52869 embeddings done
# 910/52869 embeddings done
# 911/52869 embeddings done
# 912/52869 embeddings done
# 913/52869 embeddings done
# 914/52869 embeddings done
# 915/52869 embeddings done
# 916/52869 embeddings done
# 917/52869 embeddings done
# 918/52869 embeddings done
# 919/52869 embeddings done
# 920/52869 embeddings done
# 921/52869 embeddings done
# 922/52869 embeddings done
# 923/52869 embeddings done
# 924/52869 embeddings done
# 925/52869 embeddings done
# 926/52869 embeddings done
# 927/52869 embeddings done
# 928/52869 embeddings done
# 929/52869 embeddings done
# 930/52869 embeddings done
# 931/52869 embeddings done
# 932/52869 embeddings done
# 933/52869 embeddings done
# 934/52869 embeddings done
# 935/52869 embeddings done
# 936/52869 embeddings done
# 937/52869 embeddings done
# 938/52869 embeddings done
# 939/52869 embeddings done
# 940/52869 embeddings done
# 941/52869 embeddings done
# 942/52869 embeddings done
# 943/52869 embeddings done
# 944/52869 embeddings done
# 945/52869 embeddings done
# 946/52869 embeddings done
# 947/52869 embeddings done
# 948/52869 embeddings done
# 949/52869 embeddings done
# 950/52869 embeddings done
# 951/52869 embeddings done
# 952/52869 embeddings done
# 953/52869 embeddings done
# 954/52869 embeddings done
# 955/52869 embeddings done
# 956/52869 embeddings done
# 957/52869 embeddings done
# 958/52869 embeddings done
# 959/52869 embeddings done
# 960/52869 embeddings done
# 961/52869 embeddings done
# 962/52869 embeddings done
# 963/52869 embeddings done
# 964/52869 embeddings done
# 965/52869 embeddings done
# 966/52869 embeddings done
# 967/52869 embeddings done
# 968/52869 embeddings done
# 969/52869 embeddings done
# 970/52869 embeddings done
# 971/52869 embeddings done
# 972/52869 embeddings done
# 973/52869 embeddings done
# 974/52869 embeddings done
# 975/52869 embeddings done
# 976/52869 embeddings done
# 977/52869 embeddings done
# 978/52869 embeddings done
# 979/52869 embeddings done
# 980/52869 embeddings done
# 981/52869 embeddings done
# 982/52869 embeddings done
# 983/52869 embeddings done
# 984/52869 embeddings done
# 985/52869 embeddings done
# 986/52869 embeddings done
# 987/52869 embeddings done
# 988/52869 embeddings done
# 989/52869 embeddings done
# 990/52869 embeddings done
# 991/52869 embeddings done
# 992/52869 embeddings done
# 993/52869 embeddings done
# 994/52869 embeddings done
# 995/52869 embeddings done
# 996/52869 embeddings done
# 997/52869 embeddings done
# 998/52869 embeddings done
# 999/52869 embeddings done
# 1000/52869 embeddings done
# 1001/52869 embeddings done
# 1002/52869 embeddings done
# 1003/52869 embeddings done
# 1004/52869 embeddings done
# 1005/52869 embeddings done
# 1006/52869 embeddings done
# 1007/52869 embeddings done
# 1008/52869 embeddings done
# 1009/52869 embeddings done
# 1010/52869 embeddings done
# 1011/52869 embeddings done
# 1012/52869 embeddings done
# 1013/52869 embeddings done
# 1014/52869 embeddings done
# 1015/52869 embeddings done
# 1016/52869 embeddings done
# 1017/52869 embeddings done
# 1018/52869 embeddings done
# 1019/52869 embeddings done
# 1020/52869 embeddings done
# 1021/52869 embeddings done
# 1022/52869 embeddings done
# 1023/52869 embeddings done
# 1024/52869 embeddings done
# 1025/52869 embeddings done
# 1026/52869 embeddings done
# 1027/52869 embeddings done
# 1028/52869 embeddings done
# 1029/52869 embeddings done
# 1030/52869 embeddings done
# 1031/52869 embeddings done
# 1032/52869 embeddings done
# 1033/52869 embeddings done
# 1034/52869 embeddings done
# 1035/52869 embeddings done
# 1036/52869 embeddings done
# 1037/52869 embeddings done
# 1038/52869 embeddings done
# 1039/52869 embeddings done
# 1040/52869 embeddings done
# 1041/52869 embeddings done
# 1042/52869 embeddings done
# 1043/52869 embeddings done
# 1044/52869 embeddings done
# 1045/52869 embeddings done
# 1046/52869 embeddings done
# 1047/52869 embeddings done
# 1048/52869 embeddings done
# 1049/52869 embeddings done
# 1050/52869 embeddings done
# 1051/52869 embeddings done
# 1052/52869 embeddings done
# 1053/52869 embeddings done
# 1054/52869 embeddings done
# 1055/52869 embeddings done
# 1056/52869 embeddings done
# 1057/52869 embeddings done
# 1058/52869 embeddings done
# 1059/52869 embeddings done
# 1060/52869 embeddings done
# 1061/52869 embeddings done
# 1062/52869 embeddings done
# 1063/52869 embeddings done
# 1064/52869 embeddings done
# 1065/52869 embeddings done
# 1066/52869 embeddings done
# 1067/52869 embeddings done
# 1068/52869 embeddings done
# 1069/52869 embeddings done
# 1070/52869 embeddings done
# 1071/52869 embeddings done
# 1072/52869 embeddings done
# 1073/52869 embeddings done
# 1074/52869 embeddings done
# 1075/52869 embeddings done
# 1076/52869 embeddings done
# 1077/52869 embeddings done
# 1078/52869 embeddings done
# 1079/52869 embeddings done
# 1080/52869 embeddings done
# 1081/52869 embeddings done
# 1082/52869 embeddings done
# 1083/52869 embeddings done
# 1084/52869 embeddings done
# 1085/52869 embeddings done
# 1086/52869 embeddings done
# 1087/52869 embeddings done
# 1088/52869 embeddings done
# 1089/52869 embeddings done
# 1090/52869 embeddings done
# 1091/52869 embeddings done
# 1092/52869 embeddings done
# 1093/52869 embeddings done
# 1094/52869 embeddings done
# 1095/52869 embeddings done
# 1096/52869 embeddings done
# 1097/52869 embeddings done
# 1098/52869 embeddings done
# 1099/52869 embeddings done
# 1100/52869 embeddings done
# 1101/52869 embeddings done
# 1102/52869 embeddings done
# 1103/52869 embeddings done
# 1104/52869 embeddings done
# 1105/52869 embeddings done
# 1106/52869 embeddings done
# 1107/52869 embeddings done
# 1108/52869 embeddings done
# 1109/52869 embeddings done
# 1110/52869 embeddings done
# 1111/52869 embeddings done
# 1112/52869 embeddings done
# 1113/52869 embeddings done
# 1114/52869 embeddings done
# 1115/52869 embeddings done
# 1116/52869 embeddings done
# 1117/52869 embeddings done
# 1118/52869 embeddings done
# 1119/52869 embeddings done
# 1120/52869 embeddings done
# 1121/52869 embeddings done
# 1122/52869 embeddings done
# 1123/52869 embeddings done
# 1124/52869 embeddings done
# 1125/52869 embeddings done
# 1126/52869 embeddings done
# 1127/52869 embeddings done
# 1128/52869 embeddings done
# 1129/52869 embeddings done
# 1130/52869 embeddings done
# 1131/52869 embeddings done
# 1132/52869 embeddings done
# 1133/52869 embeddings done
# 1134/52869 embeddings done
# 1135/52869 embeddings done
# 1136/52869 embeddings done
# 1137/52869 embeddings done
# 1138/52869 embeddings done
# 1139/52869 embeddings done
# 1140/52869 embeddings done
# 1141/52869 embeddings done
# 1142/52869 embeddings done
# 1143/52869 embeddings done
# 1144/52869 embeddings done
# 1145/52869 embeddings done
# 1146/52869 embeddings done
# 1147/52869 embeddings done
# 1148/52869 embeddings done
# 1149/52869 embeddings done
# 1150/52869 embeddings done
# 1151/52869 embeddings done
# 1152/52869 embeddings done
# 1153/52869 embeddings done
# 1154/52869 embeddings done
# 1155/52869 embeddings done
# 1156/52869 embeddings done
# 1157/52869 embeddings done
# 1158/52869 embeddings done
# 1159/52869 embeddings done
# 1160/52869 embeddings done
# 1161/52869 embeddings done
# 1162/52869 embeddings done
# 1163/52869 embeddings done
# 1164/52869 embeddings done
# 1165/52869 embeddings done
# 1166/52869 embeddings done
# 1167/52869 embeddings done
# 1168/52869 embeddings done
# 1169/52869 embeddings done
# 1170/52869 embeddings done
# 1171/52869 embeddings done
# 1172/52869 embeddings done
# 1173/52869 embeddings done
# 1174/52869 embeddings done
# 1175/52869 embeddings done
# 1176/52869 embeddings done
# 1177/52869 embeddings done
# 1178/52869 embeddings done
# 1179/52869 embeddings done
# 1180/52869 embeddings done
# 1181/52869 embeddings done
# 1182/52869 embeddings done
# 1183/52869 embeddings done
# 1184/52869 embeddings done
# 1185/52869 embeddings done
# 1186/52869 embeddings done
# 1187/52869 embeddings done
# 1188/52869 embeddings done
# 1189/52869 embeddings done
# 1190/52869 embeddings done
# 1191/52869 embeddings done
# 1192/52869 embeddings done
# 1193/52869 embeddings done
# 1194/52869 embeddings done
# 1195/52869 embeddings done
# 1196/52869 embeddings done
# 1197/52869 embeddings done
# 1198/52869 embeddings done
# 1199/52869 embeddings done
# 1200/52869 embeddings done
# 1201/52869 embeddings done
# 1202/52869 embeddings done
# 1203/52869 embeddings done
# 1204/52869 embeddings done
# 1205/52869 embeddings done
# 1206/52869 embeddings done
# 1207/52869 embeddings done
# 1208/52869 embeddings done
# 1209/52869 embeddings done
# 1210/52869 embeddings done
# 1211/52869 embeddings done
# 1212/52869 embeddings done
# 1213/52869 embeddings done
# 1214/52869 embeddings done
# 1215/52869 embeddings done
# 1216/52869 embeddings done
# 1217/52869 embeddings done
# 1218/52869 embeddings done
# 1219/52869 embeddings done
# 1220/52869 embeddings done
# 1221/52869 embeddings done
# 1222/52869 embeddings done
# 1223/52869 embeddings done
# 1224/52869 embeddings done
# 1225/52869 embeddings done
# 1226/52869 embeddings done
# 1227/52869 embeddings done
# 1228/52869 embeddings done
# 1229/52869 embeddings done
# 1230/52869 embeddings done
# 1231/52869 embeddings done
# 1232/52869 embeddings done
# 1233/52869 embeddings done
# 1234/52869 embeddings done
# 1235/52869 embeddings done
# 1236/52869 embeddings done
# 1237/52869 embeddings done
# 1238/52869 embeddings done
# 1239/52869 embeddings done
# 1240/52869 embeddings done
# 1241/52869 embeddings done
# 1242/52869 embeddings done
# 1243/52869 embeddings done
# 1244/52869 embeddings done
# 1245/52869 embeddings done
# 1246/52869 embeddings done
# 1247/52869 embeddings done
# 1248/52869 embeddings done
# 1249/52869 embeddings done
# 1250/52869 embeddings done
# 1251/52869 embeddings done
# 1252/52869 embeddings done
# 1253/52869 embeddings done
# 1254/52869 embeddings done
# 1255/52869 embeddings done
# 1256/52869 embeddings done
# 1257/52869 embeddings done
# 1258/52869 embeddings done
# 1259/52869 embeddings done
# 1260/52869 embeddings done
# 1261/52869 embeddings done
# 1262/52869 embeddings done
# 1263/52869 embeddings done
# 1264/52869 embeddings done
# 1265/52869 embeddings done
# 1266/52869 embeddings done
# 1267/52869 embeddings done
# 1268/52869 embeddings done
# 1269/52869 embeddings done
# 1270/52869 embeddings done
# 1271/52869 embeddings done
# 1272/52869 embeddings done
# 1273/52869 embeddings done
# 1274/52869 embeddings done
# 1275/52869 embeddings done
# 1276/52869 embeddings done
# 1277/52869 embeddings done
# 1278/52869 embeddings done
# 1279/52869 embeddings done
# 1280/52869 embeddings done
# 1281/52869 embeddings done
# 1282/52869 embeddings done
# 1283/52869 embeddings done
# 1284/52869 embeddings done
# 1285/52869 embeddings done
# 1286/52869 embeddings done
# 1287/52869 embeddings done
# 1288/52869 embeddings done
# 1289/52869 embeddings done
# 1290/52869 embeddings done
# 1291/52869 embeddings done
# 1292/52869 embeddings done
# 1293/52869 embeddings done
# 1294/52869 embeddings done
# 1295/52869 embeddings done
# 1296/52869 embeddings done
# 1297/52869 embeddings done
# 1298/52869 embeddings done
# 1299/52869 embeddings done
# 1300/52869 embeddings done
# 1301/52869 embeddings done
# 1302/52869 embeddings done
# 1303/52869 embeddings done
# 1304/52869 embeddings done
# 1305/52869 embeddings done
# 1306/52869 embeddings done
# 1307/52869 embeddings done
# 1308/52869 embeddings done
# 1309/52869 embeddings done
# 1310/52869 embeddings done
# 1311/52869 embeddings done
# 1312/52869 embeddings done
# 1313/52869 embeddings done
# 1314/52869 embeddings done
# 1315/52869 embeddings done
# 1316/52869 embeddings done
# 1317/52869 embeddings done
# 1318/52869 embeddings done
# 1319/52869 embeddings done
# 1320/52869 embeddings done
# 1321/52869 embeddings done
# 1322/52869 embeddings done
# 1323/52869 embeddings done
# 1324/52869 embeddings done
# 1325/52869 embeddings done
# 1326/52869 embeddings done
# 1327/52869 embeddings done
# 1328/52869 embeddings done
# 1329/52869 embeddings done
# 1330/52869 embeddings done
# 1331/52869 embeddings done
# 1332/52869 embeddings done
# 1333/52869 embeddings done
# 1334/52869 embeddings done
# 1335/52869 embeddings done
# 1336/52869 embeddings done
# 1337/52869 embeddings done
# 1338/52869 embeddings done
# 1339/52869 embeddings done
# 1340/52869 embeddings done
# 1341/52869 embeddings done
# 1342/52869 embeddings done
# 1343/52869 embeddings done
# 1344/52869 embeddings done
# 1345/52869 embeddings done
# 1346/52869 embeddings done
# 1347/52869 embeddings done
# 1348/52869 embeddings done
# 1349/52869 embeddings done
# 1350/52869 embeddings done
# 1351/52869 embeddings done
# 1352/52869 embeddings done
# 1353/52869 embeddings done
# 1354/52869 embeddings done
# 1355/52869 embeddings done
# 1356/52869 embeddings done
# 1357/52869 embeddings done
# 1358/52869 embeddings done
# 1359/52869 embeddings done
# 1360/52869 embeddings done
# 1361/52869 embeddings done
# 1362/52869 embeddings done
# 1363/52869 embeddings done
# 1364/52869 embeddings done
# 1365/52869 embeddings done
# 1366/52869 embeddings done
# 1367/52869 embeddings done
# 1368/52869 embeddings done
# 1369/52869 embeddings done
# 1370/52869 embeddings done
# 1371/52869 embeddings done
# 1372/52869 embeddings done
# 1373/52869 embeddings done
# 1374/52869 embeddings done
# 1375/52869 embeddings done
# 1376/52869 embeddings done
# 1377/52869 embeddings done
# 1378/52869 embeddings done
# 1379/52869 embeddings done
# 1380/52869 embeddings done
# 1381/52869 embeddings done
# 1382/52869 embeddings done
# 1383/52869 embeddings done
# 1384/52869 embeddings done
# 1385/52869 embeddings done
# 1386/52869 embeddings done
# 1387/52869 embeddings done
# 1388/52869 embeddings done
# 1389/52869 embeddings done
# 1390/52869 embeddings done
# 1391/52869 embeddings done
# 1392/52869 embeddings done
# 1393/52869 embeddings done
# 1394/52869 embeddings done
# 1395/52869 embeddings done
# 1396/52869 embeddings done
# 1397/52869 embeddings done
# 1398/52869 embeddings done
# 1399/52869 embeddings done
# 1400/52869 embeddings done
# 1401/52869 embeddings done
# 1402/52869 embeddings done
# 1403/52869 embeddings done
# 1404/52869 embeddings done
# 1405/52869 embeddings done
# 1406/52869 embeddings done
# 1407/52869 embeddings done
# 1408/52869 embeddings done
# 1409/52869 embeddings done
# 1410/52869 embeddings done
# 1411/52869 embeddings done
# 1412/52869 embeddings done
# 1413/52869 embeddings done
# 1414/52869 embeddings done
# 1415/52869 embeddings done
# 1416/52869 embeddings done
# 1417/52869 embeddings done
# 1418/52869 embeddings done
# 1419/52869 embeddings done
# 1420/52869 embeddings done
# 1421/52869 embeddings done
# 1422/52869 embeddings done
# 1423/52869 embeddings done
# 1424/52869 embeddings done
# 1425/52869 embeddings done
# 1426/52869 embeddings done
# 1427/52869 embeddings done
# 1428/52869 embeddings done
# 1429/52869 embeddings done
# 1430/52869 embeddings done
# 1431/52869 embeddings done
# 1432/52869 embeddings done
# 1433/52869 embeddings done
# 1434/52869 embeddings done
# 1435/52869 embeddings done
# 1436/52869 embeddings done
# 1437/52869 embeddings done
# 1438/52869 embeddings done
# 1439/52869 embeddings done
# 1440/52869 embeddings done
# 1441/52869 embeddings done
# 1442/52869 embeddings done
# 1443/52869 embeddings done
# 1444/52869 embeddings done
# 1445/52869 embeddings done
# 1446/52869 embeddings done
# 1447/52869 embeddings done
# 1448/52869 embeddings done
# 1449/52869 embeddings done
# 1450/52869 embeddings done
# 1451/52869 embeddings done
# 1452/52869 embeddings done
# 1453/52869 embeddings done
# 1454/52869 embeddings done
# 1455/52869 embeddings done
# 1456/52869 embeddings done
# 1457/52869 embeddings done
# 1458/52869 embeddings done
# 1459/52869 embeddings done
# 1460/52869 embeddings done
# 1461/52869 embeddings done
# 1462/52869 embeddings done
# 1463/52869 embeddings done
# 1464/52869 embeddings done
# 1465/52869 embeddings done
# 1466/52869 embeddings done
# 1467/52869 embeddings done
# 1468/52869 embeddings done
# 1469/52869 embeddings done
# 1470/52869 embeddings done
# 1471/52869 embeddings done
# 1472/52869 embeddings done
# 1473/52869 embeddings done
# 1474/52869 embeddings done
# 1475/52869 embeddings done
# 1476/52869 embeddings done
# 1477/52869 embeddings done
# 1478/52869 embeddings done
# 1479/52869 embeddings done
# 1480/52869 embeddings done
# 1481/52869 embeddings done
# 1482/52869 embeddings done
# 1483/52869 embeddings done
# 1484/52869 embeddings done
# 1485/52869 embeddings done
# 1486/52869 embeddings done
# 1487/52869 embeddings done
# 1488/52869 embeddings done
# 1489/52869 embeddings done
# 1490/52869 embeddings done
# 1491/52869 embeddings done
# 1492/52869 embeddings done
# 1493/52869 embeddings done
# 1494/52869 embeddings done
# 1495/52869 embeddings done
# 1496/52869 embeddings done
# 1497/52869 embeddings done
# 1498/52869 embeddings done
# 1499/52869 embeddings done
# 1500/52869 embeddings done
# 1501/52869 embeddings done
# 1502/52869 embeddings done
# 1503/52869 embeddings done
# 1504/52869 embeddings done
# 1505/52869 embeddings done
# 1506/52869 embeddings done
# 1507/52869 embeddings done
# 1508/52869 embeddings done
# 1509/52869 embeddings done
# 1510/52869 embeddings done
# 1511/52869 embeddings done
# 1512/52869 embeddings done
# 1513/52869 embeddings done
# 1514/52869 embeddings done
# 1515/52869 embeddings done
# 1516/52869 embeddings done
# 1517/52869 embeddings done
# 1518/52869 embeddings done
# 1519/52869 embeddings done
# 1520/52869 embeddings done
# 1521/52869 embeddings done
# 1522/52869 embeddings done
# 1523/52869 embeddings done
# 1524/52869 embeddings done
# 1525/52869 embeddings done
# 1526/52869 embeddings done
# 1527/52869 embeddings done
# 1528/52869 embeddings done
# 1529/52869 embeddings done
# 1530/52869 embeddings done
# 1531/52869 embeddings done
# 1532/52869 embeddings done
# 1533/52869 embeddings done
# 1534/52869 embeddings done
# 1535/52869 embeddings done
# 1536/52869 embeddings done
# 1537/52869 embeddings done
# 1538/52869 embeddings done
# 1539/52869 embeddings done
# 1540/52869 embeddings done
# 1541/52869 embeddings done
# 1542/52869 embeddings done
# 1543/52869 embeddings done
# 1544/52869 embeddings done
# 1545/52869 embeddings done
# 1546/52869 embeddings done
# 1547/52869 embeddings done
# 1548/52869 embeddings done
# 1549/52869 embeddings done
# 1550/52869 embeddings done
# 1551/52869 embeddings done
# 1552/52869 embeddings done
# 1553/52869 embeddings done
# 1554/52869 embeddings done
# 1555/52869 embeddings done
# 1556/52869 embeddings done
# 1557/52869 embeddings done
# 1558/52869 embeddings done
# 1559/52869 embeddings done
# 1560/52869 embeddings done
# 1561/52869 embeddings done
# 1562/52869 embeddings done
# 1563/52869 embeddings done
# 1564/52869 embeddings done
# 1565/52869 embeddings done
# 1566/52869 embeddings done
# 1567/52869 embeddings done
# 1568/52869 embeddings done
# 1569/52869 embeddings done
# 1570/52869 embeddings done
# 1571/52869 embeddings done
# 1572/52869 embeddings done
# 1573/52869 embeddings done
# 1574/52869 embeddings done
# 1575/52869 embeddings done
# 1576/52869 embeddings done
# 1577/52869 embeddings done
# 1578/52869 embeddings done
# 1579/52869 embeddings done
# 1580/52869 embeddings done
# 1581/52869 embeddings done
# 1582/52869 embeddings done
# 1583/52869 embeddings done
# 1584/52869 embeddings done
# 1585/52869 embeddings done
# 1586/52869 embeddings done
# 1587/52869 embeddings done
# 1588/52869 embeddings done
# 1589/52869 embeddings done
# 1590/52869 embeddings done
# 1591/52869 embeddings done
# 1592/52869 embeddings done
# 1593/52869 embeddings done
# 1594/52869 embeddings done
# 1595/52869 embeddings done
# 1596/52869 embeddings done
# 1597/52869 embeddings done
# 1598/52869 embeddings done
# 1599/52869 embeddings done
# 1600/52869 embeddings done
# 1601/52869 embeddings done
# 1602/52869 embeddings done
# 1603/52869 embeddings done
# 1604/52869 embeddings done
# 1605/52869 embeddings done
# 1606/52869 embeddings done
# 1607/52869 embeddings done
# 1608/52869 embeddings done
# 1609/52869 embeddings done
# 1610/52869 embeddings done
# 1611/52869 embeddings done
# 1612/52869 embeddings done
# 1613/52869 embeddings done
# 1614/52869 embeddings done
# 1615/52869 embeddings done
# 1616/52869 embeddings done
# 1617/52869 embeddings done
# 1618/52869 embeddings done
# 1619/52869 embeddings done
# 1620/52869 embeddings done
# 1621/52869 embeddings done
# 1622/52869 embeddings done
# 1623/52869 embeddings done
# 1624/52869 embeddings done
# 1625/52869 embeddings done
# 1626/52869 embeddings done
# 1627/52869 embeddings done
# 1628/52869 embeddings done
# 1629/52869 embeddings done
# 1630/52869 embeddings done
# 1631/52869 embeddings done
# 1632/52869 embeddings done
# 1633/52869 embeddings done
# 1634/52869 embeddings done
# 1635/52869 embeddings done
# 1636/52869 embeddings done
# 1637/52869 embeddings done
# 1638/52869 embeddings done
# 1639/52869 embeddings done
# 1640/52869 embeddings done
# 1641/52869 embeddings done
# 1642/52869 embeddings done
# 1643/52869 embeddings done
# 1644/52869 embeddings done
# 1645/52869 embeddings done
# 1646/52869 embeddings done
# 1647/52869 embeddings done
# 1648/52869 embeddings done
# 1649/52869 embeddings done
# 1650/52869 embeddings done
# 1651/52869 embeddings done
# 1652/52869 embeddings done
# 1653/52869 embeddings done
# 1654/52869 embeddings done
# 1655/52869 embeddings done
# 1656/52869 embeddings done
# 1657/52869 embeddings done
# 1658/52869 embeddings done
# 1659/52869 embeddings done
# 1660/52869 embeddings done
# 1661/52869 embeddings done
# 1662/52869 embeddings done
# 1663/52869 embeddings done
# 1664/52869 embeddings done
# 1665/52869 embeddings done
# 1666/52869 embeddings done
# 1667/52869 embeddings done
# 1668/52869 embeddings done
# 1669/52869 embeddings done
# 1670/52869 embeddings done
# 1671/52869 embeddings done
# 1672/52869 embeddings done
# 1673/52869 embeddings done
# 1674/52869 embeddings done
# 1675/52869 embeddings done
# 1676/52869 embeddings done
# 1677/52869 embeddings done
# 1678/52869 embeddings done
# 1679/52869 embeddings done
# 1680/52869 embeddings done
# 1681/52869 embeddings done
# 1682/52869 embeddings done
# 1683/52869 embeddings done
# 1684/52869 embeddings done
# 1685/52869 embeddings done
# 1686/52869 embeddings done
# 1687/52869 embeddings done
# 1688/52869 embeddings done
# 1689/52869 embeddings done
# 1690/52869 embeddings done
# 1691/52869 embeddings done
# 1692/52869 embeddings done
# 1693/52869 embeddings done
# 1694/52869 embeddings done
# 1695/52869 embeddings done
# 1696/52869 embeddings done
# 1697/52869 embeddings done
# 1698/52869 embeddings done
# 1699/52869 embeddings done
# 1700/52869 embeddings done
# 1701/52869 embeddings done
# 1702/52869 embeddings done
# 1703/52869 embeddings done
# 1704/52869 embeddings done
# 1705/52869 embeddings done
# 1706/52869 embeddings done
# 1707/52869 embeddings done
# 1708/52869 embeddings done
# 1709/52869 embeddings done
# 1710/52869 embeddings done
# 1711/52869 embeddings done
# 1712/52869 embeddings done
# 1713/52869 embeddings done
# 1714/52869 embeddings done
# 1715/52869 embeddings done
# 1716/52869 embeddings done
# 1717/52869 embeddings done
# 1718/52869 embeddings done
# 1719/52869 embeddings done
# 1720/52869 embeddings done
# 1721/52869 embeddings done
# 1722/52869 embeddings done
# 1723/52869 embeddings done
# 1724/52869 embeddings done
# 1725/52869 embeddings done
# 1726/52869 embeddings done
# 1727/52869 embeddings done
# 1728/52869 embeddings done
# 1729/52869 embeddings done
# 1730/52869 embeddings done
# 1731/52869 embeddings done
# 1732/52869 embeddings done
# 1733/52869 embeddings done
# 1734/52869 embeddings done
# 1735/52869 embeddings done
# 1736/52869 embeddings done
# 1737/52869 embeddings done
# 1738/52869 embeddings done
# 1739/52869 embeddings done
# 1740/52869 embeddings done
# 1741/52869 embeddings done
# 1742/52869 embeddings done
# 1743/52869 embeddings done
# 1744/52869 embeddings done
# 1745/52869 embeddings done
# 1746/52869 embeddings done
# 1747/52869 embeddings done
# 1748/52869 embeddings done
# 1749/52869 embeddings done
# 1750/52869 embeddings done
# 1751/52869 embeddings done
# 1752/52869 embeddings done
# 1753/52869 embeddings done
# 1754/52869 embeddings done
# 1755/52869 embeddings done
# 1756/52869 embeddings done
# 1757/52869 embeddings done
# 1758/52869 embeddings done
# 1759/52869 embeddings done
# 1760/52869 embeddings done
# 1761/52869 embeddings done
# 1762/52869 embeddings done
# 1763/52869 embeddings done
# 1764/52869 embeddings done
# 1765/52869 embeddings done
# 1766/52869 embeddings done
# 1767/52869 embeddings done
# 1768/52869 embeddings done
# 1769/52869 embeddings done
# 1770/52869 embeddings done
# 1771/52869 embeddings done
# 1772/52869 embeddings done
# 1773/52869 embeddings done
# 1774/52869 embeddings done
# 1775/52869 embeddings done
# 1776/52869 embeddings done
# 1777/52869 embeddings done
# 1778/52869 embeddings done
# 1779/52869 embeddings done
# 1780/52869 embeddings done
# 1781/52869 embeddings done
# 1782/52869 embeddings done
# 1783/52869 embeddings done
# 1784/52869 embeddings done
# 1785/52869 embeddings done
# 1786/52869 embeddings done
# 1787/52869 embeddings done
# 1788/52869 embeddings done
# 1789/52869 embeddings done
# 1790/52869 embeddings done
# 1791/52869 embeddings done
# 1792/52869 embeddings done
# 1793/52869 embeddings done
# 1794/52869 embeddings done
# 1795/52869 embeddings done
# 1796/52869 embeddings done
# 1797/52869 embeddings done
# ...
# 52306/52869 embeddings done
# 52307/52869 embeddings done
# 52308/52869 embeddings done
# 52309/52869 embeddings done
# 52310/52869 embeddings done
# 52311/52869 embeddings done
# 52312/52869 embeddings done
# 52313/52869 embeddings done
# 52314/52869 embeddings done
# 52315/52869 embeddings done
# 52316/52869 embeddings done
# 52317/52869 embeddings done
# 52318/52869 embeddings done
# 52319/52869 embeddings done
# 52320/52869 embeddings done
# 52321/52869 embeddings done
# 52322/52869 embeddings done
# 52323/52869 embeddings done
# 52324/52869 embeddings done
# 52325/52869 embeddings done
# 52326/52869 embeddings done
# 52327/52869 embeddings done
# 52328/52869 embeddings done
# 52329/52869 embeddings done
# 52330/52869 embeddings done
# 52331/52869 embeddings done
# 52332/52869 embeddings done
# 52333/52869 embeddings done
# 52334/52869 embeddings done
# 52335/52869 embeddings done
# 52336/52869 embeddings done
# 52337/52869 embeddings done
# 52338/52869 embeddings done
# 52339/52869 embeddings done
# 52340/52869 embeddings done
# 52341/52869 embeddings done
# 52342/52869 embeddings done
# 52343/52869 embeddings done
# 52344/52869 embeddings done
# 52345/52869 embeddings done
# 52346/52869 embeddings done
# 52347/52869 embeddings done
# 52348/52869 embeddings done
# 52349/52869 embeddings done
# 52350/52869 embeddings done
# 52351/52869 embeddings done
# 52352/52869 embeddings done
# 52353/52869 embeddings done
# 52354/52869 embeddings done
# 52355/52869 embeddings done
# 52356/52869 embeddings done
# 52357/52869 embeddings done
# 52358/52869 embeddings done
# 52359/52869 embeddings done
# 52360/52869 embeddings done
# 52361/52869 embeddings done
# 52362/52869 embeddings done
# 52363/52869 embeddings done
# 52364/52869 embeddings done
# 52365/52869 embeddings done
# 52366/52869 embeddings done
# 52367/52869 embeddings done
# 52368/52869 embeddings done
# 52369/52869 embeddings done
# 52370/52869 embeddings done
# 52371/52869 embeddings done
# 52372/52869 embeddings done
# 52373/52869 embeddings done
# 52374/52869 embeddings done
# 52375/52869 embeddings done
# 52376/52869 embeddings done
# 52377/52869 embeddings done
# 52378/52869 embeddings done
# 52379/52869 embeddings done
# 52380/52869 embeddings done
# 52381/52869 embeddings done
# 52382/52869 embeddings done
# 52383/52869 embeddings done
# 52384/52869 embeddings done
# 52385/52869 embeddings done
# 52386/52869 embeddings done
# 52387/52869 embeddings done
# 52388/52869 embeddings done
# 52389/52869 embeddings done
# 52390/52869 embeddings done
# 52391/52869 embeddings done
# 52392/52869 embeddings done
# 52393/52869 embeddings done
# 52394/52869 embeddings done
# 52395/52869 embeddings done
# 52396/52869 embeddings done
# 52397/52869 embeddings done
# 52398/52869 embeddings done
# 52399/52869 embeddings done
# 52400/52869 embeddings done
# 52401/52869 embeddings done
# 52402/52869 embeddings done
# 52403/52869 embeddings done
# 52404/52869 embeddings done
# 52405/52869 embeddings done
# 52406/52869 embeddings done
# 52407/52869 embeddings done
# 52408/52869 embeddings done
# 52409/52869 embeddings done
# 52410/52869 embeddings done
# 52411/52869 embeddings done
# 52412/52869 embeddings done
# 52413/52869 embeddings done
# 52414/52869 embeddings done
# 52415/52869 embeddings done
# 52416/52869 embeddings done
# 52417/52869 embeddings done
# 52418/52869 embeddings done
# 52419/52869 embeddings done
# 52420/52869 embeddings done
# 52421/52869 embeddings done
# 52422/52869 embeddings done
# 52423/52869 embeddings done
# 52424/52869 embeddings done
# 52425/52869 embeddings done
# 52426/52869 embeddings done
# 52427/52869 embeddings done
# 52428/52869 embeddings done
# 52429/52869 embeddings done
# 52430/52869 embeddings done
# 52431/52869 embeddings done
# 52432/52869 embeddings done
# 52433/52869 embeddings done
# 52434/52869 embeddings done
# 52435/52869 embeddings done
# 52436/52869 embeddings done
# 52437/52869 embeddings done
# 52438/52869 embeddings done
# 52439/52869 embeddings done
# 52440/52869 embeddings done
# 52441/52869 embeddings done
# 52442/52869 embeddings done
# 52443/52869 embeddings done
# 52444/52869 embeddings done
# 52445/52869 embeddings done
# 52446/52869 embeddings done
# 52447/52869 embeddings done
# 52448/52869 embeddings done
# 52449/52869 embeddings done
# 52450/52869 embeddings done
# 52451/52869 embeddings done
# 52452/52869 embeddings done
# 52453/52869 embeddings done
# 52454/52869 embeddings done
# 52455/52869 embeddings done
# 52456/52869 embeddings done
# 52457/52869 embeddings done
# 52458/52869 embeddings done
# 52459/52869 embeddings done
# 52460/52869 embeddings done
# 52461/52869 embeddings done
# 52462/52869 embeddings done
# 52463/52869 embeddings done
# 52464/52869 embeddings done
# 52465/52869 embeddings done
# 52466/52869 embeddings done
# 52467/52869 embeddings done
# 52468/52869 embeddings done
# 52469/52869 embeddings done
# 52470/52869 embeddings done
# 52471/52869 embeddings done
# 52472/52869 embeddings done
# 52473/52869 embeddings done
# 52474/52869 embeddings done
# 52475/52869 embeddings done
# 52476/52869 embeddings done
# 52477/52869 embeddings done
# 52478/52869 embeddings done
# 52479/52869 embeddings done
# 52480/52869 embeddings done
# 52481/52869 embeddings done
# 52482/52869 embeddings done
# 52483/52869 embeddings done
# 52484/52869 embeddings done
# 52485/52869 embeddings done
# 52486/52869 embeddings done
# 52487/52869 embeddings done
# 52488/52869 embeddings done
# 52489/52869 embeddings done
# 52490/52869 embeddings done
# 52491/52869 embeddings done
# 52492/52869 embeddings done
# 52493/52869 embeddings done
# 52494/52869 embeddings done
# 52495/52869 embeddings done
# 52496/52869 embeddings done
# 52497/52869 embeddings done
# 52498/52869 embeddings done
# 52499/52869 embeddings done
# 52500/52869 embeddings done
# 52501/52869 embeddings done
# 52502/52869 embeddings done
# 52503/52869 embeddings done
# 52504/52869 embeddings done
# 52505/52869 embeddings done
# 52506/52869 embeddings done
# 52507/52869 embeddings done
# 52508/52869 embeddings done
# 52509/52869 embeddings done
# 52510/52869 embeddings done
# 52511/52869 embeddings done
# 52512/52869 embeddings done
# 52513/52869 embeddings done
# 52514/52869 embeddings done
# 52515/52869 embeddings done
# 52516/52869 embeddings done
# 52517/52869 embeddings done
# 52518/52869 embeddings done
# 52519/52869 embeddings done
# 52520/52869 embeddings done
# 52521/52869 embeddings done
# 52522/52869 embeddings done
# 52523/52869 embeddings done
# 52524/52869 embeddings done
# 52525/52869 embeddings done
# 52526/52869 embeddings done
# 52527/52869 embeddings done
# 52528/52869 embeddings done
# 52529/52869 embeddings done
# 52530/52869 embeddings done
# 52531/52869 embeddings done
# 52532/52869 embeddings done
# 52533/52869 embeddings done
# 52534/52869 embeddings done
# 52535/52869 embeddings done
# 52536/52869 embeddings done
# 52537/52869 embeddings done
# 52538/52869 embeddings done
# 52539/52869 embeddings done
# 52540/52869 embeddings done
# 52541/52869 embeddings done
# 52542/52869 embeddings done
# 52543/52869 embeddings done
# 52544/52869 embeddings done
# 52545/52869 embeddings done
# 52546/52869 embeddings done
# 52547/52869 embeddings done
# 52548/52869 embeddings done
# 52549/52869 embeddings done
# 52550/52869 embeddings done
# 52551/52869 embeddings done
# 52552/52869 embeddings done
# 52553/52869 embeddings done
# 52554/52869 embeddings done
# 52555/52869 embeddings done
# 52556/52869 embeddings done
# 52557/52869 embeddings done
# 52558/52869 embeddings done
# 52559/52869 embeddings done
# 52560/52869 embeddings done
# 52561/52869 embeddings done
# 52562/52869 embeddings done
# 52563/52869 embeddings done
# 52564/52869 embeddings done
# 52565/52869 embeddings done
# 52566/52869 embeddings done
# 52567/52869 embeddings done
# 52568/52869 embeddings done
# 52569/52869 embeddings done
# 52570/52869 embeddings done
# 52571/52869 embeddings done
# 52572/52869 embeddings done
# 52573/52869 embeddings done
# 52574/52869 embeddings done
# 52575/52869 embeddings done
# 52576/52869 embeddings done
# 52577/52869 embeddings done
# 52578/52869 embeddings done
# 52579/52869 embeddings done
# 52580/52869 embeddings done
# 52581/52869 embeddings done
# 52582/52869 embeddings done
# 52583/52869 embeddings done
# 52584/52869 embeddings done
# 52585/52869 embeddings done
# 52586/52869 embeddings done
# 52587/52869 embeddings done
# 52588/52869 embeddings done
# 52589/52869 embeddings done
# 52590/52869 embeddings done
# 52591/52869 embeddings done
# 52592/52869 embeddings done
# 52593/52869 embeddings done
# 52594/52869 embeddings done
# 52595/52869 embeddings done
# 52596/52869 embeddings done
# 52597/52869 embeddings done
# 52598/52869 embeddings done
# 52599/52869 embeddings done
# 52600/52869 embeddings done
# 52601/52869 embeddings done
# 52602/52869 embeddings done
# 52603/52869 embeddings done
# 52604/52869 embeddings done
# 52605/52869 embeddings done
# 52606/52869 embeddings done
# 52607/52869 embeddings done
# 52608/52869 embeddings done
# 52609/52869 embeddings done
# 52610/52869 embeddings done
# 52611/52869 embeddings done
# 52612/52869 embeddings done
# 52613/52869 embeddings done
# 52614/52869 embeddings done
# 52615/52869 embeddings done
# 52616/52869 embeddings done
# 52617/52869 embeddings done
# 52618/52869 embeddings done
# 52619/52869 embeddings done
# 52620/52869 embeddings done
# 52621/52869 embeddings done
# 52622/52869 embeddings done
# 52623/52869 embeddings done
# 52624/52869 embeddings done
# 52625/52869 embeddings done
# 52626/52869 embeddings done
# 52627/52869 embeddings done
# 52628/52869 embeddings done
# 52629/52869 embeddings done
# 52630/52869 embeddings done
# 52631/52869 embeddings done
# 52632/52869 embeddings done
# 52633/52869 embeddings done
# 52634/52869 embeddings done
# 52635/52869 embeddings done
# 52636/52869 embeddings done
# 52637/52869 embeddings done
# 52638/52869 embeddings done
# 52639/52869 embeddings done
# 52640/52869 embeddings done
# 52641/52869 embeddings done
# 52642/52869 embeddings done
# 52643/52869 embeddings done
# 52644/52869 embeddings done
# 52645/52869 embeddings done
# 52646/52869 embeddings done
# 52647/52869 embeddings done
# 52648/52869 embeddings done
# 52649/52869 embeddings done
# 52650/52869 embeddings done
# 52651/52869 embeddings done
# 52652/52869 embeddings done
# 52653/52869 embeddings done
# 52654/52869 embeddings done
# 52655/52869 embeddings done
# 52656/52869 embeddings done
# 52657/52869 embeddings done
# 52658/52869 embeddings done
# 52659/52869 embeddings done
# 52660/52869 embeddings done
# 52661/52869 embeddings done
# 52662/52869 embeddings done
# 52663/52869 embeddings done
# 52664/52869 embeddings done
# 52665/52869 embeddings done
# 52666/52869 embeddings done
# 52667/52869 embeddings done
# 52668/52869 embeddings done
# 52669/52869 embeddings done
# 52670/52869 embeddings done
# 52671/52869 embeddings done
# 52672/52869 embeddings done
# 52673/52869 embeddings done
# 52674/52869 embeddings done
# 52675/52869 embeddings done
# 52676/52869 embeddings done
# 52677/52869 embeddings done
# 52678/52869 embeddings done
# 52679/52869 embeddings done
# 52680/52869 embeddings done
# 52681/52869 embeddings done
# 52682/52869 embeddings done
# 52683/52869 embeddings done
# 52684/52869 embeddings done
# 52685/52869 embeddings done
# 52686/52869 embeddings done
# 52687/52869 embeddings done
# 52688/52869 embeddings done
# 52689/52869 embeddings done
# 52690/52869 embeddings done
# 52691/52869 embeddings done
# 52692/52869 embeddings done
# 52693/52869 embeddings done
# 52694/52869 embeddings done
# 52695/52869 embeddings done
# 52696/52869 embeddings done
# 52697/52869 embeddings done
# 52698/52869 embeddings done
# 52699/52869 embeddings done
# 52700/52869 embeddings done
# 52701/52869 embeddings done
# 52702/52869 embeddings done
# 52703/52869 embeddings done
# 52704/52869 embeddings done
# 52705/52869 embeddings done
# 52706/52869 embeddings done
# 52707/52869 embeddings done
# 52708/52869 embeddings done
# 52709/52869 embeddings done
# 52710/52869 embeddings done
# 52711/52869 embeddings done
# 52712/52869 embeddings done
# 52713/52869 embeddings done
# 52714/52869 embeddings done
# 52715/52869 embeddings done
# 52716/52869 embeddings done
# 52717/52869 embeddings done
# 52718/52869 embeddings done
# 52719/52869 embeddings done
# 52720/52869 embeddings done
# 52721/52869 embeddings done
# 52722/52869 embeddings done
# 52723/52869 embeddings done
# 52724/52869 embeddings done
# 52725/52869 embeddings done
# 52726/52869 embeddings done
# 52727/52869 embeddings done
# 52728/52869 embeddings done
# 52729/52869 embeddings done
# 52730/52869 embeddings done
# 52731/52869 embeddings done
# 52732/52869 embeddings done
# 52733/52869 embeddings done
# 52734/52869 embeddings done
# 52735/52869 embeddings done
# 52736/52869 embeddings done
# 52737/52869 embeddings done
# 52738/52869 embeddings done
# 52739/52869 embeddings done
# 52740/52869 embeddings done
# 52741/52869 embeddings done
# 52742/52869 embeddings done
# 52743/52869 embeddings done
# 52744/52869 embeddings done
# 52745/52869 embeddings done
# 52746/52869 embeddings done
# 52747/52869 embeddings done
# 52748/52869 embeddings done
# 52749/52869 embeddings done
# 52750/52869 embeddings done
# 52751/52869 embeddings done
# 52752/52869 embeddings done
# 52753/52869 embeddings done
# 52754/52869 embeddings done
# 52755/52869 embeddings done
# 52756/52869 embeddings done
# 52757/52869 embeddings done
# 52758/52869 embeddings done
# 52759/52869 embeddings done
# 52760/52869 embeddings done
# 52761/52869 embeddings done
# 52762/52869 embeddings done
# 52763/52869 embeddings done
# 52764/52869 embeddings done
# 52765/52869 embeddings done
# 52766/52869 embeddings done
# 52767/52869 embeddings done
# 52768/52869 embeddings done
# 52769/52869 embeddings done
# 52770/52869 embeddings done
# 52771/52869 embeddings done
# 52772/52869 embeddings done
# 52773/52869 embeddings done
# 52774/52869 embeddings done
# 52775/52869 embeddings done
# 52776/52869 embeddings done
# 52777/52869 embeddings done
# 52778/52869 embeddings done
# 52779/52869 embeddings done
# 52780/52869 embeddings done
# 52781/52869 embeddings done
# 52782/52869 embeddings done
# 52783/52869 embeddings done
# 52784/52869 embeddings done
# 52785/52869 embeddings done
# 52786/52869 embeddings done
# 52787/52869 embeddings done
# 52788/52869 embeddings done
# 52789/52869 embeddings done
# 52790/52869 embeddings done
# 52791/52869 embeddings done
# 52792/52869 embeddings done
# 52793/52869 embeddings done
# 52794/52869 embeddings done
# 52795/52869 embeddings done
# 52796/52869 embeddings done
# 52797/52869 embeddings done
# 52798/52869 embeddings done
# 52799/52869 embeddings done
# 52800/52869 embeddings done
# 52801/52869 embeddings done
# 52802/52869 embeddings done
# 52803/52869 embeddings done
# 52804/52869 embeddings done
# 52805/52869 embeddings done
# 52806/52869 embeddings done
# 52807/52869 embeddings done
# 52808/52869 embeddings done
# 52809/52869 embeddings done
# 52810/52869 embeddings done
# 52811/52869 embeddings done
# 52812/52869 embeddings done
# 52813/52869 embeddings done
# 52814/52869 embeddings done
# 52815/52869 embeddings done
# 52816/52869 embeddings done
# 52817/52869 embeddings done
# 52818/52869 embeddings done
# 52819/52869 embeddings done
# 52820/52869 embeddings done
# 52821/52869 embeddings done
# 52822/52869 embeddings done
# 52823/52869 embeddings done
# 52824/52869 embeddings done
# 52825/52869 embeddings done
# 52826/52869 embeddings done
# 52827/52869 embeddings done
# 52828/52869 embeddings done
# 52829/52869 embeddings done
# 52830/52869 embeddings done
# 52831/52869 embeddings done
# 52832/52869 embeddings done
# 52833/52869 embeddings done
# 52834/52869 embeddings done
# 52835/52869 embeddings done
# 52836/52869 embeddings done
# 52837/52869 embeddings done
# 52838/52869 embeddings done
# 52839/52869 embeddings done
# 52840/52869 embeddings done
# 52841/52869 embeddings done
# 52842/52869 embeddings done
# 52843/52869 embeddings done
# 52844/52869 embeddings done
# 52845/52869 embeddings done
# 52846/52869 embeddings done
# 52847/52869 embeddings done
# 52848/52869 embeddings done
# 52849/52869 embeddings done
# 52850/52869 embeddings done
# 52851/52869 embeddings done
# 52852/52869 embeddings done
# 52853/52869 embeddings done
# 52854/52869 embeddings done
# 52855/52869 embeddings done
# 52856/52869 embeddings done
# 52857/52869 embeddings done
# 52858/52869 embeddings done
# 52859/52869 embeddings done
# 52860/52869 embeddings done
# 52861/52869 embeddings done
# 52862/52869 embeddings done
# 52863/52869 embeddings done
# 52864/52869 embeddings done
# 52865/52869 embeddings done
# 52866/52869 embeddings done
# 52867/52869 embeddings done
# 52868/52869 embeddings done
# 52869/52869 embeddings done
# Embeddings from file '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500.txt' added to FAISS index between indice 80311 to 133180.

# %%
import json
import os
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

def scoreWikiAnswers(input_file_path, output_file_path, data_file_path="", skiplines = 0):
    wiki_embedding = WikitextsDocumentScorer()
    if data_file_path and os.path.exists(data_file_path):
        wiki_embedding.create_embedding(data_file_path)
    gen = OpenAIAtomicFactGenerator()

    qa_data = []
    scores = []
    with open(input_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            qa_data.append(json.loads(line))
    for i, qa in enumerate(qa_data):
        if i < skiplines:
            continue
        query = qa['input']
        subclaims_score = {}
        retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10, threshold=0.3)
        response = wiki_embedding.faiss_manager.generate_response_from_context(query, retrieved_docs)
        atomicFacts = gen.get_facts_from_text(response)
        for fact in atomicFacts:
            purefact = fact.rpartition(':')[0] if ':' in fact else fact
            score = wiki_embedding.score(purefact, retrieved_docs)
            subclaims_score[purefact] = float(score)
        #sort subclaims based on score
        subclaims_score = sorted(subclaims_score.items(), key=lambda x: x[1], reverse=True)
        answer = qa['output'][0]['answer']
        calibrate_score = float(wiki_embedding.score(query + ' ' + answer, retrieved_docs))
        with open(output_file_path, 'a', encoding='utf-8') as f:
            f.write(json.dumps({'query': query, 'answer': answer, 'calibrate_score': f"{calibrate_score:.2f}", 'response': response, 'subclaims_score': subclaims_score}) + '\n')
        print(f'calibrate data {i} / {len(qa_data)} done')

# %%
#calibrate data
file_path = "../index_store/conformalhotpot500/hotpotqa-train-kilt-500.jsonl"
scoreWikiAnswers(file_path, '../index_store/conformalhotpot500/hotpot_calibrate_score_500.jsonl', '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# File '../index_store/conformalhotpot500/title_text_map_hotpotqa_500.txt' already exists in the FAISS index.
# calibrate data 0 / 500 done
# calibrate data 1 / 500 done
# calibrate data 2 / 500 done
# calibrate data 3 / 500 done
# calibrate data 4 / 500 done
# calibrate data 5 / 500 done
# calibrate data 6 / 500 done
# calibrate data 7 / 500 done
# calibrate data 8 / 500 done
# calibrate data 9 / 500 done
# calibrate data 10 / 500 done
# calibrate data 11 / 500 done
# calibrate data 12 / 500 done
# calibrate data 13 / 500 done
# calibrate data 14 / 500 done
# calibrate data 15 / 500 done
# calibrate data 16 / 500 done
# calibrate data 17 / 500 done
# calibrate data 18 / 500 done
# calibrate data 19 / 500 done
# calibrate data 20 / 500 done
# calibrate data 21 / 500 done
# calibrate data 22 / 500 done
# calibrate data 23 / 500 done
# calibrate data 24 / 500 done
# calibrate data 25 / 500 done
# calibrate data 26 / 500 done
# calibrate data 27 / 500 done
# calibrate data 28 / 500 done
# calibrate data 29 / 500 done
# calibrate data 30 / 500 done
# calibrate data 31 / 500 done
# calibrate data 32 / 500 done
# calibrate data 33 / 500 done
# calibrate data 34 / 500 done
# calibrate data 35 / 500 done
# calibrate data 36 / 500 done
# calibrate data 37 / 500 done
# calibrate data 38 / 500 done
# calibrate data 39 / 500 done
# calibrate data 40 / 500 done
# calibrate data 41 / 500 done
# calibrate data 42 / 500 done
# calibrate data 43 / 500 done
# calibrate data 44 / 500 done
# calibrate data 45 / 500 done
# calibrate data 46 / 500 done
# calibrate data 47 / 500 done
# calibrate data 48 / 500 done
# calibrate data 49 / 500 done
# calibrate data 50 / 500 done
# calibrate data 51 / 500 done
# calibrate data 52 / 500 done
# calibrate data 53 / 500 done
# calibrate data 54 / 500 done
# calibrate data 55 / 500 done
# calibrate data 56 / 500 done
# calibrate data 57 / 500 done
# calibrate data 58 / 500 done
# calibrate data 59 / 500 done
# calibrate data 60 / 500 done
# calibrate data 61 / 500 done
# calibrate data 62 / 500 done
# calibrate data 63 / 500 done
# calibrate data 64 / 500 done
# calibrate data 65 / 500 done
# calibrate data 66 / 500 done
# calibrate data 67 / 500 done
# calibrate data 68 / 500 done
# calibrate data 69 / 500 done
# calibrate data 70 / 500 done
# calibrate data 71 / 500 done
# calibrate data 72 / 500 done
# calibrate data 73 / 500 done
# calibrate data 74 / 500 done
# calibrate data 75 / 500 done
# calibrate data 76 / 500 done
# calibrate data 77 / 500 done
# calibrate data 78 / 500 done
# calibrate data 79 / 500 done
# calibrate data 80 / 500 done
# calibrate data 81 / 500 done
# calibrate data 82 / 500 done
# calibrate data 83 / 500 done
# calibrate data 84 / 500 done
# calibrate data 85 / 500 done
# calibrate data 86 / 500 done
# calibrate data 87 / 500 done
# calibrate data 88 / 500 done
# calibrate data 89 / 500 done
# calibrate data 90 / 500 done
# calibrate data 91 / 500 done
# calibrate data 92 / 500 done
# calibrate data 93 / 500 done
# calibrate data 94 / 500 done
# calibrate data 95 / 500 done
# calibrate data 96 / 500 done
# calibrate data 97 / 500 done
# calibrate data 98 / 500 done
# calibrate data 99 / 500 done
# calibrate data 100 / 500 done
# calibrate data 101 / 500 done
# calibrate data 102 / 500 done
# calibrate data 103 / 500 done
# calibrate data 104 / 500 done
# calibrate data 105 / 500 done
# calibrate data 106 / 500 done
# calibrate data 107 / 500 done
# calibrate data 108 / 500 done
# calibrate data 109 / 500 done
# calibrate data 110 / 500 done
# calibrate data 111 / 500 done
# calibrate data 112 / 500 done
# calibrate data 113 / 500 done
# calibrate data 114 / 500 done
# calibrate data 115 / 500 done
# calibrate data 116 / 500 done
# calibrate data 117 / 500 done
# calibrate data 118 / 500 done
# calibrate data 119 / 500 done
# calibrate data 120 / 500 done
# calibrate data 121 / 500 done
# calibrate data 122 / 500 done
# calibrate data 123 / 500 done
# calibrate data 124 / 500 done
# calibrate data 125 / 500 done
# calibrate data 126 / 500 done
# calibrate data 127 / 500 done
# calibrate data 128 / 500 done
# calibrate data 129 / 500 done
# calibrate data 130 / 500 done
# calibrate data 131 / 500 done
# calibrate data 132 / 500 done
# calibrate data 133 / 500 done
# calibrate data 134 / 500 done
# calibrate data 135 / 500 done
# calibrate data 136 / 500 done
# calibrate data 137 / 500 done
# calibrate data 138 / 500 done
# calibrate data 139 / 500 done
# calibrate data 140 / 500 done
# calibrate data 141 / 500 done
# calibrate data 142 / 500 done
# calibrate data 143 / 500 done
# calibrate data 144 / 500 done
# calibrate data 145 / 500 done
# calibrate data 146 / 500 done
# calibrate data 147 / 500 done
# calibrate data 148 / 500 done
# calibrate data 149 / 500 done
# calibrate data 150 / 500 done
# calibrate data 151 / 500 done
# calibrate data 152 / 500 done
# calibrate data 153 / 500 done
# calibrate data 154 / 500 done
# calibrate data 155 / 500 done
# calibrate data 156 / 500 done
# calibrate data 157 / 500 done
# calibrate data 158 / 500 done
# calibrate data 159 / 500 done
# calibrate data 160 / 500 done
# calibrate data 161 / 500 done
# calibrate data 162 / 500 done
# calibrate data 163 / 500 done
# calibrate data 164 / 500 done
# calibrate data 165 / 500 done
# calibrate data 166 / 500 done
# calibrate data 167 / 500 done
# calibrate data 168 / 500 done
# calibrate data 169 / 500 done
# calibrate data 170 / 500 done
# calibrate data 171 / 500 done
# calibrate data 172 / 500 done
# calibrate data 173 / 500 done
# calibrate data 174 / 500 done
# calibrate data 175 / 500 done
# calibrate data 176 / 500 done
# calibrate data 177 / 500 done
# calibrate data 178 / 500 done
# calibrate data 179 / 500 done
# calibrate data 180 / 500 done
# calibrate data 181 / 500 done
# calibrate data 182 / 500 done
# calibrate data 183 / 500 done
# calibrate data 184 / 500 done
# calibrate data 185 / 500 done
# calibrate data 186 / 500 done
# calibrate data 187 / 500 done
# calibrate data 188 / 500 done
# calibrate data 189 / 500 done
# calibrate data 190 / 500 done
# calibrate data 191 / 500 done
# calibrate data 192 / 500 done
# calibrate data 193 / 500 done
# calibrate data 194 / 500 done
# calibrate data 195 / 500 done
# calibrate data 196 / 500 done
# calibrate data 197 / 500 done
# calibrate data 198 / 500 done
# calibrate data 199 / 500 done
# calibrate data 200 / 500 done
# calibrate data 201 / 500 done
# calibrate data 202 / 500 done
# calibrate data 203 / 500 done
# calibrate data 204 / 500 done
# calibrate data 205 / 500 done
# calibrate data 206 / 500 done
# calibrate data 207 / 500 done
# calibrate data 208 / 500 done
# calibrate data 209 / 500 done
# calibrate data 210 / 500 done
# calibrate data 211 / 500 done
# calibrate data 212 / 500 done
# calibrate data 213 / 500 done
# calibrate data 214 / 500 done
# calibrate data 215 / 500 done
# calibrate data 216 / 500 done
# calibrate data 217 / 500 done
# calibrate data 218 / 500 done
# calibrate data 219 / 500 done
# calibrate data 220 / 500 done
# calibrate data 221 / 500 done
# calibrate data 222 / 500 done
# calibrate data 223 / 500 done
# calibrate data 224 / 500 done
# calibrate data 225 / 500 done
# calibrate data 226 / 500 done
# calibrate data 227 / 500 done
# calibrate data 228 / 500 done
# calibrate data 229 / 500 done
# calibrate data 230 / 500 done
# calibrate data 231 / 500 done
# calibrate data 232 / 500 done
# calibrate data 233 / 500 done
# calibrate data 234 / 500 done
# calibrate data 235 / 500 done
# calibrate data 236 / 500 done
# calibrate data 237 / 500 done
# calibrate data 238 / 500 done
# calibrate data 239 / 500 done
# calibrate data 240 / 500 done
# calibrate data 241 / 500 done
# calibrate data 242 / 500 done
# calibrate data 243 / 500 done
# calibrate data 244 / 500 done
# calibrate data 245 / 500 done
# calibrate data 246 / 500 done
# calibrate data 247 / 500 done
# calibrate data 248 / 500 done
# calibrate data 249 / 500 done
# calibrate data 250 / 500 done
# calibrate data 251 / 500 done
# calibrate data 252 / 500 done
# calibrate data 253 / 500 done
# calibrate data 254 / 500 done
# calibrate data 255 / 500 done
# calibrate data 256 / 500 done
# calibrate data 257 / 500 done
# calibrate data 258 / 500 done
# calibrate data 259 / 500 done
# calibrate data 260 / 500 done
# calibrate data 261 / 500 done
# calibrate data 262 / 500 done
# calibrate data 263 / 500 done
# calibrate data 264 / 500 done
# calibrate data 265 / 500 done
# calibrate data 266 / 500 done
# calibrate data 267 / 500 done
# calibrate data 268 / 500 done
# calibrate data 269 / 500 done
# calibrate data 270 / 500 done
# calibrate data 271 / 500 done
# calibrate data 272 / 500 done
# calibrate data 273 / 500 done
# calibrate data 274 / 500 done
# calibrate data 275 / 500 done
# calibrate data 276 / 500 done
# calibrate data 277 / 500 done
# calibrate data 278 / 500 done
# calibrate data 279 / 500 done
# calibrate data 280 / 500 done
# calibrate data 281 / 500 done
# calibrate data 282 / 500 done
# calibrate data 283 / 500 done
# calibrate data 284 / 500 done
# calibrate data 285 / 500 done
# calibrate data 286 / 500 done
# calibrate data 287 / 500 done
# calibrate data 288 / 500 done
# calibrate data 289 / 500 done
# calibrate data 290 / 500 done
# calibrate data 291 / 500 done
# calibrate data 292 / 500 done
# calibrate data 293 / 500 done
# calibrate data 294 / 500 done
# calibrate data 295 / 500 done
# calibrate data 296 / 500 done
# calibrate data 297 / 500 done
# calibrate data 298 / 500 done
# calibrate data 299 / 500 done
# calibrate data 300 / 500 done
# calibrate data 301 / 500 done
# calibrate data 302 / 500 done
# calibrate data 303 / 500 done
# calibrate data 304 / 500 done
# calibrate data 305 / 500 done
# calibrate data 306 / 500 done
# calibrate data 307 / 500 done
# calibrate data 308 / 500 done
# calibrate data 309 / 500 done
# calibrate data 310 / 500 done
# calibrate data 311 / 500 done
# calibrate data 312 / 500 done
# calibrate data 313 / 500 done
# calibrate data 314 / 500 done
# calibrate data 315 / 500 done
# calibrate data 316 / 500 done
# calibrate data 317 / 500 done
# calibrate data 318 / 500 done
# calibrate data 319 / 500 done
# calibrate data 320 / 500 done
# calibrate data 321 / 500 done
# calibrate data 322 / 500 done
# calibrate data 323 / 500 done
# calibrate data 324 / 500 done
# calibrate data 325 / 500 done
# calibrate data 326 / 500 done
# calibrate data 327 / 500 done
# calibrate data 328 / 500 done
# calibrate data 329 / 500 done
# calibrate data 330 / 500 done
# calibrate data 331 / 500 done
# calibrate data 332 / 500 done
# calibrate data 333 / 500 done
# calibrate data 334 / 500 done
# calibrate data 335 / 500 done
# calibrate data 336 / 500 done
# calibrate data 337 / 500 done
# calibrate data 338 / 500 done
# calibrate data 339 / 500 done
# calibrate data 340 / 500 done
# calibrate data 341 / 500 done
# calibrate data 342 / 500 done
# calibrate data 343 / 500 done
# calibrate data 344 / 500 done
# calibrate data 345 / 500 done
# calibrate data 346 / 500 done
# calibrate data 347 / 500 done
# calibrate data 348 / 500 done
# calibrate data 349 / 500 done
# calibrate data 350 / 500 done
# calibrate data 351 / 500 done
# calibrate data 352 / 500 done
# calibrate data 353 / 500 done
# calibrate data 354 / 500 done
# calibrate data 355 / 500 done
# calibrate data 356 / 500 done
# calibrate data 357 / 500 done
# calibrate data 358 / 500 done
# calibrate data 359 / 500 done
# calibrate data 360 / 500 done
# calibrate data 361 / 500 done
# calibrate data 362 / 500 done
# calibrate data 363 / 500 done
# calibrate data 364 / 500 done
# calibrate data 365 / 500 done
# calibrate data 366 / 500 done
# calibrate data 367 / 500 done
# calibrate data 368 / 500 done
# calibrate data 369 / 500 done
# calibrate data 370 / 500 done
# calibrate data 371 / 500 done
# calibrate data 372 / 500 done
# calibrate data 373 / 500 done
# calibrate data 374 / 500 done
# calibrate data 375 / 500 done
# calibrate data 376 / 500 done
# calibrate data 377 / 500 done
# calibrate data 378 / 500 done
# calibrate data 379 / 500 done
# calibrate data 380 / 500 done
# calibrate data 381 / 500 done
# calibrate data 382 / 500 done
# calibrate data 383 / 500 done
# calibrate data 384 / 500 done
# calibrate data 385 / 500 done
# calibrate data 386 / 500 done
# calibrate data 387 / 500 done
# calibrate data 388 / 500 done
# calibrate data 389 / 500 done
# calibrate data 390 / 500 done
# calibrate data 391 / 500 done
# calibrate data 392 / 500 done
# calibrate data 393 / 500 done
# calibrate data 394 / 500 done
# calibrate data 395 / 500 done
# calibrate data 396 / 500 done
# calibrate data 397 / 500 done
# calibrate data 398 / 500 done
# calibrate data 399 / 500 done
# calibrate data 400 / 500 done
# calibrate data 401 / 500 done
# calibrate data 402 / 500 done
# calibrate data 403 / 500 done
# calibrate data 404 / 500 done
# calibrate data 405 / 500 done
# calibrate data 406 / 500 done
# calibrate data 407 / 500 done
# calibrate data 408 / 500 done
# calibrate data 409 / 500 done
# calibrate data 410 / 500 done
# calibrate data 411 / 500 done
# calibrate data 412 / 500 done
# calibrate data 413 / 500 done
# calibrate data 414 / 500 done
# calibrate data 415 / 500 done
# calibrate data 416 / 500 done
# calibrate data 417 / 500 done
# calibrate data 418 / 500 done
# calibrate data 419 / 500 done
# calibrate data 420 / 500 done
# calibrate data 421 / 500 done
# calibrate data 422 / 500 done
# calibrate data 423 / 500 done
# calibrate data 424 / 500 done
# calibrate data 425 / 500 done
# calibrate data 426 / 500 done
# calibrate data 427 / 500 done
# calibrate data 428 / 500 done
# calibrate data 429 / 500 done
# calibrate data 430 / 500 done
# calibrate data 431 / 500 done
# calibrate data 432 / 500 done
# calibrate data 433 / 500 done
# calibrate data 434 / 500 done
# calibrate data 435 / 500 done
# calibrate data 436 / 500 done
# calibrate data 437 / 500 done
# calibrate data 438 / 500 done
# calibrate data 439 / 500 done
# calibrate data 440 / 500 done
# calibrate data 441 / 500 done
# calibrate data 442 / 500 done
# calibrate data 443 / 500 done
# calibrate data 444 / 500 done
# calibrate data 445 / 500 done
# calibrate data 446 / 500 done
# calibrate data 447 / 500 done
# calibrate data 448 / 500 done
# calibrate data 449 / 500 done
# calibrate data 450 / 500 done
# calibrate data 451 / 500 done
# calibrate data 452 / 500 done
# calibrate data 453 / 500 done
# calibrate data 454 / 500 done
# calibrate data 455 / 500 done
# calibrate data 456 / 500 done
# calibrate data 457 / 500 done
# calibrate data 458 / 500 done
# calibrate data 459 / 500 done
# calibrate data 460 / 500 done
# calibrate data 461 / 500 done
# calibrate data 462 / 500 done
# calibrate data 463 / 500 done
# calibrate data 464 / 500 done
# calibrate data 465 / 500 done
# calibrate data 466 / 500 done
# calibrate data 467 / 500 done
# calibrate data 468 / 500 done
# calibrate data 469 / 500 done
# calibrate data 470 / 500 done
# calibrate data 471 / 500 done
# calibrate data 472 / 500 done
# calibrate data 473 / 500 done
# calibrate data 474 / 500 done
# calibrate data 475 / 500 done
# calibrate data 476 / 500 done
# calibrate data 477 / 500 done
# calibrate data 478 / 500 done
# calibrate data 479 / 500 done
# calibrate data 480 / 500 done
# calibrate data 481 / 500 done
# calibrate data 482 / 500 done
# calibrate data 483 / 500 done
# calibrate data 484 / 500 done
# calibrate data 485 / 500 done
# calibrate data 486 / 500 done
# calibrate data 487 / 500 done
# calibrate data 488 / 500 done
# calibrate data 489 / 500 done
# calibrate data 490 / 500 done
# calibrate data 491 / 500 done
# calibrate data 492 / 500 done
# calibrate data 493 / 500 done
# calibrate data 494 / 500 done
# calibrate data 495 / 500 done
# calibrate data 496 / 500 done
# calibrate data 497 / 500 done
# calibrate data 498 / 500 done
# calibrate data 499 / 500 done

# %%
import json
from llm.openai_claim_verification import OpenAIClaimVerification

verifier = OpenAIClaimVerification()
llm_responses_file_path = 'llm_responses_500.jsonl'
# Function to transform subclaims_score into the desired format
def annotate_subclaims(data, data_type='wiki'):
    transformed_claims = []
    query = data['query']
    answer = ''
    if data_type.lower() == 'wiki':
        answer = data['answer']
    elif data_type.lower() == 'med':
        answer = str(data['answers'])
    elif data_type.lower() == 'factscore':
        answer = str(data['response'])
    else:
        raise ValueError('Invalid data type')

    with open (llm_responses_file_path, "w") as llm_responses_file:
        for subclaim, score in data["subclaims_score"]:
            res = verifier.openAI_response(query, answer, subclaim)
            annotation = verifier.detect_label(res)
            transformed_claims.append({
                "subclaim": subclaim,
                "similarity-score": score,
                "annotation": annotation
                # Assuming annotation is optional and could be added later
            })
            llm_responses_file.write(json.dumps({'subclaim': subclaim, 'score' : score, 'annotation': annotation, 'llmResponse': res},
                                                ensure_ascii=False) + '\n')
    return {
        "prompt": data["query"],
        "original-output": data["response"],
        "claims": transformed_claims,
    }

# %%
conformal_format_file_path = 'conformal_format_500.jsonl'
input_file = '../index_store/conformalhotpot500/hotpot_calibrate_score_500.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
idx = 0
# Process the file
with open(input_file, "r") as infile, open(output_file, "w") as outfile:
    outfile.write('{"data": [\n')
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data)
        outfile.write(json.dumps(transformed_data, ensure_ascii=False) + ",\n")
        idx += 1
    outfile.write(']}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Processing line 51
# Processing line 52
# Processing line 53
# Processing line 54
# Processing line 55
# Processing line 56
# Processing line 57
# Processing line 58
# Processing line 59
# Processing line 60
# Processing line 61
# Processing line 62
# Processing line 63
# Processing line 64
# Processing line 65
# Processing line 66
# Processing line 67
# Processing line 68
# Processing line 69
# Processing line 70
# Processing line 71
# Processing line 72
# Processing line 73
# Processing line 74
# Processing line 75
# Processing line 76
# Processing line 77
# Processing line 78
# Processing line 79
# Processing line 80
# Processing line 81
# Processing line 82
# Processing line 83
# Processing line 84
# Processing line 85
# Processing line 86
# Processing line 87
# Processing line 88
# Processing line 89
# Processing line 90
# Processing line 91
# Processing line 92
# Processing line 93
# Processing line 94
# Processing line 95
# Processing line 96
# Processing line 97
# Processing line 98
# Processing line 99
# Processing line 100
# Processing line 101
# Processing line 102
# Processing line 103
# Processing line 104
# Processing line 105
# Processing line 106
# Processing line 107
# Processing line 108
# Processing line 109
# Processing line 110
# Processing line 111
# Processing line 112
# Processing line 113
# Processing line 114
# Processing line 115
# Processing line 116
# Processing line 117
# Processing line 118
# Processing line 119
# Processing line 120
# Processing line 121
# Processing line 122
# Processing line 123
# Processing line 124
# Processing line 125
# Processing line 126
# Processing line 127
# Processing line 128
# Processing line 129
# Processing line 130
# Processing line 131
# Processing line 132
# Processing line 133
# Processing line 134
# Processing line 135
# Processing line 136
# Processing line 137
# Processing line 138
# Processing line 139
# Processing line 140
# Processing line 141
# Processing line 142
# Processing line 143
# Processing line 144
# Processing line 145
# Processing line 146
# Processing line 147
# Processing line 148
# Processing line 149
# Processing line 150
# Processing line 151
# Processing line 152
# Processing line 153
# Processing line 154
# Processing line 155
# Processing line 156
# Processing line 157
# Processing line 158
# Processing line 159
# Processing line 160
# Processing line 161
# Processing line 162
# Processing line 163
# Processing line 164
# Processing line 165
# Processing line 166
# Processing line 167
# Processing line 168
# Processing line 169
# Processing line 170
# Processing line 171
# Processing line 172
# Processing line 173
# Processing line 174
# Processing line 175
# Processing line 176
# Processing line 177
# Processing line 178
# Processing line 179
# Processing line 180
# Processing line 181
# Processing line 182
# Processing line 183
# Processing line 184
# Processing line 185
# Processing line 186
# Processing line 187
# Processing line 188
# Processing line 189
# Processing line 190
# Processing line 191
# Processing line 192
# Processing line 193
# Processing line 194
# Processing line 195
# Processing line 196
# Processing line 197
# Processing line 198
# Processing line 199
# Processing line 200
# Processing line 201
# Processing line 202
# Processing line 203
# Processing line 204
# Processing line 205
# Processing line 206
# Processing line 207
# Processing line 208
# Processing line 209
# Processing line 210
# Processing line 211
# Processing line 212
# Processing line 213
# Processing line 214
# Processing line 215
# Processing line 216
# Processing line 217
# Processing line 218
# Processing line 219
# Processing line 220
# Processing line 221
# Processing line 222
# Processing line 223
# Processing line 224
# Processing line 225
# Processing line 226
# Processing line 227
# Processing line 228
# Processing line 229
# Processing line 230
# Processing line 231
# Processing line 232
# Processing line 233
# Processing line 234
# Processing line 235
# Processing line 236
# Processing line 237
# Processing line 238
# Processing line 239
# Processing line 240
# Processing line 241
# Processing line 242
# Processing line 243
# Processing line 244
# Processing line 245
# Processing line 246
# Processing line 247
# Processing line 248
# Processing line 249
# Processing line 250
# Processing line 251
# Processing line 252
# Processing line 253
# Processing line 254
# Processing line 255
# Processing line 256
# Processing line 257
# Processing line 258
# Processing line 259
# Processing line 260
# Processing line 261
# Processing line 262
# Processing line 263
# Processing line 264
# Processing line 265
# Processing line 266
# Processing line 267
# Processing line 268
# Processing line 269
# Processing line 270
# Processing line 271
# Processing line 272
# Processing line 273
# Processing line 274
# Processing line 275
# Processing line 276
# Processing line 277
# Processing line 278
# Processing line 279
# Processing line 280
# Processing line 281
# Processing line 282
# Processing line 283
# Processing line 284
# Processing line 285
# Processing line 286
# Processing line 287
# Processing line 288
# Processing line 289
# Processing line 290
# Processing line 291
# Processing line 292
# Processing line 293
# Processing line 294
# Processing line 295
# Processing line 296
# Processing line 297
# Processing line 298
# Processing line 299
# Processing line 300
# Processing line 301
# Processing line 302
# Processing line 303
# Processing line 304
# Processing line 305
# Processing line 306
# Processing line 307
# Processing line 308
# Processing line 309
# Processing line 310
# Processing line 311
# Processing line 312
# Processing line 313
# Processing line 314
# Processing line 315
# Processing line 316
# Processing line 317
# Processing line 318
# Processing line 319
# Processing line 320
# Processing line 321
# Processing line 322
# Processing line 323
# Processing line 324
# Processing line 325
# Processing line 326
# Processing line 327
# Processing line 328
# Processing line 329
# Processing line 330
# Processing line 331
# Processing line 332
# Processing line 333
# Processing line 334
# Processing line 335
# Processing line 336
# Processing line 337
# Processing line 338
# Processing line 339
# Processing line 340
# Processing line 341
# Processing line 342
# Processing line 343
# Processing line 344
# Processing line 345
# Processing line 346
# Processing line 347
# Processing line 348
# Processing line 349
# Processing line 350
# Processing line 351
# Processing line 352
# Processing line 353
# Processing line 354
# Processing line 355
# Processing line 356
# Processing line 357
# Processing line 358
# Processing line 359
# Processing line 360
# Processing line 361
# Processing line 362
# Processing line 363
# Processing line 364
# Processing line 365
# Processing line 366
# Processing line 367
# Processing line 368
# Processing line 369
# Processing line 370
# Processing line 371
# Processing line 372
# Processing line 373
# Processing line 374
# Processing line 375
# Processing line 376
# Processing line 377
# Processing line 378
# Processing line 379
# Processing line 380
# Processing line 381
# Processing line 382
# Processing line 383
# Processing line 384
# Processing line 385
# Processing line 386
# Processing line 387
# Processing line 388
# Processing line 389
# Processing line 390
# Processing line 391
# Processing line 392
# Processing line 393
# Processing line 394
# Processing line 395
# Processing line 396
# Processing line 397
# Processing line 398
# Processing line 399
# Processing line 400
# Processing line 401
# Processing line 402
# Processing line 403
# Processing line 404
# Processing line 405
# Processing line 406
# Processing line 407
# Processing line 408
# Processing line 409
# Processing line 410
# Processing line 411
# Processing line 412
# Processing line 413
# Processing line 414
# Processing line 415
# Processing line 416
# Processing line 417
# Processing line 418
# Processing line 419
# Processing line 420
# Processing line 421
# Processing line 422
# Processing line 423
# Processing line 424
# Processing line 425
# Processing line 426
# Processing line 427
# Processing line 428
# Processing line 429
# Processing line 430
# Processing line 431
# Processing line 432
# Processing line 433
# Processing line 434
# Processing line 435
# Processing line 436
# Processing line 437
# Processing line 438
# Processing line 439
# Processing line 440
# Processing line 441
# Processing line 442
# Processing line 443
# Processing line 444
# Processing line 445
# Processing line 446
# Processing line 447
# Processing line 448
# Processing line 449
# Processing line 450
# Processing line 451
# Processing line 452
# Processing line 453
# Processing line 454
# Processing line 455
# Processing line 456
# Processing line 457
# Processing line 458
# Processing line 459
# Processing line 460
# Processing line 461
# Processing line 462
# Processing line 463
# Processing line 464
# Processing line 465
# Processing line 466
# Processing line 467
# Processing line 468
# Processing line 469
# Processing line 470
# Processing line 471
# Processing line 472
# Processing line 473
# Processing line 474
# Processing line 475
# Processing line 476
# Processing line 477
# Processing line 478
# Processing line 479
# Processing line 480
# Processing line 481
# Processing line 482
# Processing line 483
# Processing line 484
# Processing line 485
# Processing line 486
# Processing line 487
# Processing line 488
# Processing line 489
# Processing line 490
# Processing line 491
# Processing line 492
# Processing line 493
# Processing line 494
# Processing line 495
# Processing line 496
# Processing line 497
# Processing line 498
# Processing line 499
# Transformed data written to similarity_annotations.jsonl.

# %%
print(transformed_data)
# Out:
# {'prompt': 'Musician and satirist Allie Goertz wrote a song about the "The Simpsons" character Milhouse, who Matt Groening named after who?', 'original-output': 'The character Milhouse from "The Simpsons" was named by Matt Groening after U.S. President Richard Nixon, whose middle name was Milhous.', 'claims': [{'subclaim': 'The character Milhouse from "The Simpsons" was named by Matt Groening after U.S. President Richard Nixon', 'similarity-score': 0.29849618673324585, 'annotation': 'S'}, {'subclaim': " Richard Nixon's middle name was Milhous", 'similarity-score': 0.14918304979801178, 'annotation': 'F'}]}

# %% [markdown]
# ## PopQA ##

# %% [markdown]
# **Create Embedding Only**

# %%
data_path = '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt'
wiki_embedding = WikitextsDocumentScorer()
wiki_embedding.create_embedding(data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Associated texts saved to file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# 1/15390 embeddings done
# 2/15390 embeddings done
# 3/15390 embeddings done
# 4/15390 embeddings done
# 5/15390 embeddings done
# 6/15390 embeddings done
# 7/15390 embeddings done
# 8/15390 embeddings done
# 9/15390 embeddings done
# 10/15390 embeddings done
# 11/15390 embeddings done
# 12/15390 embeddings done
# 13/15390 embeddings done
# 14/15390 embeddings done
# 15/15390 embeddings done
# 16/15390 embeddings done
# 17/15390 embeddings done
# 18/15390 embeddings done
# 19/15390 embeddings done
# 20/15390 embeddings done
# 21/15390 embeddings done
# 22/15390 embeddings done
# 23/15390 embeddings done
# 24/15390 embeddings done
# 25/15390 embeddings done
# 26/15390 embeddings done
# 27/15390 embeddings done
# 28/15390 embeddings done
# 29/15390 embeddings done
# 30/15390 embeddings done
# 31/15390 embeddings done
# 32/15390 embeddings done
# 33/15390 embeddings done
# 34/15390 embeddings done
# 35/15390 embeddings done
# 36/15390 embeddings done
# 37/15390 embeddings done
# 38/15390 embeddings done
# 39/15390 embeddings done
# 40/15390 embeddings done
# 41/15390 embeddings done
# 42/15390 embeddings done
# 43/15390 embeddings done
# 44/15390 embeddings done
# 45/15390 embeddings done
# 46/15390 embeddings done
# 47/15390 embeddings done
# 48/15390 embeddings done
# 49/15390 embeddings done
# 50/15390 embeddings done
# 51/15390 embeddings done
# 52/15390 embeddings done
# 53/15390 embeddings done
# 54/15390 embeddings done
# 55/15390 embeddings done
# 56/15390 embeddings done
# 57/15390 embeddings done
# 58/15390 embeddings done
# 59/15390 embeddings done
# 60/15390 embeddings done
# 61/15390 embeddings done
# 62/15390 embeddings done
# 63/15390 embeddings done
# 64/15390 embeddings done
# 65/15390 embeddings done
# 66/15390 embeddings done
# 67/15390 embeddings done
# 68/15390 embeddings done
# 69/15390 embeddings done
# 70/15390 embeddings done
# 71/15390 embeddings done
# 72/15390 embeddings done
# 73/15390 embeddings done
# 74/15390 embeddings done
# 75/15390 embeddings done
# 76/15390 embeddings done
# 77/15390 embeddings done
# 78/15390 embeddings done
# 79/15390 embeddings done
# 80/15390 embeddings done
# 81/15390 embeddings done
# 82/15390 embeddings done
# 83/15390 embeddings done
# 84/15390 embeddings done
# 85/15390 embeddings done
# 86/15390 embeddings done
# 87/15390 embeddings done
# 88/15390 embeddings done
# 89/15390 embeddings done
# 90/15390 embeddings done
# 91/15390 embeddings done
# 92/15390 embeddings done
# 93/15390 embeddings done
# 94/15390 embeddings done
# 95/15390 embeddings done
# 96/15390 embeddings done
# 97/15390 embeddings done
# 98/15390 embeddings done
# 99/15390 embeddings done
# 100/15390 embeddings done
# 101/15390 embeddings done
# 102/15390 embeddings done
# 103/15390 embeddings done
# 104/15390 embeddings done
# 105/15390 embeddings done
# 106/15390 embeddings done
# 107/15390 embeddings done
# 108/15390 embeddings done
# 109/15390 embeddings done
# 110/15390 embeddings done
# 111/15390 embeddings done
# 112/15390 embeddings done
# 113/15390 embeddings done
# 114/15390 embeddings done
# 115/15390 embeddings done
# 116/15390 embeddings done
# 117/15390 embeddings done
# 118/15390 embeddings done
# 119/15390 embeddings done
# 120/15390 embeddings done
# 121/15390 embeddings done
# 122/15390 embeddings done
# 123/15390 embeddings done
# 124/15390 embeddings done
# 125/15390 embeddings done
# 126/15390 embeddings done
# 127/15390 embeddings done
# 128/15390 embeddings done
# 129/15390 embeddings done
# 130/15390 embeddings done
# 131/15390 embeddings done
# 132/15390 embeddings done
# 133/15390 embeddings done
# 134/15390 embeddings done
# 135/15390 embeddings done
# 136/15390 embeddings done
# 137/15390 embeddings done
# 138/15390 embeddings done
# 139/15390 embeddings done
# 140/15390 embeddings done
# 141/15390 embeddings done
# 142/15390 embeddings done
# 143/15390 embeddings done
# 144/15390 embeddings done
# 145/15390 embeddings done
# 146/15390 embeddings done
# 147/15390 embeddings done
# 148/15390 embeddings done
# 149/15390 embeddings done
# 150/15390 embeddings done
# 151/15390 embeddings done
# 152/15390 embeddings done
# 153/15390 embeddings done
# 154/15390 embeddings done
# 155/15390 embeddings done
# 156/15390 embeddings done
# 157/15390 embeddings done
# 158/15390 embeddings done
# 159/15390 embeddings done
# 160/15390 embeddings done
# 161/15390 embeddings done
# 162/15390 embeddings done
# 163/15390 embeddings done
# 164/15390 embeddings done
# 165/15390 embeddings done
# 166/15390 embeddings done
# 167/15390 embeddings done
# 168/15390 embeddings done
# 169/15390 embeddings done
# 170/15390 embeddings done
# 171/15390 embeddings done
# 172/15390 embeddings done
# 173/15390 embeddings done
# 174/15390 embeddings done
# 175/15390 embeddings done
# 176/15390 embeddings done
# 177/15390 embeddings done
# 178/15390 embeddings done
# 179/15390 embeddings done
# 180/15390 embeddings done
# 181/15390 embeddings done
# 182/15390 embeddings done
# 183/15390 embeddings done
# 184/15390 embeddings done
# 185/15390 embeddings done
# 186/15390 embeddings done
# 187/15390 embeddings done
# 188/15390 embeddings done
# 189/15390 embeddings done
# 190/15390 embeddings done
# 191/15390 embeddings done
# 192/15390 embeddings done
# 193/15390 embeddings done
# 194/15390 embeddings done
# 195/15390 embeddings done
# 196/15390 embeddings done
# 197/15390 embeddings done
# 198/15390 embeddings done
# 199/15390 embeddings done
# 200/15390 embeddings done
# 201/15390 embeddings done
# 202/15390 embeddings done
# 203/15390 embeddings done
# 204/15390 embeddings done
# 205/15390 embeddings done
# 206/15390 embeddings done
# 207/15390 embeddings done
# 208/15390 embeddings done
# 209/15390 embeddings done
# 210/15390 embeddings done
# 211/15390 embeddings done
# 212/15390 embeddings done
# 213/15390 embeddings done
# 214/15390 embeddings done
# 215/15390 embeddings done
# 216/15390 embeddings done
# 217/15390 embeddings done
# 218/15390 embeddings done
# 219/15390 embeddings done
# 220/15390 embeddings done
# 221/15390 embeddings done
# 222/15390 embeddings done
# 223/15390 embeddings done
# 224/15390 embeddings done
# 225/15390 embeddings done
# 226/15390 embeddings done
# 227/15390 embeddings done
# 228/15390 embeddings done
# 229/15390 embeddings done
# 230/15390 embeddings done
# 231/15390 embeddings done
# 232/15390 embeddings done
# 233/15390 embeddings done
# 234/15390 embeddings done
# 235/15390 embeddings done
# 236/15390 embeddings done
# 237/15390 embeddings done
# 238/15390 embeddings done
# 239/15390 embeddings done
# 240/15390 embeddings done
# 241/15390 embeddings done
# 242/15390 embeddings done
# 243/15390 embeddings done
# 244/15390 embeddings done
# 245/15390 embeddings done
# 246/15390 embeddings done
# 247/15390 embeddings done
# 248/15390 embeddings done
# 249/15390 embeddings done
# 250/15390 embeddings done
# 251/15390 embeddings done
# 252/15390 embeddings done
# 253/15390 embeddings done
# 254/15390 embeddings done
# 255/15390 embeddings done
# 256/15390 embeddings done
# 257/15390 embeddings done
# 258/15390 embeddings done
# 259/15390 embeddings done
# 260/15390 embeddings done
# 261/15390 embeddings done
# 262/15390 embeddings done
# 263/15390 embeddings done
# 264/15390 embeddings done
# 265/15390 embeddings done
# 266/15390 embeddings done
# 267/15390 embeddings done
# 268/15390 embeddings done
# 269/15390 embeddings done
# 270/15390 embeddings done
# 271/15390 embeddings done
# 272/15390 embeddings done
# 273/15390 embeddings done
# 274/15390 embeddings done
# 275/15390 embeddings done
# 276/15390 embeddings done
# 277/15390 embeddings done
# 278/15390 embeddings done
# 279/15390 embeddings done
# 280/15390 embeddings done
# 281/15390 embeddings done
# 282/15390 embeddings done
# 283/15390 embeddings done
# 284/15390 embeddings done
# 285/15390 embeddings done
# 286/15390 embeddings done
# 287/15390 embeddings done
# 288/15390 embeddings done
# 289/15390 embeddings done
# 290/15390 embeddings done
# 291/15390 embeddings done
# 292/15390 embeddings done
# 293/15390 embeddings done
# 294/15390 embeddings done
# 295/15390 embeddings done
# 296/15390 embeddings done
# 297/15390 embeddings done
# 298/15390 embeddings done
# 299/15390 embeddings done
# 300/15390 embeddings done
# 301/15390 embeddings done
# 302/15390 embeddings done
# 303/15390 embeddings done
# 304/15390 embeddings done
# 305/15390 embeddings done
# 306/15390 embeddings done
# 307/15390 embeddings done
# 308/15390 embeddings done
# 309/15390 embeddings done
# 310/15390 embeddings done
# 311/15390 embeddings done
# 312/15390 embeddings done
# 313/15390 embeddings done
# 314/15390 embeddings done
# 315/15390 embeddings done
# 316/15390 embeddings done
# 317/15390 embeddings done
# 318/15390 embeddings done
# 319/15390 embeddings done
# 320/15390 embeddings done
# 321/15390 embeddings done
# 322/15390 embeddings done
# 323/15390 embeddings done
# 324/15390 embeddings done
# 325/15390 embeddings done
# 326/15390 embeddings done
# 327/15390 embeddings done
# 328/15390 embeddings done
# 329/15390 embeddings done
# 330/15390 embeddings done
# 331/15390 embeddings done
# 332/15390 embeddings done
# 333/15390 embeddings done
# 334/15390 embeddings done
# 335/15390 embeddings done
# 336/15390 embeddings done
# 337/15390 embeddings done
# 338/15390 embeddings done
# 339/15390 embeddings done
# 340/15390 embeddings done
# 341/15390 embeddings done
# 342/15390 embeddings done
# 343/15390 embeddings done
# 344/15390 embeddings done
# 345/15390 embeddings done
# 346/15390 embeddings done
# 347/15390 embeddings done
# 348/15390 embeddings done
# 349/15390 embeddings done
# 350/15390 embeddings done
# 351/15390 embeddings done
# 352/15390 embeddings done
# 353/15390 embeddings done
# 354/15390 embeddings done
# 355/15390 embeddings done
# 356/15390 embeddings done
# 357/15390 embeddings done
# 358/15390 embeddings done
# 359/15390 embeddings done
# 360/15390 embeddings done
# 361/15390 embeddings done
# 362/15390 embeddings done
# 363/15390 embeddings done
# 364/15390 embeddings done
# 365/15390 embeddings done
# 366/15390 embeddings done
# 367/15390 embeddings done
# 368/15390 embeddings done
# 369/15390 embeddings done
# 370/15390 embeddings done
# 371/15390 embeddings done
# 372/15390 embeddings done
# 373/15390 embeddings done
# 374/15390 embeddings done
# 375/15390 embeddings done
# 376/15390 embeddings done
# 377/15390 embeddings done
# 378/15390 embeddings done
# 379/15390 embeddings done
# 380/15390 embeddings done
# 381/15390 embeddings done
# 382/15390 embeddings done
# 383/15390 embeddings done
# 384/15390 embeddings done
# 385/15390 embeddings done
# 386/15390 embeddings done
# 387/15390 embeddings done
# 388/15390 embeddings done
# 389/15390 embeddings done
# 390/15390 embeddings done
# 391/15390 embeddings done
# 392/15390 embeddings done
# 393/15390 embeddings done
# 394/15390 embeddings done
# 395/15390 embeddings done
# 396/15390 embeddings done
# 397/15390 embeddings done
# 398/15390 embeddings done
# 399/15390 embeddings done
# 400/15390 embeddings done
# 401/15390 embeddings done
# 402/15390 embeddings done
# 403/15390 embeddings done
# 404/15390 embeddings done
# 405/15390 embeddings done
# 406/15390 embeddings done
# 407/15390 embeddings done
# 408/15390 embeddings done
# 409/15390 embeddings done
# 410/15390 embeddings done
# 411/15390 embeddings done
# 412/15390 embeddings done
# 413/15390 embeddings done
# 414/15390 embeddings done
# 415/15390 embeddings done
# 416/15390 embeddings done
# 417/15390 embeddings done
# 418/15390 embeddings done
# 419/15390 embeddings done
# 420/15390 embeddings done
# 421/15390 embeddings done
# 422/15390 embeddings done
# 423/15390 embeddings done
# 424/15390 embeddings done
# 425/15390 embeddings done
# 426/15390 embeddings done
# 427/15390 embeddings done
# 428/15390 embeddings done
# 429/15390 embeddings done
# 430/15390 embeddings done
# 431/15390 embeddings done
# 432/15390 embeddings done
# 433/15390 embeddings done
# 434/15390 embeddings done
# 435/15390 embeddings done
# 436/15390 embeddings done
# 437/15390 embeddings done
# 438/15390 embeddings done
# 439/15390 embeddings done
# 440/15390 embeddings done
# 441/15390 embeddings done
# 442/15390 embeddings done
# 443/15390 embeddings done
# 444/15390 embeddings done
# 445/15390 embeddings done
# 446/15390 embeddings done
# 447/15390 embeddings done
# 448/15390 embeddings done
# 449/15390 embeddings done
# 450/15390 embeddings done
# 451/15390 embeddings done
# 452/15390 embeddings done
# 453/15390 embeddings done
# 454/15390 embeddings done
# 455/15390 embeddings done
# 456/15390 embeddings done
# 457/15390 embeddings done
# 458/15390 embeddings done
# 459/15390 embeddings done
# 460/15390 embeddings done
# 461/15390 embeddings done
# 462/15390 embeddings done
# 463/15390 embeddings done
# 464/15390 embeddings done
# 465/15390 embeddings done
# 466/15390 embeddings done
# 467/15390 embeddings done
# 468/15390 embeddings done
# 469/15390 embeddings done
# 470/15390 embeddings done
# 471/15390 embeddings done
# 472/15390 embeddings done
# 473/15390 embeddings done
# 474/15390 embeddings done
# 475/15390 embeddings done
# 476/15390 embeddings done
# 477/15390 embeddings done
# 478/15390 embeddings done
# 479/15390 embeddings done
# 480/15390 embeddings done
# 481/15390 embeddings done
# 482/15390 embeddings done
# 483/15390 embeddings done
# 484/15390 embeddings done
# 485/15390 embeddings done
# 486/15390 embeddings done
# 487/15390 embeddings done
# 488/15390 embeddings done
# 489/15390 embeddings done
# 490/15390 embeddings done
# 491/15390 embeddings done
# 492/15390 embeddings done
# 493/15390 embeddings done
# 494/15390 embeddings done
# 495/15390 embeddings done
# 496/15390 embeddings done
# 497/15390 embeddings done
# 498/15390 embeddings done
# 499/15390 embeddings done
# 500/15390 embeddings done
# 501/15390 embeddings done
# 502/15390 embeddings done
# 503/15390 embeddings done
# 504/15390 embeddings done
# 505/15390 embeddings done
# 506/15390 embeddings done
# 507/15390 embeddings done
# 508/15390 embeddings done
# 509/15390 embeddings done
# 510/15390 embeddings done
# 511/15390 embeddings done
# 512/15390 embeddings done
# 513/15390 embeddings done
# 514/15390 embeddings done
# 515/15390 embeddings done
# 516/15390 embeddings done
# 517/15390 embeddings done
# 518/15390 embeddings done
# 519/15390 embeddings done
# 520/15390 embeddings done
# 521/15390 embeddings done
# 522/15390 embeddings done
# 523/15390 embeddings done
# 524/15390 embeddings done
# 525/15390 embeddings done
# 526/15390 embeddings done
# 527/15390 embeddings done
# 528/15390 embeddings done
# 529/15390 embeddings done
# 530/15390 embeddings done
# 531/15390 embeddings done
# 532/15390 embeddings done
# 533/15390 embeddings done
# 534/15390 embeddings done
# 535/15390 embeddings done
# 536/15390 embeddings done
# 537/15390 embeddings done
# 538/15390 embeddings done
# 539/15390 embeddings done
# 540/15390 embeddings done
# 541/15390 embeddings done
# 542/15390 embeddings done
# 543/15390 embeddings done
# 544/15390 embeddings done
# 545/15390 embeddings done
# 546/15390 embeddings done
# 547/15390 embeddings done
# 548/15390 embeddings done
# 549/15390 embeddings done
# 550/15390 embeddings done
# 551/15390 embeddings done
# 552/15390 embeddings done
# 553/15390 embeddings done
# 554/15390 embeddings done
# 555/15390 embeddings done
# 556/15390 embeddings done
# 557/15390 embeddings done
# 558/15390 embeddings done
# 559/15390 embeddings done
# 560/15390 embeddings done
# 561/15390 embeddings done
# 562/15390 embeddings done
# 563/15390 embeddings done
# 564/15390 embeddings done
# 565/15390 embeddings done
# 566/15390 embeddings done
# 567/15390 embeddings done
# 568/15390 embeddings done
# 569/15390 embeddings done
# 570/15390 embeddings done
# 571/15390 embeddings done
# 572/15390 embeddings done
# 573/15390 embeddings done
# 574/15390 embeddings done
# 575/15390 embeddings done
# 576/15390 embeddings done
# 577/15390 embeddings done
# 578/15390 embeddings done
# 579/15390 embeddings done
# 580/15390 embeddings done
# 581/15390 embeddings done
# 582/15390 embeddings done
# 583/15390 embeddings done
# 584/15390 embeddings done
# 585/15390 embeddings done
# 586/15390 embeddings done
# 587/15390 embeddings done
# 588/15390 embeddings done
# 589/15390 embeddings done
# 590/15390 embeddings done
# 591/15390 embeddings done
# 592/15390 embeddings done
# 593/15390 embeddings done
# 594/15390 embeddings done
# 595/15390 embeddings done
# 596/15390 embeddings done
# 597/15390 embeddings done
# 598/15390 embeddings done
# 599/15390 embeddings done
# 600/15390 embeddings done
# 601/15390 embeddings done
# 602/15390 embeddings done
# 603/15390 embeddings done
# 604/15390 embeddings done
# 605/15390 embeddings done
# 606/15390 embeddings done
# 607/15390 embeddings done
# 608/15390 embeddings done
# 609/15390 embeddings done
# 610/15390 embeddings done
# 611/15390 embeddings done
# 612/15390 embeddings done
# 613/15390 embeddings done
# 614/15390 embeddings done
# 615/15390 embeddings done
# 616/15390 embeddings done
# 617/15390 embeddings done
# 618/15390 embeddings done
# 619/15390 embeddings done
# 620/15390 embeddings done
# 621/15390 embeddings done
# 622/15390 embeddings done
# 623/15390 embeddings done
# 624/15390 embeddings done
# 625/15390 embeddings done
# 626/15390 embeddings done
# 627/15390 embeddings done
# 628/15390 embeddings done
# 629/15390 embeddings done
# 630/15390 embeddings done
# 631/15390 embeddings done
# 632/15390 embeddings done
# 633/15390 embeddings done
# 634/15390 embeddings done
# 635/15390 embeddings done
# 636/15390 embeddings done
# 637/15390 embeddings done
# 638/15390 embeddings done
# 639/15390 embeddings done
# 640/15390 embeddings done
# 641/15390 embeddings done
# 642/15390 embeddings done
# 643/15390 embeddings done
# 644/15390 embeddings done
# 645/15390 embeddings done
# 646/15390 embeddings done
# 647/15390 embeddings done
# 648/15390 embeddings done
# 649/15390 embeddings done
# 650/15390 embeddings done
# 651/15390 embeddings done
# 652/15390 embeddings done
# 653/15390 embeddings done
# 654/15390 embeddings done
# 655/15390 embeddings done
# 656/15390 embeddings done
# 657/15390 embeddings done
# 658/15390 embeddings done
# 659/15390 embeddings done
# 660/15390 embeddings done
# 661/15390 embeddings done
# 662/15390 embeddings done
# 663/15390 embeddings done
# 664/15390 embeddings done
# 665/15390 embeddings done
# 666/15390 embeddings done
# 667/15390 embeddings done
# 668/15390 embeddings done
# 669/15390 embeddings done
# 670/15390 embeddings done
# 671/15390 embeddings done
# 672/15390 embeddings done
# 673/15390 embeddings done
# 674/15390 embeddings done
# 675/15390 embeddings done
# 676/15390 embeddings done
# 677/15390 embeddings done
# 678/15390 embeddings done
# 679/15390 embeddings done
# 680/15390 embeddings done
# 681/15390 embeddings done
# 682/15390 embeddings done
# 683/15390 embeddings done
# 684/15390 embeddings done
# 685/15390 embeddings done
# 686/15390 embeddings done
# 687/15390 embeddings done
# 688/15390 embeddings done
# 689/15390 embeddings done
# 690/15390 embeddings done
# 691/15390 embeddings done
# 692/15390 embeddings done
# 693/15390 embeddings done
# 694/15390 embeddings done
# 695/15390 embeddings done
# 696/15390 embeddings done
# 697/15390 embeddings done
# 698/15390 embeddings done
# 699/15390 embeddings done
# 700/15390 embeddings done
# 701/15390 embeddings done
# 702/15390 embeddings done
# 703/15390 embeddings done
# 704/15390 embeddings done
# 705/15390 embeddings done
# 706/15390 embeddings done
# 707/15390 embeddings done
# 708/15390 embeddings done
# 709/15390 embeddings done
# 710/15390 embeddings done
# 711/15390 embeddings done
# 712/15390 embeddings done
# 713/15390 embeddings done
# 714/15390 embeddings done
# 715/15390 embeddings done
# 716/15390 embeddings done
# 717/15390 embeddings done
# 718/15390 embeddings done
# 719/15390 embeddings done
# 720/15390 embeddings done
# 721/15390 embeddings done
# 722/15390 embeddings done
# 723/15390 embeddings done
# 724/15390 embeddings done
# 725/15390 embeddings done
# 726/15390 embeddings done
# 727/15390 embeddings done
# 728/15390 embeddings done
# 729/15390 embeddings done
# 730/15390 embeddings done
# 731/15390 embeddings done
# 732/15390 embeddings done
# 733/15390 embeddings done
# 734/15390 embeddings done
# 735/15390 embeddings done
# 736/15390 embeddings done
# 737/15390 embeddings done
# 738/15390 embeddings done
# 739/15390 embeddings done
# 740/15390 embeddings done
# 741/15390 embeddings done
# 742/15390 embeddings done
# 743/15390 embeddings done
# 744/15390 embeddings done
# 745/15390 embeddings done
# 746/15390 embeddings done
# 747/15390 embeddings done
# 748/15390 embeddings done
# 749/15390 embeddings done
# 750/15390 embeddings done
# 751/15390 embeddings done
# 752/15390 embeddings done
# 753/15390 embeddings done
# 754/15390 embeddings done
# 755/15390 embeddings done
# 756/15390 embeddings done
# 757/15390 embeddings done
# 758/15390 embeddings done
# 759/15390 embeddings done
# 760/15390 embeddings done
# 761/15390 embeddings done
# 762/15390 embeddings done
# 763/15390 embeddings done
# 764/15390 embeddings done
# 765/15390 embeddings done
# 766/15390 embeddings done
# 767/15390 embeddings done
# 768/15390 embeddings done
# 769/15390 embeddings done
# 770/15390 embeddings done
# 771/15390 embeddings done
# 772/15390 embeddings done
# 773/15390 embeddings done
# 774/15390 embeddings done
# 775/15390 embeddings done
# 776/15390 embeddings done
# 777/15390 embeddings done
# 778/15390 embeddings done
# 779/15390 embeddings done
# 780/15390 embeddings done
# 781/15390 embeddings done
# 782/15390 embeddings done
# 783/15390 embeddings done
# 784/15390 embeddings done
# 785/15390 embeddings done
# 786/15390 embeddings done
# 787/15390 embeddings done
# 788/15390 embeddings done
# 789/15390 embeddings done
# 790/15390 embeddings done
# 791/15390 embeddings done
# 792/15390 embeddings done
# 793/15390 embeddings done
# 794/15390 embeddings done
# 795/15390 embeddings done
# 796/15390 embeddings done
# 797/15390 embeddings done
# 798/15390 embeddings done
# 799/15390 embeddings done
# 800/15390 embeddings done
# 801/15390 embeddings done
# 802/15390 embeddings done
# 803/15390 embeddings done
# 804/15390 embeddings done
# 805/15390 embeddings done
# 806/15390 embeddings done
# 807/15390 embeddings done
# 808/15390 embeddings done
# 809/15390 embeddings done
# 810/15390 embeddings done
# 811/15390 embeddings done
# 812/15390 embeddings done
# 813/15390 embeddings done
# 814/15390 embeddings done
# 815/15390 embeddings done
# 816/15390 embeddings done
# 817/15390 embeddings done
# 818/15390 embeddings done
# 819/15390 embeddings done
# 820/15390 embeddings done
# 821/15390 embeddings done
# 822/15390 embeddings done
# 823/15390 embeddings done
# 824/15390 embeddings done
# 825/15390 embeddings done
# 826/15390 embeddings done
# 827/15390 embeddings done
# 828/15390 embeddings done
# 829/15390 embeddings done
# 830/15390 embeddings done
# 831/15390 embeddings done
# 832/15390 embeddings done
# 833/15390 embeddings done
# 834/15390 embeddings done
# 835/15390 embeddings done
# 836/15390 embeddings done
# 837/15390 embeddings done
# 838/15390 embeddings done
# 839/15390 embeddings done
# 840/15390 embeddings done
# 841/15390 embeddings done
# 842/15390 embeddings done
# 843/15390 embeddings done
# 844/15390 embeddings done
# 845/15390 embeddings done
# 846/15390 embeddings done
# 847/15390 embeddings done
# 848/15390 embeddings done
# 849/15390 embeddings done
# 850/15390 embeddings done
# 851/15390 embeddings done
# 852/15390 embeddings done
# 853/15390 embeddings done
# 854/15390 embeddings done
# 855/15390 embeddings done
# 856/15390 embeddings done
# 857/15390 embeddings done
# 858/15390 embeddings done
# 859/15390 embeddings done
# 860/15390 embeddings done
# 861/15390 embeddings done
# 862/15390 embeddings done
# 863/15390 embeddings done
# 864/15390 embeddings done
# 865/15390 embeddings done
# 866/15390 embeddings done
# 867/15390 embeddings done
# 868/15390 embeddings done
# 869/15390 embeddings done
# 870/15390 embeddings done
# 871/15390 embeddings done
# 872/15390 embeddings done
# 873/15390 embeddings done
# 874/15390 embeddings done
# 875/15390 embeddings done
# 876/15390 embeddings done
# 877/15390 embeddings done
# 878/15390 embeddings done
# 879/15390 embeddings done
# 880/15390 embeddings done
# 881/15390 embeddings done
# 882/15390 embeddings done
# 883/15390 embeddings done
# 884/15390 embeddings done
# 885/15390 embeddings done
# 886/15390 embeddings done
# 887/15390 embeddings done
# 888/15390 embeddings done
# 889/15390 embeddings done
# 890/15390 embeddings done
# 891/15390 embeddings done
# 892/15390 embeddings done
# 893/15390 embeddings done
# 894/15390 embeddings done
# 895/15390 embeddings done
# 896/15390 embeddings done
# 897/15390 embeddings done
# 898/15390 embeddings done
# 899/15390 embeddings done
# 900/15390 embeddings done
# 901/15390 embeddings done
# 902/15390 embeddings done
# 903/15390 embeddings done
# 904/15390 embeddings done
# 905/15390 embeddings done
# 906/15390 embeddings done
# 907/15390 embeddings done
# 908/15390 embeddings done
# 909/15390 embeddings done
# 910/15390 embeddings done
# 911/15390 embeddings done
# 912/15390 embeddings done
# 913/15390 embeddings done
# 914/15390 embeddings done
# 915/15390 embeddings done
# 916/15390 embeddings done
# 917/15390 embeddings done
# 918/15390 embeddings done
# 919/15390 embeddings done
# 920/15390 embeddings done
# 921/15390 embeddings done
# 922/15390 embeddings done
# 923/15390 embeddings done
# 924/15390 embeddings done
# 925/15390 embeddings done
# 926/15390 embeddings done
# 927/15390 embeddings done
# 928/15390 embeddings done
# 929/15390 embeddings done
# 930/15390 embeddings done
# 931/15390 embeddings done
# 932/15390 embeddings done
# 933/15390 embeddings done
# 934/15390 embeddings done
# 935/15390 embeddings done
# 936/15390 embeddings done
# 937/15390 embeddings done
# 938/15390 embeddings done
# 939/15390 embeddings done
# 940/15390 embeddings done
# 941/15390 embeddings done
# 942/15390 embeddings done
# 943/15390 embeddings done
# 944/15390 embeddings done
# 945/15390 embeddings done
# 946/15390 embeddings done
# 947/15390 embeddings done
# 948/15390 embeddings done
# 949/15390 embeddings done
# 950/15390 embeddings done
# 951/15390 embeddings done
# 952/15390 embeddings done
# 953/15390 embeddings done
# 954/15390 embeddings done
# 955/15390 embeddings done
# 956/15390 embeddings done
# 957/15390 embeddings done
# 958/15390 embeddings done
# 959/15390 embeddings done
# 960/15390 embeddings done
# 961/15390 embeddings done
# 962/15390 embeddings done
# 963/15390 embeddings done
# 964/15390 embeddings done
# 965/15390 embeddings done
# 966/15390 embeddings done
# 967/15390 embeddings done
# 968/15390 embeddings done
# 969/15390 embeddings done
# 970/15390 embeddings done
# 971/15390 embeddings done
# 972/15390 embeddings done
# 973/15390 embeddings done
# 974/15390 embeddings done
# 975/15390 embeddings done
# 976/15390 embeddings done
# 977/15390 embeddings done
# 978/15390 embeddings done
# 979/15390 embeddings done
# 980/15390 embeddings done
# 981/15390 embeddings done
# 982/15390 embeddings done
# 983/15390 embeddings done
# 984/15390 embeddings done
# 985/15390 embeddings done
# 986/15390 embeddings done
# 987/15390 embeddings done
# 988/15390 embeddings done
# 989/15390 embeddings done
# 990/15390 embeddings done
# 991/15390 embeddings done
# 992/15390 embeddings done
# 993/15390 embeddings done
# 994/15390 embeddings done
# 995/15390 embeddings done
# 996/15390 embeddings done
# 997/15390 embeddings done
# 998/15390 embeddings done
# 999/15390 embeddings done
# 1000/15390 embeddings done
# 1001/15390 embeddings done
# 1002/15390 embeddings done
# 1003/15390 embeddings done
# 1004/15390 embeddings done
# 1005/15390 embeddings done
# 1006/15390 embeddings done
# 1007/15390 embeddings done
# 1008/15390 embeddings done
# 1009/15390 embeddings done
# 1010/15390 embeddings done
# 1011/15390 embeddings done
# 1012/15390 embeddings done
# 1013/15390 embeddings done
# 1014/15390 embeddings done
# 1015/15390 embeddings done
# 1016/15390 embeddings done
# 1017/15390 embeddings done
# 1018/15390 embeddings done
# 1019/15390 embeddings done
# 1020/15390 embeddings done
# 1021/15390 embeddings done
# 1022/15390 embeddings done
# 1023/15390 embeddings done
# 1024/15390 embeddings done
# 1025/15390 embeddings done
# 1026/15390 embeddings done
# 1027/15390 embeddings done
# 1028/15390 embeddings done
# 1029/15390 embeddings done
# 1030/15390 embeddings done
# 1031/15390 embeddings done
# 1032/15390 embeddings done
# 1033/15390 embeddings done
# 1034/15390 embeddings done
# 1035/15390 embeddings done
# 1036/15390 embeddings done
# 1037/15390 embeddings done
# 1038/15390 embeddings done
# 1039/15390 embeddings done
# 1040/15390 embeddings done
# 1041/15390 embeddings done
# 1042/15390 embeddings done
# 1043/15390 embeddings done
# 1044/15390 embeddings done
# 1045/15390 embeddings done
# 1046/15390 embeddings done
# 1047/15390 embeddings done
# 1048/15390 embeddings done
# 1049/15390 embeddings done
# 1050/15390 embeddings done
# 1051/15390 embeddings done
# 1052/15390 embeddings done
# 1053/15390 embeddings done
# 1054/15390 embeddings done
# 1055/15390 embeddings done
# 1056/15390 embeddings done
# 1057/15390 embeddings done
# 1058/15390 embeddings done
# 1059/15390 embeddings done
# 1060/15390 embeddings done
# 1061/15390 embeddings done
# 1062/15390 embeddings done
# 1063/15390 embeddings done
# 1064/15390 embeddings done
# 1065/15390 embeddings done
# 1066/15390 embeddings done
# 1067/15390 embeddings done
# 1068/15390 embeddings done
# 1069/15390 embeddings done
# 1070/15390 embeddings done
# 1071/15390 embeddings done
# 1072/15390 embeddings done
# 1073/15390 embeddings done
# 1074/15390 embeddings done
# 1075/15390 embeddings done
# 1076/15390 embeddings done
# 1077/15390 embeddings done
# 1078/15390 embeddings done
# 1079/15390 embeddings done
# 1080/15390 embeddings done
# 1081/15390 embeddings done
# 1082/15390 embeddings done
# 1083/15390 embeddings done
# 1084/15390 embeddings done
# 1085/15390 embeddings done
# 1086/15390 embeddings done
# 1087/15390 embeddings done
# 1088/15390 embeddings done
# 1089/15390 embeddings done
# 1090/15390 embeddings done
# 1091/15390 embeddings done
# 1092/15390 embeddings done
# 1093/15390 embeddings done
# 1094/15390 embeddings done
# 1095/15390 embeddings done
# 1096/15390 embeddings done
# 1097/15390 embeddings done
# 1098/15390 embeddings done
# 1099/15390 embeddings done
# 1100/15390 embeddings done
# 1101/15390 embeddings done
# 1102/15390 embeddings done
# 1103/15390 embeddings done
# 1104/15390 embeddings done
# 1105/15390 embeddings done
# 1106/15390 embeddings done
# 1107/15390 embeddings done
# 1108/15390 embeddings done
# 1109/15390 embeddings done
# 1110/15390 embeddings done
# 1111/15390 embeddings done
# 1112/15390 embeddings done
# 1113/15390 embeddings done
# 1114/15390 embeddings done
# 1115/15390 embeddings done
# 1116/15390 embeddings done
# 1117/15390 embeddings done
# 1118/15390 embeddings done
# 1119/15390 embeddings done
# 1120/15390 embeddings done
# 1121/15390 embeddings done
# 1122/15390 embeddings done
# 1123/15390 embeddings done
# 1124/15390 embeddings done
# 1125/15390 embeddings done
# 1126/15390 embeddings done
# 1127/15390 embeddings done
# 1128/15390 embeddings done
# 1129/15390 embeddings done
# 1130/15390 embeddings done
# 1131/15390 embeddings done
# 1132/15390 embeddings done
# 1133/15390 embeddings done
# 1134/15390 embeddings done
# 1135/15390 embeddings done
# 1136/15390 embeddings done
# 1137/15390 embeddings done
# 1138/15390 embeddings done
# 1139/15390 embeddings done
# 1140/15390 embeddings done
# 1141/15390 embeddings done
# 1142/15390 embeddings done
# 1143/15390 embeddings done
# 1144/15390 embeddings done
# 1145/15390 embeddings done
# 1146/15390 embeddings done
# 1147/15390 embeddings done
# 1148/15390 embeddings done
# 1149/15390 embeddings done
# 1150/15390 embeddings done
# 1151/15390 embeddings done
# 1152/15390 embeddings done
# 1153/15390 embeddings done
# 1154/15390 embeddings done
# 1155/15390 embeddings done
# 1156/15390 embeddings done
# 1157/15390 embeddings done
# 1158/15390 embeddings done
# 1159/15390 embeddings done
# 1160/15390 embeddings done
# 1161/15390 embeddings done
# 1162/15390 embeddings done
# 1163/15390 embeddings done
# 1164/15390 embeddings done
# 1165/15390 embeddings done
# 1166/15390 embeddings done
# 1167/15390 embeddings done
# 1168/15390 embeddings done
# 1169/15390 embeddings done
# 1170/15390 embeddings done
# 1171/15390 embeddings done
# 1172/15390 embeddings done
# 1173/15390 embeddings done
# 1174/15390 embeddings done
# 1175/15390 embeddings done
# 1176/15390 embeddings done
# 1177/15390 embeddings done
# 1178/15390 embeddings done
# 1179/15390 embeddings done
# 1180/15390 embeddings done
# 1181/15390 embeddings done
# 1182/15390 embeddings done
# 1183/15390 embeddings done
# 1184/15390 embeddings done
# 1185/15390 embeddings done
# 1186/15390 embeddings done
# 1187/15390 embeddings done
# 1188/15390 embeddings done
# 1189/15390 embeddings done
# 1190/15390 embeddings done
# 1191/15390 embeddings done
# 1192/15390 embeddings done
# 1193/15390 embeddings done
# 1194/15390 embeddings done
# 1195/15390 embeddings done
# 1196/15390 embeddings done
# 1197/15390 embeddings done
# 1198/15390 embeddings done
# 1199/15390 embeddings done
# 1200/15390 embeddings done
# 1201/15390 embeddings done
# 1202/15390 embeddings done
# 1203/15390 embeddings done
# 1204/15390 embeddings done
# 1205/15390 embeddings done
# 1206/15390 embeddings done
# 1207/15390 embeddings done
# 1208/15390 embeddings done
# 1209/15390 embeddings done
# 1210/15390 embeddings done
# 1211/15390 embeddings done
# 1212/15390 embeddings done
# 1213/15390 embeddings done
# 1214/15390 embeddings done
# 1215/15390 embeddings done
# 1216/15390 embeddings done
# 1217/15390 embeddings done
# 1218/15390 embeddings done
# 1219/15390 embeddings done
# 1220/15390 embeddings done
# 1221/15390 embeddings done
# 1222/15390 embeddings done
# 1223/15390 embeddings done
# 1224/15390 embeddings done
# 1225/15390 embeddings done
# 1226/15390 embeddings done
# 1227/15390 embeddings done
# 1228/15390 embeddings done
# 1229/15390 embeddings done
# 1230/15390 embeddings done
# 1231/15390 embeddings done
# 1232/15390 embeddings done
# 1233/15390 embeddings done
# 1234/15390 embeddings done
# 1235/15390 embeddings done
# 1236/15390 embeddings done
# 1237/15390 embeddings done
# 1238/15390 embeddings done
# 1239/15390 embeddings done
# 1240/15390 embeddings done
# 1241/15390 embeddings done
# 1242/15390 embeddings done
# 1243/15390 embeddings done
# 1244/15390 embeddings done
# 1245/15390 embeddings done
# 1246/15390 embeddings done
# 1247/15390 embeddings done
# 1248/15390 embeddings done
# 1249/15390 embeddings done
# 1250/15390 embeddings done
# 1251/15390 embeddings done
# 1252/15390 embeddings done
# 1253/15390 embeddings done
# 1254/15390 embeddings done
# 1255/15390 embeddings done
# 1256/15390 embeddings done
# 1257/15390 embeddings done
# 1258/15390 embeddings done
# 1259/15390 embeddings done
# 1260/15390 embeddings done
# 1261/15390 embeddings done
# 1262/15390 embeddings done
# 1263/15390 embeddings done
# 1264/15390 embeddings done
# 1265/15390 embeddings done
# 1266/15390 embeddings done
# 1267/15390 embeddings done
# 1268/15390 embeddings done
# 1269/15390 embeddings done
# 1270/15390 embeddings done
# 1271/15390 embeddings done
# 1272/15390 embeddings done
# 1273/15390 embeddings done
# 1274/15390 embeddings done
# 1275/15390 embeddings done
# 1276/15390 embeddings done
# 1277/15390 embeddings done
# 1278/15390 embeddings done
# 1279/15390 embeddings done
# 1280/15390 embeddings done
# 1281/15390 embeddings done
# 1282/15390 embeddings done
# 1283/15390 embeddings done
# 1284/15390 embeddings done
# 1285/15390 embeddings done
# 1286/15390 embeddings done
# 1287/15390 embeddings done
# 1288/15390 embeddings done
# 1289/15390 embeddings done
# 1290/15390 embeddings done
# 1291/15390 embeddings done
# 1292/15390 embeddings done
# 1293/15390 embeddings done
# 1294/15390 embeddings done
# 1295/15390 embeddings done
# 1296/15390 embeddings done
# 1297/15390 embeddings done
# 1298/15390 embeddings done
# 1299/15390 embeddings done
# 1300/15390 embeddings done
# 1301/15390 embeddings done
# 1302/15390 embeddings done
# 1303/15390 embeddings done
# 1304/15390 embeddings done
# 1305/15390 embeddings done
# 1306/15390 embeddings done
# 1307/15390 embeddings done
# 1308/15390 embeddings done
# 1309/15390 embeddings done
# 1310/15390 embeddings done
# 1311/15390 embeddings done
# 1312/15390 embeddings done
# 1313/15390 embeddings done
# 1314/15390 embeddings done
# 1315/15390 embeddings done
# 1316/15390 embeddings done
# 1317/15390 embeddings done
# 1318/15390 embeddings done
# 1319/15390 embeddings done
# 1320/15390 embeddings done
# 1321/15390 embeddings done
# 1322/15390 embeddings done
# 1323/15390 embeddings done
# 1324/15390 embeddings done
# 1325/15390 embeddings done
# 1326/15390 embeddings done
# 1327/15390 embeddings done
# 1328/15390 embeddings done
# 1329/15390 embeddings done
# 1330/15390 embeddings done
# 1331/15390 embeddings done
# 1332/15390 embeddings done
# 1333/15390 embeddings done
# 1334/15390 embeddings done
# 1335/15390 embeddings done
# 1336/15390 embeddings done
# 1337/15390 embeddings done
# 1338/15390 embeddings done
# 1339/15390 embeddings done
# 1340/15390 embeddings done
# 1341/15390 embeddings done
# 1342/15390 embeddings done
# 1343/15390 embeddings done
# 1344/15390 embeddings done
# 1345/15390 embeddings done
# 1346/15390 embeddings done
# 1347/15390 embeddings done
# 1348/15390 embeddings done
# 1349/15390 embeddings done
# 1350/15390 embeddings done
# 1351/15390 embeddings done
# 1352/15390 embeddings done
# 1353/15390 embeddings done
# 1354/15390 embeddings done
# 1355/15390 embeddings done
# 1356/15390 embeddings done
# 1357/15390 embeddings done
# 1358/15390 embeddings done
# 1359/15390 embeddings done
# 1360/15390 embeddings done
# 1361/15390 embeddings done
# 1362/15390 embeddings done
# 1363/15390 embeddings done
# 1364/15390 embeddings done
# 1365/15390 embeddings done
# 1366/15390 embeddings done
# 1367/15390 embeddings done
# 1368/15390 embeddings done
# 1369/15390 embeddings done
# 1370/15390 embeddings done
# 1371/15390 embeddings done
# 1372/15390 embeddings done
# 1373/15390 embeddings done
# 1374/15390 embeddings done
# 1375/15390 embeddings done
# 1376/15390 embeddings done
# 1377/15390 embeddings done
# 1378/15390 embeddings done
# 1379/15390 embeddings done
# 1380/15390 embeddings done
# 1381/15390 embeddings done
# 1382/15390 embeddings done
# 1383/15390 embeddings done
# 1384/15390 embeddings done
# 1385/15390 embeddings done
# 1386/15390 embeddings done
# 1387/15390 embeddings done
# 1388/15390 embeddings done
# 1389/15390 embeddings done
# 1390/15390 embeddings done
# 1391/15390 embeddings done
# 1392/15390 embeddings done
# 1393/15390 embeddings done
# 1394/15390 embeddings done
# 1395/15390 embeddings done
# 1396/15390 embeddings done
# 1397/15390 embeddings done
# 1398/15390 embeddings done
# 1399/15390 embeddings done
# 1400/15390 embeddings done
# 1401/15390 embeddings done
# 1402/15390 embeddings done
# 1403/15390 embeddings done
# 1404/15390 embeddings done
# 1405/15390 embeddings done
# 1406/15390 embeddings done
# 1407/15390 embeddings done
# 1408/15390 embeddings done
# 1409/15390 embeddings done
# 1410/15390 embeddings done
# 1411/15390 embeddings done
# 1412/15390 embeddings done
# 1413/15390 embeddings done
# 1414/15390 embeddings done
# 1415/15390 embeddings done
# 1416/15390 embeddings done
# 1417/15390 embeddings done
# 1418/15390 embeddings done
# 1419/15390 embeddings done
# 1420/15390 embeddings done
# 1421/15390 embeddings done
# 1422/15390 embeddings done
# 1423/15390 embeddings done
# 1424/15390 embeddings done
# 1425/15390 embeddings done
# 1426/15390 embeddings done
# 1427/15390 embeddings done
# 1428/15390 embeddings done
# 1429/15390 embeddings done
# 1430/15390 embeddings done
# 1431/15390 embeddings done
# 1432/15390 embeddings done
# 1433/15390 embeddings done
# 1434/15390 embeddings done
# 1435/15390 embeddings done
# 1436/15390 embeddings done
# 1437/15390 embeddings done
# 1438/15390 embeddings done
# 1439/15390 embeddings done
# 1440/15390 embeddings done
# 1441/15390 embeddings done
# 1442/15390 embeddings done
# 1443/15390 embeddings done
# 1444/15390 embeddings done
# 1445/15390 embeddings done
# 1446/15390 embeddings done
# 1447/15390 embeddings done
# 1448/15390 embeddings done
# 1449/15390 embeddings done
# 1450/15390 embeddings done
# 1451/15390 embeddings done
# 1452/15390 embeddings done
# 1453/15390 embeddings done
# 1454/15390 embeddings done
# 1455/15390 embeddings done
# 1456/15390 embeddings done
# 1457/15390 embeddings done
# 1458/15390 embeddings done
# 1459/15390 embeddings done
# 1460/15390 embeddings done
# 1461/15390 embeddings done
# 1462/15390 embeddings done
# 1463/15390 embeddings done
# 1464/15390 embeddings done
# 1465/15390 embeddings done
# 1466/15390 embeddings done
# 1467/15390 embeddings done
# 1468/15390 embeddings done
# 1469/15390 embeddings done
# 1470/15390 embeddings done
# 1471/15390 embeddings done
# 1472/15390 embeddings done
# 1473/15390 embeddings done
# 1474/15390 embeddings done
# 1475/15390 embeddings done
# 1476/15390 embeddings done
# 1477/15390 embeddings done
# 1478/15390 embeddings done
# 1479/15390 embeddings done
# 1480/15390 embeddings done
# 1481/15390 embeddings done
# 1482/15390 embeddings done
# 1483/15390 embeddings done
# 1484/15390 embeddings done
# 1485/15390 embeddings done
# 1486/15390 embeddings done
# 1487/15390 embeddings done
# 1488/15390 embeddings done
# 1489/15390 embeddings done
# 1490/15390 embeddings done
# 1491/15390 embeddings done
# 1492/15390 embeddings done
# 1493/15390 embeddings done
# 1494/15390 embeddings done
# 1495/15390 embeddings done
# 1496/15390 embeddings done
# 1497/15390 embeddings done
# 1498/15390 embeddings done
# 1499/15390 embeddings done
# 1500/15390 embeddings done
# 1501/15390 embeddings done
# 1502/15390 embeddings done
# 1503/15390 embeddings done
# 1504/15390 embeddings done
# 1505/15390 embeddings done
# 1506/15390 embeddings done
# 1507/15390 embeddings done
# 1508/15390 embeddings done
# 1509/15390 embeddings done
# 1510/15390 embeddings done
# 1511/15390 embeddings done
# 1512/15390 embeddings done
# 1513/15390 embeddings done
# 1514/15390 embeddings done
# 1515/15390 embeddings done
# 1516/15390 embeddings done
# 1517/15390 embeddings done
# 1518/15390 embeddings done
# 1519/15390 embeddings done
# 1520/15390 embeddings done
# 1521/15390 embeddings done
# 1522/15390 embeddings done
# 1523/15390 embeddings done
# 1524/15390 embeddings done
# 1525/15390 embeddings done
# 1526/15390 embeddings done
# 1527/15390 embeddings done
# 1528/15390 embeddings done
# 1529/15390 embeddings done
# 1530/15390 embeddings done
# 1531/15390 embeddings done
# 1532/15390 embeddings done
# 1533/15390 embeddings done
# 1534/15390 embeddings done
# 1535/15390 embeddings done
# 1536/15390 embeddings done
# 1537/15390 embeddings done
# 1538/15390 embeddings done
# 1539/15390 embeddings done
# 1540/15390 embeddings done
# 1541/15390 embeddings done
# 1542/15390 embeddings done
# 1543/15390 embeddings done
# 1544/15390 embeddings done
# 1545/15390 embeddings done
# 1546/15390 embeddings done
# 1547/15390 embeddings done
# 1548/15390 embeddings done
# 1549/15390 embeddings done
# 1550/15390 embeddings done
# 1551/15390 embeddings done
# 1552/15390 embeddings done
# 1553/15390 embeddings done
# 1554/15390 embeddings done
# 1555/15390 embeddings done
# 1556/15390 embeddings done
# 1557/15390 embeddings done
# 1558/15390 embeddings done
# 1559/15390 embeddings done
# 1560/15390 embeddings done
# 1561/15390 embeddings done
# 1562/15390 embeddings done
# 1563/15390 embeddings done
# 1564/15390 embeddings done
# 1565/15390 embeddings done
# 1566/15390 embeddings done
# 1567/15390 embeddings done
# 1568/15390 embeddings done
# 1569/15390 embeddings done
# 1570/15390 embeddings done
# 1571/15390 embeddings done
# 1572/15390 embeddings done
# 1573/15390 embeddings done
# 1574/15390 embeddings done
# 1575/15390 embeddings done
# 1576/15390 embeddings done
# 1577/15390 embeddings done
# 1578/15390 embeddings done
# 1579/15390 embeddings done
# 1580/15390 embeddings done
# 1581/15390 embeddings done
# 1582/15390 embeddings done
# 1583/15390 embeddings done
# 1584/15390 embeddings done
# 1585/15390 embeddings done
# 1586/15390 embeddings done
# 1587/15390 embeddings done
# 1588/15390 embeddings done
# 1589/15390 embeddings done
# 1590/15390 embeddings done
# 1591/15390 embeddings done
# 1592/15390 embeddings done
# 1593/15390 embeddings done
# 1594/15390 embeddings done
# 1595/15390 embeddings done
# 1596/15390 embeddings done
# 1597/15390 embeddings done
# 1598/15390 embeddings done
# 1599/15390 embeddings done
# 1600/15390 embeddings done
# 1601/15390 embeddings done
# 1602/15390 embeddings done
# 1603/15390 embeddings done
# 1604/15390 embeddings done
# 1605/15390 embeddings done
# 1606/15390 embeddings done
# 1607/15390 embeddings done
# 1608/15390 embeddings done
# 1609/15390 embeddings done
# 1610/15390 embeddings done
# 1611/15390 embeddings done
# 1612/15390 embeddings done
# 1613/15390 embeddings done
# 1614/15390 embeddings done
# 1615/15390 embeddings done
# 1616/15390 embeddings done
# 1617/15390 embeddings done
# 1618/15390 embeddings done
# 1619/15390 embeddings done
# 1620/15390 embeddings done
# 1621/15390 embeddings done
# 1622/15390 embeddings done
# 1623/15390 embeddings done
# 1624/15390 embeddings done
# 1625/15390 embeddings done
# 1626/15390 embeddings done
# 1627/15390 embeddings done
# 1628/15390 embeddings done
# 1629/15390 embeddings done
# 1630/15390 embeddings done
# 1631/15390 embeddings done
# 1632/15390 embeddings done
# 1633/15390 embeddings done
# 1634/15390 embeddings done
# 1635/15390 embeddings done
# 1636/15390 embeddings done
# 1637/15390 embeddings done
# 1638/15390 embeddings done
# 1639/15390 embeddings done
# 1640/15390 embeddings done
# 1641/15390 embeddings done
# 1642/15390 embeddings done
# 1643/15390 embeddings done
# 1644/15390 embeddings done
# 1645/15390 embeddings done
# 1646/15390 embeddings done
# 1647/15390 embeddings done
# 1648/15390 embeddings done
# 1649/15390 embeddings done
# 1650/15390 embeddings done
# 1651/15390 embeddings done
# 1652/15390 embeddings done
# 1653/15390 embeddings done
# 1654/15390 embeddings done
# 1655/15390 embeddings done
# 1656/15390 embeddings done
# 1657/15390 embeddings done
# 1658/15390 embeddings done
# 1659/15390 embeddings done
# 1660/15390 embeddings done
# 1661/15390 embeddings done
# 1662/15390 embeddings done
# 1663/15390 embeddings done
# 1664/15390 embeddings done
# 1665/15390 embeddings done
# 1666/15390 embeddings done
# 1667/15390 embeddings done
# 1668/15390 embeddings done
# 1669/15390 embeddings done
# 1670/15390 embeddings done
# 1671/15390 embeddings done
# 1672/15390 embeddings done
# 1673/15390 embeddings done
# 1674/15390 embeddings done
# 1675/15390 embeddings done
# 1676/15390 embeddings done
# 1677/15390 embeddings done
# 1678/15390 embeddings done
# 1679/15390 embeddings done
# 1680/15390 embeddings done
# 1681/15390 embeddings done
# 1682/15390 embeddings done
# 1683/15390 embeddings done
# 1684/15390 embeddings done
# 1685/15390 embeddings done
# 1686/15390 embeddings done
# 1687/15390 embeddings done
# 1688/15390 embeddings done
# 1689/15390 embeddings done
# 1690/15390 embeddings done
# 1691/15390 embeddings done
# 1692/15390 embeddings done
# 1693/15390 embeddings done
# 1694/15390 embeddings done
# 1695/15390 embeddings done
# 1696/15390 embeddings done
# 1697/15390 embeddings done
# 1698/15390 embeddings done
# 1699/15390 embeddings done
# 1700/15390 embeddings done
# 1701/15390 embeddings done
# 1702/15390 embeddings done
# 1703/15390 embeddings done
# 1704/15390 embeddings done
# 1705/15390 embeddings done
# 1706/15390 embeddings done
# 1707/15390 embeddings done
# 1708/15390 embeddings done
# 1709/15390 embeddings done
# 1710/15390 embeddings done
# 1711/15390 embeddings done
# 1712/15390 embeddings done
# 1713/15390 embeddings done
# 1714/15390 embeddings done
# 1715/15390 embeddings done
# 1716/15390 embeddings done
# 1717/15390 embeddings done
# 1718/15390 embeddings done
# 1719/15390 embeddings done
# 1720/15390 embeddings done
# 1721/15390 embeddings done
# 1722/15390 embeddings done
# 1723/15390 embeddings done
# 1724/15390 embeddings done
# 1725/15390 embeddings done
# 1726/15390 embeddings done
# 1727/15390 embeddings done
# 1728/15390 embeddings done
# 1729/15390 embeddings done
# 1730/15390 embeddings done
# 1731/15390 embeddings done
# 1732/15390 embeddings done
# 1733/15390 embeddings done
# 1734/15390 embeddings done
# 1735/15390 embeddings done
# 1736/15390 embeddings done
# 1737/15390 embeddings done
# 1738/15390 embeddings done
# 1739/15390 embeddings done
# 1740/15390 embeddings done
# 1741/15390 embeddings done
# 1742/15390 embeddings done
# 1743/15390 embeddings done
# 1744/15390 embeddings done
# 1745/15390 embeddings done
# 1746/15390 embeddings done
# 1747/15390 embeddings done
# 1748/15390 embeddings done
# 1749/15390 embeddings done
# 1750/15390 embeddings done
# 1751/15390 embeddings done
# 1752/15390 embeddings done
# 1753/15390 embeddings done
# 1754/15390 embeddings done
# 1755/15390 embeddings done
# 1756/15390 embeddings done
# 1757/15390 embeddings done
# 1758/15390 embeddings done
# 1759/15390 embeddings done
# 1760/15390 embeddings done
# 1761/15390 embeddings done
# 1762/15390 embeddings done
# 1763/15390 embeddings done
# 1764/15390 embeddings done
# 1765/15390 embeddings done
# 1766/15390 embeddings done
# 1767/15390 embeddings done
# 1768/15390 embeddings done
# 1769/15390 embeddings done
# 1770/15390 embeddings done
# 1771/15390 embeddings done
# 1772/15390 embeddings done
# 1773/15390 embeddings done
# 1774/15390 embeddings done
# 1775/15390 embeddings done
# 1776/15390 embeddings done
# 1777/15390 embeddings done
# 1778/15390 embeddings done
# 1779/15390 embeddings done
# 1780/15390 embeddings done
# 1781/15390 embeddings done
# 1782/15390 embeddings done
# 1783/15390 embeddings done
# 1784/15390 embeddings done
# 1785/15390 embeddings done
# 1786/15390 embeddings done
# 1787/15390 embeddings done
# 1788/15390 embeddings done
# 1789/15390 embeddings done
# 1790/15390 embeddings done
# 1791/15390 embeddings done
# 1792/15390 embeddings done
# 1793/15390 embeddings done
# 1794/15390 embeddings done
# 1795/15390 embeddings done
# 1796/15390 embeddings done
# 1797/15390 embeddings done
# 1798/15390 embeddings done
# 1799/15390 embeddings done
# 1800/15390 embeddings done
# 1801/15390 embeddings done
# 1802/15390 embeddings done
# ...
# 14827/15390 embeddings done
# 14828/15390 embeddings done
# 14829/15390 embeddings done
# 14830/15390 embeddings done
# 14831/15390 embeddings done
# 14832/15390 embeddings done
# 14833/15390 embeddings done
# 14834/15390 embeddings done
# 14835/15390 embeddings done
# 14836/15390 embeddings done
# 14837/15390 embeddings done
# 14838/15390 embeddings done
# 14839/15390 embeddings done
# 14840/15390 embeddings done
# 14841/15390 embeddings done
# 14842/15390 embeddings done
# 14843/15390 embeddings done
# 14844/15390 embeddings done
# 14845/15390 embeddings done
# 14846/15390 embeddings done
# 14847/15390 embeddings done
# 14848/15390 embeddings done
# 14849/15390 embeddings done
# 14850/15390 embeddings done
# 14851/15390 embeddings done
# 14852/15390 embeddings done
# 14853/15390 embeddings done
# 14854/15390 embeddings done
# 14855/15390 embeddings done
# 14856/15390 embeddings done
# 14857/15390 embeddings done
# 14858/15390 embeddings done
# 14859/15390 embeddings done
# 14860/15390 embeddings done
# 14861/15390 embeddings done
# 14862/15390 embeddings done
# 14863/15390 embeddings done
# 14864/15390 embeddings done
# 14865/15390 embeddings done
# 14866/15390 embeddings done
# 14867/15390 embeddings done
# 14868/15390 embeddings done
# 14869/15390 embeddings done
# 14870/15390 embeddings done
# 14871/15390 embeddings done
# 14872/15390 embeddings done
# 14873/15390 embeddings done
# 14874/15390 embeddings done
# 14875/15390 embeddings done
# 14876/15390 embeddings done
# 14877/15390 embeddings done
# 14878/15390 embeddings done
# 14879/15390 embeddings done
# 14880/15390 embeddings done
# 14881/15390 embeddings done
# 14882/15390 embeddings done
# 14883/15390 embeddings done
# 14884/15390 embeddings done
# 14885/15390 embeddings done
# 14886/15390 embeddings done
# 14887/15390 embeddings done
# 14888/15390 embeddings done
# 14889/15390 embeddings done
# 14890/15390 embeddings done
# 14891/15390 embeddings done
# 14892/15390 embeddings done
# 14893/15390 embeddings done
# 14894/15390 embeddings done
# 14895/15390 embeddings done
# 14896/15390 embeddings done
# 14897/15390 embeddings done
# 14898/15390 embeddings done
# 14899/15390 embeddings done
# 14900/15390 embeddings done
# 14901/15390 embeddings done
# 14902/15390 embeddings done
# 14903/15390 embeddings done
# 14904/15390 embeddings done
# 14905/15390 embeddings done
# 14906/15390 embeddings done
# 14907/15390 embeddings done
# 14908/15390 embeddings done
# 14909/15390 embeddings done
# 14910/15390 embeddings done
# 14911/15390 embeddings done
# 14912/15390 embeddings done
# 14913/15390 embeddings done
# 14914/15390 embeddings done
# 14915/15390 embeddings done
# 14916/15390 embeddings done
# 14917/15390 embeddings done
# 14918/15390 embeddings done
# 14919/15390 embeddings done
# 14920/15390 embeddings done
# 14921/15390 embeddings done
# 14922/15390 embeddings done
# 14923/15390 embeddings done
# 14924/15390 embeddings done
# 14925/15390 embeddings done
# 14926/15390 embeddings done
# 14927/15390 embeddings done
# 14928/15390 embeddings done
# 14929/15390 embeddings done
# 14930/15390 embeddings done
# 14931/15390 embeddings done
# 14932/15390 embeddings done
# 14933/15390 embeddings done
# 14934/15390 embeddings done
# 14935/15390 embeddings done
# 14936/15390 embeddings done
# 14937/15390 embeddings done
# 14938/15390 embeddings done
# 14939/15390 embeddings done
# 14940/15390 embeddings done
# 14941/15390 embeddings done
# 14942/15390 embeddings done
# 14943/15390 embeddings done
# 14944/15390 embeddings done
# 14945/15390 embeddings done
# 14946/15390 embeddings done
# 14947/15390 embeddings done
# 14948/15390 embeddings done
# 14949/15390 embeddings done
# 14950/15390 embeddings done
# 14951/15390 embeddings done
# 14952/15390 embeddings done
# 14953/15390 embeddings done
# 14954/15390 embeddings done
# 14955/15390 embeddings done
# 14956/15390 embeddings done
# 14957/15390 embeddings done
# 14958/15390 embeddings done
# 14959/15390 embeddings done
# 14960/15390 embeddings done
# 14961/15390 embeddings done
# 14962/15390 embeddings done
# 14963/15390 embeddings done
# 14964/15390 embeddings done
# 14965/15390 embeddings done
# 14966/15390 embeddings done
# 14967/15390 embeddings done
# 14968/15390 embeddings done
# 14969/15390 embeddings done
# 14970/15390 embeddings done
# 14971/15390 embeddings done
# 14972/15390 embeddings done
# 14973/15390 embeddings done
# 14974/15390 embeddings done
# 14975/15390 embeddings done
# 14976/15390 embeddings done
# 14977/15390 embeddings done
# 14978/15390 embeddings done
# 14979/15390 embeddings done
# 14980/15390 embeddings done
# 14981/15390 embeddings done
# 14982/15390 embeddings done
# 14983/15390 embeddings done
# 14984/15390 embeddings done
# 14985/15390 embeddings done
# 14986/15390 embeddings done
# 14987/15390 embeddings done
# 14988/15390 embeddings done
# 14989/15390 embeddings done
# 14990/15390 embeddings done
# 14991/15390 embeddings done
# 14992/15390 embeddings done
# 14993/15390 embeddings done
# 14994/15390 embeddings done
# 14995/15390 embeddings done
# 14996/15390 embeddings done
# 14997/15390 embeddings done
# 14998/15390 embeddings done
# 14999/15390 embeddings done
# 15000/15390 embeddings done
# 15001/15390 embeddings done
# 15002/15390 embeddings done
# 15003/15390 embeddings done
# 15004/15390 embeddings done
# 15005/15390 embeddings done
# 15006/15390 embeddings done
# 15007/15390 embeddings done
# 15008/15390 embeddings done
# 15009/15390 embeddings done
# 15010/15390 embeddings done
# 15011/15390 embeddings done
# 15012/15390 embeddings done
# 15013/15390 embeddings done
# 15014/15390 embeddings done
# 15015/15390 embeddings done
# 15016/15390 embeddings done
# 15017/15390 embeddings done
# 15018/15390 embeddings done
# 15019/15390 embeddings done
# 15020/15390 embeddings done
# 15021/15390 embeddings done
# 15022/15390 embeddings done
# 15023/15390 embeddings done
# 15024/15390 embeddings done
# 15025/15390 embeddings done
# 15026/15390 embeddings done
# 15027/15390 embeddings done
# 15028/15390 embeddings done
# 15029/15390 embeddings done
# 15030/15390 embeddings done
# 15031/15390 embeddings done
# 15032/15390 embeddings done
# 15033/15390 embeddings done
# 15034/15390 embeddings done
# 15035/15390 embeddings done
# 15036/15390 embeddings done
# 15037/15390 embeddings done
# 15038/15390 embeddings done
# 15039/15390 embeddings done
# 15040/15390 embeddings done
# 15041/15390 embeddings done
# 15042/15390 embeddings done
# 15043/15390 embeddings done
# 15044/15390 embeddings done
# 15045/15390 embeddings done
# 15046/15390 embeddings done
# 15047/15390 embeddings done
# 15048/15390 embeddings done
# 15049/15390 embeddings done
# 15050/15390 embeddings done
# 15051/15390 embeddings done
# 15052/15390 embeddings done
# 15053/15390 embeddings done
# 15054/15390 embeddings done
# 15055/15390 embeddings done
# 15056/15390 embeddings done
# 15057/15390 embeddings done
# 15058/15390 embeddings done
# 15059/15390 embeddings done
# 15060/15390 embeddings done
# 15061/15390 embeddings done
# 15062/15390 embeddings done
# 15063/15390 embeddings done
# 15064/15390 embeddings done
# 15065/15390 embeddings done
# 15066/15390 embeddings done
# 15067/15390 embeddings done
# 15068/15390 embeddings done
# 15069/15390 embeddings done
# 15070/15390 embeddings done
# 15071/15390 embeddings done
# 15072/15390 embeddings done
# 15073/15390 embeddings done
# 15074/15390 embeddings done
# 15075/15390 embeddings done
# 15076/15390 embeddings done
# 15077/15390 embeddings done
# 15078/15390 embeddings done
# 15079/15390 embeddings done
# 15080/15390 embeddings done
# 15081/15390 embeddings done
# 15082/15390 embeddings done
# 15083/15390 embeddings done
# 15084/15390 embeddings done
# 15085/15390 embeddings done
# 15086/15390 embeddings done
# 15087/15390 embeddings done
# 15088/15390 embeddings done
# 15089/15390 embeddings done
# 15090/15390 embeddings done
# 15091/15390 embeddings done
# 15092/15390 embeddings done
# 15093/15390 embeddings done
# 15094/15390 embeddings done
# 15095/15390 embeddings done
# 15096/15390 embeddings done
# 15097/15390 embeddings done
# 15098/15390 embeddings done
# 15099/15390 embeddings done
# 15100/15390 embeddings done
# 15101/15390 embeddings done
# 15102/15390 embeddings done
# 15103/15390 embeddings done
# 15104/15390 embeddings done
# 15105/15390 embeddings done
# 15106/15390 embeddings done
# 15107/15390 embeddings done
# 15108/15390 embeddings done
# 15109/15390 embeddings done
# 15110/15390 embeddings done
# 15111/15390 embeddings done
# 15112/15390 embeddings done
# 15113/15390 embeddings done
# 15114/15390 embeddings done
# 15115/15390 embeddings done
# 15116/15390 embeddings done
# 15117/15390 embeddings done
# 15118/15390 embeddings done
# 15119/15390 embeddings done
# 15120/15390 embeddings done
# 15121/15390 embeddings done
# 15122/15390 embeddings done
# 15123/15390 embeddings done
# 15124/15390 embeddings done
# 15125/15390 embeddings done
# 15126/15390 embeddings done
# 15127/15390 embeddings done
# 15128/15390 embeddings done
# 15129/15390 embeddings done
# 15130/15390 embeddings done
# 15131/15390 embeddings done
# 15132/15390 embeddings done
# 15133/15390 embeddings done
# 15134/15390 embeddings done
# 15135/15390 embeddings done
# 15136/15390 embeddings done
# 15137/15390 embeddings done
# 15138/15390 embeddings done
# 15139/15390 embeddings done
# 15140/15390 embeddings done
# 15141/15390 embeddings done
# 15142/15390 embeddings done
# 15143/15390 embeddings done
# 15144/15390 embeddings done
# 15145/15390 embeddings done
# 15146/15390 embeddings done
# 15147/15390 embeddings done
# 15148/15390 embeddings done
# 15149/15390 embeddings done
# 15150/15390 embeddings done
# 15151/15390 embeddings done
# 15152/15390 embeddings done
# 15153/15390 embeddings done
# 15154/15390 embeddings done
# 15155/15390 embeddings done
# 15156/15390 embeddings done
# 15157/15390 embeddings done
# 15158/15390 embeddings done
# 15159/15390 embeddings done
# 15160/15390 embeddings done
# 15161/15390 embeddings done
# 15162/15390 embeddings done
# 15163/15390 embeddings done
# 15164/15390 embeddings done
# 15165/15390 embeddings done
# 15166/15390 embeddings done
# 15167/15390 embeddings done
# 15168/15390 embeddings done
# 15169/15390 embeddings done
# 15170/15390 embeddings done
# 15171/15390 embeddings done
# 15172/15390 embeddings done
# 15173/15390 embeddings done
# 15174/15390 embeddings done
# 15175/15390 embeddings done
# 15176/15390 embeddings done
# 15177/15390 embeddings done
# 15178/15390 embeddings done
# 15179/15390 embeddings done
# 15180/15390 embeddings done
# 15181/15390 embeddings done
# 15182/15390 embeddings done
# 15183/15390 embeddings done
# 15184/15390 embeddings done
# 15185/15390 embeddings done
# 15186/15390 embeddings done
# 15187/15390 embeddings done
# 15188/15390 embeddings done
# 15189/15390 embeddings done
# 15190/15390 embeddings done
# 15191/15390 embeddings done
# 15192/15390 embeddings done
# 15193/15390 embeddings done
# 15194/15390 embeddings done
# 15195/15390 embeddings done
# 15196/15390 embeddings done
# 15197/15390 embeddings done
# 15198/15390 embeddings done
# 15199/15390 embeddings done
# 15200/15390 embeddings done
# 15201/15390 embeddings done
# 15202/15390 embeddings done
# 15203/15390 embeddings done
# 15204/15390 embeddings done
# 15205/15390 embeddings done
# 15206/15390 embeddings done
# 15207/15390 embeddings done
# 15208/15390 embeddings done
# 15209/15390 embeddings done
# 15210/15390 embeddings done
# 15211/15390 embeddings done
# 15212/15390 embeddings done
# 15213/15390 embeddings done
# 15214/15390 embeddings done
# 15215/15390 embeddings done
# 15216/15390 embeddings done
# 15217/15390 embeddings done
# 15218/15390 embeddings done
# 15219/15390 embeddings done
# 15220/15390 embeddings done
# 15221/15390 embeddings done
# 15222/15390 embeddings done
# 15223/15390 embeddings done
# 15224/15390 embeddings done
# 15225/15390 embeddings done
# 15226/15390 embeddings done
# 15227/15390 embeddings done
# 15228/15390 embeddings done
# 15229/15390 embeddings done
# 15230/15390 embeddings done
# 15231/15390 embeddings done
# 15232/15390 embeddings done
# 15233/15390 embeddings done
# 15234/15390 embeddings done
# 15235/15390 embeddings done
# 15236/15390 embeddings done
# 15237/15390 embeddings done
# 15238/15390 embeddings done
# 15239/15390 embeddings done
# 15240/15390 embeddings done
# 15241/15390 embeddings done
# 15242/15390 embeddings done
# 15243/15390 embeddings done
# 15244/15390 embeddings done
# 15245/15390 embeddings done
# 15246/15390 embeddings done
# 15247/15390 embeddings done
# 15248/15390 embeddings done
# 15249/15390 embeddings done
# 15250/15390 embeddings done
# 15251/15390 embeddings done
# 15252/15390 embeddings done
# 15253/15390 embeddings done
# 15254/15390 embeddings done
# 15255/15390 embeddings done
# 15256/15390 embeddings done
# 15257/15390 embeddings done
# 15258/15390 embeddings done
# 15259/15390 embeddings done
# 15260/15390 embeddings done
# 15261/15390 embeddings done
# 15262/15390 embeddings done
# 15263/15390 embeddings done
# 15264/15390 embeddings done
# 15265/15390 embeddings done
# 15266/15390 embeddings done
# 15267/15390 embeddings done
# 15268/15390 embeddings done
# 15269/15390 embeddings done
# 15270/15390 embeddings done
# 15271/15390 embeddings done
# 15272/15390 embeddings done
# 15273/15390 embeddings done
# 15274/15390 embeddings done
# 15275/15390 embeddings done
# 15276/15390 embeddings done
# 15277/15390 embeddings done
# 15278/15390 embeddings done
# 15279/15390 embeddings done
# 15280/15390 embeddings done
# 15281/15390 embeddings done
# 15282/15390 embeddings done
# 15283/15390 embeddings done
# 15284/15390 embeddings done
# 15285/15390 embeddings done
# 15286/15390 embeddings done
# 15287/15390 embeddings done
# 15288/15390 embeddings done
# 15289/15390 embeddings done
# 15290/15390 embeddings done
# 15291/15390 embeddings done
# 15292/15390 embeddings done
# 15293/15390 embeddings done
# 15294/15390 embeddings done
# 15295/15390 embeddings done
# 15296/15390 embeddings done
# 15297/15390 embeddings done
# 15298/15390 embeddings done
# 15299/15390 embeddings done
# 15300/15390 embeddings done
# 15301/15390 embeddings done
# 15302/15390 embeddings done
# 15303/15390 embeddings done
# 15304/15390 embeddings done
# 15305/15390 embeddings done
# 15306/15390 embeddings done
# 15307/15390 embeddings done
# 15308/15390 embeddings done
# 15309/15390 embeddings done
# 15310/15390 embeddings done
# 15311/15390 embeddings done
# 15312/15390 embeddings done
# 15313/15390 embeddings done
# 15314/15390 embeddings done
# 15315/15390 embeddings done
# 15316/15390 embeddings done
# 15317/15390 embeddings done
# 15318/15390 embeddings done
# 15319/15390 embeddings done
# 15320/15390 embeddings done
# 15321/15390 embeddings done
# 15322/15390 embeddings done
# 15323/15390 embeddings done
# 15324/15390 embeddings done
# 15325/15390 embeddings done
# 15326/15390 embeddings done
# 15327/15390 embeddings done
# 15328/15390 embeddings done
# 15329/15390 embeddings done
# 15330/15390 embeddings done
# 15331/15390 embeddings done
# 15332/15390 embeddings done
# 15333/15390 embeddings done
# 15334/15390 embeddings done
# 15335/15390 embeddings done
# 15336/15390 embeddings done
# 15337/15390 embeddings done
# 15338/15390 embeddings done
# 15339/15390 embeddings done
# 15340/15390 embeddings done
# 15341/15390 embeddings done
# 15342/15390 embeddings done
# 15343/15390 embeddings done
# 15344/15390 embeddings done
# 15345/15390 embeddings done
# 15346/15390 embeddings done
# 15347/15390 embeddings done
# 15348/15390 embeddings done
# 15349/15390 embeddings done
# 15350/15390 embeddings done
# 15351/15390 embeddings done
# 15352/15390 embeddings done
# 15353/15390 embeddings done
# 15354/15390 embeddings done
# 15355/15390 embeddings done
# 15356/15390 embeddings done
# 15357/15390 embeddings done
# 15358/15390 embeddings done
# 15359/15390 embeddings done
# 15360/15390 embeddings done
# 15361/15390 embeddings done
# 15362/15390 embeddings done
# 15363/15390 embeddings done
# 15364/15390 embeddings done
# 15365/15390 embeddings done
# 15366/15390 embeddings done
# 15367/15390 embeddings done
# 15368/15390 embeddings done
# 15369/15390 embeddings done
# 15370/15390 embeddings done
# 15371/15390 embeddings done
# 15372/15390 embeddings done
# 15373/15390 embeddings done
# 15374/15390 embeddings done
# 15375/15390 embeddings done
# 15376/15390 embeddings done
# 15377/15390 embeddings done
# 15378/15390 embeddings done
# 15379/15390 embeddings done
# 15380/15390 embeddings done
# 15381/15390 embeddings done
# 15382/15390 embeddings done
# 15383/15390 embeddings done
# 15384/15390 embeddings done
# 15385/15390 embeddings done
# 15386/15390 embeddings done
# 15387/15390 embeddings done
# 15388/15390 embeddings done
# 15389/15390 embeddings done
# 15390/15390 embeddings done
# Embeddings from file '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt' added to FAISS index between indice 64921 to 80311.

# %%
file_path = "../index_store/conformalpopqa1000/popqa-train-kilt-1000-1500.jsonl"
scoreWikiAnswers(file_path, '../index_store/conformalpopqa1000/popqa_calibrate_score_1000_1500.jsonl', '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# File '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500.txt' already exists in the FAISS index.
# calibrate data 0 / 500 done
# calibrate data 1 / 500 done
# calibrate data 2 / 500 done
# calibrate data 3 / 500 done
# calibrate data 4 / 500 done
# calibrate data 5 / 500 done
# calibrate data 6 / 500 done
# calibrate data 7 / 500 done
# calibrate data 8 / 500 done
# calibrate data 9 / 500 done
# calibrate data 10 / 500 done
# calibrate data 11 / 500 done
# calibrate data 12 / 500 done
# calibrate data 13 / 500 done
# calibrate data 14 / 500 done
# calibrate data 15 / 500 done
# calibrate data 16 / 500 done
# calibrate data 17 / 500 done
# calibrate data 18 / 500 done
# calibrate data 19 / 500 done
# calibrate data 20 / 500 done
# calibrate data 21 / 500 done
# calibrate data 22 / 500 done
# calibrate data 23 / 500 done
# calibrate data 24 / 500 done
# calibrate data 25 / 500 done
# calibrate data 26 / 500 done
# calibrate data 27 / 500 done
# calibrate data 28 / 500 done
# calibrate data 29 / 500 done
# calibrate data 30 / 500 done
# calibrate data 31 / 500 done
# calibrate data 32 / 500 done
# calibrate data 33 / 500 done
# calibrate data 34 / 500 done
# calibrate data 35 / 500 done
# calibrate data 36 / 500 done
# calibrate data 37 / 500 done
# calibrate data 38 / 500 done
# calibrate data 39 / 500 done
# calibrate data 40 / 500 done
# calibrate data 41 / 500 done
# calibrate data 42 / 500 done
# calibrate data 43 / 500 done
# calibrate data 44 / 500 done
# calibrate data 45 / 500 done
# calibrate data 46 / 500 done
# calibrate data 47 / 500 done
# calibrate data 48 / 500 done
# calibrate data 49 / 500 done
# calibrate data 50 / 500 done
# calibrate data 51 / 500 done
# calibrate data 52 / 500 done
# calibrate data 53 / 500 done
# calibrate data 54 / 500 done
# calibrate data 55 / 500 done
# calibrate data 56 / 500 done
# calibrate data 57 / 500 done
# calibrate data 58 / 500 done
# calibrate data 59 / 500 done
# calibrate data 60 / 500 done
# calibrate data 61 / 500 done
# calibrate data 62 / 500 done
# calibrate data 63 / 500 done
# calibrate data 64 / 500 done
# calibrate data 65 / 500 done
# calibrate data 66 / 500 done
# calibrate data 67 / 500 done
# calibrate data 68 / 500 done
# calibrate data 69 / 500 done
# calibrate data 70 / 500 done
# calibrate data 71 / 500 done
# calibrate data 72 / 500 done
# calibrate data 73 / 500 done
# calibrate data 74 / 500 done
# calibrate data 75 / 500 done
# calibrate data 76 / 500 done
# calibrate data 77 / 500 done
# calibrate data 78 / 500 done
# calibrate data 79 / 500 done
# calibrate data 80 / 500 done
# calibrate data 81 / 500 done
# calibrate data 82 / 500 done
# calibrate data 83 / 500 done
# calibrate data 84 / 500 done
# calibrate data 85 / 500 done
# calibrate data 86 / 500 done
# calibrate data 87 / 500 done
# calibrate data 88 / 500 done
# calibrate data 89 / 500 done
# calibrate data 90 / 500 done
# calibrate data 91 / 500 done
# calibrate data 92 / 500 done
# calibrate data 93 / 500 done
# calibrate data 94 / 500 done
# calibrate data 95 / 500 done
# calibrate data 96 / 500 done
# calibrate data 97 / 500 done
# calibrate data 98 / 500 done
# calibrate data 99 / 500 done
# calibrate data 100 / 500 done
# calibrate data 101 / 500 done
# calibrate data 102 / 500 done
# calibrate data 103 / 500 done
# calibrate data 104 / 500 done
# calibrate data 105 / 500 done
# calibrate data 106 / 500 done
# calibrate data 107 / 500 done
# calibrate data 108 / 500 done
# calibrate data 109 / 500 done
# calibrate data 110 / 500 done
# calibrate data 111 / 500 done
# calibrate data 112 / 500 done
# calibrate data 113 / 500 done
# calibrate data 114 / 500 done
# calibrate data 115 / 500 done
# calibrate data 116 / 500 done
# calibrate data 117 / 500 done
# calibrate data 118 / 500 done
# calibrate data 119 / 500 done
# calibrate data 120 / 500 done
# calibrate data 121 / 500 done
# calibrate data 122 / 500 done
# calibrate data 123 / 500 done
# calibrate data 124 / 500 done
# calibrate data 125 / 500 done
# calibrate data 126 / 500 done
# calibrate data 127 / 500 done
# calibrate data 128 / 500 done
# calibrate data 129 / 500 done
# calibrate data 130 / 500 done
# calibrate data 131 / 500 done
# calibrate data 132 / 500 done
# calibrate data 133 / 500 done
# calibrate data 134 / 500 done
# calibrate data 135 / 500 done
# calibrate data 136 / 500 done
# calibrate data 137 / 500 done
# calibrate data 138 / 500 done
# calibrate data 139 / 500 done
# calibrate data 140 / 500 done
# calibrate data 141 / 500 done
# calibrate data 142 / 500 done
# calibrate data 143 / 500 done
# calibrate data 144 / 500 done
# calibrate data 145 / 500 done
# calibrate data 146 / 500 done
# calibrate data 147 / 500 done
# calibrate data 148 / 500 done
# calibrate data 149 / 500 done
# calibrate data 150 / 500 done
# calibrate data 151 / 500 done
# calibrate data 152 / 500 done
# calibrate data 153 / 500 done
# calibrate data 154 / 500 done
# calibrate data 155 / 500 done
# calibrate data 156 / 500 done
# calibrate data 157 / 500 done
# calibrate data 158 / 500 done
# calibrate data 159 / 500 done
# calibrate data 160 / 500 done
# calibrate data 161 / 500 done
# calibrate data 162 / 500 done
# calibrate data 163 / 500 done
# calibrate data 164 / 500 done
# calibrate data 165 / 500 done
# calibrate data 166 / 500 done
# calibrate data 167 / 500 done
# calibrate data 168 / 500 done
# calibrate data 169 / 500 done
# calibrate data 170 / 500 done
# calibrate data 171 / 500 done
# calibrate data 172 / 500 done
# calibrate data 173 / 500 done
# calibrate data 174 / 500 done
# calibrate data 175 / 500 done
# calibrate data 176 / 500 done
# calibrate data 177 / 500 done
# calibrate data 178 / 500 done
# calibrate data 179 / 500 done
# calibrate data 180 / 500 done
# calibrate data 181 / 500 done
# calibrate data 182 / 500 done
# calibrate data 183 / 500 done
# calibrate data 184 / 500 done
# calibrate data 185 / 500 done
# calibrate data 186 / 500 done
# calibrate data 187 / 500 done
# calibrate data 188 / 500 done
# calibrate data 189 / 500 done
# calibrate data 190 / 500 done
# calibrate data 191 / 500 done
# calibrate data 192 / 500 done
# calibrate data 193 / 500 done
# calibrate data 194 / 500 done
# calibrate data 195 / 500 done
# calibrate data 196 / 500 done
# calibrate data 197 / 500 done
# calibrate data 198 / 500 done
# calibrate data 199 / 500 done
# calibrate data 200 / 500 done
# calibrate data 201 / 500 done
# calibrate data 202 / 500 done
# calibrate data 203 / 500 done
# calibrate data 204 / 500 done
# calibrate data 205 / 500 done
# calibrate data 206 / 500 done
# calibrate data 207 / 500 done
# calibrate data 208 / 500 done
# calibrate data 209 / 500 done
# calibrate data 210 / 500 done
# calibrate data 211 / 500 done
# calibrate data 212 / 500 done
# calibrate data 213 / 500 done
# calibrate data 214 / 500 done
# calibrate data 215 / 500 done
# calibrate data 216 / 500 done
# calibrate data 217 / 500 done
# calibrate data 218 / 500 done
# calibrate data 219 / 500 done
# calibrate data 220 / 500 done
# calibrate data 221 / 500 done
# calibrate data 222 / 500 done
# calibrate data 223 / 500 done
# calibrate data 224 / 500 done
# calibrate data 225 / 500 done
# calibrate data 226 / 500 done
# calibrate data 227 / 500 done
# calibrate data 228 / 500 done
# calibrate data 229 / 500 done
# calibrate data 230 / 500 done
# calibrate data 231 / 500 done
# calibrate data 232 / 500 done
# calibrate data 233 / 500 done
# calibrate data 234 / 500 done
# calibrate data 235 / 500 done
# calibrate data 236 / 500 done
# calibrate data 237 / 500 done
# calibrate data 238 / 500 done
# calibrate data 239 / 500 done
# calibrate data 240 / 500 done
# calibrate data 241 / 500 done
# calibrate data 242 / 500 done
# calibrate data 243 / 500 done
# calibrate data 244 / 500 done
# calibrate data 245 / 500 done
# calibrate data 246 / 500 done
# calibrate data 247 / 500 done
# calibrate data 248 / 500 done
# calibrate data 249 / 500 done
# calibrate data 250 / 500 done
# calibrate data 251 / 500 done
# calibrate data 252 / 500 done
# calibrate data 253 / 500 done
# calibrate data 254 / 500 done
# calibrate data 255 / 500 done
# calibrate data 256 / 500 done
# calibrate data 257 / 500 done
# calibrate data 258 / 500 done
# calibrate data 259 / 500 done
# calibrate data 260 / 500 done
# calibrate data 261 / 500 done
# calibrate data 262 / 500 done
# calibrate data 263 / 500 done
# calibrate data 264 / 500 done
# calibrate data 265 / 500 done
# calibrate data 266 / 500 done
# calibrate data 267 / 500 done
# calibrate data 268 / 500 done
# calibrate data 269 / 500 done
# calibrate data 270 / 500 done
# calibrate data 271 / 500 done
# calibrate data 272 / 500 done
# calibrate data 273 / 500 done
# calibrate data 274 / 500 done
# calibrate data 275 / 500 done
# calibrate data 276 / 500 done
# calibrate data 277 / 500 done
# calibrate data 278 / 500 done
# calibrate data 279 / 500 done
# calibrate data 280 / 500 done
# calibrate data 281 / 500 done
# calibrate data 282 / 500 done
# calibrate data 283 / 500 done
# calibrate data 284 / 500 done
# calibrate data 285 / 500 done
# calibrate data 286 / 500 done
# calibrate data 287 / 500 done
# calibrate data 288 / 500 done
# calibrate data 289 / 500 done
# calibrate data 290 / 500 done
# calibrate data 291 / 500 done
# calibrate data 292 / 500 done
# calibrate data 293 / 500 done
# calibrate data 294 / 500 done
# calibrate data 295 / 500 done
# calibrate data 296 / 500 done
# calibrate data 297 / 500 done
# calibrate data 298 / 500 done
# calibrate data 299 / 500 done
# calibrate data 300 / 500 done
# calibrate data 301 / 500 done
# calibrate data 302 / 500 done
# calibrate data 303 / 500 done
# calibrate data 304 / 500 done
# calibrate data 305 / 500 done
# calibrate data 306 / 500 done
# calibrate data 307 / 500 done
# calibrate data 308 / 500 done
# calibrate data 309 / 500 done
# calibrate data 310 / 500 done
# calibrate data 311 / 500 done
# calibrate data 312 / 500 done
# calibrate data 313 / 500 done
# calibrate data 314 / 500 done
# calibrate data 315 / 500 done
# calibrate data 316 / 500 done
# calibrate data 317 / 500 done
# calibrate data 318 / 500 done
# calibrate data 319 / 500 done
# calibrate data 320 / 500 done
# calibrate data 321 / 500 done
# calibrate data 322 / 500 done
# calibrate data 323 / 500 done
# calibrate data 324 / 500 done
# calibrate data 325 / 500 done
# calibrate data 326 / 500 done
# calibrate data 327 / 500 done
# calibrate data 328 / 500 done
# calibrate data 329 / 500 done
# calibrate data 330 / 500 done
# calibrate data 331 / 500 done
# calibrate data 332 / 500 done
# calibrate data 333 / 500 done
# calibrate data 334 / 500 done
# calibrate data 335 / 500 done
# calibrate data 336 / 500 done
# calibrate data 337 / 500 done
# calibrate data 338 / 500 done
# calibrate data 339 / 500 done
# calibrate data 340 / 500 done
# calibrate data 341 / 500 done
# calibrate data 342 / 500 done
# calibrate data 343 / 500 done
# calibrate data 344 / 500 done
# calibrate data 345 / 500 done
# calibrate data 346 / 500 done
# calibrate data 347 / 500 done
# calibrate data 348 / 500 done
# calibrate data 349 / 500 done
# calibrate data 350 / 500 done
# calibrate data 351 / 500 done
# calibrate data 352 / 500 done
# calibrate data 353 / 500 done
# calibrate data 354 / 500 done
# calibrate data 355 / 500 done
# calibrate data 356 / 500 done
# calibrate data 357 / 500 done
# calibrate data 358 / 500 done
# calibrate data 359 / 500 done
# calibrate data 360 / 500 done
# calibrate data 361 / 500 done
# calibrate data 362 / 500 done
# calibrate data 363 / 500 done
# calibrate data 364 / 500 done
# calibrate data 365 / 500 done
# calibrate data 366 / 500 done
# calibrate data 367 / 500 done
# calibrate data 368 / 500 done
# calibrate data 369 / 500 done
# calibrate data 370 / 500 done
# calibrate data 371 / 500 done
# calibrate data 372 / 500 done
# calibrate data 373 / 500 done
# calibrate data 374 / 500 done
# calibrate data 375 / 500 done
# calibrate data 376 / 500 done
# calibrate data 377 / 500 done
# calibrate data 378 / 500 done
# calibrate data 379 / 500 done
# calibrate data 380 / 500 done
# calibrate data 381 / 500 done
# calibrate data 382 / 500 done
# calibrate data 383 / 500 done
# calibrate data 384 / 500 done
# calibrate data 385 / 500 done
# calibrate data 386 / 500 done
# calibrate data 387 / 500 done
# calibrate data 388 / 500 done
# calibrate data 389 / 500 done
# calibrate data 390 / 500 done
# calibrate data 391 / 500 done
# calibrate data 392 / 500 done
# calibrate data 393 / 500 done
# calibrate data 394 / 500 done
# calibrate data 395 / 500 done
# calibrate data 396 / 500 done
# calibrate data 397 / 500 done
# calibrate data 398 / 500 done
# calibrate data 399 / 500 done
# calibrate data 400 / 500 done
# calibrate data 401 / 500 done
# calibrate data 402 / 500 done
# calibrate data 403 / 500 done
# calibrate data 404 / 500 done
# calibrate data 405 / 500 done
# calibrate data 406 / 500 done
# calibrate data 407 / 500 done
# calibrate data 408 / 500 done
# calibrate data 409 / 500 done
# calibrate data 410 / 500 done
# calibrate data 411 / 500 done
# calibrate data 412 / 500 done
# calibrate data 413 / 500 done
# calibrate data 414 / 500 done
# calibrate data 415 / 500 done
# calibrate data 416 / 500 done
# calibrate data 417 / 500 done
# calibrate data 418 / 500 done
# calibrate data 419 / 500 done
# calibrate data 420 / 500 done
# calibrate data 421 / 500 done
# calibrate data 422 / 500 done
# calibrate data 423 / 500 done
# calibrate data 424 / 500 done
# calibrate data 425 / 500 done
# calibrate data 426 / 500 done
# calibrate data 427 / 500 done
# calibrate data 428 / 500 done
# calibrate data 429 / 500 done
# calibrate data 430 / 500 done
# calibrate data 431 / 500 done
# calibrate data 432 / 500 done
# calibrate data 433 / 500 done
# calibrate data 434 / 500 done
# calibrate data 435 / 500 done
# calibrate data 436 / 500 done
# calibrate data 437 / 500 done
# calibrate data 438 / 500 done
# calibrate data 439 / 500 done
# calibrate data 440 / 500 done
# calibrate data 441 / 500 done
# calibrate data 442 / 500 done
# calibrate data 443 / 500 done
# calibrate data 444 / 500 done
# calibrate data 445 / 500 done
# calibrate data 446 / 500 done
# calibrate data 447 / 500 done
# calibrate data 448 / 500 done
# calibrate data 449 / 500 done
# calibrate data 450 / 500 done
# calibrate data 451 / 500 done
# calibrate data 452 / 500 done
# calibrate data 453 / 500 done
# calibrate data 454 / 500 done
# calibrate data 455 / 500 done
# calibrate data 456 / 500 done
# calibrate data 457 / 500 done
# calibrate data 458 / 500 done
# calibrate data 459 / 500 done
# calibrate data 460 / 500 done
# calibrate data 461 / 500 done
# calibrate data 462 / 500 done
# calibrate data 463 / 500 done
# calibrate data 464 / 500 done
# calibrate data 465 / 500 done
# calibrate data 466 / 500 done
# calibrate data 467 / 500 done
# calibrate data 468 / 500 done
# calibrate data 469 / 500 done
# calibrate data 470 / 500 done
# calibrate data 471 / 500 done
# calibrate data 472 / 500 done
# calibrate data 473 / 500 done
# calibrate data 474 / 500 done
# calibrate data 475 / 500 done
# calibrate data 476 / 500 done
# calibrate data 477 / 500 done
# calibrate data 478 / 500 done
# calibrate data 479 / 500 done
# calibrate data 480 / 500 done
# calibrate data 481 / 500 done
# calibrate data 482 / 500 done
# calibrate data 483 / 500 done
# calibrate data 484 / 500 done
# calibrate data 485 / 500 done
# calibrate data 486 / 500 done
# calibrate data 487 / 500 done
# calibrate data 488 / 500 done
# calibrate data 489 / 500 done
# calibrate data 490 / 500 done
# calibrate data 491 / 500 done
# calibrate data 492 / 500 done
# calibrate data 493 / 500 done
# calibrate data 494 / 500 done
# calibrate data 495 / 500 done
# calibrate data 496 / 500 done
# calibrate data 497 / 500 done
# calibrate data 498 / 500 done
# calibrate data 499 / 500 done

# %% [markdown]
# **Create Embedding + Score**

# %%
file_path = "../index_store/conformalpopqa500/popqa-train-kilt-500.jsonl"
scoreWikiAnswers(file_path, '../index_store/conformalpopqa500/popqa_calibrate_score_500.jsonl', '../index_store/conformalpopqa500/title_text_map_popqa_500.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# File '../index_store/conformalpopqa500/title_text_map_popqa_500.txt' already exists in the FAISS index.
# calibrate data 0 / 505 done
# calibrate data 1 / 505 done
# calibrate data 2 / 505 done
# calibrate data 3 / 505 done
# calibrate data 4 / 505 done
# calibrate data 5 / 505 done
# calibrate data 6 / 505 done
# calibrate data 7 / 505 done
# calibrate data 8 / 505 done
# calibrate data 9 / 505 done
# calibrate data 10 / 505 done
# calibrate data 11 / 505 done
# calibrate data 12 / 505 done
# calibrate data 13 / 505 done
# calibrate data 14 / 505 done
# calibrate data 15 / 505 done
# calibrate data 16 / 505 done
# calibrate data 17 / 505 done
# calibrate data 18 / 505 done
# calibrate data 19 / 505 done
# calibrate data 20 / 505 done
# calibrate data 21 / 505 done
# calibrate data 22 / 505 done
# calibrate data 23 / 505 done
# calibrate data 24 / 505 done
# calibrate data 25 / 505 done
# calibrate data 26 / 505 done
# calibrate data 27 / 505 done
# calibrate data 28 / 505 done
# calibrate data 29 / 505 done
# calibrate data 30 / 505 done
# calibrate data 31 / 505 done
# calibrate data 32 / 505 done
# calibrate data 33 / 505 done
# calibrate data 34 / 505 done
# calibrate data 35 / 505 done
# calibrate data 36 / 505 done
# calibrate data 37 / 505 done
# calibrate data 38 / 505 done
# calibrate data 39 / 505 done
# calibrate data 40 / 505 done
# calibrate data 41 / 505 done
# calibrate data 42 / 505 done
# calibrate data 43 / 505 done
# calibrate data 44 / 505 done
# calibrate data 45 / 505 done
# calibrate data 46 / 505 done
# calibrate data 47 / 505 done
# calibrate data 48 / 505 done
# calibrate data 49 / 505 done
# calibrate data 50 / 505 done
# calibrate data 51 / 505 done
# calibrate data 52 / 505 done
# calibrate data 53 / 505 done
# calibrate data 54 / 505 done
# calibrate data 55 / 505 done
# calibrate data 56 / 505 done
# calibrate data 57 / 505 done
# calibrate data 58 / 505 done
# calibrate data 59 / 505 done
# calibrate data 60 / 505 done
# calibrate data 61 / 505 done
# calibrate data 62 / 505 done
# calibrate data 63 / 505 done
# calibrate data 64 / 505 done
# calibrate data 65 / 505 done
# calibrate data 66 / 505 done
# calibrate data 67 / 505 done
# calibrate data 68 / 505 done
# calibrate data 69 / 505 done
# calibrate data 70 / 505 done
# calibrate data 71 / 505 done
# calibrate data 72 / 505 done
# calibrate data 73 / 505 done
# calibrate data 74 / 505 done
# calibrate data 75 / 505 done
# calibrate data 76 / 505 done
# calibrate data 77 / 505 done
# calibrate data 78 / 505 done
# calibrate data 79 / 505 done
# calibrate data 80 / 505 done
# calibrate data 81 / 505 done
# calibrate data 82 / 505 done
# calibrate data 83 / 505 done
# calibrate data 84 / 505 done
# calibrate data 85 / 505 done
# calibrate data 86 / 505 done
# calibrate data 87 / 505 done
# calibrate data 88 / 505 done
# calibrate data 89 / 505 done
# calibrate data 90 / 505 done
# calibrate data 91 / 505 done
# calibrate data 92 / 505 done
# calibrate data 93 / 505 done
# calibrate data 94 / 505 done
# calibrate data 95 / 505 done
# calibrate data 96 / 505 done
# calibrate data 97 / 505 done
# calibrate data 98 / 505 done
# calibrate data 99 / 505 done
# calibrate data 100 / 505 done
# calibrate data 101 / 505 done
# calibrate data 102 / 505 done
# calibrate data 103 / 505 done
# calibrate data 104 / 505 done
# calibrate data 105 / 505 done
# calibrate data 106 / 505 done
# calibrate data 107 / 505 done
# calibrate data 108 / 505 done
# calibrate data 109 / 505 done
# calibrate data 110 / 505 done
# calibrate data 111 / 505 done
# calibrate data 112 / 505 done
# calibrate data 113 / 505 done
# calibrate data 114 / 505 done
# calibrate data 115 / 505 done
# calibrate data 116 / 505 done
# calibrate data 117 / 505 done
# calibrate data 118 / 505 done
# calibrate data 119 / 505 done
# calibrate data 120 / 505 done
# calibrate data 121 / 505 done
# calibrate data 122 / 505 done
# calibrate data 123 / 505 done
# calibrate data 124 / 505 done
# calibrate data 125 / 505 done
# calibrate data 126 / 505 done
# calibrate data 127 / 505 done
# calibrate data 128 / 505 done
# calibrate data 129 / 505 done
# calibrate data 130 / 505 done
# calibrate data 131 / 505 done
# calibrate data 132 / 505 done
# calibrate data 133 / 505 done
# calibrate data 134 / 505 done
# calibrate data 135 / 505 done
# calibrate data 136 / 505 done
# calibrate data 137 / 505 done
# calibrate data 138 / 505 done
# calibrate data 139 / 505 done
# calibrate data 140 / 505 done
# calibrate data 141 / 505 done
# calibrate data 142 / 505 done
# calibrate data 143 / 505 done
# calibrate data 144 / 505 done
# calibrate data 145 / 505 done
# calibrate data 146 / 505 done
# calibrate data 147 / 505 done
# calibrate data 148 / 505 done
# calibrate data 149 / 505 done
# calibrate data 150 / 505 done
# calibrate data 151 / 505 done
# calibrate data 152 / 505 done
# calibrate data 153 / 505 done
# calibrate data 154 / 505 done
# calibrate data 155 / 505 done
# calibrate data 156 / 505 done
# calibrate data 157 / 505 done
# calibrate data 158 / 505 done
# calibrate data 159 / 505 done
# calibrate data 160 / 505 done
# calibrate data 161 / 505 done
# calibrate data 162 / 505 done
# calibrate data 163 / 505 done
# calibrate data 164 / 505 done
# calibrate data 165 / 505 done
# calibrate data 166 / 505 done
# calibrate data 167 / 505 done
# calibrate data 168 / 505 done
# calibrate data 169 / 505 done
# calibrate data 170 / 505 done
# calibrate data 171 / 505 done
# calibrate data 172 / 505 done
# calibrate data 173 / 505 done
# calibrate data 174 / 505 done
# calibrate data 175 / 505 done
# calibrate data 176 / 505 done
# calibrate data 177 / 505 done
# calibrate data 178 / 505 done
# calibrate data 179 / 505 done
# calibrate data 180 / 505 done
# calibrate data 181 / 505 done
# calibrate data 182 / 505 done
# calibrate data 183 / 505 done
# calibrate data 184 / 505 done
# calibrate data 185 / 505 done
# calibrate data 186 / 505 done
# calibrate data 187 / 505 done
# calibrate data 188 / 505 done
# calibrate data 189 / 505 done
# calibrate data 190 / 505 done
# calibrate data 191 / 505 done
# calibrate data 192 / 505 done
# calibrate data 193 / 505 done
# calibrate data 194 / 505 done
# calibrate data 195 / 505 done
# calibrate data 196 / 505 done
# calibrate data 197 / 505 done
# calibrate data 198 / 505 done
# calibrate data 199 / 505 done
# calibrate data 200 / 505 done
# calibrate data 201 / 505 done
# calibrate data 202 / 505 done
# calibrate data 203 / 505 done
# calibrate data 204 / 505 done
# calibrate data 205 / 505 done
# calibrate data 206 / 505 done
# calibrate data 207 / 505 done
# calibrate data 208 / 505 done
# calibrate data 209 / 505 done
# calibrate data 210 / 505 done
# calibrate data 211 / 505 done
# calibrate data 212 / 505 done
# calibrate data 213 / 505 done
# calibrate data 214 / 505 done
# calibrate data 215 / 505 done
# calibrate data 216 / 505 done
# calibrate data 217 / 505 done
# calibrate data 218 / 505 done
# calibrate data 219 / 505 done
# calibrate data 220 / 505 done
# calibrate data 221 / 505 done
# calibrate data 222 / 505 done
# calibrate data 223 / 505 done
# calibrate data 224 / 505 done
# calibrate data 225 / 505 done
# calibrate data 226 / 505 done
# calibrate data 227 / 505 done
# calibrate data 228 / 505 done
# calibrate data 229 / 505 done
# calibrate data 230 / 505 done
# calibrate data 231 / 505 done
# calibrate data 232 / 505 done
# calibrate data 233 / 505 done
# calibrate data 234 / 505 done
# calibrate data 235 / 505 done
# calibrate data 236 / 505 done
# calibrate data 237 / 505 done
# calibrate data 238 / 505 done
# calibrate data 239 / 505 done
# calibrate data 240 / 505 done
# calibrate data 241 / 505 done
# calibrate data 242 / 505 done
# calibrate data 243 / 505 done
# calibrate data 244 / 505 done
# calibrate data 245 / 505 done
# calibrate data 246 / 505 done
# calibrate data 247 / 505 done
# calibrate data 248 / 505 done
# calibrate data 249 / 505 done
# calibrate data 250 / 505 done
# calibrate data 251 / 505 done
# calibrate data 252 / 505 done
# calibrate data 253 / 505 done
# calibrate data 254 / 505 done
# calibrate data 255 / 505 done
# calibrate data 256 / 505 done
# calibrate data 257 / 505 done
# calibrate data 258 / 505 done
# calibrate data 259 / 505 done
# calibrate data 260 / 505 done
# calibrate data 261 / 505 done
# calibrate data 262 / 505 done
# calibrate data 263 / 505 done
# calibrate data 264 / 505 done
# calibrate data 265 / 505 done
# calibrate data 266 / 505 done
# calibrate data 267 / 505 done
# calibrate data 268 / 505 done
# calibrate data 269 / 505 done
# calibrate data 270 / 505 done
# calibrate data 271 / 505 done
# calibrate data 272 / 505 done
# calibrate data 273 / 505 done
# calibrate data 274 / 505 done
# calibrate data 275 / 505 done
# calibrate data 276 / 505 done
# calibrate data 277 / 505 done
# calibrate data 278 / 505 done
# calibrate data 279 / 505 done
# calibrate data 280 / 505 done
# calibrate data 281 / 505 done
# calibrate data 282 / 505 done
# calibrate data 283 / 505 done
# calibrate data 284 / 505 done
# calibrate data 285 / 505 done
# calibrate data 286 / 505 done
# calibrate data 287 / 505 done
# calibrate data 288 / 505 done
# calibrate data 289 / 505 done
# calibrate data 290 / 505 done
# calibrate data 291 / 505 done
# calibrate data 292 / 505 done
# calibrate data 293 / 505 done
# calibrate data 294 / 505 done
# calibrate data 295 / 505 done
# calibrate data 296 / 505 done
# calibrate data 297 / 505 done
# calibrate data 298 / 505 done
# calibrate data 299 / 505 done
# calibrate data 300 / 505 done
# calibrate data 301 / 505 done
# calibrate data 302 / 505 done
# calibrate data 303 / 505 done
# calibrate data 304 / 505 done
# calibrate data 305 / 505 done
# calibrate data 306 / 505 done
# calibrate data 307 / 505 done
# calibrate data 308 / 505 done
# calibrate data 309 / 505 done
# calibrate data 310 / 505 done
# calibrate data 311 / 505 done
# calibrate data 312 / 505 done
# calibrate data 313 / 505 done
# calibrate data 314 / 505 done
# calibrate data 315 / 505 done
# calibrate data 316 / 505 done
# calibrate data 317 / 505 done
# calibrate data 318 / 505 done
# calibrate data 319 / 505 done
# calibrate data 320 / 505 done
# calibrate data 321 / 505 done
# calibrate data 322 / 505 done
# calibrate data 323 / 505 done
# calibrate data 324 / 505 done
# calibrate data 325 / 505 done
# calibrate data 326 / 505 done
# calibrate data 327 / 505 done
# calibrate data 328 / 505 done
# calibrate data 329 / 505 done
# calibrate data 330 / 505 done
# calibrate data 331 / 505 done
# calibrate data 332 / 505 done
# calibrate data 333 / 505 done
# calibrate data 334 / 505 done
# calibrate data 335 / 505 done
# calibrate data 336 / 505 done
# calibrate data 337 / 505 done
# calibrate data 338 / 505 done
# calibrate data 339 / 505 done
# calibrate data 340 / 505 done
# calibrate data 341 / 505 done
# calibrate data 342 / 505 done
# calibrate data 343 / 505 done
# calibrate data 344 / 505 done
# calibrate data 345 / 505 done
# calibrate data 346 / 505 done
# calibrate data 347 / 505 done
# calibrate data 348 / 505 done
# calibrate data 349 / 505 done
# calibrate data 350 / 505 done
# calibrate data 351 / 505 done
# calibrate data 352 / 505 done
# calibrate data 353 / 505 done
# calibrate data 354 / 505 done
# calibrate data 355 / 505 done
# calibrate data 356 / 505 done
# calibrate data 357 / 505 done
# calibrate data 358 / 505 done
# calibrate data 359 / 505 done
# calibrate data 360 / 505 done
# calibrate data 361 / 505 done
# calibrate data 362 / 505 done
# calibrate data 363 / 505 done
# calibrate data 364 / 505 done
# calibrate data 365 / 505 done
# calibrate data 366 / 505 done
# calibrate data 367 / 505 done
# calibrate data 368 / 505 done
# calibrate data 369 / 505 done
# calibrate data 370 / 505 done
# calibrate data 371 / 505 done
# calibrate data 372 / 505 done
# calibrate data 373 / 505 done
# calibrate data 374 / 505 done
# calibrate data 375 / 505 done
# calibrate data 376 / 505 done
# calibrate data 377 / 505 done
# calibrate data 378 / 505 done
# calibrate data 379 / 505 done
# calibrate data 380 / 505 done
# calibrate data 381 / 505 done
# calibrate data 382 / 505 done
# calibrate data 383 / 505 done
# calibrate data 384 / 505 done
# calibrate data 385 / 505 done
# calibrate data 386 / 505 done
# calibrate data 387 / 505 done
# calibrate data 388 / 505 done
# calibrate data 389 / 505 done
# calibrate data 390 / 505 done
# calibrate data 391 / 505 done
# calibrate data 392 / 505 done
# calibrate data 393 / 505 done
# calibrate data 394 / 505 done
# calibrate data 395 / 505 done
# calibrate data 396 / 505 done
# calibrate data 397 / 505 done
# calibrate data 398 / 505 done
# calibrate data 399 / 505 done
# calibrate data 400 / 505 done
# calibrate data 401 / 505 done
# calibrate data 402 / 505 done
# calibrate data 403 / 505 done
# calibrate data 404 / 505 done
# calibrate data 405 / 505 done
# calibrate data 406 / 505 done
# calibrate data 407 / 505 done
# calibrate data 408 / 505 done
# calibrate data 409 / 505 done
# calibrate data 410 / 505 done
# calibrate data 411 / 505 done
# calibrate data 412 / 505 done
# calibrate data 413 / 505 done
# calibrate data 414 / 505 done
# calibrate data 415 / 505 done
# calibrate data 416 / 505 done
# calibrate data 417 / 505 done
# calibrate data 418 / 505 done
# calibrate data 419 / 505 done
# calibrate data 420 / 505 done
# calibrate data 421 / 505 done
# calibrate data 422 / 505 done
# calibrate data 423 / 505 done
# calibrate data 424 / 505 done
# calibrate data 425 / 505 done
# calibrate data 426 / 505 done
# calibrate data 427 / 505 done
# calibrate data 428 / 505 done
# calibrate data 429 / 505 done
# calibrate data 430 / 505 done
# calibrate data 431 / 505 done
# calibrate data 432 / 505 done
# calibrate data 433 / 505 done
# calibrate data 434 / 505 done
# calibrate data 435 / 505 done
# calibrate data 436 / 505 done
# calibrate data 437 / 505 done
# calibrate data 438 / 505 done
# calibrate data 439 / 505 done
# calibrate data 440 / 505 done
# calibrate data 441 / 505 done
# calibrate data 442 / 505 done
# calibrate data 443 / 505 done
# calibrate data 444 / 505 done
# calibrate data 445 / 505 done
# calibrate data 446 / 505 done
# calibrate data 447 / 505 done
# calibrate data 448 / 505 done
# calibrate data 449 / 505 done
# calibrate data 450 / 505 done
# calibrate data 451 / 505 done
# calibrate data 452 / 505 done
# calibrate data 453 / 505 done
# calibrate data 454 / 505 done
# calibrate data 455 / 505 done
# calibrate data 456 / 505 done
# calibrate data 457 / 505 done
# calibrate data 458 / 505 done
# calibrate data 459 / 505 done
# calibrate data 460 / 505 done
# calibrate data 461 / 505 done
# calibrate data 462 / 505 done
# calibrate data 463 / 505 done
# calibrate data 464 / 505 done
# calibrate data 465 / 505 done
# calibrate data 466 / 505 done
# calibrate data 467 / 505 done
# calibrate data 468 / 505 done
# calibrate data 469 / 505 done
# calibrate data 470 / 505 done
# calibrate data 471 / 505 done
# calibrate data 472 / 505 done
# calibrate data 473 / 505 done
# calibrate data 474 / 505 done
# calibrate data 475 / 505 done
# calibrate data 476 / 505 done
# calibrate data 477 / 505 done
# calibrate data 478 / 505 done
# calibrate data 479 / 505 done
# calibrate data 480 / 505 done
# calibrate data 481 / 505 done
# calibrate data 482 / 505 done
# calibrate data 483 / 505 done
# calibrate data 484 / 505 done
# calibrate data 485 / 505 done
# calibrate data 486 / 505 done
# calibrate data 487 / 505 done
# calibrate data 488 / 505 done
# calibrate data 489 / 505 done
# calibrate data 490 / 505 done
# calibrate data 491 / 505 done
# calibrate data 492 / 505 done
# calibrate data 493 / 505 done
# calibrate data 494 / 505 done
# calibrate data 495 / 505 done
# calibrate data 496 / 505 done
# calibrate data 497 / 505 done
# calibrate data 498 / 505 done
# calibrate data 499 / 505 done
# calibrate data 500 / 505 done
# calibrate data 501 / 505 done
# calibrate data 502 / 505 done
# calibrate data 503 / 505 done
# calibrate data 504 / 505 done

# %%
from rag.faiss_manager import FAISSIndexManager

fm = FAISSIndexManager()
fm.is_indice_align()
# Out:
# True

# %%
input_file = '../index_store/conformalpopqa1000/popqa_calibrate_score_1000_1500.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
transformed_data_list = []

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    idx = 0
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data, 'wiki')
        transformed_data_list.append(transformed_data)
        idx += 1
    
    # Write the JSON array to the output file
    outfile.write('{"results": ')
    outfile.write(json.dumps(transformed_data_list, ensure_ascii=False))
    outfile.write('}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Processing line 51
# Processing line 52
# Processing line 53
# Processing line 54
# Processing line 55
# Processing line 56
# Processing line 57
# Processing line 58
# Processing line 59
# Processing line 60
# Processing line 61
# Processing line 62
# Processing line 63
# Processing line 64
# Processing line 65
# Processing line 66
# Processing line 67
# Processing line 68
# Processing line 69
# Processing line 70
# Processing line 71
# Processing line 72
# Processing line 73
# Processing line 74
# Processing line 75
# Processing line 76
# Processing line 77
# Processing line 78
# Processing line 79
# Processing line 80
# Processing line 81
# Processing line 82
# Processing line 83
# Processing line 84
# Processing line 85
# Processing line 86
# Processing line 87
# Processing line 88
# Processing line 89
# Processing line 90
# Processing line 91
# Processing line 92
# Processing line 93
# Processing line 94
# Processing line 95
# Processing line 96
# Processing line 97
# Processing line 98
# Processing line 99
# Processing line 100
# Processing line 101
# Processing line 102
# Processing line 103
# Processing line 104
# Processing line 105
# Processing line 106
# Processing line 107
# Processing line 108
# Processing line 109
# Processing line 110
# Processing line 111
# Processing line 112
# Processing line 113
# Processing line 114
# Processing line 115
# Processing line 116
# Processing line 117
# Processing line 118
# Processing line 119
# Processing line 120
# Processing line 121
# Processing line 122
# Processing line 123
# Processing line 124
# Processing line 125
# Processing line 126
# Processing line 127
# Processing line 128
# Processing line 129
# Processing line 130
# Processing line 131
# Processing line 132
# Processing line 133
# Processing line 134
# Processing line 135
# Processing line 136
# Processing line 137
# Processing line 138
# Processing line 139
# Processing line 140
# Processing line 141
# Processing line 142
# Processing line 143
# Processing line 144
# Processing line 145
# Processing line 146
# Processing line 147
# Processing line 148
# Processing line 149
# Processing line 150
# Processing line 151
# Processing line 152
# Processing line 153
# Processing line 154
# Processing line 155
# Processing line 156
# Processing line 157
# Processing line 158
# Processing line 159
# Processing line 160
# Processing line 161
# Processing line 162
# Processing line 163
# Processing line 164
# Processing line 165
# Processing line 166
# Processing line 167
# Processing line 168
# Processing line 169
# Processing line 170
# Processing line 171
# Processing line 172
# Processing line 173
# Processing line 174
# Processing line 175
# Processing line 176
# Processing line 177
# Processing line 178
# Processing line 179
# Processing line 180
# Processing line 181
# Processing line 182
# Processing line 183
# Processing line 184
# Processing line 185
# Processing line 186
# Processing line 187
# Processing line 188
# Processing line 189
# Processing line 190
# Processing line 191
# Processing line 192
# Processing line 193
# Processing line 194
# Processing line 195
# Processing line 196
# Processing line 197
# Processing line 198
# Processing line 199
# Processing line 200
# Processing line 201
# Processing line 202
# Processing line 203
# Processing line 204
# Processing line 205
# Processing line 206
# Processing line 207
# Processing line 208
# Processing line 209
# Processing line 210
# Processing line 211
# Processing line 212
# Processing line 213
# Processing line 214
# Processing line 215
# Processing line 216
# Processing line 217
# Processing line 218
# Processing line 219
# Processing line 220
# Processing line 221
# Processing line 222
# Processing line 223
# Processing line 224
# Processing line 225
# Processing line 226
# Processing line 227
# Processing line 228
# Processing line 229
# Processing line 230
# Processing line 231
# Processing line 232
# Processing line 233
# Processing line 234
# Processing line 235
# Processing line 236
# Processing line 237
# Processing line 238
# Processing line 239
# Processing line 240
# Processing line 241
# Processing line 242
# Processing line 243
# Processing line 244
# Processing line 245
# Processing line 246
# Processing line 247
# Processing line 248
# Processing line 249
# Processing line 250
# Processing line 251
# Processing line 252
# Processing line 253
# Processing line 254
# Processing line 255
# Processing line 256
# Processing line 257
# Processing line 258
# Processing line 259
# Processing line 260
# Processing line 261
# Processing line 262
# Processing line 263
# Processing line 264
# Processing line 265
# Processing line 266
# Processing line 267
# Processing line 268
# Processing line 269
# Processing line 270
# Processing line 271
# Processing line 272
# Processing line 273
# Processing line 274
# Processing line 275
# Processing line 276
# Processing line 277
# Processing line 278
# Processing line 279
# Processing line 280
# Processing line 281
# Processing line 282
# Processing line 283
# Processing line 284
# Processing line 285
# Processing line 286
# Processing line 287
# Processing line 288
# Processing line 289
# Processing line 290
# Processing line 291
# Processing line 292
# Processing line 293
# Processing line 294
# Processing line 295
# Processing line 296
# Processing line 297
# Processing line 298
# Processing line 299
# Processing line 300
# Processing line 301
# Processing line 302
# Processing line 303
# Processing line 304
# Processing line 305
# Processing line 306
# Processing line 307
# Processing line 308
# Processing line 309
# Processing line 310
# Processing line 311
# Processing line 312
# Processing line 313
# Processing line 314
# Processing line 315
# Processing line 316
# Processing line 317
# Processing line 318
# Processing line 319
# Processing line 320
# Processing line 321
# Processing line 322
# Processing line 323
# Processing line 324
# Processing line 325
# Processing line 326
# Processing line 327
# Processing line 328
# Processing line 329
# Processing line 330
# Processing line 331
# Processing line 332
# Processing line 333
# Processing line 334
# Processing line 335
# Processing line 336
# Processing line 337
# Processing line 338
# Processing line 339
# Processing line 340
# Processing line 341
# Processing line 342
# Processing line 343
# Processing line 344
# Processing line 345
# Processing line 346
# Processing line 347
# Processing line 348
# Processing line 349
# Processing line 350
# Processing line 351
# Processing line 352
# Processing line 353
# Processing line 354
# Processing line 355
# Processing line 356
# Processing line 357
# Processing line 358
# Processing line 359
# Processing line 360
# Processing line 361
# Processing line 362
# Processing line 363
# Processing line 364
# Processing line 365
# Processing line 366
# Processing line 367
# Processing line 368
# Processing line 369
# Processing line 370
# Processing line 371
# Processing line 372
# Processing line 373
# Processing line 374
# Processing line 375
# Processing line 376
# Processing line 377
# Processing line 378
# Processing line 379
# Processing line 380
# Processing line 381
# Processing line 382
# Processing line 383
# Processing line 384
# Processing line 385
# Processing line 386
# Processing line 387
# Processing line 388
# Processing line 389
# Processing line 390
# Processing line 391
# Processing line 392
# Processing line 393
# Processing line 394
# Processing line 395
# Processing line 396
# Processing line 397
# Processing line 398
# Processing line 399
# Processing line 400
# Processing line 401
# Processing line 402
# Processing line 403
# Processing line 404
# Processing line 405
# Processing line 406
# Processing line 407
# Processing line 408
# Processing line 409
# Processing line 410
# Processing line 411
# Processing line 412
# Processing line 413
# Processing line 414
# Processing line 415
# Processing line 416
# Processing line 417
# Processing line 418
# Processing line 419
# Processing line 420
# Processing line 421
# Processing line 422
# Processing line 423
# Processing line 424
# Processing line 425
# Processing line 426
# Processing line 427
# Processing line 428
# Processing line 429
# Processing line 430
# Processing line 431
# Processing line 432
# Processing line 433
# Processing line 434
# Processing line 435
# Processing line 436
# Processing line 437
# Processing line 438
# Processing line 439
# Processing line 440
# Processing line 441
# Processing line 442
# Processing line 443
# Processing line 444
# Processing line 445
# Processing line 446
# Processing line 447
# Processing line 448
# Processing line 449
# Processing line 450
# Processing line 451
# Processing line 452
# Processing line 453
# Processing line 454
# Processing line 455
# Processing line 456
# Processing line 457
# Processing line 458
# Processing line 459
# Processing line 460
# Processing line 461
# Processing line 462
# Processing line 463
# Processing line 464
# Processing line 465
# Processing line 466
# Processing line 467
# Processing line 468
# Processing line 469
# Processing line 470
# Processing line 471
# Processing line 472
# Processing line 473
# Processing line 474
# Processing line 475
# Processing line 476
# Processing line 477
# Processing line 478
# Processing line 479
# Processing line 480
# Processing line 481
# Processing line 482
# Processing line 483
# Processing line 484
# Processing line 485
# Processing line 486
# Processing line 487
# Processing line 488
# Processing line 489
# Processing line 490
# Processing line 491
# Processing line 492
# Processing line 493
# Processing line 494
# Processing line 495
# Processing line 496
# Processing line 497
# Processing line 498
# Processing line 499
# Transformed data written to similarity_annotations.jsonl.

# %%
import os
os.getcwd()
# Out:
# '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/rag'

# %%
import os

from rag.scorer.document_scorer import DocumentScorer

def conformal_pred(prompt, scorer: DocumentScorer, model='gpt-4'):
    threshold = 0.40
    (output, merged_output, all_subclaims, accepted_subclaims)= scorer.say_less(prompt, threshold, model)
    print("Original output: ")
    print(output)
    print("\n\n\n\n\nModified output: ")
    print(merged_output)
    print("\n\n\n\nAccepted sub-claims: ")
    print(accepted_subclaims)
    print("\n\n\n\nAll sub-claims: ")
    print(all_subclaims)

# %%
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer
wiki_embedding = WikitextsDocumentScorer()
prompt = "What is George Rankin's occupation?"
conformal_pred(prompt, wiki_embedding)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Original output:
# George Rankin was both an Australian soldier and a politician. He served in the military, achieving the rank of major general, and was also a member of the House of Representatives and the Senate, representing the Country Party of Australia.
#
#
#
#
#
# Modified output:
# George Rankin's occupation was a soldier.
#
#
#
#
# Accepted sub-claims:
# [('George Rankin was an Australian soldier', 0.45235167679190635)]
#
#
#
#
# All sub-claims:
# [('George Rankin was an Australian soldier', 0.45235167679190635), (' George Rankin was a politician', 0.39989348105192185), (' George Rankin served in the military', 0.399246557366848), (' George Rankin achieved the rank of major general', 0.36969011533260343), (' George Rankin was a member of the House of Representatives', 0.3528019578754902), (' George Rankin was a member of the Senate', 0.3573167937278747), (' George Rankin represented the Country Party of Australia', 0.3946427712440491)]

# %% [markdown]
# ## MedicalQA ##

# %%
data_path = '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs.txt'
wiki_embedding = WikitextsDocumentScorer()
wiki_embedding.create_embedding(data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Associated texts saved to file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# 1/3677 embeddings done
# 2/3677 embeddings done
# 3/3677 embeddings done
# 4/3677 embeddings done
# 5/3677 embeddings done
# 6/3677 embeddings done
# 7/3677 embeddings done
# 8/3677 embeddings done
# 9/3677 embeddings done
# 10/3677 embeddings done
# 11/3677 embeddings done
# 12/3677 embeddings done
# 13/3677 embeddings done
# 14/3677 embeddings done
# 15/3677 embeddings done
# 16/3677 embeddings done
# 17/3677 embeddings done
# 18/3677 embeddings done
# 19/3677 embeddings done
# 20/3677 embeddings done
# 21/3677 embeddings done
# 22/3677 embeddings done
# 23/3677 embeddings done
# 24/3677 embeddings done
# 25/3677 embeddings done
# 26/3677 embeddings done
# 27/3677 embeddings done
# 28/3677 embeddings done
# 29/3677 embeddings done
# 30/3677 embeddings done
# 31/3677 embeddings done
# 32/3677 embeddings done
# 33/3677 embeddings done
# 34/3677 embeddings done
# 35/3677 embeddings done
# 36/3677 embeddings done
# 37/3677 embeddings done
# 38/3677 embeddings done
# 39/3677 embeddings done
# 40/3677 embeddings done
# 41/3677 embeddings done
# 42/3677 embeddings done
# 43/3677 embeddings done
# 44/3677 embeddings done
# 45/3677 embeddings done
# 46/3677 embeddings done
# 47/3677 embeddings done
# 48/3677 embeddings done
# 49/3677 embeddings done
# 50/3677 embeddings done
# 51/3677 embeddings done
# 52/3677 embeddings done
# 53/3677 embeddings done
# 54/3677 embeddings done
# 55/3677 embeddings done
# 56/3677 embeddings done
# 57/3677 embeddings done
# 58/3677 embeddings done
# 59/3677 embeddings done
# 60/3677 embeddings done
# 61/3677 embeddings done
# 62/3677 embeddings done
# 63/3677 embeddings done
# 64/3677 embeddings done
# 65/3677 embeddings done
# 66/3677 embeddings done
# 67/3677 embeddings done
# 68/3677 embeddings done
# 69/3677 embeddings done
# 70/3677 embeddings done
# 71/3677 embeddings done
# 72/3677 embeddings done
# 73/3677 embeddings done
# 74/3677 embeddings done
# 75/3677 embeddings done
# 76/3677 embeddings done
# 77/3677 embeddings done
# 78/3677 embeddings done
# 79/3677 embeddings done
# 80/3677 embeddings done
# 81/3677 embeddings done
# 82/3677 embeddings done
# 83/3677 embeddings done
# 84/3677 embeddings done
# 85/3677 embeddings done
# 86/3677 embeddings done
# 87/3677 embeddings done
# 88/3677 embeddings done
# 89/3677 embeddings done
# 90/3677 embeddings done
# 91/3677 embeddings done
# 92/3677 embeddings done
# 93/3677 embeddings done
# 94/3677 embeddings done
# 95/3677 embeddings done
# 96/3677 embeddings done
# 97/3677 embeddings done
# 98/3677 embeddings done
# 99/3677 embeddings done
# 100/3677 embeddings done
# 101/3677 embeddings done
# 102/3677 embeddings done
# 103/3677 embeddings done
# 104/3677 embeddings done
# 105/3677 embeddings done
# 106/3677 embeddings done
# 107/3677 embeddings done
# 108/3677 embeddings done
# 109/3677 embeddings done
# 110/3677 embeddings done
# 111/3677 embeddings done
# 112/3677 embeddings done
# 113/3677 embeddings done
# 114/3677 embeddings done
# 115/3677 embeddings done
# 116/3677 embeddings done
# 117/3677 embeddings done
# 118/3677 embeddings done
# 119/3677 embeddings done
# 120/3677 embeddings done
# 121/3677 embeddings done
# 122/3677 embeddings done
# 123/3677 embeddings done
# 124/3677 embeddings done
# 125/3677 embeddings done
# 126/3677 embeddings done
# 127/3677 embeddings done
# 128/3677 embeddings done
# 129/3677 embeddings done
# 130/3677 embeddings done
# 131/3677 embeddings done
# 132/3677 embeddings done
# 133/3677 embeddings done
# 134/3677 embeddings done
# 135/3677 embeddings done
# 136/3677 embeddings done
# 137/3677 embeddings done
# 138/3677 embeddings done
# 139/3677 embeddings done
# 140/3677 embeddings done
# 141/3677 embeddings done
# 142/3677 embeddings done
# 143/3677 embeddings done
# 144/3677 embeddings done
# 145/3677 embeddings done
# 146/3677 embeddings done
# 147/3677 embeddings done
# 148/3677 embeddings done
# 149/3677 embeddings done
# 150/3677 embeddings done
# 151/3677 embeddings done
# 152/3677 embeddings done
# 153/3677 embeddings done
# 154/3677 embeddings done
# 155/3677 embeddings done
# 156/3677 embeddings done
# 157/3677 embeddings done
# 158/3677 embeddings done
# 159/3677 embeddings done
# 160/3677 embeddings done
# 161/3677 embeddings done
# 162/3677 embeddings done
# 163/3677 embeddings done
# 164/3677 embeddings done
# 165/3677 embeddings done
# 166/3677 embeddings done
# 167/3677 embeddings done
# 168/3677 embeddings done
# 169/3677 embeddings done
# 170/3677 embeddings done
# 171/3677 embeddings done
# 172/3677 embeddings done
# 173/3677 embeddings done
# 174/3677 embeddings done
# 175/3677 embeddings done
# 176/3677 embeddings done
# 177/3677 embeddings done
# 178/3677 embeddings done
# 179/3677 embeddings done
# 180/3677 embeddings done
# 181/3677 embeddings done
# 182/3677 embeddings done
# 183/3677 embeddings done
# 184/3677 embeddings done
# 185/3677 embeddings done
# 186/3677 embeddings done
# 187/3677 embeddings done
# 188/3677 embeddings done
# 189/3677 embeddings done
# 190/3677 embeddings done
# 191/3677 embeddings done
# 192/3677 embeddings done
# 193/3677 embeddings done
# 194/3677 embeddings done
# 195/3677 embeddings done
# 196/3677 embeddings done
# 197/3677 embeddings done
# 198/3677 embeddings done
# 199/3677 embeddings done
# 200/3677 embeddings done
# 201/3677 embeddings done
# 202/3677 embeddings done
# 203/3677 embeddings done
# 204/3677 embeddings done
# 205/3677 embeddings done
# 206/3677 embeddings done
# 207/3677 embeddings done
# 208/3677 embeddings done
# 209/3677 embeddings done
# 210/3677 embeddings done
# 211/3677 embeddings done
# 212/3677 embeddings done
# 213/3677 embeddings done
# 214/3677 embeddings done
# 215/3677 embeddings done
# 216/3677 embeddings done
# 217/3677 embeddings done
# 218/3677 embeddings done
# 219/3677 embeddings done
# 220/3677 embeddings done
# 221/3677 embeddings done
# 222/3677 embeddings done
# 223/3677 embeddings done
# 224/3677 embeddings done
# 225/3677 embeddings done
# 226/3677 embeddings done
# 227/3677 embeddings done
# 228/3677 embeddings done
# 229/3677 embeddings done
# 230/3677 embeddings done
# 231/3677 embeddings done
# 232/3677 embeddings done
# 233/3677 embeddings done
# 234/3677 embeddings done
# 235/3677 embeddings done
# 236/3677 embeddings done
# 237/3677 embeddings done
# 238/3677 embeddings done
# 239/3677 embeddings done
# 240/3677 embeddings done
# 241/3677 embeddings done
# 242/3677 embeddings done
# 243/3677 embeddings done
# 244/3677 embeddings done
# 245/3677 embeddings done
# 246/3677 embeddings done
# 247/3677 embeddings done
# 248/3677 embeddings done
# 249/3677 embeddings done
# 250/3677 embeddings done
# 251/3677 embeddings done
# 252/3677 embeddings done
# 253/3677 embeddings done
# 254/3677 embeddings done
# 255/3677 embeddings done
# 256/3677 embeddings done
# 257/3677 embeddings done
# 258/3677 embeddings done
# 259/3677 embeddings done
# 260/3677 embeddings done
# 261/3677 embeddings done
# 262/3677 embeddings done
# 263/3677 embeddings done
# 264/3677 embeddings done
# 265/3677 embeddings done
# 266/3677 embeddings done
# 267/3677 embeddings done
# 268/3677 embeddings done
# 269/3677 embeddings done
# 270/3677 embeddings done
# 271/3677 embeddings done
# 272/3677 embeddings done
# 273/3677 embeddings done
# 274/3677 embeddings done
# 275/3677 embeddings done
# 276/3677 embeddings done
# 277/3677 embeddings done
# 278/3677 embeddings done
# 279/3677 embeddings done
# 280/3677 embeddings done
# 281/3677 embeddings done
# 282/3677 embeddings done
# 283/3677 embeddings done
# 284/3677 embeddings done
# 285/3677 embeddings done
# 286/3677 embeddings done
# 287/3677 embeddings done
# 288/3677 embeddings done
# 289/3677 embeddings done
# 290/3677 embeddings done
# 291/3677 embeddings done
# 292/3677 embeddings done
# 293/3677 embeddings done
# 294/3677 embeddings done
# 295/3677 embeddings done
# 296/3677 embeddings done
# 297/3677 embeddings done
# 298/3677 embeddings done
# 299/3677 embeddings done
# 300/3677 embeddings done
# 301/3677 embeddings done
# 302/3677 embeddings done
# 303/3677 embeddings done
# 304/3677 embeddings done
# 305/3677 embeddings done
# 306/3677 embeddings done
# 307/3677 embeddings done
# 308/3677 embeddings done
# 309/3677 embeddings done
# 310/3677 embeddings done
# 311/3677 embeddings done
# 312/3677 embeddings done
# 313/3677 embeddings done
# 314/3677 embeddings done
# 315/3677 embeddings done
# 316/3677 embeddings done
# 317/3677 embeddings done
# 318/3677 embeddings done
# 319/3677 embeddings done
# 320/3677 embeddings done
# 321/3677 embeddings done
# 322/3677 embeddings done
# 323/3677 embeddings done
# 324/3677 embeddings done
# 325/3677 embeddings done
# 326/3677 embeddings done
# 327/3677 embeddings done
# 328/3677 embeddings done
# 329/3677 embeddings done
# 330/3677 embeddings done
# 331/3677 embeddings done
# 332/3677 embeddings done
# 333/3677 embeddings done
# 334/3677 embeddings done
# 335/3677 embeddings done
# 336/3677 embeddings done
# 337/3677 embeddings done
# 338/3677 embeddings done
# 339/3677 embeddings done
# 340/3677 embeddings done
# 341/3677 embeddings done
# 342/3677 embeddings done
# 343/3677 embeddings done
# 344/3677 embeddings done
# 345/3677 embeddings done
# 346/3677 embeddings done
# 347/3677 embeddings done
# 348/3677 embeddings done
# 349/3677 embeddings done
# 350/3677 embeddings done
# 351/3677 embeddings done
# 352/3677 embeddings done
# 353/3677 embeddings done
# 354/3677 embeddings done
# 355/3677 embeddings done
# 356/3677 embeddings done
# 357/3677 embeddings done
# 358/3677 embeddings done
# 359/3677 embeddings done
# 360/3677 embeddings done
# 361/3677 embeddings done
# 362/3677 embeddings done
# 363/3677 embeddings done
# 364/3677 embeddings done
# 365/3677 embeddings done
# 366/3677 embeddings done
# 367/3677 embeddings done
# 368/3677 embeddings done
# 369/3677 embeddings done
# 370/3677 embeddings done
# 371/3677 embeddings done
# 372/3677 embeddings done
# 373/3677 embeddings done
# 374/3677 embeddings done
# 375/3677 embeddings done
# 376/3677 embeddings done
# 377/3677 embeddings done
# 378/3677 embeddings done
# 379/3677 embeddings done
# 380/3677 embeddings done
# 381/3677 embeddings done
# 382/3677 embeddings done
# 383/3677 embeddings done
# 384/3677 embeddings done
# 385/3677 embeddings done
# 386/3677 embeddings done
# 387/3677 embeddings done
# 388/3677 embeddings done
# 389/3677 embeddings done
# 390/3677 embeddings done
# 391/3677 embeddings done
# 392/3677 embeddings done
# 393/3677 embeddings done
# 394/3677 embeddings done
# 395/3677 embeddings done
# 396/3677 embeddings done
# 397/3677 embeddings done
# 398/3677 embeddings done
# 399/3677 embeddings done
# 400/3677 embeddings done
# 401/3677 embeddings done
# 402/3677 embeddings done
# 403/3677 embeddings done
# 404/3677 embeddings done
# 405/3677 embeddings done
# 406/3677 embeddings done
# 407/3677 embeddings done
# 408/3677 embeddings done
# 409/3677 embeddings done
# 410/3677 embeddings done
# 411/3677 embeddings done
# 412/3677 embeddings done
# 413/3677 embeddings done
# 414/3677 embeddings done
# 415/3677 embeddings done
# 416/3677 embeddings done
# 417/3677 embeddings done
# 418/3677 embeddings done
# 419/3677 embeddings done
# 420/3677 embeddings done
# 421/3677 embeddings done
# 422/3677 embeddings done
# 423/3677 embeddings done
# 424/3677 embeddings done
# 425/3677 embeddings done
# 426/3677 embeddings done
# 427/3677 embeddings done
# 428/3677 embeddings done
# 429/3677 embeddings done
# 430/3677 embeddings done
# 431/3677 embeddings done
# 432/3677 embeddings done
# 433/3677 embeddings done
# 434/3677 embeddings done
# 435/3677 embeddings done
# 436/3677 embeddings done
# 437/3677 embeddings done
# 438/3677 embeddings done
# 439/3677 embeddings done
# 440/3677 embeddings done
# 441/3677 embeddings done
# 442/3677 embeddings done
# 443/3677 embeddings done
# 444/3677 embeddings done
# 445/3677 embeddings done
# 446/3677 embeddings done
# 447/3677 embeddings done
# 448/3677 embeddings done
# 449/3677 embeddings done
# 450/3677 embeddings done
# 451/3677 embeddings done
# 452/3677 embeddings done
# 453/3677 embeddings done
# 454/3677 embeddings done
# 455/3677 embeddings done
# 456/3677 embeddings done
# 457/3677 embeddings done
# 458/3677 embeddings done
# 459/3677 embeddings done
# 460/3677 embeddings done
# 461/3677 embeddings done
# 462/3677 embeddings done
# 463/3677 embeddings done
# 464/3677 embeddings done
# 465/3677 embeddings done
# 466/3677 embeddings done
# 467/3677 embeddings done
# 468/3677 embeddings done
# 469/3677 embeddings done
# 470/3677 embeddings done
# 471/3677 embeddings done
# 472/3677 embeddings done
# 473/3677 embeddings done
# 474/3677 embeddings done
# 475/3677 embeddings done
# 476/3677 embeddings done
# 477/3677 embeddings done
# 478/3677 embeddings done
# 479/3677 embeddings done
# 480/3677 embeddings done
# 481/3677 embeddings done
# 482/3677 embeddings done
# 483/3677 embeddings done
# 484/3677 embeddings done
# 485/3677 embeddings done
# 486/3677 embeddings done
# 487/3677 embeddings done
# 488/3677 embeddings done
# 489/3677 embeddings done
# 490/3677 embeddings done
# 491/3677 embeddings done
# 492/3677 embeddings done
# 493/3677 embeddings done
# 494/3677 embeddings done
# 495/3677 embeddings done
# 496/3677 embeddings done
# 497/3677 embeddings done
# 498/3677 embeddings done
# 499/3677 embeddings done
# 500/3677 embeddings done
# 501/3677 embeddings done
# 502/3677 embeddings done
# 503/3677 embeddings done
# 504/3677 embeddings done
# 505/3677 embeddings done
# 506/3677 embeddings done
# 507/3677 embeddings done
# 508/3677 embeddings done
# 509/3677 embeddings done
# 510/3677 embeddings done
# 511/3677 embeddings done
# 512/3677 embeddings done
# 513/3677 embeddings done
# 514/3677 embeddings done
# 515/3677 embeddings done
# 516/3677 embeddings done
# 517/3677 embeddings done
# 518/3677 embeddings done
# 519/3677 embeddings done
# 520/3677 embeddings done
# 521/3677 embeddings done
# 522/3677 embeddings done
# 523/3677 embeddings done
# 524/3677 embeddings done
# 525/3677 embeddings done
# 526/3677 embeddings done
# 527/3677 embeddings done
# 528/3677 embeddings done
# 529/3677 embeddings done
# 530/3677 embeddings done
# 531/3677 embeddings done
# 532/3677 embeddings done
# 533/3677 embeddings done
# 534/3677 embeddings done
# 535/3677 embeddings done
# 536/3677 embeddings done
# 537/3677 embeddings done
# 538/3677 embeddings done
# 539/3677 embeddings done
# 540/3677 embeddings done
# 541/3677 embeddings done
# 542/3677 embeddings done
# 543/3677 embeddings done
# 544/3677 embeddings done
# 545/3677 embeddings done
# 546/3677 embeddings done
# 547/3677 embeddings done
# 548/3677 embeddings done
# 549/3677 embeddings done
# 550/3677 embeddings done
# 551/3677 embeddings done
# 552/3677 embeddings done
# 553/3677 embeddings done
# 554/3677 embeddings done
# 555/3677 embeddings done
# 556/3677 embeddings done
# 557/3677 embeddings done
# 558/3677 embeddings done
# 559/3677 embeddings done
# 560/3677 embeddings done
# 561/3677 embeddings done
# 562/3677 embeddings done
# 563/3677 embeddings done
# 564/3677 embeddings done
# 565/3677 embeddings done
# 566/3677 embeddings done
# 567/3677 embeddings done
# 568/3677 embeddings done
# 569/3677 embeddings done
# 570/3677 embeddings done
# 571/3677 embeddings done
# 572/3677 embeddings done
# 573/3677 embeddings done
# 574/3677 embeddings done
# 575/3677 embeddings done
# 576/3677 embeddings done
# 577/3677 embeddings done
# 578/3677 embeddings done
# 579/3677 embeddings done
# 580/3677 embeddings done
# 581/3677 embeddings done
# 582/3677 embeddings done
# 583/3677 embeddings done
# 584/3677 embeddings done
# 585/3677 embeddings done
# 586/3677 embeddings done
# 587/3677 embeddings done
# 588/3677 embeddings done
# 589/3677 embeddings done
# 590/3677 embeddings done
# 591/3677 embeddings done
# 592/3677 embeddings done
# 593/3677 embeddings done
# 594/3677 embeddings done
# 595/3677 embeddings done
# 596/3677 embeddings done
# 597/3677 embeddings done
# 598/3677 embeddings done
# 599/3677 embeddings done
# 600/3677 embeddings done
# 601/3677 embeddings done
# 602/3677 embeddings done
# 603/3677 embeddings done
# 604/3677 embeddings done
# 605/3677 embeddings done
# 606/3677 embeddings done
# 607/3677 embeddings done
# 608/3677 embeddings done
# 609/3677 embeddings done
# 610/3677 embeddings done
# 611/3677 embeddings done
# 612/3677 embeddings done
# 613/3677 embeddings done
# 614/3677 embeddings done
# 615/3677 embeddings done
# 616/3677 embeddings done
# 617/3677 embeddings done
# 618/3677 embeddings done
# 619/3677 embeddings done
# 620/3677 embeddings done
# 621/3677 embeddings done
# 622/3677 embeddings done
# 623/3677 embeddings done
# 624/3677 embeddings done
# 625/3677 embeddings done
# 626/3677 embeddings done
# 627/3677 embeddings done
# 628/3677 embeddings done
# 629/3677 embeddings done
# 630/3677 embeddings done
# 631/3677 embeddings done
# 632/3677 embeddings done
# 633/3677 embeddings done
# 634/3677 embeddings done
# 635/3677 embeddings done
# 636/3677 embeddings done
# 637/3677 embeddings done
# 638/3677 embeddings done
# 639/3677 embeddings done
# 640/3677 embeddings done
# 641/3677 embeddings done
# 642/3677 embeddings done
# 643/3677 embeddings done
# 644/3677 embeddings done
# 645/3677 embeddings done
# 646/3677 embeddings done
# 647/3677 embeddings done
# 648/3677 embeddings done
# 649/3677 embeddings done
# 650/3677 embeddings done
# 651/3677 embeddings done
# 652/3677 embeddings done
# 653/3677 embeddings done
# 654/3677 embeddings done
# 655/3677 embeddings done
# 656/3677 embeddings done
# 657/3677 embeddings done
# 658/3677 embeddings done
# 659/3677 embeddings done
# 660/3677 embeddings done
# 661/3677 embeddings done
# 662/3677 embeddings done
# 663/3677 embeddings done
# 664/3677 embeddings done
# 665/3677 embeddings done
# 666/3677 embeddings done
# 667/3677 embeddings done
# 668/3677 embeddings done
# 669/3677 embeddings done
# 670/3677 embeddings done
# 671/3677 embeddings done
# 672/3677 embeddings done
# 673/3677 embeddings done
# 674/3677 embeddings done
# 675/3677 embeddings done
# 676/3677 embeddings done
# 677/3677 embeddings done
# 678/3677 embeddings done
# 679/3677 embeddings done
# 680/3677 embeddings done
# 681/3677 embeddings done
# 682/3677 embeddings done
# 683/3677 embeddings done
# 684/3677 embeddings done
# 685/3677 embeddings done
# 686/3677 embeddings done
# 687/3677 embeddings done
# 688/3677 embeddings done
# 689/3677 embeddings done
# 690/3677 embeddings done
# 691/3677 embeddings done
# 692/3677 embeddings done
# 693/3677 embeddings done
# 694/3677 embeddings done
# 695/3677 embeddings done
# 696/3677 embeddings done
# 697/3677 embeddings done
# 698/3677 embeddings done
# 699/3677 embeddings done
# 700/3677 embeddings done
# 701/3677 embeddings done
# 702/3677 embeddings done
# 703/3677 embeddings done
# 704/3677 embeddings done
# 705/3677 embeddings done
# 706/3677 embeddings done
# 707/3677 embeddings done
# 708/3677 embeddings done
# 709/3677 embeddings done
# 710/3677 embeddings done
# 711/3677 embeddings done
# 712/3677 embeddings done
# 713/3677 embeddings done
# 714/3677 embeddings done
# 715/3677 embeddings done
# 716/3677 embeddings done
# 717/3677 embeddings done
# 718/3677 embeddings done
# 719/3677 embeddings done
# 720/3677 embeddings done
# 721/3677 embeddings done
# 722/3677 embeddings done
# 723/3677 embeddings done
# 724/3677 embeddings done
# 725/3677 embeddings done
# 726/3677 embeddings done
# 727/3677 embeddings done
# 728/3677 embeddings done
# 729/3677 embeddings done
# 730/3677 embeddings done
# 731/3677 embeddings done
# 732/3677 embeddings done
# 733/3677 embeddings done
# 734/3677 embeddings done
# 735/3677 embeddings done
# 736/3677 embeddings done
# 737/3677 embeddings done
# 738/3677 embeddings done
# 739/3677 embeddings done
# 740/3677 embeddings done
# 741/3677 embeddings done
# 742/3677 embeddings done
# 743/3677 embeddings done
# 744/3677 embeddings done
# 745/3677 embeddings done
# 746/3677 embeddings done
# 747/3677 embeddings done
# 748/3677 embeddings done
# 749/3677 embeddings done
# 750/3677 embeddings done
# 751/3677 embeddings done
# 752/3677 embeddings done
# 753/3677 embeddings done
# 754/3677 embeddings done
# 755/3677 embeddings done
# 756/3677 embeddings done
# 757/3677 embeddings done
# 758/3677 embeddings done
# 759/3677 embeddings done
# 760/3677 embeddings done
# 761/3677 embeddings done
# 762/3677 embeddings done
# 763/3677 embeddings done
# 764/3677 embeddings done
# 765/3677 embeddings done
# 766/3677 embeddings done
# 767/3677 embeddings done
# 768/3677 embeddings done
# 769/3677 embeddings done
# 770/3677 embeddings done
# 771/3677 embeddings done
# 772/3677 embeddings done
# 773/3677 embeddings done
# 774/3677 embeddings done
# 775/3677 embeddings done
# 776/3677 embeddings done
# 777/3677 embeddings done
# 778/3677 embeddings done
# 779/3677 embeddings done
# 780/3677 embeddings done
# 781/3677 embeddings done
# 782/3677 embeddings done
# 783/3677 embeddings done
# 784/3677 embeddings done
# 785/3677 embeddings done
# 786/3677 embeddings done
# 787/3677 embeddings done
# 788/3677 embeddings done
# 789/3677 embeddings done
# 790/3677 embeddings done
# 791/3677 embeddings done
# 792/3677 embeddings done
# 793/3677 embeddings done
# 794/3677 embeddings done
# 795/3677 embeddings done
# 796/3677 embeddings done
# 797/3677 embeddings done
# 798/3677 embeddings done
# 799/3677 embeddings done
# 800/3677 embeddings done
# 801/3677 embeddings done
# 802/3677 embeddings done
# 803/3677 embeddings done
# 804/3677 embeddings done
# 805/3677 embeddings done
# 806/3677 embeddings done
# 807/3677 embeddings done
# 808/3677 embeddings done
# 809/3677 embeddings done
# 810/3677 embeddings done
# 811/3677 embeddings done
# 812/3677 embeddings done
# 813/3677 embeddings done
# 814/3677 embeddings done
# 815/3677 embeddings done
# 816/3677 embeddings done
# 817/3677 embeddings done
# 818/3677 embeddings done
# 819/3677 embeddings done
# 820/3677 embeddings done
# 821/3677 embeddings done
# 822/3677 embeddings done
# 823/3677 embeddings done
# 824/3677 embeddings done
# 825/3677 embeddings done
# 826/3677 embeddings done
# 827/3677 embeddings done
# 828/3677 embeddings done
# 829/3677 embeddings done
# 830/3677 embeddings done
# 831/3677 embeddings done
# 832/3677 embeddings done
# 833/3677 embeddings done
# 834/3677 embeddings done
# 835/3677 embeddings done
# 836/3677 embeddings done
# 837/3677 embeddings done
# 838/3677 embeddings done
# 839/3677 embeddings done
# 840/3677 embeddings done
# 841/3677 embeddings done
# 842/3677 embeddings done
# 843/3677 embeddings done
# 844/3677 embeddings done
# 845/3677 embeddings done
# 846/3677 embeddings done
# 847/3677 embeddings done
# 848/3677 embeddings done
# 849/3677 embeddings done
# 850/3677 embeddings done
# 851/3677 embeddings done
# 852/3677 embeddings done
# 853/3677 embeddings done
# 854/3677 embeddings done
# 855/3677 embeddings done
# 856/3677 embeddings done
# 857/3677 embeddings done
# 858/3677 embeddings done
# 859/3677 embeddings done
# 860/3677 embeddings done
# 861/3677 embeddings done
# 862/3677 embeddings done
# 863/3677 embeddings done
# 864/3677 embeddings done
# 865/3677 embeddings done
# 866/3677 embeddings done
# 867/3677 embeddings done
# 868/3677 embeddings done
# 869/3677 embeddings done
# 870/3677 embeddings done
# 871/3677 embeddings done
# 872/3677 embeddings done
# 873/3677 embeddings done
# 874/3677 embeddings done
# 875/3677 embeddings done
# 876/3677 embeddings done
# 877/3677 embeddings done
# 878/3677 embeddings done
# 879/3677 embeddings done
# 880/3677 embeddings done
# 881/3677 embeddings done
# 882/3677 embeddings done
# 883/3677 embeddings done
# 884/3677 embeddings done
# 885/3677 embeddings done
# 886/3677 embeddings done
# 887/3677 embeddings done
# 888/3677 embeddings done
# 889/3677 embeddings done
# 890/3677 embeddings done
# 891/3677 embeddings done
# 892/3677 embeddings done
# 893/3677 embeddings done
# 894/3677 embeddings done
# 895/3677 embeddings done
# 896/3677 embeddings done
# 897/3677 embeddings done
# 898/3677 embeddings done
# 899/3677 embeddings done
# 900/3677 embeddings done
# 901/3677 embeddings done
# 902/3677 embeddings done
# 903/3677 embeddings done
# 904/3677 embeddings done
# 905/3677 embeddings done
# 906/3677 embeddings done
# 907/3677 embeddings done
# 908/3677 embeddings done
# 909/3677 embeddings done
# 910/3677 embeddings done
# 911/3677 embeddings done
# 912/3677 embeddings done
# 913/3677 embeddings done
# 914/3677 embeddings done
# 915/3677 embeddings done
# 916/3677 embeddings done
# 917/3677 embeddings done
# 918/3677 embeddings done
# 919/3677 embeddings done
# 920/3677 embeddings done
# 921/3677 embeddings done
# 922/3677 embeddings done
# 923/3677 embeddings done
# 924/3677 embeddings done
# 925/3677 embeddings done
# 926/3677 embeddings done
# 927/3677 embeddings done
# 928/3677 embeddings done
# 929/3677 embeddings done
# 930/3677 embeddings done
# 931/3677 embeddings done
# 932/3677 embeddings done
# 933/3677 embeddings done
# 934/3677 embeddings done
# 935/3677 embeddings done
# 936/3677 embeddings done
# 937/3677 embeddings done
# 938/3677 embeddings done
# 939/3677 embeddings done
# 940/3677 embeddings done
# 941/3677 embeddings done
# 942/3677 embeddings done
# 943/3677 embeddings done
# 944/3677 embeddings done
# 945/3677 embeddings done
# 946/3677 embeddings done
# 947/3677 embeddings done
# 948/3677 embeddings done
# 949/3677 embeddings done
# 950/3677 embeddings done
# 951/3677 embeddings done
# 952/3677 embeddings done
# 953/3677 embeddings done
# 954/3677 embeddings done
# 955/3677 embeddings done
# 956/3677 embeddings done
# 957/3677 embeddings done
# 958/3677 embeddings done
# 959/3677 embeddings done
# 960/3677 embeddings done
# 961/3677 embeddings done
# 962/3677 embeddings done
# 963/3677 embeddings done
# 964/3677 embeddings done
# 965/3677 embeddings done
# 966/3677 embeddings done
# 967/3677 embeddings done
# 968/3677 embeddings done
# 969/3677 embeddings done
# 970/3677 embeddings done
# 971/3677 embeddings done
# 972/3677 embeddings done
# 973/3677 embeddings done
# 974/3677 embeddings done
# 975/3677 embeddings done
# 976/3677 embeddings done
# 977/3677 embeddings done
# 978/3677 embeddings done
# 979/3677 embeddings done
# 980/3677 embeddings done
# 981/3677 embeddings done
# 982/3677 embeddings done
# 983/3677 embeddings done
# 984/3677 embeddings done
# 985/3677 embeddings done
# 986/3677 embeddings done
# 987/3677 embeddings done
# 988/3677 embeddings done
# 989/3677 embeddings done
# 990/3677 embeddings done
# 991/3677 embeddings done
# 992/3677 embeddings done
# 993/3677 embeddings done
# 994/3677 embeddings done
# 995/3677 embeddings done
# 996/3677 embeddings done
# 997/3677 embeddings done
# 998/3677 embeddings done
# 999/3677 embeddings done
# 1000/3677 embeddings done
# 1001/3677 embeddings done
# 1002/3677 embeddings done
# 1003/3677 embeddings done
# 1004/3677 embeddings done
# 1005/3677 embeddings done
# 1006/3677 embeddings done
# 1007/3677 embeddings done
# 1008/3677 embeddings done
# 1009/3677 embeddings done
# 1010/3677 embeddings done
# 1011/3677 embeddings done
# 1012/3677 embeddings done
# 1013/3677 embeddings done
# 1014/3677 embeddings done
# 1015/3677 embeddings done
# 1016/3677 embeddings done
# 1017/3677 embeddings done
# 1018/3677 embeddings done
# 1019/3677 embeddings done
# 1020/3677 embeddings done
# 1021/3677 embeddings done
# 1022/3677 embeddings done
# 1023/3677 embeddings done
# 1024/3677 embeddings done
# 1025/3677 embeddings done
# 1026/3677 embeddings done
# 1027/3677 embeddings done
# 1028/3677 embeddings done
# 1029/3677 embeddings done
# 1030/3677 embeddings done
# 1031/3677 embeddings done
# 1032/3677 embeddings done
# 1033/3677 embeddings done
# 1034/3677 embeddings done
# 1035/3677 embeddings done
# 1036/3677 embeddings done
# 1037/3677 embeddings done
# 1038/3677 embeddings done
# 1039/3677 embeddings done
# 1040/3677 embeddings done
# 1041/3677 embeddings done
# 1042/3677 embeddings done
# 1043/3677 embeddings done
# 1044/3677 embeddings done
# 1045/3677 embeddings done
# 1046/3677 embeddings done
# 1047/3677 embeddings done
# 1048/3677 embeddings done
# 1049/3677 embeddings done
# 1050/3677 embeddings done
# 1051/3677 embeddings done
# 1052/3677 embeddings done
# 1053/3677 embeddings done
# 1054/3677 embeddings done
# 1055/3677 embeddings done
# 1056/3677 embeddings done
# 1057/3677 embeddings done
# 1058/3677 embeddings done
# 1059/3677 embeddings done
# 1060/3677 embeddings done
# 1061/3677 embeddings done
# 1062/3677 embeddings done
# 1063/3677 embeddings done
# 1064/3677 embeddings done
# 1065/3677 embeddings done
# 1066/3677 embeddings done
# 1067/3677 embeddings done
# 1068/3677 embeddings done
# 1069/3677 embeddings done
# 1070/3677 embeddings done
# 1071/3677 embeddings done
# 1072/3677 embeddings done
# 1073/3677 embeddings done
# 1074/3677 embeddings done
# 1075/3677 embeddings done
# 1076/3677 embeddings done
# 1077/3677 embeddings done
# 1078/3677 embeddings done
# 1079/3677 embeddings done
# 1080/3677 embeddings done
# 1081/3677 embeddings done
# 1082/3677 embeddings done
# 1083/3677 embeddings done
# 1084/3677 embeddings done
# 1085/3677 embeddings done
# 1086/3677 embeddings done
# 1087/3677 embeddings done
# 1088/3677 embeddings done
# 1089/3677 embeddings done
# 1090/3677 embeddings done
# 1091/3677 embeddings done
# 1092/3677 embeddings done
# 1093/3677 embeddings done
# 1094/3677 embeddings done
# 1095/3677 embeddings done
# 1096/3677 embeddings done
# 1097/3677 embeddings done
# 1098/3677 embeddings done
# 1099/3677 embeddings done
# 1100/3677 embeddings done
# 1101/3677 embeddings done
# 1102/3677 embeddings done
# 1103/3677 embeddings done
# 1104/3677 embeddings done
# 1105/3677 embeddings done
# 1106/3677 embeddings done
# 1107/3677 embeddings done
# 1108/3677 embeddings done
# 1109/3677 embeddings done
# 1110/3677 embeddings done
# 1111/3677 embeddings done
# 1112/3677 embeddings done
# 1113/3677 embeddings done
# 1114/3677 embeddings done
# 1115/3677 embeddings done
# 1116/3677 embeddings done
# 1117/3677 embeddings done
# 1118/3677 embeddings done
# 1119/3677 embeddings done
# 1120/3677 embeddings done
# 1121/3677 embeddings done
# 1122/3677 embeddings done
# 1123/3677 embeddings done
# 1124/3677 embeddings done
# 1125/3677 embeddings done
# 1126/3677 embeddings done
# 1127/3677 embeddings done
# 1128/3677 embeddings done
# 1129/3677 embeddings done
# 1130/3677 embeddings done
# 1131/3677 embeddings done
# 1132/3677 embeddings done
# 1133/3677 embeddings done
# 1134/3677 embeddings done
# 1135/3677 embeddings done
# 1136/3677 embeddings done
# 1137/3677 embeddings done
# 1138/3677 embeddings done
# 1139/3677 embeddings done
# 1140/3677 embeddings done
# 1141/3677 embeddings done
# 1142/3677 embeddings done
# 1143/3677 embeddings done
# 1144/3677 embeddings done
# 1145/3677 embeddings done
# 1146/3677 embeddings done
# 1147/3677 embeddings done
# 1148/3677 embeddings done
# 1149/3677 embeddings done
# 1150/3677 embeddings done
# 1151/3677 embeddings done
# 1152/3677 embeddings done
# 1153/3677 embeddings done
# 1154/3677 embeddings done
# 1155/3677 embeddings done
# 1156/3677 embeddings done
# 1157/3677 embeddings done
# 1158/3677 embeddings done
# 1159/3677 embeddings done
# 1160/3677 embeddings done
# 1161/3677 embeddings done
# 1162/3677 embeddings done
# 1163/3677 embeddings done
# 1164/3677 embeddings done
# 1165/3677 embeddings done
# 1166/3677 embeddings done
# 1167/3677 embeddings done
# 1168/3677 embeddings done
# 1169/3677 embeddings done
# 1170/3677 embeddings done
# 1171/3677 embeddings done
# 1172/3677 embeddings done
# 1173/3677 embeddings done
# 1174/3677 embeddings done
# 1175/3677 embeddings done
# 1176/3677 embeddings done
# 1177/3677 embeddings done
# 1178/3677 embeddings done
# 1179/3677 embeddings done
# 1180/3677 embeddings done
# 1181/3677 embeddings done
# 1182/3677 embeddings done
# 1183/3677 embeddings done
# 1184/3677 embeddings done
# 1185/3677 embeddings done
# 1186/3677 embeddings done
# 1187/3677 embeddings done
# 1188/3677 embeddings done
# 1189/3677 embeddings done
# 1190/3677 embeddings done
# 1191/3677 embeddings done
# 1192/3677 embeddings done
# 1193/3677 embeddings done
# 1194/3677 embeddings done
# 1195/3677 embeddings done
# 1196/3677 embeddings done
# 1197/3677 embeddings done
# 1198/3677 embeddings done
# 1199/3677 embeddings done
# 1200/3677 embeddings done
# 1201/3677 embeddings done
# 1202/3677 embeddings done
# 1203/3677 embeddings done
# 1204/3677 embeddings done
# 1205/3677 embeddings done
# 1206/3677 embeddings done
# 1207/3677 embeddings done
# 1208/3677 embeddings done
# 1209/3677 embeddings done
# 1210/3677 embeddings done
# 1211/3677 embeddings done
# 1212/3677 embeddings done
# 1213/3677 embeddings done
# 1214/3677 embeddings done
# 1215/3677 embeddings done
# 1216/3677 embeddings done
# 1217/3677 embeddings done
# 1218/3677 embeddings done
# 1219/3677 embeddings done
# 1220/3677 embeddings done
# 1221/3677 embeddings done
# 1222/3677 embeddings done
# 1223/3677 embeddings done
# 1224/3677 embeddings done
# 1225/3677 embeddings done
# 1226/3677 embeddings done
# 1227/3677 embeddings done
# 1228/3677 embeddings done
# 1229/3677 embeddings done
# 1230/3677 embeddings done
# 1231/3677 embeddings done
# 1232/3677 embeddings done
# 1233/3677 embeddings done
# 1234/3677 embeddings done
# 1235/3677 embeddings done
# 1236/3677 embeddings done
# 1237/3677 embeddings done
# 1238/3677 embeddings done
# 1239/3677 embeddings done
# 1240/3677 embeddings done
# 1241/3677 embeddings done
# 1242/3677 embeddings done
# 1243/3677 embeddings done
# 1244/3677 embeddings done
# 1245/3677 embeddings done
# 1246/3677 embeddings done
# 1247/3677 embeddings done
# 1248/3677 embeddings done
# 1249/3677 embeddings done
# 1250/3677 embeddings done
# 1251/3677 embeddings done
# 1252/3677 embeddings done
# 1253/3677 embeddings done
# 1254/3677 embeddings done
# 1255/3677 embeddings done
# 1256/3677 embeddings done
# 1257/3677 embeddings done
# 1258/3677 embeddings done
# 1259/3677 embeddings done
# 1260/3677 embeddings done
# 1261/3677 embeddings done
# 1262/3677 embeddings done
# 1263/3677 embeddings done
# 1264/3677 embeddings done
# 1265/3677 embeddings done
# 1266/3677 embeddings done
# 1267/3677 embeddings done
# 1268/3677 embeddings done
# 1269/3677 embeddings done
# 1270/3677 embeddings done
# 1271/3677 embeddings done
# 1272/3677 embeddings done
# 1273/3677 embeddings done
# 1274/3677 embeddings done
# 1275/3677 embeddings done
# 1276/3677 embeddings done
# 1277/3677 embeddings done
# 1278/3677 embeddings done
# 1279/3677 embeddings done
# 1280/3677 embeddings done
# 1281/3677 embeddings done
# 1282/3677 embeddings done
# 1283/3677 embeddings done
# 1284/3677 embeddings done
# 1285/3677 embeddings done
# 1286/3677 embeddings done
# 1287/3677 embeddings done
# 1288/3677 embeddings done
# 1289/3677 embeddings done
# 1290/3677 embeddings done
# 1291/3677 embeddings done
# 1292/3677 embeddings done
# 1293/3677 embeddings done
# 1294/3677 embeddings done
# 1295/3677 embeddings done
# 1296/3677 embeddings done
# 1297/3677 embeddings done
# 1298/3677 embeddings done
# 1299/3677 embeddings done
# 1300/3677 embeddings done
# 1301/3677 embeddings done
# 1302/3677 embeddings done
# 1303/3677 embeddings done
# 1304/3677 embeddings done
# 1305/3677 embeddings done
# 1306/3677 embeddings done
# 1307/3677 embeddings done
# 1308/3677 embeddings done
# 1309/3677 embeddings done
# 1310/3677 embeddings done
# 1311/3677 embeddings done
# 1312/3677 embeddings done
# 1313/3677 embeddings done
# 1314/3677 embeddings done
# 1315/3677 embeddings done
# 1316/3677 embeddings done
# 1317/3677 embeddings done
# 1318/3677 embeddings done
# 1319/3677 embeddings done
# 1320/3677 embeddings done
# 1321/3677 embeddings done
# 1322/3677 embeddings done
# 1323/3677 embeddings done
# 1324/3677 embeddings done
# 1325/3677 embeddings done
# 1326/3677 embeddings done
# 1327/3677 embeddings done
# 1328/3677 embeddings done
# 1329/3677 embeddings done
# 1330/3677 embeddings done
# 1331/3677 embeddings done
# 1332/3677 embeddings done
# 1333/3677 embeddings done
# 1334/3677 embeddings done
# 1335/3677 embeddings done
# 1336/3677 embeddings done
# 1337/3677 embeddings done
# 1338/3677 embeddings done
# 1339/3677 embeddings done
# 1340/3677 embeddings done
# 1341/3677 embeddings done
# 1342/3677 embeddings done
# 1343/3677 embeddings done
# 1344/3677 embeddings done
# 1345/3677 embeddings done
# 1346/3677 embeddings done
# 1347/3677 embeddings done
# 1348/3677 embeddings done
# 1349/3677 embeddings done
# 1350/3677 embeddings done
# 1351/3677 embeddings done
# 1352/3677 embeddings done
# 1353/3677 embeddings done
# 1354/3677 embeddings done
# 1355/3677 embeddings done
# 1356/3677 embeddings done
# 1357/3677 embeddings done
# 1358/3677 embeddings done
# 1359/3677 embeddings done
# 1360/3677 embeddings done
# 1361/3677 embeddings done
# 1362/3677 embeddings done
# 1363/3677 embeddings done
# 1364/3677 embeddings done
# 1365/3677 embeddings done
# 1366/3677 embeddings done
# 1367/3677 embeddings done
# 1368/3677 embeddings done
# 1369/3677 embeddings done
# 1370/3677 embeddings done
# 1371/3677 embeddings done
# 1372/3677 embeddings done
# 1373/3677 embeddings done
# 1374/3677 embeddings done
# 1375/3677 embeddings done
# 1376/3677 embeddings done
# 1377/3677 embeddings done
# 1378/3677 embeddings done
# 1379/3677 embeddings done
# 1380/3677 embeddings done
# 1381/3677 embeddings done
# 1382/3677 embeddings done
# 1383/3677 embeddings done
# 1384/3677 embeddings done
# 1385/3677 embeddings done
# 1386/3677 embeddings done
# 1387/3677 embeddings done
# 1388/3677 embeddings done
# 1389/3677 embeddings done
# 1390/3677 embeddings done
# 1391/3677 embeddings done
# 1392/3677 embeddings done
# 1393/3677 embeddings done
# 1394/3677 embeddings done
# 1395/3677 embeddings done
# 1396/3677 embeddings done
# 1397/3677 embeddings done
# 1398/3677 embeddings done
# 1399/3677 embeddings done
# 1400/3677 embeddings done
# 1401/3677 embeddings done
# 1402/3677 embeddings done
# 1403/3677 embeddings done
# 1404/3677 embeddings done
# 1405/3677 embeddings done
# 1406/3677 embeddings done
# 1407/3677 embeddings done
# 1408/3677 embeddings done
# 1409/3677 embeddings done
# 1410/3677 embeddings done
# 1411/3677 embeddings done
# 1412/3677 embeddings done
# 1413/3677 embeddings done
# 1414/3677 embeddings done
# 1415/3677 embeddings done
# 1416/3677 embeddings done
# 1417/3677 embeddings done
# 1418/3677 embeddings done
# 1419/3677 embeddings done
# 1420/3677 embeddings done
# 1421/3677 embeddings done
# 1422/3677 embeddings done
# 1423/3677 embeddings done
# 1424/3677 embeddings done
# 1425/3677 embeddings done
# 1426/3677 embeddings done
# 1427/3677 embeddings done
# 1428/3677 embeddings done
# 1429/3677 embeddings done
# 1430/3677 embeddings done
# 1431/3677 embeddings done
# 1432/3677 embeddings done
# 1433/3677 embeddings done
# 1434/3677 embeddings done
# 1435/3677 embeddings done
# 1436/3677 embeddings done
# 1437/3677 embeddings done
# 1438/3677 embeddings done
# 1439/3677 embeddings done
# 1440/3677 embeddings done
# 1441/3677 embeddings done
# 1442/3677 embeddings done
# 1443/3677 embeddings done
# 1444/3677 embeddings done
# 1445/3677 embeddings done
# 1446/3677 embeddings done
# 1447/3677 embeddings done
# 1448/3677 embeddings done
# 1449/3677 embeddings done
# 1450/3677 embeddings done
# 1451/3677 embeddings done
# 1452/3677 embeddings done
# 1453/3677 embeddings done
# 1454/3677 embeddings done
# 1455/3677 embeddings done
# 1456/3677 embeddings done
# 1457/3677 embeddings done
# 1458/3677 embeddings done
# 1459/3677 embeddings done
# 1460/3677 embeddings done
# 1461/3677 embeddings done
# 1462/3677 embeddings done
# 1463/3677 embeddings done
# 1464/3677 embeddings done
# 1465/3677 embeddings done
# 1466/3677 embeddings done
# 1467/3677 embeddings done
# 1468/3677 embeddings done
# 1469/3677 embeddings done
# 1470/3677 embeddings done
# 1471/3677 embeddings done
# 1472/3677 embeddings done
# 1473/3677 embeddings done
# 1474/3677 embeddings done
# 1475/3677 embeddings done
# 1476/3677 embeddings done
# 1477/3677 embeddings done
# 1478/3677 embeddings done
# 1479/3677 embeddings done
# 1480/3677 embeddings done
# 1481/3677 embeddings done
# 1482/3677 embeddings done
# 1483/3677 embeddings done
# 1484/3677 embeddings done
# 1485/3677 embeddings done
# 1486/3677 embeddings done
# 1487/3677 embeddings done
# 1488/3677 embeddings done
# 1489/3677 embeddings done
# 1490/3677 embeddings done
# 1491/3677 embeddings done
# 1492/3677 embeddings done
# 1493/3677 embeddings done
# 1494/3677 embeddings done
# 1495/3677 embeddings done
# 1496/3677 embeddings done
# 1497/3677 embeddings done
# 1498/3677 embeddings done
# 1499/3677 embeddings done
# 1500/3677 embeddings done
# 1501/3677 embeddings done
# 1502/3677 embeddings done
# 1503/3677 embeddings done
# 1504/3677 embeddings done
# 1505/3677 embeddings done
# 1506/3677 embeddings done
# 1507/3677 embeddings done
# 1508/3677 embeddings done
# 1509/3677 embeddings done
# 1510/3677 embeddings done
# 1511/3677 embeddings done
# 1512/3677 embeddings done
# 1513/3677 embeddings done
# 1514/3677 embeddings done
# 1515/3677 embeddings done
# 1516/3677 embeddings done
# 1517/3677 embeddings done
# 1518/3677 embeddings done
# 1519/3677 embeddings done
# 1520/3677 embeddings done
# 1521/3677 embeddings done
# 1522/3677 embeddings done
# 1523/3677 embeddings done
# 1524/3677 embeddings done
# 1525/3677 embeddings done
# 1526/3677 embeddings done
# 1527/3677 embeddings done
# 1528/3677 embeddings done
# 1529/3677 embeddings done
# 1530/3677 embeddings done
# 1531/3677 embeddings done
# 1532/3677 embeddings done
# 1533/3677 embeddings done
# 1534/3677 embeddings done
# 1535/3677 embeddings done
# 1536/3677 embeddings done
# 1537/3677 embeddings done
# 1538/3677 embeddings done
# 1539/3677 embeddings done
# 1540/3677 embeddings done
# 1541/3677 embeddings done
# 1542/3677 embeddings done
# 1543/3677 embeddings done
# 1544/3677 embeddings done
# 1545/3677 embeddings done
# 1546/3677 embeddings done
# 1547/3677 embeddings done
# 1548/3677 embeddings done
# 1549/3677 embeddings done
# 1550/3677 embeddings done
# 1551/3677 embeddings done
# 1552/3677 embeddings done
# 1553/3677 embeddings done
# 1554/3677 embeddings done
# 1555/3677 embeddings done
# 1556/3677 embeddings done
# 1557/3677 embeddings done
# 1558/3677 embeddings done
# 1559/3677 embeddings done
# 1560/3677 embeddings done
# 1561/3677 embeddings done
# 1562/3677 embeddings done
# 1563/3677 embeddings done
# 1564/3677 embeddings done
# 1565/3677 embeddings done
# 1566/3677 embeddings done
# 1567/3677 embeddings done
# 1568/3677 embeddings done
# 1569/3677 embeddings done
# 1570/3677 embeddings done
# 1571/3677 embeddings done
# 1572/3677 embeddings done
# 1573/3677 embeddings done
# 1574/3677 embeddings done
# 1575/3677 embeddings done
# 1576/3677 embeddings done
# 1577/3677 embeddings done
# 1578/3677 embeddings done
# 1579/3677 embeddings done
# 1580/3677 embeddings done
# 1581/3677 embeddings done
# 1582/3677 embeddings done
# 1583/3677 embeddings done
# 1584/3677 embeddings done
# 1585/3677 embeddings done
# 1586/3677 embeddings done
# 1587/3677 embeddings done
# 1588/3677 embeddings done
# 1589/3677 embeddings done
# 1590/3677 embeddings done
# 1591/3677 embeddings done
# 1592/3677 embeddings done
# 1593/3677 embeddings done
# 1594/3677 embeddings done
# 1595/3677 embeddings done
# 1596/3677 embeddings done
# 1597/3677 embeddings done
# 1598/3677 embeddings done
# 1599/3677 embeddings done
# 1600/3677 embeddings done
# 1601/3677 embeddings done
# 1602/3677 embeddings done
# 1603/3677 embeddings done
# 1604/3677 embeddings done
# 1605/3677 embeddings done
# 1606/3677 embeddings done
# 1607/3677 embeddings done
# 1608/3677 embeddings done
# 1609/3677 embeddings done
# 1610/3677 embeddings done
# 1611/3677 embeddings done
# 1612/3677 embeddings done
# 1613/3677 embeddings done
# 1614/3677 embeddings done
# 1615/3677 embeddings done
# 1616/3677 embeddings done
# 1617/3677 embeddings done
# 1618/3677 embeddings done
# 1619/3677 embeddings done
# 1620/3677 embeddings done
# 1621/3677 embeddings done
# 1622/3677 embeddings done
# 1623/3677 embeddings done
# 1624/3677 embeddings done
# 1625/3677 embeddings done
# 1626/3677 embeddings done
# 1627/3677 embeddings done
# 1628/3677 embeddings done
# 1629/3677 embeddings done
# 1630/3677 embeddings done
# 1631/3677 embeddings done
# 1632/3677 embeddings done
# 1633/3677 embeddings done
# 1634/3677 embeddings done
# 1635/3677 embeddings done
# 1636/3677 embeddings done
# 1637/3677 embeddings done
# 1638/3677 embeddings done
# 1639/3677 embeddings done
# 1640/3677 embeddings done
# 1641/3677 embeddings done
# 1642/3677 embeddings done
# 1643/3677 embeddings done
# 1644/3677 embeddings done
# 1645/3677 embeddings done
# 1646/3677 embeddings done
# 1647/3677 embeddings done
# 1648/3677 embeddings done
# 1649/3677 embeddings done
# 1650/3677 embeddings done
# 1651/3677 embeddings done
# 1652/3677 embeddings done
# 1653/3677 embeddings done
# 1654/3677 embeddings done
# 1655/3677 embeddings done
# 1656/3677 embeddings done
# 1657/3677 embeddings done
# 1658/3677 embeddings done
# 1659/3677 embeddings done
# 1660/3677 embeddings done
# 1661/3677 embeddings done
# 1662/3677 embeddings done
# 1663/3677 embeddings done
# 1664/3677 embeddings done
# 1665/3677 embeddings done
# 1666/3677 embeddings done
# 1667/3677 embeddings done
# 1668/3677 embeddings done
# 1669/3677 embeddings done
# 1670/3677 embeddings done
# 1671/3677 embeddings done
# 1672/3677 embeddings done
# 1673/3677 embeddings done
# 1674/3677 embeddings done
# 1675/3677 embeddings done
# 1676/3677 embeddings done
# 1677/3677 embeddings done
# 1678/3677 embeddings done
# 1679/3677 embeddings done
# 1680/3677 embeddings done
# 1681/3677 embeddings done
# 1682/3677 embeddings done
# 1683/3677 embeddings done
# 1684/3677 embeddings done
# 1685/3677 embeddings done
# 1686/3677 embeddings done
# 1687/3677 embeddings done
# 1688/3677 embeddings done
# 1689/3677 embeddings done
# 1690/3677 embeddings done
# 1691/3677 embeddings done
# 1692/3677 embeddings done
# 1693/3677 embeddings done
# 1694/3677 embeddings done
# 1695/3677 embeddings done
# 1696/3677 embeddings done
# 1697/3677 embeddings done
# 1698/3677 embeddings done
# 1699/3677 embeddings done
# 1700/3677 embeddings done
# 1701/3677 embeddings done
# 1702/3677 embeddings done
# 1703/3677 embeddings done
# 1704/3677 embeddings done
# 1705/3677 embeddings done
# 1706/3677 embeddings done
# 1707/3677 embeddings done
# 1708/3677 embeddings done
# 1709/3677 embeddings done
# 1710/3677 embeddings done
# 1711/3677 embeddings done
# 1712/3677 embeddings done
# 1713/3677 embeddings done
# 1714/3677 embeddings done
# 1715/3677 embeddings done
# 1716/3677 embeddings done
# 1717/3677 embeddings done
# 1718/3677 embeddings done
# 1719/3677 embeddings done
# 1720/3677 embeddings done
# 1721/3677 embeddings done
# 1722/3677 embeddings done
# 1723/3677 embeddings done
# 1724/3677 embeddings done
# 1725/3677 embeddings done
# 1726/3677 embeddings done
# 1727/3677 embeddings done
# 1728/3677 embeddings done
# 1729/3677 embeddings done
# 1730/3677 embeddings done
# 1731/3677 embeddings done
# 1732/3677 embeddings done
# 1733/3677 embeddings done
# 1734/3677 embeddings done
# 1735/3677 embeddings done
# 1736/3677 embeddings done
# 1737/3677 embeddings done
# 1738/3677 embeddings done
# 1739/3677 embeddings done
# 1740/3677 embeddings done
# 1741/3677 embeddings done
# 1742/3677 embeddings done
# 1743/3677 embeddings done
# 1744/3677 embeddings done
# 1745/3677 embeddings done
# 1746/3677 embeddings done
# 1747/3677 embeddings done
# 1748/3677 embeddings done
# 1749/3677 embeddings done
# 1750/3677 embeddings done
# 1751/3677 embeddings done
# 1752/3677 embeddings done
# 1753/3677 embeddings done
# 1754/3677 embeddings done
# 1755/3677 embeddings done
# 1756/3677 embeddings done
# 1757/3677 embeddings done
# 1758/3677 embeddings done
# 1759/3677 embeddings done
# 1760/3677 embeddings done
# 1761/3677 embeddings done
# 1762/3677 embeddings done
# 1763/3677 embeddings done
# 1764/3677 embeddings done
# 1765/3677 embeddings done
# 1766/3677 embeddings done
# 1767/3677 embeddings done
# 1768/3677 embeddings done
# 1769/3677 embeddings done
# 1770/3677 embeddings done
# 1771/3677 embeddings done
# 1772/3677 embeddings done
# 1773/3677 embeddings done
# 1774/3677 embeddings done
# 1775/3677 embeddings done
# 1776/3677 embeddings done
# 1777/3677 embeddings done
# 1778/3677 embeddings done
# 1779/3677 embeddings done
# 1780/3677 embeddings done
# 1781/3677 embeddings done
# 1782/3677 embeddings done
# 1783/3677 embeddings done
# 1784/3677 embeddings done
# 1785/3677 embeddings done
# 1786/3677 embeddings done
# 1787/3677 embeddings done
# 1788/3677 embeddings done
# 1789/3677 embeddings done
# 1790/3677 embeddings done
# 1791/3677 embeddings done
# 1792/3677 embeddings done
# 1793/3677 embeddings done
# 1794/3677 embeddings done
# 1795/3677 embeddings done
# 1796/3677 embeddings done
# 1797/3677 embeddings done
# 1798/3677 embeddings done
# 1799/3677 embeddings done
# 1800/3677 embeddings done
# 1801/3677 embeddings done
# 1802/3677 embeddings done
# 1803/3677 embeddings done
# 1804/3677 embeddings done
# 1805/3677 embeddings done
# 1806/3677 embeddings done
# 1807/3677 embeddings done
# 1808/3677 embeddings done
# 1809/3677 embeddings done
# 1810/3677 embeddings done
# 1811/3677 embeddings done
# 1812/3677 embeddings done
# 1813/3677 embeddings done
# 1814/3677 embeddings done
# 1815/3677 embeddings done
# 1816/3677 embeddings done
# 1817/3677 embeddings done
# 1818/3677 embeddings done
# 1819/3677 embeddings done
# 1820/3677 embeddings done
# 1821/3677 embeddings done
# 1822/3677 embeddings done
# 1823/3677 embeddings done
# 1824/3677 embeddings done
# 1825/3677 embeddings done
# 1826/3677 embeddings done
# 1827/3677 embeddings done
# 1828/3677 embeddings done
# 1829/3677 embeddings done
# 1830/3677 embeddings done
# 1831/3677 embeddings done
# 1832/3677 embeddings done
# 1833/3677 embeddings done
# 1834/3677 embeddings done
# 1835/3677 embeddings done
# 1836/3677 embeddings done
# 1837/3677 embeddings done
# 1838/3677 embeddings done
# 1839/3677 embeddings done
# 1840/3677 embeddings done
# 1841/3677 embeddings done
# 1842/3677 embeddings done
# 1843/3677 embeddings done
# 1844/3677 embeddings done
# 1845/3677 embeddings done
# 1846/3677 embeddings done
# 1847/3677 embeddings done
# 1848/3677 embeddings done
# 1849/3677 embeddings done
# 1850/3677 embeddings done
# 1851/3677 embeddings done
# 1852/3677 embeddings done
# 1853/3677 embeddings done
# 1854/3677 embeddings done
# 1855/3677 embeddings done
# 1856/3677 embeddings done
# 1857/3677 embeddings done
# 1858/3677 embeddings done
# 1859/3677 embeddings done
# 1860/3677 embeddings done
# ...
# 3070/3677 embeddings done
# 3071/3677 embeddings done
# 3072/3677 embeddings done
# 3073/3677 embeddings done
# 3074/3677 embeddings done
# 3075/3677 embeddings done
# 3076/3677 embeddings done
# 3077/3677 embeddings done
# 3078/3677 embeddings done
# 3079/3677 embeddings done
# 3080/3677 embeddings done
# 3081/3677 embeddings done
# 3082/3677 embeddings done
# 3083/3677 embeddings done
# 3084/3677 embeddings done
# 3085/3677 embeddings done
# 3086/3677 embeddings done
# 3087/3677 embeddings done
# 3088/3677 embeddings done
# 3089/3677 embeddings done
# 3090/3677 embeddings done
# 3091/3677 embeddings done
# 3092/3677 embeddings done
# 3093/3677 embeddings done
# 3094/3677 embeddings done
# 3095/3677 embeddings done
# 3096/3677 embeddings done
# 3097/3677 embeddings done
# 3098/3677 embeddings done
# 3099/3677 embeddings done
# 3100/3677 embeddings done
# 3101/3677 embeddings done
# 3102/3677 embeddings done
# 3103/3677 embeddings done
# 3104/3677 embeddings done
# 3105/3677 embeddings done
# 3106/3677 embeddings done
# 3107/3677 embeddings done
# 3108/3677 embeddings done
# 3109/3677 embeddings done
# 3110/3677 embeddings done
# 3111/3677 embeddings done
# 3112/3677 embeddings done
# 3113/3677 embeddings done
# 3114/3677 embeddings done
# 3115/3677 embeddings done
# 3116/3677 embeddings done
# 3117/3677 embeddings done
# 3118/3677 embeddings done
# 3119/3677 embeddings done
# 3120/3677 embeddings done
# 3121/3677 embeddings done
# 3122/3677 embeddings done
# 3123/3677 embeddings done
# 3124/3677 embeddings done
# 3125/3677 embeddings done
# 3126/3677 embeddings done
# 3127/3677 embeddings done
# 3128/3677 embeddings done
# 3129/3677 embeddings done
# 3130/3677 embeddings done
# 3131/3677 embeddings done
# 3132/3677 embeddings done
# 3133/3677 embeddings done
# 3134/3677 embeddings done
# 3135/3677 embeddings done
# 3136/3677 embeddings done
# 3137/3677 embeddings done
# 3138/3677 embeddings done
# 3139/3677 embeddings done
# 3140/3677 embeddings done
# 3141/3677 embeddings done
# 3142/3677 embeddings done
# 3143/3677 embeddings done
# 3144/3677 embeddings done
# 3145/3677 embeddings done
# 3146/3677 embeddings done
# 3147/3677 embeddings done
# 3148/3677 embeddings done
# 3149/3677 embeddings done
# 3150/3677 embeddings done
# 3151/3677 embeddings done
# 3152/3677 embeddings done
# 3153/3677 embeddings done
# 3154/3677 embeddings done
# 3155/3677 embeddings done
# 3156/3677 embeddings done
# 3157/3677 embeddings done
# 3158/3677 embeddings done
# 3159/3677 embeddings done
# 3160/3677 embeddings done
# 3161/3677 embeddings done
# 3162/3677 embeddings done
# 3163/3677 embeddings done
# 3164/3677 embeddings done
# 3165/3677 embeddings done
# 3166/3677 embeddings done
# 3167/3677 embeddings done
# 3168/3677 embeddings done
# 3169/3677 embeddings done
# 3170/3677 embeddings done
# 3171/3677 embeddings done
# 3172/3677 embeddings done
# 3173/3677 embeddings done
# 3174/3677 embeddings done
# 3175/3677 embeddings done
# 3176/3677 embeddings done
# 3177/3677 embeddings done
# 3178/3677 embeddings done
# 3179/3677 embeddings done
# 3180/3677 embeddings done
# 3181/3677 embeddings done
# 3182/3677 embeddings done
# 3183/3677 embeddings done
# 3184/3677 embeddings done
# 3185/3677 embeddings done
# 3186/3677 embeddings done
# 3187/3677 embeddings done
# 3188/3677 embeddings done
# 3189/3677 embeddings done
# 3190/3677 embeddings done
# 3191/3677 embeddings done
# 3192/3677 embeddings done
# 3193/3677 embeddings done
# 3194/3677 embeddings done
# 3195/3677 embeddings done
# 3196/3677 embeddings done
# 3197/3677 embeddings done
# 3198/3677 embeddings done
# 3199/3677 embeddings done
# 3200/3677 embeddings done
# 3201/3677 embeddings done
# 3202/3677 embeddings done
# 3203/3677 embeddings done
# 3204/3677 embeddings done
# 3205/3677 embeddings done
# 3206/3677 embeddings done
# 3207/3677 embeddings done
# 3208/3677 embeddings done
# 3209/3677 embeddings done
# 3210/3677 embeddings done
# 3211/3677 embeddings done
# 3212/3677 embeddings done
# 3213/3677 embeddings done
# 3214/3677 embeddings done
# 3215/3677 embeddings done
# 3216/3677 embeddings done
# 3217/3677 embeddings done
# 3218/3677 embeddings done
# 3219/3677 embeddings done
# 3220/3677 embeddings done
# 3221/3677 embeddings done
# 3222/3677 embeddings done
# 3223/3677 embeddings done
# 3224/3677 embeddings done
# 3225/3677 embeddings done
# 3226/3677 embeddings done
# 3227/3677 embeddings done
# 3228/3677 embeddings done
# 3229/3677 embeddings done
# 3230/3677 embeddings done
# 3231/3677 embeddings done
# 3232/3677 embeddings done
# 3233/3677 embeddings done
# 3234/3677 embeddings done
# 3235/3677 embeddings done
# 3236/3677 embeddings done
# 3237/3677 embeddings done
# 3238/3677 embeddings done
# 3239/3677 embeddings done
# 3240/3677 embeddings done
# 3241/3677 embeddings done
# 3242/3677 embeddings done
# 3243/3677 embeddings done
# 3244/3677 embeddings done
# 3245/3677 embeddings done
# 3246/3677 embeddings done
# 3247/3677 embeddings done
# 3248/3677 embeddings done
# 3249/3677 embeddings done
# 3250/3677 embeddings done
# 3251/3677 embeddings done
# 3252/3677 embeddings done
# 3253/3677 embeddings done
# 3254/3677 embeddings done
# 3255/3677 embeddings done
# 3256/3677 embeddings done
# 3257/3677 embeddings done
# 3258/3677 embeddings done
# 3259/3677 embeddings done
# 3260/3677 embeddings done
# 3261/3677 embeddings done
# 3262/3677 embeddings done
# 3263/3677 embeddings done
# 3264/3677 embeddings done
# 3265/3677 embeddings done
# 3266/3677 embeddings done
# 3267/3677 embeddings done
# 3268/3677 embeddings done
# 3269/3677 embeddings done
# 3270/3677 embeddings done
# 3271/3677 embeddings done
# 3272/3677 embeddings done
# 3273/3677 embeddings done
# 3274/3677 embeddings done
# 3275/3677 embeddings done
# 3276/3677 embeddings done
# 3277/3677 embeddings done
# 3278/3677 embeddings done
# 3279/3677 embeddings done
# 3280/3677 embeddings done
# 3281/3677 embeddings done
# 3282/3677 embeddings done
# 3283/3677 embeddings done
# 3284/3677 embeddings done
# 3285/3677 embeddings done
# 3286/3677 embeddings done
# 3287/3677 embeddings done
# 3288/3677 embeddings done
# 3289/3677 embeddings done
# 3290/3677 embeddings done
# 3291/3677 embeddings done
# 3292/3677 embeddings done
# 3293/3677 embeddings done
# 3294/3677 embeddings done
# 3295/3677 embeddings done
# 3296/3677 embeddings done
# 3297/3677 embeddings done
# 3298/3677 embeddings done
# 3299/3677 embeddings done
# 3300/3677 embeddings done
# 3301/3677 embeddings done
# 3302/3677 embeddings done
# 3303/3677 embeddings done
# 3304/3677 embeddings done
# 3305/3677 embeddings done
# 3306/3677 embeddings done
# 3307/3677 embeddings done
# 3308/3677 embeddings done
# 3309/3677 embeddings done
# 3310/3677 embeddings done
# 3311/3677 embeddings done
# 3312/3677 embeddings done
# 3313/3677 embeddings done
# 3314/3677 embeddings done
# 3315/3677 embeddings done
# 3316/3677 embeddings done
# 3317/3677 embeddings done
# 3318/3677 embeddings done
# 3319/3677 embeddings done
# 3320/3677 embeddings done
# 3321/3677 embeddings done
# 3322/3677 embeddings done
# 3323/3677 embeddings done
# 3324/3677 embeddings done
# 3325/3677 embeddings done
# 3326/3677 embeddings done
# 3327/3677 embeddings done
# 3328/3677 embeddings done
# 3329/3677 embeddings done
# 3330/3677 embeddings done
# 3331/3677 embeddings done
# 3332/3677 embeddings done
# 3333/3677 embeddings done
# 3334/3677 embeddings done
# 3335/3677 embeddings done
# 3336/3677 embeddings done
# 3337/3677 embeddings done
# 3338/3677 embeddings done
# 3339/3677 embeddings done
# 3340/3677 embeddings done
# 3341/3677 embeddings done
# 3342/3677 embeddings done
# 3343/3677 embeddings done
# 3344/3677 embeddings done
# 3345/3677 embeddings done
# 3346/3677 embeddings done
# 3347/3677 embeddings done
# 3348/3677 embeddings done
# 3349/3677 embeddings done
# 3350/3677 embeddings done
# 3351/3677 embeddings done
# 3352/3677 embeddings done
# 3353/3677 embeddings done
# 3354/3677 embeddings done
# 3355/3677 embeddings done
# 3356/3677 embeddings done
# 3357/3677 embeddings done
# 3358/3677 embeddings done
# 3359/3677 embeddings done
# 3360/3677 embeddings done
# 3361/3677 embeddings done
# 3362/3677 embeddings done
# 3363/3677 embeddings done
# 3364/3677 embeddings done
# 3365/3677 embeddings done
# 3366/3677 embeddings done
# 3367/3677 embeddings done
# 3368/3677 embeddings done
# 3369/3677 embeddings done
# 3370/3677 embeddings done
# 3371/3677 embeddings done
# 3372/3677 embeddings done
# 3373/3677 embeddings done
# 3374/3677 embeddings done
# 3375/3677 embeddings done
# 3376/3677 embeddings done
# 3377/3677 embeddings done
# 3378/3677 embeddings done
# 3379/3677 embeddings done
# 3380/3677 embeddings done
# 3381/3677 embeddings done
# 3382/3677 embeddings done
# 3383/3677 embeddings done
# 3384/3677 embeddings done
# 3385/3677 embeddings done
# 3386/3677 embeddings done
# 3387/3677 embeddings done
# 3388/3677 embeddings done
# 3389/3677 embeddings done
# 3390/3677 embeddings done
# 3391/3677 embeddings done
# 3392/3677 embeddings done
# 3393/3677 embeddings done
# 3394/3677 embeddings done
# 3395/3677 embeddings done
# 3396/3677 embeddings done
# 3397/3677 embeddings done
# 3398/3677 embeddings done
# 3399/3677 embeddings done
# 3400/3677 embeddings done
# 3401/3677 embeddings done
# 3402/3677 embeddings done
# 3403/3677 embeddings done
# 3404/3677 embeddings done
# 3405/3677 embeddings done
# 3406/3677 embeddings done
# 3407/3677 embeddings done
# 3408/3677 embeddings done
# 3409/3677 embeddings done
# 3410/3677 embeddings done
# 3411/3677 embeddings done
# 3412/3677 embeddings done
# 3413/3677 embeddings done
# 3414/3677 embeddings done
# 3415/3677 embeddings done
# 3416/3677 embeddings done
# 3417/3677 embeddings done
# 3418/3677 embeddings done
# 3419/3677 embeddings done
# 3420/3677 embeddings done
# 3421/3677 embeddings done
# 3422/3677 embeddings done
# 3423/3677 embeddings done
# 3424/3677 embeddings done
# 3425/3677 embeddings done
# 3426/3677 embeddings done
# 3427/3677 embeddings done
# 3428/3677 embeddings done
# 3429/3677 embeddings done
# 3430/3677 embeddings done
# 3431/3677 embeddings done
# 3432/3677 embeddings done
# 3433/3677 embeddings done
# 3434/3677 embeddings done
# 3435/3677 embeddings done
# 3436/3677 embeddings done
# 3437/3677 embeddings done
# 3438/3677 embeddings done
# 3439/3677 embeddings done
# 3440/3677 embeddings done
# 3441/3677 embeddings done
# 3442/3677 embeddings done
# 3443/3677 embeddings done
# 3444/3677 embeddings done
# 3445/3677 embeddings done
# 3446/3677 embeddings done
# 3447/3677 embeddings done
# 3448/3677 embeddings done
# 3449/3677 embeddings done
# 3450/3677 embeddings done
# 3451/3677 embeddings done
# 3452/3677 embeddings done
# 3453/3677 embeddings done
# 3454/3677 embeddings done
# 3455/3677 embeddings done
# 3456/3677 embeddings done
# 3457/3677 embeddings done
# 3458/3677 embeddings done
# 3459/3677 embeddings done
# 3460/3677 embeddings done
# 3461/3677 embeddings done
# 3462/3677 embeddings done
# 3463/3677 embeddings done
# 3464/3677 embeddings done
# 3465/3677 embeddings done
# 3466/3677 embeddings done
# 3467/3677 embeddings done
# 3468/3677 embeddings done
# 3469/3677 embeddings done
# 3470/3677 embeddings done
# 3471/3677 embeddings done
# 3472/3677 embeddings done
# 3473/3677 embeddings done
# 3474/3677 embeddings done
# 3475/3677 embeddings done
# 3476/3677 embeddings done
# 3477/3677 embeddings done
# 3478/3677 embeddings done
# 3479/3677 embeddings done
# 3480/3677 embeddings done
# 3481/3677 embeddings done
# 3482/3677 embeddings done
# 3483/3677 embeddings done
# 3484/3677 embeddings done
# 3485/3677 embeddings done
# 3486/3677 embeddings done
# 3487/3677 embeddings done
# 3488/3677 embeddings done
# 3489/3677 embeddings done
# 3490/3677 embeddings done
# 3491/3677 embeddings done
# 3492/3677 embeddings done
# 3493/3677 embeddings done
# 3494/3677 embeddings done
# 3495/3677 embeddings done
# 3496/3677 embeddings done
# 3497/3677 embeddings done
# 3498/3677 embeddings done
# 3499/3677 embeddings done
# 3500/3677 embeddings done
# 3501/3677 embeddings done
# 3502/3677 embeddings done
# 3503/3677 embeddings done
# 3504/3677 embeddings done
# 3505/3677 embeddings done
# 3506/3677 embeddings done
# 3507/3677 embeddings done
# 3508/3677 embeddings done
# 3509/3677 embeddings done
# 3510/3677 embeddings done
# 3511/3677 embeddings done
# 3512/3677 embeddings done
# 3513/3677 embeddings done
# 3514/3677 embeddings done
# 3515/3677 embeddings done
# 3516/3677 embeddings done
# 3517/3677 embeddings done
# 3518/3677 embeddings done
# 3519/3677 embeddings done
# 3520/3677 embeddings done
# 3521/3677 embeddings done
# 3522/3677 embeddings done
# 3523/3677 embeddings done
# 3524/3677 embeddings done
# 3525/3677 embeddings done
# 3526/3677 embeddings done
# 3527/3677 embeddings done
# 3528/3677 embeddings done
# 3529/3677 embeddings done
# 3530/3677 embeddings done
# 3531/3677 embeddings done
# 3532/3677 embeddings done
# 3533/3677 embeddings done
# 3534/3677 embeddings done
# 3535/3677 embeddings done
# 3536/3677 embeddings done
# 3537/3677 embeddings done
# 3538/3677 embeddings done
# 3539/3677 embeddings done
# 3540/3677 embeddings done
# 3541/3677 embeddings done
# 3542/3677 embeddings done
# 3543/3677 embeddings done
# 3544/3677 embeddings done
# 3545/3677 embeddings done
# 3546/3677 embeddings done
# 3547/3677 embeddings done
# 3548/3677 embeddings done
# 3549/3677 embeddings done
# 3550/3677 embeddings done
# 3551/3677 embeddings done
# 3552/3677 embeddings done
# 3553/3677 embeddings done
# 3554/3677 embeddings done
# 3555/3677 embeddings done
# 3556/3677 embeddings done
# 3557/3677 embeddings done
# 3558/3677 embeddings done
# 3559/3677 embeddings done
# 3560/3677 embeddings done
# 3561/3677 embeddings done
# 3562/3677 embeddings done
# 3563/3677 embeddings done
# 3564/3677 embeddings done
# 3565/3677 embeddings done
# 3566/3677 embeddings done
# 3567/3677 embeddings done
# 3568/3677 embeddings done
# 3569/3677 embeddings done
# 3570/3677 embeddings done
# 3571/3677 embeddings done
# 3572/3677 embeddings done
# 3573/3677 embeddings done
# 3574/3677 embeddings done
# 3575/3677 embeddings done
# 3576/3677 embeddings done
# 3577/3677 embeddings done
# 3578/3677 embeddings done
# 3579/3677 embeddings done
# 3580/3677 embeddings done
# 3581/3677 embeddings done
# 3582/3677 embeddings done
# 3583/3677 embeddings done
# 3584/3677 embeddings done
# 3585/3677 embeddings done
# 3586/3677 embeddings done
# 3587/3677 embeddings done
# 3588/3677 embeddings done
# 3589/3677 embeddings done
# 3590/3677 embeddings done
# 3591/3677 embeddings done
# 3592/3677 embeddings done
# 3593/3677 embeddings done
# 3594/3677 embeddings done
# 3595/3677 embeddings done
# 3596/3677 embeddings done
# 3597/3677 embeddings done
# 3598/3677 embeddings done
# 3599/3677 embeddings done
# 3600/3677 embeddings done
# 3601/3677 embeddings done
# 3602/3677 embeddings done
# 3603/3677 embeddings done
# 3604/3677 embeddings done
# 3605/3677 embeddings done
# 3606/3677 embeddings done
# 3607/3677 embeddings done
# 3608/3677 embeddings done
# 3609/3677 embeddings done
# 3610/3677 embeddings done
# 3611/3677 embeddings done
# 3612/3677 embeddings done
# 3613/3677 embeddings done
# 3614/3677 embeddings done
# 3615/3677 embeddings done
# 3616/3677 embeddings done
# 3617/3677 embeddings done
# 3618/3677 embeddings done
# 3619/3677 embeddings done
# 3620/3677 embeddings done
# 3621/3677 embeddings done
# 3622/3677 embeddings done
# 3623/3677 embeddings done
# 3624/3677 embeddings done
# 3625/3677 embeddings done
# 3626/3677 embeddings done
# 3627/3677 embeddings done
# 3628/3677 embeddings done
# 3629/3677 embeddings done
# 3630/3677 embeddings done
# 3631/3677 embeddings done
# 3632/3677 embeddings done
# 3633/3677 embeddings done
# 3634/3677 embeddings done
# 3635/3677 embeddings done
# 3636/3677 embeddings done
# 3637/3677 embeddings done
# 3638/3677 embeddings done
# 3639/3677 embeddings done
# 3640/3677 embeddings done
# 3641/3677 embeddings done
# 3642/3677 embeddings done
# 3643/3677 embeddings done
# 3644/3677 embeddings done
# 3645/3677 embeddings done
# 3646/3677 embeddings done
# 3647/3677 embeddings done
# 3648/3677 embeddings done
# 3649/3677 embeddings done
# 3650/3677 embeddings done
# 3651/3677 embeddings done
# 3652/3677 embeddings done
# 3653/3677 embeddings done
# 3654/3677 embeddings done
# 3655/3677 embeddings done
# 3656/3677 embeddings done
# 3657/3677 embeddings done
# 3658/3677 embeddings done
# 3659/3677 embeddings done
# 3660/3677 embeddings done
# 3661/3677 embeddings done
# 3662/3677 embeddings done
# 3663/3677 embeddings done
# 3664/3677 embeddings done
# 3665/3677 embeddings done
# 3666/3677 embeddings done
# 3667/3677 embeddings done
# 3668/3677 embeddings done
# 3669/3677 embeddings done
# 3670/3677 embeddings done
# 3671/3677 embeddings done
# 3672/3677 embeddings done
# 3673/3677 embeddings done
# 3674/3677 embeddings done
# 3675/3677 embeddings done
# 3676/3677 embeddings done
# 3677/3677 embeddings done
# Embeddings from file '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs.txt' added to FAISS index between indice 133180 to 136857.

# %%
import json
import os
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

def scoreMedAnswers(input_file_path, output_file_path, data_file_path="", skiplines = 0):
    wiki_embedding = WikitextsDocumentScorer()
    if data_file_path and os.path.exists(data_file_path):
        wiki_embedding.create_embedding(data_file_path)
    gen = OpenAIAtomicFactGenerator()

    qa_data = []
    with open(input_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            qa_data.append(json.loads(line))
    for i, qa in enumerate(qa_data):
        if i < skiplines:
            continue
        query = qa['Question']
        subclaims_score = {}
        retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10, threshold=0.3)
        response = wiki_embedding.faiss_manager.generate_response_from_context(query, retrieved_docs)
        atomicFacts = gen.get_facts_from_text(response)
        for fact in atomicFacts:
            purefact = fact.rpartition(':')[0] if ':' in fact else fact
            score = wiki_embedding.score(purefact, retrieved_docs)
            subclaims_score[purefact] = float(score)
        #sort subclaims based on score
        subclaims_score = sorted(subclaims_score.items(), key=lambda x: x[1], reverse=True)
        answers = qa['Must_have']
        calibrate_scores = [float(wiki_embedding.score(query + ' ' + answer, retrieved_docs)) for answer in answers]
        with open(output_file_path, 'a', encoding='utf-8') as f:
            f.write(json.dumps({'query': query, 'answers': answers, 'calibrate_score': [f"{calibrate_score:.2f}" for calibrate_score in calibrate_scores], 'response': response, 'subclaims_score': subclaims_score}) + '\n')
        print(f'calculate score for data {i} / {len(qa_data)} done')

# %%
file_path = "../index_store/medqa/medication_qa_500.jsonl"
scoreMedAnswers(file_path, '../index_store/medqa/medication_qa_calibrate_score_500.jsonl', data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# File '/Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs.txt' already exists in the FAISS index.
# calculate score for data 0 / 500 done
# calculate score for data 1 / 500 done
# calculate score for data 2 / 500 done
# calculate score for data 3 / 500 done
# calculate score for data 4 / 500 done
# calculate score for data 5 / 500 done
# calculate score for data 6 / 500 done
# calculate score for data 7 / 500 done
# calculate score for data 8 / 500 done
# calculate score for data 9 / 500 done
# calculate score for data 10 / 500 done
# calculate score for data 11 / 500 done
# calculate score for data 12 / 500 done
# calculate score for data 13 / 500 done
# calculate score for data 14 / 500 done
# calculate score for data 15 / 500 done
# calculate score for data 16 / 500 done
# calculate score for data 17 / 500 done
# calculate score for data 18 / 500 done
# calculate score for data 19 / 500 done
# calculate score for data 20 / 500 done
# calculate score for data 21 / 500 done
# calculate score for data 22 / 500 done
# calculate score for data 23 / 500 done
# calculate score for data 24 / 500 done
# calculate score for data 25 / 500 done
# calculate score for data 26 / 500 done
# calculate score for data 27 / 500 done
# calculate score for data 28 / 500 done
# calculate score for data 29 / 500 done
# calculate score for data 30 / 500 done
# calculate score for data 31 / 500 done
# calculate score for data 32 / 500 done
# calculate score for data 33 / 500 done
# calculate score for data 34 / 500 done
# calculate score for data 35 / 500 done
# calculate score for data 36 / 500 done
# calculate score for data 37 / 500 done
# calculate score for data 38 / 500 done
# calculate score for data 39 / 500 done
# calculate score for data 40 / 500 done
# calculate score for data 41 / 500 done
# calculate score for data 42 / 500 done
# calculate score for data 43 / 500 done
# calculate score for data 44 / 500 done
# calculate score for data 45 / 500 done
# calculate score for data 46 / 500 done
# calculate score for data 47 / 500 done
# calculate score for data 48 / 500 done
# calculate score for data 49 / 500 done
# calculate score for data 50 / 500 done
# calculate score for data 51 / 500 done
# calculate score for data 52 / 500 done
# calculate score for data 53 / 500 done
# calculate score for data 54 / 500 done
# calculate score for data 55 / 500 done
# calculate score for data 56 / 500 done
# calculate score for data 57 / 500 done
# calculate score for data 58 / 500 done
# calculate score for data 59 / 500 done
# calculate score for data 60 / 500 done
# calculate score for data 61 / 500 done
# calculate score for data 62 / 500 done
# calculate score for data 63 / 500 done
# calculate score for data 64 / 500 done
# calculate score for data 65 / 500 done
# calculate score for data 66 / 500 done
# calculate score for data 67 / 500 done
# calculate score for data 68 / 500 done
# calculate score for data 69 / 500 done
# calculate score for data 70 / 500 done
# calculate score for data 71 / 500 done
# calculate score for data 72 / 500 done
# calculate score for data 73 / 500 done
# calculate score for data 74 / 500 done
# calculate score for data 75 / 500 done
# calculate score for data 76 / 500 done
# calculate score for data 77 / 500 done
# calculate score for data 78 / 500 done
# calculate score for data 79 / 500 done
# calculate score for data 80 / 500 done
# calculate score for data 81 / 500 done
# calculate score for data 82 / 500 done
# calculate score for data 83 / 500 done
# calculate score for data 84 / 500 done
# calculate score for data 85 / 500 done
# calculate score for data 86 / 500 done
# calculate score for data 87 / 500 done
# calculate score for data 88 / 500 done
# calculate score for data 89 / 500 done
# calculate score for data 90 / 500 done
# calculate score for data 91 / 500 done
# calculate score for data 92 / 500 done
# calculate score for data 93 / 500 done
# calculate score for data 94 / 500 done
# calculate score for data 95 / 500 done
# calculate score for data 96 / 500 done
# calculate score for data 97 / 500 done
# calculate score for data 98 / 500 done
# calculate score for data 99 / 500 done
# calculate score for data 100 / 500 done
# calculate score for data 101 / 500 done
# calculate score for data 102 / 500 done
# calculate score for data 103 / 500 done
# calculate score for data 104 / 500 done
# calculate score for data 105 / 500 done
# calculate score for data 106 / 500 done
# calculate score for data 107 / 500 done
# calculate score for data 108 / 500 done
# calculate score for data 109 / 500 done
# calculate score for data 110 / 500 done
# calculate score for data 111 / 500 done
# calculate score for data 112 / 500 done
# calculate score for data 113 / 500 done
# calculate score for data 114 / 500 done
# calculate score for data 115 / 500 done
# calculate score for data 116 / 500 done
# calculate score for data 117 / 500 done
# calculate score for data 118 / 500 done
# calculate score for data 119 / 500 done
# calculate score for data 120 / 500 done
# calculate score for data 121 / 500 done
# calculate score for data 122 / 500 done
# calculate score for data 123 / 500 done
# calculate score for data 124 / 500 done
# calculate score for data 125 / 500 done
# calculate score for data 126 / 500 done
# calculate score for data 127 / 500 done
# calculate score for data 128 / 500 done
# calculate score for data 129 / 500 done
# calculate score for data 130 / 500 done
# calculate score for data 131 / 500 done
# calculate score for data 132 / 500 done
# calculate score for data 133 / 500 done
# calculate score for data 134 / 500 done
# calculate score for data 135 / 500 done
# calculate score for data 136 / 500 done
# calculate score for data 137 / 500 done
# calculate score for data 138 / 500 done
# calculate score for data 139 / 500 done
# calculate score for data 140 / 500 done
# calculate score for data 141 / 500 done
# calculate score for data 142 / 500 done
# calculate score for data 143 / 500 done
# calculate score for data 144 / 500 done
# calculate score for data 145 / 500 done
# calculate score for data 146 / 500 done
# calculate score for data 147 / 500 done
# calculate score for data 148 / 500 done
# calculate score for data 149 / 500 done
# calculate score for data 150 / 500 done
# calculate score for data 151 / 500 done
# calculate score for data 152 / 500 done
# calculate score for data 153 / 500 done
# calculate score for data 154 / 500 done
# calculate score for data 155 / 500 done
# calculate score for data 156 / 500 done
# calculate score for data 157 / 500 done
# calculate score for data 158 / 500 done
# calculate score for data 159 / 500 done
# calculate score for data 160 / 500 done
# calculate score for data 161 / 500 done
# calculate score for data 162 / 500 done
# calculate score for data 163 / 500 done
# calculate score for data 164 / 500 done
# calculate score for data 165 / 500 done
# calculate score for data 166 / 500 done
# calculate score for data 167 / 500 done
# calculate score for data 168 / 500 done
# calculate score for data 169 / 500 done
# calculate score for data 170 / 500 done
# calculate score for data 171 / 500 done
# calculate score for data 172 / 500 done
# calculate score for data 173 / 500 done
# calculate score for data 174 / 500 done
# calculate score for data 175 / 500 done
# calculate score for data 176 / 500 done
# calculate score for data 177 / 500 done
# calculate score for data 178 / 500 done
# calculate score for data 179 / 500 done
# calculate score for data 180 / 500 done
# calculate score for data 181 / 500 done
# calculate score for data 182 / 500 done
# calculate score for data 183 / 500 done
# calculate score for data 184 / 500 done
# calculate score for data 185 / 500 done
# calculate score for data 186 / 500 done
# calculate score for data 187 / 500 done
# calculate score for data 188 / 500 done
# calculate score for data 189 / 500 done
# calculate score for data 190 / 500 done
# calculate score for data 191 / 500 done
# calculate score for data 192 / 500 done
# calculate score for data 193 / 500 done
# calculate score for data 194 / 500 done
# calculate score for data 195 / 500 done
# calculate score for data 196 / 500 done
# calculate score for data 197 / 500 done
# calculate score for data 198 / 500 done
# calculate score for data 199 / 500 done
# calculate score for data 200 / 500 done
# calculate score for data 201 / 500 done
# calculate score for data 202 / 500 done
# calculate score for data 203 / 500 done
# calculate score for data 204 / 500 done
# calculate score for data 205 / 500 done
# calculate score for data 206 / 500 done
# calculate score for data 207 / 500 done
# calculate score for data 208 / 500 done
# calculate score for data 209 / 500 done
# calculate score for data 210 / 500 done
# calculate score for data 211 / 500 done
# calculate score for data 212 / 500 done
# calculate score for data 213 / 500 done
# calculate score for data 214 / 500 done
# calculate score for data 215 / 500 done
# calculate score for data 216 / 500 done
# calculate score for data 217 / 500 done
# calculate score for data 218 / 500 done
# calculate score for data 219 / 500 done
# calculate score for data 220 / 500 done
# calculate score for data 221 / 500 done
# calculate score for data 222 / 500 done
# calculate score for data 223 / 500 done
# calculate score for data 224 / 500 done
# calculate score for data 225 / 500 done
# calculate score for data 226 / 500 done
# calculate score for data 227 / 500 done
# calculate score for data 228 / 500 done
# calculate score for data 229 / 500 done
# calculate score for data 230 / 500 done
# calculate score for data 231 / 500 done
# calculate score for data 232 / 500 done
# calculate score for data 233 / 500 done
# calculate score for data 234 / 500 done
# calculate score for data 235 / 500 done
# calculate score for data 236 / 500 done
# calculate score for data 237 / 500 done
# calculate score for data 238 / 500 done
# calculate score for data 239 / 500 done
# calculate score for data 240 / 500 done
# calculate score for data 241 / 500 done
# calculate score for data 242 / 500 done
# calculate score for data 243 / 500 done
# calculate score for data 244 / 500 done
# calculate score for data 245 / 500 done
# calculate score for data 246 / 500 done
# calculate score for data 247 / 500 done
# calculate score for data 248 / 500 done
# calculate score for data 249 / 500 done
# calculate score for data 250 / 500 done
# calculate score for data 251 / 500 done
# calculate score for data 252 / 500 done
# calculate score for data 253 / 500 done
# calculate score for data 254 / 500 done
# calculate score for data 255 / 500 done
# calculate score for data 256 / 500 done
# calculate score for data 257 / 500 done
# calculate score for data 258 / 500 done
# calculate score for data 259 / 500 done
# calculate score for data 260 / 500 done
# calculate score for data 261 / 500 done
# calculate score for data 262 / 500 done
# calculate score for data 263 / 500 done
# calculate score for data 264 / 500 done
# calculate score for data 265 / 500 done
# calculate score for data 266 / 500 done
# calculate score for data 267 / 500 done
# calculate score for data 268 / 500 done
# calculate score for data 269 / 500 done
# calculate score for data 270 / 500 done
# calculate score for data 271 / 500 done
# calculate score for data 272 / 500 done
# calculate score for data 273 / 500 done
# calculate score for data 274 / 500 done
# calculate score for data 275 / 500 done
# calculate score for data 276 / 500 done
# calculate score for data 277 / 500 done
# calculate score for data 278 / 500 done
# calculate score for data 279 / 500 done
# calculate score for data 280 / 500 done
# calculate score for data 281 / 500 done
# calculate score for data 282 / 500 done
# calculate score for data 283 / 500 done
# calculate score for data 284 / 500 done
# calculate score for data 285 / 500 done
# calculate score for data 286 / 500 done
# calculate score for data 287 / 500 done
# calculate score for data 288 / 500 done
# calculate score for data 289 / 500 done
# calculate score for data 290 / 500 done
# calculate score for data 291 / 500 done
# calculate score for data 292 / 500 done
# calculate score for data 293 / 500 done
# calculate score for data 294 / 500 done
# calculate score for data 295 / 500 done
# calculate score for data 296 / 500 done
# calculate score for data 297 / 500 done
# calculate score for data 298 / 500 done
# calculate score for data 299 / 500 done
# calculate score for data 300 / 500 done
# calculate score for data 301 / 500 done
# calculate score for data 302 / 500 done
# calculate score for data 303 / 500 done
# calculate score for data 304 / 500 done
# calculate score for data 305 / 500 done
# calculate score for data 306 / 500 done
# calculate score for data 307 / 500 done
# calculate score for data 308 / 500 done
# calculate score for data 309 / 500 done
# calculate score for data 310 / 500 done
# calculate score for data 311 / 500 done
# calculate score for data 312 / 500 done
# calculate score for data 313 / 500 done
# calculate score for data 314 / 500 done
# calculate score for data 315 / 500 done
# calculate score for data 316 / 500 done
# calculate score for data 317 / 500 done
# calculate score for data 318 / 500 done
# calculate score for data 319 / 500 done
# calculate score for data 320 / 500 done
# calculate score for data 321 / 500 done
# calculate score for data 322 / 500 done
# calculate score for data 323 / 500 done
# calculate score for data 324 / 500 done
# calculate score for data 325 / 500 done
# calculate score for data 326 / 500 done
# calculate score for data 327 / 500 done
# calculate score for data 328 / 500 done
# calculate score for data 329 / 500 done
# calculate score for data 330 / 500 done
# calculate score for data 331 / 500 done
# calculate score for data 332 / 500 done
# calculate score for data 333 / 500 done
# calculate score for data 334 / 500 done
# calculate score for data 335 / 500 done
# calculate score for data 336 / 500 done
# calculate score for data 337 / 500 done
# calculate score for data 338 / 500 done
# calculate score for data 339 / 500 done
# calculate score for data 340 / 500 done
# calculate score for data 341 / 500 done
# calculate score for data 342 / 500 done
# calculate score for data 343 / 500 done
# calculate score for data 344 / 500 done
# calculate score for data 345 / 500 done
# calculate score for data 346 / 500 done
# calculate score for data 347 / 500 done
# calculate score for data 348 / 500 done
# calculate score for data 349 / 500 done
# calculate score for data 350 / 500 done
# calculate score for data 351 / 500 done
# calculate score for data 352 / 500 done
# calculate score for data 353 / 500 done
# calculate score for data 354 / 500 done
# calculate score for data 355 / 500 done
# calculate score for data 356 / 500 done
# calculate score for data 357 / 500 done
# calculate score for data 358 / 500 done
# calculate score for data 359 / 500 done
# calculate score for data 360 / 500 done
# calculate score for data 361 / 500 done
# calculate score for data 362 / 500 done
# calculate score for data 363 / 500 done
# calculate score for data 364 / 500 done
# calculate score for data 365 / 500 done
# calculate score for data 366 / 500 done
# calculate score for data 367 / 500 done
# calculate score for data 368 / 500 done
# calculate score for data 369 / 500 done
# calculate score for data 370 / 500 done
# calculate score for data 371 / 500 done
# calculate score for data 372 / 500 done
# calculate score for data 373 / 500 done
# calculate score for data 374 / 500 done
# calculate score for data 375 / 500 done
# calculate score for data 376 / 500 done
# calculate score for data 377 / 500 done
# calculate score for data 378 / 500 done
# calculate score for data 379 / 500 done
# calculate score for data 380 / 500 done
# calculate score for data 381 / 500 done
# calculate score for data 382 / 500 done
# calculate score for data 383 / 500 done
# calculate score for data 384 / 500 done
# calculate score for data 385 / 500 done
# calculate score for data 386 / 500 done
# calculate score for data 387 / 500 done
# calculate score for data 388 / 500 done
# calculate score for data 389 / 500 done
# calculate score for data 390 / 500 done
# calculate score for data 391 / 500 done
# calculate score for data 392 / 500 done
# calculate score for data 393 / 500 done
# calculate score for data 394 / 500 done
# calculate score for data 395 / 500 done
# calculate score for data 396 / 500 done
# calculate score for data 397 / 500 done
# calculate score for data 398 / 500 done
# calculate score for data 399 / 500 done
# calculate score for data 400 / 500 done
# calculate score for data 401 / 500 done
# calculate score for data 402 / 500 done
# calculate score for data 403 / 500 done
# calculate score for data 404 / 500 done
# calculate score for data 405 / 500 done
# calculate score for data 406 / 500 done
# calculate score for data 407 / 500 done
# calculate score for data 408 / 500 done
# calculate score for data 409 / 500 done
# calculate score for data 410 / 500 done
# calculate score for data 411 / 500 done
# calculate score for data 412 / 500 done
# calculate score for data 413 / 500 done
# calculate score for data 414 / 500 done
# calculate score for data 415 / 500 done
# calculate score for data 416 / 500 done
# calculate score for data 417 / 500 done
# calculate score for data 418 / 500 done
# calculate score for data 419 / 500 done
# calculate score for data 420 / 500 done
# calculate score for data 421 / 500 done
# calculate score for data 422 / 500 done
# calculate score for data 423 / 500 done
# calculate score for data 424 / 500 done
# calculate score for data 425 / 500 done
# calculate score for data 426 / 500 done
# calculate score for data 427 / 500 done
# calculate score for data 428 / 500 done
# calculate score for data 429 / 500 done
# calculate score for data 430 / 500 done
# calculate score for data 431 / 500 done
# calculate score for data 432 / 500 done
# calculate score for data 433 / 500 done
# calculate score for data 434 / 500 done
# calculate score for data 435 / 500 done
# calculate score for data 436 / 500 done
# calculate score for data 437 / 500 done
# calculate score for data 438 / 500 done
# calculate score for data 439 / 500 done
# calculate score for data 440 / 500 done
# calculate score for data 441 / 500 done
# calculate score for data 442 / 500 done
# calculate score for data 443 / 500 done
# calculate score for data 444 / 500 done
# calculate score for data 445 / 500 done
# calculate score for data 446 / 500 done
# calculate score for data 447 / 500 done
# calculate score for data 448 / 500 done
# calculate score for data 449 / 500 done
# calculate score for data 450 / 500 done
# calculate score for data 451 / 500 done
# calculate score for data 452 / 500 done
# calculate score for data 453 / 500 done
# calculate score for data 454 / 500 done
# calculate score for data 455 / 500 done
# calculate score for data 456 / 500 done
# calculate score for data 457 / 500 done
# calculate score for data 458 / 500 done
# calculate score for data 459 / 500 done
# calculate score for data 460 / 500 done
# calculate score for data 461 / 500 done
# calculate score for data 462 / 500 done
# calculate score for data 463 / 500 done
# calculate score for data 464 / 500 done
# calculate score for data 465 / 500 done
# calculate score for data 466 / 500 done
# calculate score for data 467 / 500 done
# calculate score for data 468 / 500 done
# calculate score for data 469 / 500 done
# calculate score for data 470 / 500 done
# calculate score for data 471 / 500 done
# calculate score for data 472 / 500 done
# calculate score for data 473 / 500 done
# calculate score for data 474 / 500 done
# calculate score for data 475 / 500 done
# calculate score for data 476 / 500 done
# calculate score for data 477 / 500 done
# calculate score for data 478 / 500 done
# calculate score for data 479 / 500 done
# calculate score for data 480 / 500 done
# calculate score for data 481 / 500 done
# calculate score for data 482 / 500 done
# calculate score for data 483 / 500 done
# calculate score for data 484 / 500 done
# calculate score for data 485 / 500 done
# calculate score for data 486 / 500 done
# calculate score for data 487 / 500 done
# calculate score for data 488 / 500 done
# calculate score for data 489 / 500 done
# calculate score for data 490 / 500 done
# calculate score for data 491 / 500 done
# calculate score for data 492 / 500 done
# calculate score for data 493 / 500 done
# calculate score for data 494 / 500 done
# calculate score for data 495 / 500 done
# calculate score for data 496 / 500 done
# calculate score for data 497 / 500 done
# calculate score for data 498 / 500 done
# calculate score for data 499 / 500 done

# %%
input_file = '../index_store/medqa/medication_qa_calibrate_score_500.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
transformed_data_list = []

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    idx = 0
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data, 'med')
        transformed_data_list.append(transformed_data)
        idx += 1
    
    # Write the JSON array to the output file
    outfile.write('{"results": ')
    outfile.write(json.dumps(transformed_data_list, ensure_ascii=False))
    outfile.write('}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Processing line 51
# Processing line 52
# Processing line 53
# Processing line 54
# Processing line 55
# Processing line 56
# Processing line 57
# Processing line 58
# Processing line 59
# Processing line 60
# Processing line 61
# Processing line 62
# Processing line 63
# Processing line 64
# Processing line 65
# Processing line 66
# Processing line 67
# Processing line 68
# Processing line 69
# Processing line 70
# Processing line 71
# Processing line 72
# Processing line 73
# Processing line 74
# Processing line 75
# Processing line 76
# Processing line 77
# Processing line 78
# Processing line 79
# Processing line 80
# Processing line 81
# Processing line 82
# Processing line 83
# Processing line 84
# Processing line 85
# Processing line 86
# Processing line 87
# Processing line 88
# Processing line 89
# Processing line 90
# Processing line 91
# Processing line 92
# Processing line 93
# Processing line 94
# Processing line 95
# Processing line 96
# Processing line 97
# Processing line 98
# Processing line 99
# Processing line 100
# Processing line 101
# Processing line 102
# Processing line 103
# Processing line 104
# Processing line 105
# Processing line 106
# Processing line 107
# Processing line 108
# Processing line 109
# Processing line 110
# Processing line 111
# Processing line 112
# Processing line 113
# Processing line 114
# Processing line 115
# Processing line 116
# Processing line 117
# Processing line 118
# Processing line 119
# Processing line 120
# Processing line 121
# Processing line 122
# Processing line 123
# Processing line 124
# Processing line 125
# Processing line 126
# Processing line 127
# Processing line 128
# Processing line 129
# Processing line 130
# Processing line 131
# Processing line 132
# Processing line 133
# Processing line 134
# Processing line 135
# Processing line 136
# Processing line 137
# Processing line 138
# Processing line 139
# Processing line 140
# Processing line 141
# Processing line 142
# Processing line 143
# Processing line 144
# Processing line 145
# Processing line 146
# Processing line 147
# Processing line 148
# Processing line 149
# Processing line 150
# Processing line 151
# Processing line 152
# Processing line 153
# Processing line 154
# Processing line 155
# Processing line 156
# Processing line 157
# Processing line 158
# Processing line 159
# Processing line 160
# Processing line 161
# Processing line 162
# Processing line 163
# Processing line 164
# Processing line 165
# Processing line 166
# Processing line 167
# Processing line 168
# Processing line 169
# Processing line 170
# Processing line 171
# Processing line 172
# Processing line 173
# Processing line 174
# Processing line 175
# Processing line 176
# Processing line 177
# Processing line 178
# Processing line 179
# Processing line 180
# Processing line 181
# Processing line 182
# Processing line 183
# Processing line 184
# Processing line 185
# Processing line 186
# Processing line 187
# Processing line 188
# Processing line 189
# Processing line 190
# Processing line 191
# Processing line 192
# Processing line 193
# Processing line 194
# Processing line 195
# Processing line 196
# Processing line 197
# Processing line 198
# Processing line 199
# Processing line 200
# Processing line 201
# Processing line 202
# Processing line 203
# Processing line 204
# Processing line 205
# Processing line 206
# Processing line 207
# Processing line 208
# Processing line 209
# Processing line 210
# Processing line 211
# Processing line 212
# Processing line 213
# Processing line 214
# Processing line 215
# Processing line 216
# Processing line 217
# Processing line 218
# Processing line 219
# Processing line 220
# Processing line 221
# Processing line 222
# Processing line 223
# Processing line 224
# Processing line 225
# Processing line 226
# Processing line 227
# Processing line 228
# Processing line 229
# Processing line 230
# Processing line 231
# Processing line 232
# Processing line 233
# Processing line 234
# Processing line 235
# Processing line 236
# Processing line 237
# Processing line 238
# Processing line 239
# Processing line 240
# Processing line 241
# Processing line 242
# Processing line 243
# Processing line 244
# Processing line 245
# Processing line 246
# Processing line 247
# Processing line 248
# Processing line 249
# Processing line 250
# Processing line 251
# Processing line 252
# Processing line 253
# Processing line 254
# Processing line 255
# Processing line 256
# Processing line 257
# Processing line 258
# Processing line 259
# Processing line 260
# Processing line 261
# Processing line 262
# Processing line 263
# Processing line 264
# Processing line 265
# Processing line 266
# Processing line 267
# Processing line 268
# Processing line 269
# Processing line 270
# Processing line 271
# Processing line 272
# Processing line 273
# Processing line 274
# Processing line 275
# Processing line 276
# Processing line 277
# Processing line 278
# Processing line 279
# Processing line 280
# Processing line 281
# Processing line 282
# Processing line 283
# Processing line 284
# Processing line 285
# Processing line 286
# Processing line 287
# Processing line 288
# Processing line 289
# Processing line 290
# Processing line 291
# Processing line 292
# Processing line 293
# Processing line 294
# Processing line 295
# Processing line 296
# Processing line 297
# Processing line 298
# Processing line 299
# Processing line 300
# Processing line 301
# Processing line 302
# Processing line 303
# Processing line 304
# Processing line 305
# Processing line 306
# Processing line 307
# Processing line 308
# Processing line 309
# Processing line 310
# Processing line 311
# Processing line 312
# Processing line 313
# Processing line 314
# Processing line 315
# Processing line 316
# Processing line 317
# Processing line 318
# Processing line 319
# Processing line 320
# Processing line 321
# Processing line 322
# Processing line 323
# Processing line 324
# Processing line 325
# Processing line 326
# Processing line 327
# Processing line 328
# Processing line 329
# Processing line 330
# Processing line 331
# Processing line 332
# Processing line 333
# Processing line 334
# Processing line 335
# Processing line 336
# Processing line 337
# Processing line 338
# Processing line 339
# Processing line 340
# Processing line 341
# Processing line 342
# Processing line 343
# Processing line 344
# Processing line 345
# Processing line 346
# Processing line 347
# Processing line 348
# Processing line 349
# Processing line 350
# Processing line 351
# Processing line 352
# Processing line 353
# Processing line 354
# Processing line 355
# Processing line 356
# Processing line 357
# Processing line 358
# Processing line 359
# Processing line 360
# Processing line 361
# Processing line 362
# Processing line 363
# Processing line 364
# Processing line 365
# Processing line 366
# Processing line 367
# Processing line 368
# Processing line 369
# Processing line 370
# Processing line 371
# Processing line 372
# Processing line 373
# Processing line 374
# Processing line 375
# Processing line 376
# Processing line 377
# Processing line 378
# Processing line 379
# Processing line 380
# Processing line 381
# Processing line 382
# Processing line 383
# Processing line 384
# Processing line 385
# Processing line 386
# Processing line 387
# Processing line 388
# Processing line 389
# Processing line 390
# Processing line 391
# Processing line 392
# Processing line 393
# Processing line 394
# Processing line 395
# Processing line 396
# Processing line 397
# Processing line 398
# Processing line 399
# Processing line 400
# Processing line 401
# Processing line 402
# Processing line 403
# Processing line 404
# Processing line 405
# Processing line 406
# Processing line 407
# Processing line 408
# Processing line 409
# Processing line 410
# Processing line 411
# Processing line 412
# Processing line 413
# Processing line 414
# Processing line 415
# Processing line 416
# Processing line 417
# Processing line 418
# Processing line 419
# Processing line 420
# Processing line 421
# Processing line 422
# Processing line 423
# Processing line 424
# Processing line 425
# Processing line 426
# Processing line 427
# Processing line 428
# Processing line 429
# Processing line 430
# Processing line 431
# Processing line 432
# Processing line 433
# Processing line 434
# Processing line 435
# Processing line 436
# Processing line 437
# Processing line 438
# Processing line 439
# Processing line 440
# Processing line 441
# Processing line 442
# Processing line 443
# Processing line 444
# Processing line 445
# Processing line 446
# Processing line 447
# Processing line 448
# Processing line 449
# Processing line 450
# Processing line 451
# Processing line 452
# Processing line 453
# Processing line 454
# Processing line 455
# Processing line 456
# Processing line 457
# Processing line 458
# Processing line 459
# Processing line 460
# Processing line 461
# Processing line 462
# Processing line 463
# Processing line 464
# Processing line 465
# Processing line 466
# Processing line 467
# Processing line 468
# Processing line 469
# Processing line 470
# Processing line 471
# Processing line 472
# Processing line 473
# Processing line 474
# Processing line 475
# Processing line 476
# Processing line 477
# Processing line 478
# Processing line 479
# Processing line 480
# Processing line 481
# Processing line 482
# Processing line 483
# Processing line 484
# Processing line 485
# Processing line 486
# Processing line 487
# Processing line 488
# Processing line 489
# Processing line 490
# Processing line 491
# Processing line 492
# Processing line 493
# Processing line 494
# Processing line 495
# Processing line 496
# Processing line 497
# Processing line 498
# Processing line 499
# Transformed data written to similarity_annotations.jsonl.

# %%
import json
import csv

def find_lowest_score(jsonl_file_path, csv_file_path):
    """
    Find the lowest similarity score of a subclaim such that all annotations with
    a score >= it are annotated as "S".
    
    Parameters:
        jsonl_file_path (str): Path to the JSONL file containing the data.

    Returns:
        float: The lowest similarity score meeting the condition, or None if no such score exists.
    """
    
    with open(jsonl_file_path, 'r') as file:
        results = []
        data = json.load(file)
        for line in data["data"]:
            
            # Extract claims and filter for "S" annotations
            prompt = line.get("prompt", "")
            claims = line.get("claims", [])
            scores_with_annotations = [(claim["similarity-score"], claim["annotation"]) for claim in claims]
            
            # Sort by similarity score (ascending)
            scores_with_annotations.sort()
            lowest_score = scores_with_annotations[-1][0]+0.01  # start by assuming none of subcliams are annotated as "S"
            # Iterate to find the lowest valid score
            for i, (score, annotation) in enumerate(scores_with_annotations):
                # Check if all scores >= current score have annotation "S"
                if all(ann == "S" for _, ann in scores_with_annotations[i:]):
                    lowest_score = score
                    break  # No need to check further once found
            results.append({"prompt": prompt, "local_tresh": lowest_score})
    
    # Write the results to a CSV file
    with open(csv_file_path, 'w', newline='') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=["prompt", "local_tresh"])
        writer.writeheader()
        writer.writerows(results)
        
# Example usage
jsonl_file_path = "../data/hotpotqa_similarity_annotations.jsonl"  # Replace with the path to your JSONL file
csv_file_path = "hotpotqa_localthreshold.csv"  # Replace with the path to save your CSV file
find_lowest_score(jsonl_file_path, csv_file_path)

# %% [markdown]
# ## FactScore ##

# %%
data_path = '../index_store/factscore/title_text_map_factscore.txt'
wiki_embedding = WikitextsDocumentScorer()
wiki_embedding.create_embedding(data_path)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# Associated texts saved to file: ../index_store/factscore/title_text_map_factscore_texts.json
# 1/1238 embeddings done
# 2/1238 embeddings done
# 3/1238 embeddings done
# 4/1238 embeddings done
# 5/1238 embeddings done
# 6/1238 embeddings done
# 7/1238 embeddings done
# 8/1238 embeddings done
# 9/1238 embeddings done
# 10/1238 embeddings done
# 11/1238 embeddings done
# 12/1238 embeddings done
# 13/1238 embeddings done
# 14/1238 embeddings done
# 15/1238 embeddings done
# 16/1238 embeddings done
# 17/1238 embeddings done
# 18/1238 embeddings done
# 19/1238 embeddings done
# 20/1238 embeddings done
# 21/1238 embeddings done
# 22/1238 embeddings done
# 23/1238 embeddings done
# 24/1238 embeddings done
# 25/1238 embeddings done
# 26/1238 embeddings done
# 27/1238 embeddings done
# 28/1238 embeddings done
# 29/1238 embeddings done
# 30/1238 embeddings done
# 31/1238 embeddings done
# 32/1238 embeddings done
# 33/1238 embeddings done
# 34/1238 embeddings done
# 35/1238 embeddings done
# 36/1238 embeddings done
# 37/1238 embeddings done
# 38/1238 embeddings done
# 39/1238 embeddings done
# 40/1238 embeddings done
# 41/1238 embeddings done
# 42/1238 embeddings done
# 43/1238 embeddings done
# 44/1238 embeddings done
# 45/1238 embeddings done
# 46/1238 embeddings done
# 47/1238 embeddings done
# 48/1238 embeddings done
# 49/1238 embeddings done
# 50/1238 embeddings done
# 51/1238 embeddings done
# 52/1238 embeddings done
# 53/1238 embeddings done
# 54/1238 embeddings done
# 55/1238 embeddings done
# 56/1238 embeddings done
# 57/1238 embeddings done
# 58/1238 embeddings done
# 59/1238 embeddings done
# 60/1238 embeddings done
# 61/1238 embeddings done
# 62/1238 embeddings done
# 63/1238 embeddings done
# 64/1238 embeddings done
# 65/1238 embeddings done
# 66/1238 embeddings done
# 67/1238 embeddings done
# 68/1238 embeddings done
# 69/1238 embeddings done
# 70/1238 embeddings done
# 71/1238 embeddings done
# 72/1238 embeddings done
# 73/1238 embeddings done
# 74/1238 embeddings done
# 75/1238 embeddings done
# 76/1238 embeddings done
# 77/1238 embeddings done
# 78/1238 embeddings done
# 79/1238 embeddings done
# 80/1238 embeddings done
# 81/1238 embeddings done
# 82/1238 embeddings done
# 83/1238 embeddings done
# 84/1238 embeddings done
# 85/1238 embeddings done
# 86/1238 embeddings done
# 87/1238 embeddings done
# 88/1238 embeddings done
# 89/1238 embeddings done
# 90/1238 embeddings done
# 91/1238 embeddings done
# 92/1238 embeddings done
# 93/1238 embeddings done
# 94/1238 embeddings done
# 95/1238 embeddings done
# 96/1238 embeddings done
# 97/1238 embeddings done
# 98/1238 embeddings done
# 99/1238 embeddings done
# 100/1238 embeddings done
# 101/1238 embeddings done
# 102/1238 embeddings done
# 103/1238 embeddings done
# 104/1238 embeddings done
# 105/1238 embeddings done
# 106/1238 embeddings done
# 107/1238 embeddings done
# 108/1238 embeddings done
# 109/1238 embeddings done
# 110/1238 embeddings done
# 111/1238 embeddings done
# 112/1238 embeddings done
# 113/1238 embeddings done
# 114/1238 embeddings done
# 115/1238 embeddings done
# 116/1238 embeddings done
# 117/1238 embeddings done
# 118/1238 embeddings done
# 119/1238 embeddings done
# 120/1238 embeddings done
# 121/1238 embeddings done
# 122/1238 embeddings done
# 123/1238 embeddings done
# 124/1238 embeddings done
# 125/1238 embeddings done
# 126/1238 embeddings done
# 127/1238 embeddings done
# 128/1238 embeddings done
# 129/1238 embeddings done
# 130/1238 embeddings done
# 131/1238 embeddings done
# 132/1238 embeddings done
# 133/1238 embeddings done
# 134/1238 embeddings done
# 135/1238 embeddings done
# 136/1238 embeddings done
# 137/1238 embeddings done
# 138/1238 embeddings done
# 139/1238 embeddings done
# 140/1238 embeddings done
# 141/1238 embeddings done
# 142/1238 embeddings done
# 143/1238 embeddings done
# 144/1238 embeddings done
# 145/1238 embeddings done
# 146/1238 embeddings done
# 147/1238 embeddings done
# 148/1238 embeddings done
# 149/1238 embeddings done
# 150/1238 embeddings done
# 151/1238 embeddings done
# 152/1238 embeddings done
# 153/1238 embeddings done
# 154/1238 embeddings done
# 155/1238 embeddings done
# 156/1238 embeddings done
# 157/1238 embeddings done
# 158/1238 embeddings done
# 159/1238 embeddings done
# 160/1238 embeddings done
# 161/1238 embeddings done
# 162/1238 embeddings done
# 163/1238 embeddings done
# 164/1238 embeddings done
# 165/1238 embeddings done
# 166/1238 embeddings done
# 167/1238 embeddings done
# 168/1238 embeddings done
# 169/1238 embeddings done
# 170/1238 embeddings done
# 171/1238 embeddings done
# 172/1238 embeddings done
# 173/1238 embeddings done
# 174/1238 embeddings done
# 175/1238 embeddings done
# 176/1238 embeddings done
# 177/1238 embeddings done
# 178/1238 embeddings done
# 179/1238 embeddings done
# 180/1238 embeddings done
# 181/1238 embeddings done
# 182/1238 embeddings done
# 183/1238 embeddings done
# 184/1238 embeddings done
# 185/1238 embeddings done
# 186/1238 embeddings done
# 187/1238 embeddings done
# 188/1238 embeddings done
# 189/1238 embeddings done
# 190/1238 embeddings done
# 191/1238 embeddings done
# 192/1238 embeddings done
# 193/1238 embeddings done
# 194/1238 embeddings done
# 195/1238 embeddings done
# 196/1238 embeddings done
# 197/1238 embeddings done
# 198/1238 embeddings done
# 199/1238 embeddings done
# 200/1238 embeddings done
# 201/1238 embeddings done
# 202/1238 embeddings done
# 203/1238 embeddings done
# 204/1238 embeddings done
# 205/1238 embeddings done
# 206/1238 embeddings done
# 207/1238 embeddings done
# 208/1238 embeddings done
# 209/1238 embeddings done
# 210/1238 embeddings done
# 211/1238 embeddings done
# 212/1238 embeddings done
# 213/1238 embeddings done
# 214/1238 embeddings done
# 215/1238 embeddings done
# 216/1238 embeddings done
# 217/1238 embeddings done
# 218/1238 embeddings done
# 219/1238 embeddings done
# 220/1238 embeddings done
# 221/1238 embeddings done
# 222/1238 embeddings done
# 223/1238 embeddings done
# 224/1238 embeddings done
# 225/1238 embeddings done
# 226/1238 embeddings done
# 227/1238 embeddings done
# 228/1238 embeddings done
# 229/1238 embeddings done
# 230/1238 embeddings done
# 231/1238 embeddings done
# 232/1238 embeddings done
# 233/1238 embeddings done
# 234/1238 embeddings done
# 235/1238 embeddings done
# 236/1238 embeddings done
# 237/1238 embeddings done
# 238/1238 embeddings done
# 239/1238 embeddings done
# 240/1238 embeddings done
# 241/1238 embeddings done
# 242/1238 embeddings done
# 243/1238 embeddings done
# 244/1238 embeddings done
# 245/1238 embeddings done
# 246/1238 embeddings done
# 247/1238 embeddings done
# 248/1238 embeddings done
# 249/1238 embeddings done
# 250/1238 embeddings done
# 251/1238 embeddings done
# 252/1238 embeddings done
# 253/1238 embeddings done
# 254/1238 embeddings done
# 255/1238 embeddings done
# 256/1238 embeddings done
# 257/1238 embeddings done
# 258/1238 embeddings done
# 259/1238 embeddings done
# 260/1238 embeddings done
# 261/1238 embeddings done
# 262/1238 embeddings done
# 263/1238 embeddings done
# 264/1238 embeddings done
# 265/1238 embeddings done
# 266/1238 embeddings done
# 267/1238 embeddings done
# 268/1238 embeddings done
# 269/1238 embeddings done
# 270/1238 embeddings done
# 271/1238 embeddings done
# 272/1238 embeddings done
# 273/1238 embeddings done
# 274/1238 embeddings done
# 275/1238 embeddings done
# 276/1238 embeddings done
# 277/1238 embeddings done
# 278/1238 embeddings done
# 279/1238 embeddings done
# 280/1238 embeddings done
# 281/1238 embeddings done
# 282/1238 embeddings done
# 283/1238 embeddings done
# 284/1238 embeddings done
# 285/1238 embeddings done
# 286/1238 embeddings done
# 287/1238 embeddings done
# 288/1238 embeddings done
# 289/1238 embeddings done
# 290/1238 embeddings done
# 291/1238 embeddings done
# 292/1238 embeddings done
# 293/1238 embeddings done
# 294/1238 embeddings done
# 295/1238 embeddings done
# 296/1238 embeddings done
# 297/1238 embeddings done
# 298/1238 embeddings done
# 299/1238 embeddings done
# 300/1238 embeddings done
# 301/1238 embeddings done
# 302/1238 embeddings done
# 303/1238 embeddings done
# 304/1238 embeddings done
# 305/1238 embeddings done
# 306/1238 embeddings done
# 307/1238 embeddings done
# 308/1238 embeddings done
# 309/1238 embeddings done
# 310/1238 embeddings done
# 311/1238 embeddings done
# 312/1238 embeddings done
# 313/1238 embeddings done
# 314/1238 embeddings done
# 315/1238 embeddings done
# 316/1238 embeddings done
# 317/1238 embeddings done
# 318/1238 embeddings done
# 319/1238 embeddings done
# 320/1238 embeddings done
# 321/1238 embeddings done
# 322/1238 embeddings done
# 323/1238 embeddings done
# 324/1238 embeddings done
# 325/1238 embeddings done
# 326/1238 embeddings done
# 327/1238 embeddings done
# 328/1238 embeddings done
# 329/1238 embeddings done
# 330/1238 embeddings done
# 331/1238 embeddings done
# 332/1238 embeddings done
# 333/1238 embeddings done
# 334/1238 embeddings done
# 335/1238 embeddings done
# 336/1238 embeddings done
# 337/1238 embeddings done
# 338/1238 embeddings done
# 339/1238 embeddings done
# 340/1238 embeddings done
# 341/1238 embeddings done
# 342/1238 embeddings done
# 343/1238 embeddings done
# 344/1238 embeddings done
# 345/1238 embeddings done
# 346/1238 embeddings done
# 347/1238 embeddings done
# 348/1238 embeddings done
# 349/1238 embeddings done
# 350/1238 embeddings done
# 351/1238 embeddings done
# 352/1238 embeddings done
# 353/1238 embeddings done
# 354/1238 embeddings done
# 355/1238 embeddings done
# 356/1238 embeddings done
# 357/1238 embeddings done
# 358/1238 embeddings done
# 359/1238 embeddings done
# 360/1238 embeddings done
# 361/1238 embeddings done
# 362/1238 embeddings done
# 363/1238 embeddings done
# 364/1238 embeddings done
# 365/1238 embeddings done
# 366/1238 embeddings done
# 367/1238 embeddings done
# 368/1238 embeddings done
# 369/1238 embeddings done
# 370/1238 embeddings done
# 371/1238 embeddings done
# 372/1238 embeddings done
# 373/1238 embeddings done
# 374/1238 embeddings done
# 375/1238 embeddings done
# 376/1238 embeddings done
# 377/1238 embeddings done
# 378/1238 embeddings done
# 379/1238 embeddings done
# 380/1238 embeddings done
# 381/1238 embeddings done
# 382/1238 embeddings done
# 383/1238 embeddings done
# 384/1238 embeddings done
# 385/1238 embeddings done
# 386/1238 embeddings done
# 387/1238 embeddings done
# 388/1238 embeddings done
# 389/1238 embeddings done
# 390/1238 embeddings done
# 391/1238 embeddings done
# 392/1238 embeddings done
# 393/1238 embeddings done
# 394/1238 embeddings done
# 395/1238 embeddings done
# 396/1238 embeddings done
# 397/1238 embeddings done
# 398/1238 embeddings done
# 399/1238 embeddings done
# 400/1238 embeddings done
# 401/1238 embeddings done
# 402/1238 embeddings done
# 403/1238 embeddings done
# 404/1238 embeddings done
# 405/1238 embeddings done
# 406/1238 embeddings done
# 407/1238 embeddings done
# 408/1238 embeddings done
# 409/1238 embeddings done
# 410/1238 embeddings done
# 411/1238 embeddings done
# 412/1238 embeddings done
# 413/1238 embeddings done
# 414/1238 embeddings done
# 415/1238 embeddings done
# 416/1238 embeddings done
# 417/1238 embeddings done
# 418/1238 embeddings done
# 419/1238 embeddings done
# 420/1238 embeddings done
# 421/1238 embeddings done
# 422/1238 embeddings done
# 423/1238 embeddings done
# 424/1238 embeddings done
# 425/1238 embeddings done
# 426/1238 embeddings done
# 427/1238 embeddings done
# 428/1238 embeddings done
# 429/1238 embeddings done
# 430/1238 embeddings done
# 431/1238 embeddings done
# 432/1238 embeddings done
# 433/1238 embeddings done
# 434/1238 embeddings done
# 435/1238 embeddings done
# 436/1238 embeddings done
# 437/1238 embeddings done
# 438/1238 embeddings done
# 439/1238 embeddings done
# 440/1238 embeddings done
# 441/1238 embeddings done
# 442/1238 embeddings done
# 443/1238 embeddings done
# 444/1238 embeddings done
# 445/1238 embeddings done
# 446/1238 embeddings done
# 447/1238 embeddings done
# 448/1238 embeddings done
# 449/1238 embeddings done
# 450/1238 embeddings done
# 451/1238 embeddings done
# 452/1238 embeddings done
# 453/1238 embeddings done
# 454/1238 embeddings done
# 455/1238 embeddings done
# 456/1238 embeddings done
# 457/1238 embeddings done
# 458/1238 embeddings done
# 459/1238 embeddings done
# 460/1238 embeddings done
# 461/1238 embeddings done
# 462/1238 embeddings done
# 463/1238 embeddings done
# 464/1238 embeddings done
# 465/1238 embeddings done
# 466/1238 embeddings done
# 467/1238 embeddings done
# 468/1238 embeddings done
# 469/1238 embeddings done
# 470/1238 embeddings done
# 471/1238 embeddings done
# 472/1238 embeddings done
# 473/1238 embeddings done
# 474/1238 embeddings done
# 475/1238 embeddings done
# 476/1238 embeddings done
# 477/1238 embeddings done
# 478/1238 embeddings done
# 479/1238 embeddings done
# 480/1238 embeddings done
# 481/1238 embeddings done
# 482/1238 embeddings done
# 483/1238 embeddings done
# 484/1238 embeddings done
# 485/1238 embeddings done
# 486/1238 embeddings done
# 487/1238 embeddings done
# 488/1238 embeddings done
# 489/1238 embeddings done
# 490/1238 embeddings done
# 491/1238 embeddings done
# 492/1238 embeddings done
# 493/1238 embeddings done
# 494/1238 embeddings done
# 495/1238 embeddings done
# 496/1238 embeddings done
# 497/1238 embeddings done
# 498/1238 embeddings done
# 499/1238 embeddings done
# 500/1238 embeddings done
# 501/1238 embeddings done
# 502/1238 embeddings done
# 503/1238 embeddings done
# 504/1238 embeddings done
# 505/1238 embeddings done
# 506/1238 embeddings done
# 507/1238 embeddings done
# 508/1238 embeddings done
# 509/1238 embeddings done
# 510/1238 embeddings done
# 511/1238 embeddings done
# 512/1238 embeddings done
# 513/1238 embeddings done
# 514/1238 embeddings done
# 515/1238 embeddings done
# 516/1238 embeddings done
# 517/1238 embeddings done
# 518/1238 embeddings done
# 519/1238 embeddings done
# 520/1238 embeddings done
# 521/1238 embeddings done
# 522/1238 embeddings done
# 523/1238 embeddings done
# 524/1238 embeddings done
# 525/1238 embeddings done
# 526/1238 embeddings done
# 527/1238 embeddings done
# 528/1238 embeddings done
# 529/1238 embeddings done
# 530/1238 embeddings done
# 531/1238 embeddings done
# 532/1238 embeddings done
# 533/1238 embeddings done
# 534/1238 embeddings done
# 535/1238 embeddings done
# 536/1238 embeddings done
# 537/1238 embeddings done
# 538/1238 embeddings done
# 539/1238 embeddings done
# 540/1238 embeddings done
# 541/1238 embeddings done
# 542/1238 embeddings done
# 543/1238 embeddings done
# 544/1238 embeddings done
# 545/1238 embeddings done
# 546/1238 embeddings done
# 547/1238 embeddings done
# 548/1238 embeddings done
# 549/1238 embeddings done
# 550/1238 embeddings done
# 551/1238 embeddings done
# 552/1238 embeddings done
# 553/1238 embeddings done
# 554/1238 embeddings done
# 555/1238 embeddings done
# 556/1238 embeddings done
# 557/1238 embeddings done
# 558/1238 embeddings done
# 559/1238 embeddings done
# 560/1238 embeddings done
# 561/1238 embeddings done
# 562/1238 embeddings done
# 563/1238 embeddings done
# 564/1238 embeddings done
# 565/1238 embeddings done
# 566/1238 embeddings done
# 567/1238 embeddings done
# 568/1238 embeddings done
# 569/1238 embeddings done
# 570/1238 embeddings done
# 571/1238 embeddings done
# 572/1238 embeddings done
# 573/1238 embeddings done
# 574/1238 embeddings done
# 575/1238 embeddings done
# 576/1238 embeddings done
# 577/1238 embeddings done
# 578/1238 embeddings done
# 579/1238 embeddings done
# 580/1238 embeddings done
# 581/1238 embeddings done
# 582/1238 embeddings done
# 583/1238 embeddings done
# 584/1238 embeddings done
# 585/1238 embeddings done
# 586/1238 embeddings done
# 587/1238 embeddings done
# 588/1238 embeddings done
# 589/1238 embeddings done
# 590/1238 embeddings done
# 591/1238 embeddings done
# 592/1238 embeddings done
# 593/1238 embeddings done
# 594/1238 embeddings done
# 595/1238 embeddings done
# 596/1238 embeddings done
# 597/1238 embeddings done
# 598/1238 embeddings done
# 599/1238 embeddings done
# 600/1238 embeddings done
# 601/1238 embeddings done
# 602/1238 embeddings done
# 603/1238 embeddings done
# 604/1238 embeddings done
# 605/1238 embeddings done
# 606/1238 embeddings done
# 607/1238 embeddings done
# 608/1238 embeddings done
# 609/1238 embeddings done
# 610/1238 embeddings done
# 611/1238 embeddings done
# 612/1238 embeddings done
# 613/1238 embeddings done
# 614/1238 embeddings done
# 615/1238 embeddings done
# 616/1238 embeddings done
# 617/1238 embeddings done
# 618/1238 embeddings done
# 619/1238 embeddings done
# 620/1238 embeddings done
# 621/1238 embeddings done
# 622/1238 embeddings done
# 623/1238 embeddings done
# 624/1238 embeddings done
# 625/1238 embeddings done
# 626/1238 embeddings done
# 627/1238 embeddings done
# 628/1238 embeddings done
# 629/1238 embeddings done
# 630/1238 embeddings done
# 631/1238 embeddings done
# 632/1238 embeddings done
# 633/1238 embeddings done
# 634/1238 embeddings done
# 635/1238 embeddings done
# 636/1238 embeddings done
# 637/1238 embeddings done
# 638/1238 embeddings done
# 639/1238 embeddings done
# 640/1238 embeddings done
# 641/1238 embeddings done
# 642/1238 embeddings done
# 643/1238 embeddings done
# 644/1238 embeddings done
# 645/1238 embeddings done
# 646/1238 embeddings done
# 647/1238 embeddings done
# 648/1238 embeddings done
# 649/1238 embeddings done
# 650/1238 embeddings done
# 651/1238 embeddings done
# 652/1238 embeddings done
# 653/1238 embeddings done
# 654/1238 embeddings done
# 655/1238 embeddings done
# 656/1238 embeddings done
# 657/1238 embeddings done
# 658/1238 embeddings done
# 659/1238 embeddings done
# 660/1238 embeddings done
# 661/1238 embeddings done
# 662/1238 embeddings done
# 663/1238 embeddings done
# 664/1238 embeddings done
# 665/1238 embeddings done
# 666/1238 embeddings done
# 667/1238 embeddings done
# 668/1238 embeddings done
# 669/1238 embeddings done
# 670/1238 embeddings done
# 671/1238 embeddings done
# 672/1238 embeddings done
# 673/1238 embeddings done
# 674/1238 embeddings done
# 675/1238 embeddings done
# 676/1238 embeddings done
# 677/1238 embeddings done
# 678/1238 embeddings done
# 679/1238 embeddings done
# 680/1238 embeddings done
# 681/1238 embeddings done
# 682/1238 embeddings done
# 683/1238 embeddings done
# 684/1238 embeddings done
# 685/1238 embeddings done
# 686/1238 embeddings done
# 687/1238 embeddings done
# 688/1238 embeddings done
# 689/1238 embeddings done
# 690/1238 embeddings done
# 691/1238 embeddings done
# 692/1238 embeddings done
# 693/1238 embeddings done
# 694/1238 embeddings done
# 695/1238 embeddings done
# 696/1238 embeddings done
# 697/1238 embeddings done
# 698/1238 embeddings done
# 699/1238 embeddings done
# 700/1238 embeddings done
# 701/1238 embeddings done
# 702/1238 embeddings done
# 703/1238 embeddings done
# 704/1238 embeddings done
# 705/1238 embeddings done
# 706/1238 embeddings done
# 707/1238 embeddings done
# 708/1238 embeddings done
# 709/1238 embeddings done
# 710/1238 embeddings done
# 711/1238 embeddings done
# 712/1238 embeddings done
# 713/1238 embeddings done
# 714/1238 embeddings done
# 715/1238 embeddings done
# 716/1238 embeddings done
# 717/1238 embeddings done
# 718/1238 embeddings done
# 719/1238 embeddings done
# 720/1238 embeddings done
# 721/1238 embeddings done
# 722/1238 embeddings done
# 723/1238 embeddings done
# 724/1238 embeddings done
# 725/1238 embeddings done
# 726/1238 embeddings done
# 727/1238 embeddings done
# 728/1238 embeddings done
# 729/1238 embeddings done
# 730/1238 embeddings done
# 731/1238 embeddings done
# 732/1238 embeddings done
# 733/1238 embeddings done
# 734/1238 embeddings done
# 735/1238 embeddings done
# 736/1238 embeddings done
# 737/1238 embeddings done
# 738/1238 embeddings done
# 739/1238 embeddings done
# 740/1238 embeddings done
# 741/1238 embeddings done
# 742/1238 embeddings done
# 743/1238 embeddings done
# 744/1238 embeddings done
# 745/1238 embeddings done
# 746/1238 embeddings done
# 747/1238 embeddings done
# 748/1238 embeddings done
# 749/1238 embeddings done
# 750/1238 embeddings done
# 751/1238 embeddings done
# 752/1238 embeddings done
# 753/1238 embeddings done
# 754/1238 embeddings done
# 755/1238 embeddings done
# 756/1238 embeddings done
# 757/1238 embeddings done
# 758/1238 embeddings done
# 759/1238 embeddings done
# 760/1238 embeddings done
# 761/1238 embeddings done
# 762/1238 embeddings done
# 763/1238 embeddings done
# 764/1238 embeddings done
# 765/1238 embeddings done
# 766/1238 embeddings done
# 767/1238 embeddings done
# 768/1238 embeddings done
# 769/1238 embeddings done
# 770/1238 embeddings done
# 771/1238 embeddings done
# 772/1238 embeddings done
# 773/1238 embeddings done
# 774/1238 embeddings done
# 775/1238 embeddings done
# 776/1238 embeddings done
# 777/1238 embeddings done
# 778/1238 embeddings done
# 779/1238 embeddings done
# 780/1238 embeddings done
# 781/1238 embeddings done
# 782/1238 embeddings done
# 783/1238 embeddings done
# 784/1238 embeddings done
# 785/1238 embeddings done
# 786/1238 embeddings done
# 787/1238 embeddings done
# 788/1238 embeddings done
# 789/1238 embeddings done
# 790/1238 embeddings done
# 791/1238 embeddings done
# 792/1238 embeddings done
# 793/1238 embeddings done
# 794/1238 embeddings done
# 795/1238 embeddings done
# 796/1238 embeddings done
# 797/1238 embeddings done
# 798/1238 embeddings done
# 799/1238 embeddings done
# 800/1238 embeddings done
# 801/1238 embeddings done
# 802/1238 embeddings done
# 803/1238 embeddings done
# 804/1238 embeddings done
# 805/1238 embeddings done
# 806/1238 embeddings done
# 807/1238 embeddings done
# 808/1238 embeddings done
# 809/1238 embeddings done
# 810/1238 embeddings done
# 811/1238 embeddings done
# 812/1238 embeddings done
# 813/1238 embeddings done
# 814/1238 embeddings done
# 815/1238 embeddings done
# 816/1238 embeddings done
# 817/1238 embeddings done
# 818/1238 embeddings done
# 819/1238 embeddings done
# 820/1238 embeddings done
# 821/1238 embeddings done
# 822/1238 embeddings done
# 823/1238 embeddings done
# 824/1238 embeddings done
# 825/1238 embeddings done
# 826/1238 embeddings done
# 827/1238 embeddings done
# 828/1238 embeddings done
# 829/1238 embeddings done
# 830/1238 embeddings done
# 831/1238 embeddings done
# 832/1238 embeddings done
# 833/1238 embeddings done
# 834/1238 embeddings done
# 835/1238 embeddings done
# 836/1238 embeddings done
# 837/1238 embeddings done
# 838/1238 embeddings done
# 839/1238 embeddings done
# 840/1238 embeddings done
# 841/1238 embeddings done
# 842/1238 embeddings done
# 843/1238 embeddings done
# 844/1238 embeddings done
# 845/1238 embeddings done
# 846/1238 embeddings done
# 847/1238 embeddings done
# 848/1238 embeddings done
# 849/1238 embeddings done
# 850/1238 embeddings done
# 851/1238 embeddings done
# 852/1238 embeddings done
# 853/1238 embeddings done
# 854/1238 embeddings done
# 855/1238 embeddings done
# 856/1238 embeddings done
# 857/1238 embeddings done
# 858/1238 embeddings done
# 859/1238 embeddings done
# 860/1238 embeddings done
# 861/1238 embeddings done
# 862/1238 embeddings done
# 863/1238 embeddings done
# 864/1238 embeddings done
# 865/1238 embeddings done
# 866/1238 embeddings done
# 867/1238 embeddings done
# 868/1238 embeddings done
# 869/1238 embeddings done
# 870/1238 embeddings done
# 871/1238 embeddings done
# 872/1238 embeddings done
# 873/1238 embeddings done
# 874/1238 embeddings done
# 875/1238 embeddings done
# 876/1238 embeddings done
# 877/1238 embeddings done
# 878/1238 embeddings done
# 879/1238 embeddings done
# 880/1238 embeddings done
# 881/1238 embeddings done
# 882/1238 embeddings done
# 883/1238 embeddings done
# 884/1238 embeddings done
# 885/1238 embeddings done
# 886/1238 embeddings done
# 887/1238 embeddings done
# 888/1238 embeddings done
# 889/1238 embeddings done
# 890/1238 embeddings done
# 891/1238 embeddings done
# 892/1238 embeddings done
# 893/1238 embeddings done
# 894/1238 embeddings done
# 895/1238 embeddings done
# 896/1238 embeddings done
# 897/1238 embeddings done
# 898/1238 embeddings done
# 899/1238 embeddings done
# 900/1238 embeddings done
# 901/1238 embeddings done
# 902/1238 embeddings done
# 903/1238 embeddings done
# 904/1238 embeddings done
# 905/1238 embeddings done
# 906/1238 embeddings done
# 907/1238 embeddings done
# 908/1238 embeddings done
# 909/1238 embeddings done
# 910/1238 embeddings done
# 911/1238 embeddings done
# 912/1238 embeddings done
# 913/1238 embeddings done
# 914/1238 embeddings done
# 915/1238 embeddings done
# 916/1238 embeddings done
# 917/1238 embeddings done
# 918/1238 embeddings done
# 919/1238 embeddings done
# 920/1238 embeddings done
# 921/1238 embeddings done
# 922/1238 embeddings done
# 923/1238 embeddings done
# 924/1238 embeddings done
# 925/1238 embeddings done
# 926/1238 embeddings done
# 927/1238 embeddings done
# 928/1238 embeddings done
# 929/1238 embeddings done
# 930/1238 embeddings done
# 931/1238 embeddings done
# 932/1238 embeddings done
# 933/1238 embeddings done
# 934/1238 embeddings done
# 935/1238 embeddings done
# 936/1238 embeddings done
# 937/1238 embeddings done
# 938/1238 embeddings done
# 939/1238 embeddings done
# 940/1238 embeddings done
# 941/1238 embeddings done
# 942/1238 embeddings done
# 943/1238 embeddings done
# 944/1238 embeddings done
# 945/1238 embeddings done
# 946/1238 embeddings done
# 947/1238 embeddings done
# 948/1238 embeddings done
# 949/1238 embeddings done
# 950/1238 embeddings done
# 951/1238 embeddings done
# 952/1238 embeddings done
# 953/1238 embeddings done
# 954/1238 embeddings done
# 955/1238 embeddings done
# 956/1238 embeddings done
# 957/1238 embeddings done
# 958/1238 embeddings done
# 959/1238 embeddings done
# 960/1238 embeddings done
# 961/1238 embeddings done
# 962/1238 embeddings done
# 963/1238 embeddings done
# 964/1238 embeddings done
# 965/1238 embeddings done
# 966/1238 embeddings done
# 967/1238 embeddings done
# 968/1238 embeddings done
# 969/1238 embeddings done
# 970/1238 embeddings done
# 971/1238 embeddings done
# 972/1238 embeddings done
# 973/1238 embeddings done
# 974/1238 embeddings done
# 975/1238 embeddings done
# 976/1238 embeddings done
# 977/1238 embeddings done
# 978/1238 embeddings done
# 979/1238 embeddings done
# 980/1238 embeddings done
# 981/1238 embeddings done
# 982/1238 embeddings done
# 983/1238 embeddings done
# 984/1238 embeddings done
# 985/1238 embeddings done
# 986/1238 embeddings done
# 987/1238 embeddings done
# 988/1238 embeddings done
# 989/1238 embeddings done
# 990/1238 embeddings done
# 991/1238 embeddings done
# 992/1238 embeddings done
# 993/1238 embeddings done
# 994/1238 embeddings done
# 995/1238 embeddings done
# 996/1238 embeddings done
# 997/1238 embeddings done
# 998/1238 embeddings done
# 999/1238 embeddings done
# 1000/1238 embeddings done
# 1001/1238 embeddings done
# 1002/1238 embeddings done
# 1003/1238 embeddings done
# 1004/1238 embeddings done
# 1005/1238 embeddings done
# 1006/1238 embeddings done
# 1007/1238 embeddings done
# 1008/1238 embeddings done
# 1009/1238 embeddings done
# 1010/1238 embeddings done
# 1011/1238 embeddings done
# 1012/1238 embeddings done
# 1013/1238 embeddings done
# 1014/1238 embeddings done
# 1015/1238 embeddings done
# 1016/1238 embeddings done
# 1017/1238 embeddings done
# 1018/1238 embeddings done
# 1019/1238 embeddings done
# 1020/1238 embeddings done
# 1021/1238 embeddings done
# 1022/1238 embeddings done
# 1023/1238 embeddings done
# 1024/1238 embeddings done
# 1025/1238 embeddings done
# 1026/1238 embeddings done
# 1027/1238 embeddings done
# 1028/1238 embeddings done
# 1029/1238 embeddings done
# 1030/1238 embeddings done
# 1031/1238 embeddings done
# 1032/1238 embeddings done
# 1033/1238 embeddings done
# 1034/1238 embeddings done
# 1035/1238 embeddings done
# 1036/1238 embeddings done
# 1037/1238 embeddings done
# 1038/1238 embeddings done
# 1039/1238 embeddings done
# 1040/1238 embeddings done
# 1041/1238 embeddings done
# 1042/1238 embeddings done
# 1043/1238 embeddings done
# 1044/1238 embeddings done
# 1045/1238 embeddings done
# 1046/1238 embeddings done
# 1047/1238 embeddings done
# 1048/1238 embeddings done
# 1049/1238 embeddings done
# 1050/1238 embeddings done
# 1051/1238 embeddings done
# 1052/1238 embeddings done
# 1053/1238 embeddings done
# 1054/1238 embeddings done
# 1055/1238 embeddings done
# 1056/1238 embeddings done
# 1057/1238 embeddings done
# 1058/1238 embeddings done
# 1059/1238 embeddings done
# 1060/1238 embeddings done
# 1061/1238 embeddings done
# 1062/1238 embeddings done
# 1063/1238 embeddings done
# 1064/1238 embeddings done
# 1065/1238 embeddings done
# 1066/1238 embeddings done
# 1067/1238 embeddings done
# 1068/1238 embeddings done
# 1069/1238 embeddings done
# 1070/1238 embeddings done
# 1071/1238 embeddings done
# 1072/1238 embeddings done
# 1073/1238 embeddings done
# 1074/1238 embeddings done
# 1075/1238 embeddings done
# 1076/1238 embeddings done
# 1077/1238 embeddings done
# 1078/1238 embeddings done
# 1079/1238 embeddings done
# 1080/1238 embeddings done
# 1081/1238 embeddings done
# 1082/1238 embeddings done
# 1083/1238 embeddings done
# 1084/1238 embeddings done
# 1085/1238 embeddings done
# 1086/1238 embeddings done
# 1087/1238 embeddings done
# 1088/1238 embeddings done
# 1089/1238 embeddings done
# 1090/1238 embeddings done
# 1091/1238 embeddings done
# 1092/1238 embeddings done
# 1093/1238 embeddings done
# 1094/1238 embeddings done
# 1095/1238 embeddings done
# 1096/1238 embeddings done
# 1097/1238 embeddings done
# 1098/1238 embeddings done
# 1099/1238 embeddings done
# 1100/1238 embeddings done
# 1101/1238 embeddings done
# 1102/1238 embeddings done
# 1103/1238 embeddings done
# 1104/1238 embeddings done
# 1105/1238 embeddings done
# 1106/1238 embeddings done
# 1107/1238 embeddings done
# 1108/1238 embeddings done
# 1109/1238 embeddings done
# 1110/1238 embeddings done
# 1111/1238 embeddings done
# 1112/1238 embeddings done
# 1113/1238 embeddings done
# 1114/1238 embeddings done
# 1115/1238 embeddings done
# 1116/1238 embeddings done
# 1117/1238 embeddings done
# 1118/1238 embeddings done
# 1119/1238 embeddings done
# 1120/1238 embeddings done
# 1121/1238 embeddings done
# 1122/1238 embeddings done
# 1123/1238 embeddings done
# 1124/1238 embeddings done
# 1125/1238 embeddings done
# 1126/1238 embeddings done
# 1127/1238 embeddings done
# 1128/1238 embeddings done
# 1129/1238 embeddings done
# 1130/1238 embeddings done
# 1131/1238 embeddings done
# 1132/1238 embeddings done
# 1133/1238 embeddings done
# 1134/1238 embeddings done
# 1135/1238 embeddings done
# 1136/1238 embeddings done
# 1137/1238 embeddings done
# 1138/1238 embeddings done
# 1139/1238 embeddings done
# 1140/1238 embeddings done
# 1141/1238 embeddings done
# 1142/1238 embeddings done
# 1143/1238 embeddings done
# 1144/1238 embeddings done
# 1145/1238 embeddings done
# 1146/1238 embeddings done
# 1147/1238 embeddings done
# 1148/1238 embeddings done
# 1149/1238 embeddings done
# 1150/1238 embeddings done
# 1151/1238 embeddings done
# 1152/1238 embeddings done
# 1153/1238 embeddings done
# 1154/1238 embeddings done
# 1155/1238 embeddings done
# 1156/1238 embeddings done
# 1157/1238 embeddings done
# 1158/1238 embeddings done
# 1159/1238 embeddings done
# 1160/1238 embeddings done
# 1161/1238 embeddings done
# 1162/1238 embeddings done
# 1163/1238 embeddings done
# 1164/1238 embeddings done
# 1165/1238 embeddings done
# 1166/1238 embeddings done
# 1167/1238 embeddings done
# 1168/1238 embeddings done
# 1169/1238 embeddings done
# 1170/1238 embeddings done
# 1171/1238 embeddings done
# 1172/1238 embeddings done
# 1173/1238 embeddings done
# 1174/1238 embeddings done
# 1175/1238 embeddings done
# 1176/1238 embeddings done
# 1177/1238 embeddings done
# 1178/1238 embeddings done
# 1179/1238 embeddings done
# 1180/1238 embeddings done
# 1181/1238 embeddings done
# 1182/1238 embeddings done
# 1183/1238 embeddings done
# 1184/1238 embeddings done
# 1185/1238 embeddings done
# 1186/1238 embeddings done
# 1187/1238 embeddings done
# 1188/1238 embeddings done
# 1189/1238 embeddings done
# 1190/1238 embeddings done
# 1191/1238 embeddings done
# 1192/1238 embeddings done
# 1193/1238 embeddings done
# 1194/1238 embeddings done
# 1195/1238 embeddings done
# 1196/1238 embeddings done
# 1197/1238 embeddings done
# 1198/1238 embeddings done
# 1199/1238 embeddings done
# 1200/1238 embeddings done
# 1201/1238 embeddings done
# 1202/1238 embeddings done
# 1203/1238 embeddings done
# 1204/1238 embeddings done
# 1205/1238 embeddings done
# 1206/1238 embeddings done
# 1207/1238 embeddings done
# 1208/1238 embeddings done
# 1209/1238 embeddings done
# 1210/1238 embeddings done
# 1211/1238 embeddings done
# 1212/1238 embeddings done
# 1213/1238 embeddings done
# 1214/1238 embeddings done
# 1215/1238 embeddings done
# 1216/1238 embeddings done
# 1217/1238 embeddings done
# 1218/1238 embeddings done
# 1219/1238 embeddings done
# 1220/1238 embeddings done
# 1221/1238 embeddings done
# 1222/1238 embeddings done
# 1223/1238 embeddings done
# 1224/1238 embeddings done
# 1225/1238 embeddings done
# 1226/1238 embeddings done
# 1227/1238 embeddings done
# 1228/1238 embeddings done
# 1229/1238 embeddings done
# 1230/1238 embeddings done
# 1231/1238 embeddings done
# 1232/1238 embeddings done
# 1233/1238 embeddings done
# 1234/1238 embeddings done
# 1235/1238 embeddings done
# 1236/1238 embeddings done
# 1237/1238 embeddings done
# 1238/1238 embeddings done
# Embeddings from file '../index_store/factscore/title_text_map_factscore.txt' added to FAISS index between indice 136857 to 138095.

# %%
import json
import os
from rag.llm.openai_atomicfact_generator import OpenAIAtomicFactGenerator
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

def scoreFactScoreAnswers(input_file_path, output_file_path, data_file_path="", skiplines = 0):
    wiki_embedding = WikitextsDocumentScorer()
    if data_file_path and os.path.exists(data_file_path):
        wiki_embedding.create_embedding(data_file_path)
    gen = OpenAIAtomicFactGenerator()

    names = []
    with open(input_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            names.append(line.strip())
    for i, name in enumerate(names):
        if i < skiplines:
            continue
        query = f"Question: Tell me a bio of {name}"
        subclaims_score = {}
        retrieved_docs = wiki_embedding.faiss_manager.search_faiss_index(query, top_k=10, threshold=0.3)
        response = wiki_embedding.faiss_manager.generate_response_from_context(query, retrieved_docs)
        atomicFacts = gen.get_facts_from_text(response)
        for fact in atomicFacts:
            purefact = fact.rpartition(':')[0] if ':' in fact else fact
            score = wiki_embedding.score(purefact, retrieved_docs)
            subclaims_score[purefact] = float(score)
        #sort subclaims based on score
        subclaims_score = sorted(subclaims_score.items(), key=lambda x: x[1], reverse=True)
        with open(output_file_path, 'a', encoding='utf-8') as f:
            f.write(json.dumps({'query': query, 'response': response, 'subclaims_score': subclaims_score}) + '\n')
        print(f'calibrate data {i} / {len(names)} done')

# %%
#calibrate data
file_path = "../index_store/factscore/factscore_names.txt"
scoreFactScoreAnswers(file_path, '../index_store/factscore/factscore_calibrate_score_50.jsonl', '../index_store/factscore/title_text_map_factscore.txt')
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# Loaded texts from file: ../index_store/factscore/title_text_map_factscore_texts.json
# Loaded texts from file: ../index_store/factscore/title_text_map_factscore_texts.json
# File '../index_store/factscore/title_text_map_factscore.txt' already exists in the FAISS index.
# calibrate data 0 / 50 done
# calibrate data 1 / 50 done
# calibrate data 2 / 50 done
# calibrate data 3 / 50 done
# calibrate data 4 / 50 done
# calibrate data 5 / 50 done
# calibrate data 6 / 50 done
# calibrate data 7 / 50 done
# calibrate data 8 / 50 done
# calibrate data 9 / 50 done
# calibrate data 10 / 50 done
# calibrate data 11 / 50 done
# calibrate data 12 / 50 done
# calibrate data 13 / 50 done
# calibrate data 14 / 50 done
# calibrate data 15 / 50 done
# calibrate data 16 / 50 done
# calibrate data 17 / 50 done
# calibrate data 18 / 50 done
# calibrate data 19 / 50 done
# calibrate data 20 / 50 done
# calibrate data 21 / 50 done
# calibrate data 22 / 50 done
# calibrate data 23 / 50 done
# calibrate data 24 / 50 done
# calibrate data 25 / 50 done
# calibrate data 26 / 50 done
# calibrate data 27 / 50 done
# calibrate data 28 / 50 done
# calibrate data 29 / 50 done
# calibrate data 30 / 50 done
# calibrate data 31 / 50 done
# calibrate data 32 / 50 done
# calibrate data 33 / 50 done
# calibrate data 34 / 50 done
# calibrate data 35 / 50 done
# calibrate data 36 / 50 done
# calibrate data 37 / 50 done
# calibrate data 38 / 50 done
# calibrate data 39 / 50 done
# calibrate data 40 / 50 done
# calibrate data 41 / 50 done
# calibrate data 42 / 50 done
# calibrate data 43 / 50 done
# calibrate data 44 / 50 done
# calibrate data 45 / 50 done
# calibrate data 46 / 50 done
# calibrate data 47 / 50 done
# calibrate data 48 / 50 done
# calibrate data 49 / 50 done

# %%
input_file = '../index_store/factscore/factscore_calibrate_score_50.jsonl'
# Input and output file paths
output_file = "similarity_annotations.jsonl"
transformed_data_list = []

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    idx = 0
    for line in infile:
        print(f"Processing line {idx}")
        data = json.loads(line.strip())
        transformed_data = annotate_subclaims(data, 'factscore')
        transformed_data_list.append(transformed_data)
        idx += 1
    
    # Write the JSON array to the output file
    outfile.write('{"results": ')
    outfile.write(json.dumps(transformed_data_list, ensure_ascii=False))
    outfile.write('}')
print(f"Transformed data written to {output_file}.")
# Out:
# Processing line 0
# Processing line 1
# Processing line 2
# Processing line 3
# Processing line 4
# Processing line 5
# Processing line 6
# Processing line 7
# Processing line 8
# Processing line 9
# Processing line 10
# Processing line 11
# Processing line 12
# Processing line 13
# Processing line 14
# Processing line 15
# Processing line 16
# Processing line 17
# Processing line 18
# Processing line 19
# Processing line 20
# Processing line 21
# Processing line 22
# Processing line 23
# Processing line 24
# Processing line 25
# Processing line 26
# Processing line 27
# Processing line 28
# Processing line 29
# Processing line 30
# Processing line 31
# Processing line 32
# Processing line 33
# Processing line 34
# Processing line 35
# Processing line 36
# Processing line 37
# Processing line 38
# Processing line 39
# Processing line 40
# Processing line 41
# Processing line 42
# Processing line 43
# Processing line 44
# Processing line 45
# Processing line 46
# Processing line 47
# Processing line 48
# Processing line 49
# Processing line 50
# Transformed data written to similarity_annotations.jsonl.

# %% [markdown]
# ## Conditional ##

# %%
import os

from rag.scorer.document_scorer import DocumentScorer

def conditional_conformal_pred(prompt, scorer: DocumentScorer, threshold_file, model='gpt-4'):
    (output, merged_output, all_subclaims, accepted_subclaims)= scorer.say_less_conditional(prompt, threshold_file, model)
    print("Original output: ")
    print(output)
    print("\n\n\n\n\nModified output: ")
    print(merged_output)
    print("\n\n\n\nAccepted sub-claims: ")
    print(accepted_subclaims)
    print("\n\n\n\nAll sub-claims: ")
    print(all_subclaims)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 from rag.scorer.document_scorer import DocumentScorer
#       5 def conditional_conformal_pred(prompt, scorer: DocumentScorer, threshold_file, model='gpt-4'):
#       6     (output, merged_output, all_subclaims, accepted_subclaims)= scorer.say_less_conditional(prompt, threshold_file, model)
#
# ModuleNotFoundError: No module named 'rag'

# %%
from rag.scorer.wikitexts_embedding import WikitextsDocumentScorer

file = '../data/similarity_a=0.96_alpha=0.2'
wiki_embedding = WikitextsDocumentScorer()
query = "What nationality was James Henry Miller's wife?"
conditional_conformal_pred(query, wiki_embedding, file)
# Out:
# Loaded texts from file: ../index_store/conformalhotpot500/title_text_map_hotpotqa_500_texts.json
# Loaded texts from file: ../index_store/magazine/title_text_map_texts.json
# Loaded texts from file: ../index_store/conformalpopqa500/title_text_map_popqa_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/conformalpopqa1000/title_text_map_popqa_1000_1500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/hotpot_dev500/title_text_map_hotpotqa_dev_500_texts.json
# Loaded texts from file: /Users/naihefeng/Documents/2025/study/layer6/rag_conformal_pred/index_store/medqa/medication_qa_ref_docs_texts.json
# Loaded texts from file: ../index_store/factscore/title_text_map_factscore_texts.json
# Original output:
# James Henry Miller, better known as Ewan MacColl, was married to Peggy Seeger, who is American.
#
#
#
#
#
# Modified output:
# Abstain.
#
#
#
#
# Accepted sub-claims:
# []
#
#
#
#
# All sub-claims:
# [('James Henry Miller is better known as Ewan MacColl', 0.2519583024978638), (' Ewan MacColl was married to Peggy Seeger', 0.20997323118448258), (' Peggy Seeger is American', 0.1266825996220112)]
